# %% [markdown]
# #### Context Managers

# %%
try:
    10/2
except ZeroDivisionError:
    print('zero division exception occured')
finally:
    print('finally ran!')
# Out:
# finally ran!

# %%
try:
    10/0
except ZeroDivisionError:
    print('zero division exception occured')
finally:
    print('finally ran!')
# Out:
# zero division exception occured
# finally ran!

# %%
def func():
    try:
        10/0
    except ZeroDivisionError:
        return
    finally:
        print('finally ran!')

# %%
func()
# Out:
# finally ran!

# %%
try:
    print('opening file...')
    f = open('test.txt', 'w')
    a = 1/0
except:
    print('an exception occurred')
finally:
    print('Closing file')
    f.close()
# Out:
# opening file...
# an exception occurred
# Closing file

# %%
try:
    print('opening file...')
    f = open('test.txt', 'w')
    a = 1/0
finally:
    print('Closing file')
    f.close()
# Out:
# opening file...
# Closing file
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-2a9278225009> in <module>
#       2     print('opening file...')
#       3     f = open('test.txt', 'w')
# ----> 4     a = 1/0
#       5 finally:
#       6     print('Closing file')
#
# ZeroDivisionError: division by zero

# %%
with open('test.txt', 'w') as file:
    print('inside with: file closed?', file.closed)
    
print('after with: file closed?', file.closed)
# Out:
# inside with: file closed? False
# after with: file closed? True

# %%
def test():
    with open('test.txt', 'w') as file:
        print('inside with: file closed?', file.closed)
        return file
    
file = test()
# Out:
# inside with: file closed? False

# %%
file.closed
# Out:
# True

# %%
with open('test.txt', 'w') as file:
    print('inside with: file closed?', file.closed)
    raise ValueError
# Out:
# inside with: file closed? False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-b15260d620e3> in <module>
#       1 with open('test.txt', 'w') as file:
#       2     print('inside with: file closed?', file.closed)
# ----> 3     raise ValueError
#
# ValueError:

# %%
file.closed
# Out:
# True

# %%
with open('test.txt', 'w') as f:
    f.writelines('this is a test')

# %%
with open('test.txt') as f:
    row = next(f)

# %%
f.closed
# Out:
# True

# %%
print(row)
# Out:
# this is a test

# %%
class MyContext:
    def __init__(self):
        print("init running")
        self.obj = None
        
    def __enter__(self):
        print('entering context...')
        self.obj = 'the Return object'
        return self.obj
    
    def __exit__(self, exc_type, exc_value, exc_tb):
        print('exiting context')
        if exc_type:
            print(f"*** Error occured: {exc_type}, {exc_value}")
        return False

# %%
with MyContext() as obj:
    print('inside with block')
    raise ValueError('custom message')
# Out:
# init running
# entering context...
# inside with block
# exiting context
# *** Error occured: <class 'ValueError'>, custom message
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a67c29d13a69> in <module>
#       1 with MyContext() as obj:
#       2     print('inside with block')
# ----> 3     raise ValueError('custom message')
#
# ValueError: custom message

# %%
ctx = MyContext()
print("created context...")

with ctx as obj:
    print('inside with block:', obj)
    raise ValueError('custom message')
# Out:
# init running
# created context...
# entering context...
# inside with block: the Return object
# exiting context
# *** Error occured: <class 'ValueError'>, custom message
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3e24bb94f742> in <module>
#       4 with ctx as obj:
#       5     print('inside with block:', obj)
# ----> 6     raise ValueError('custom message')
#
# ValueError: custom message

# %%
class MyContext:
    def __init__(self):
        print("init running")
        self.obj = None
        
    def __enter__(self):
        print('entering context...')
        self.obj = 'the Return object'
        return self.obj
    
    def __exit__(self, exc_type, exc_value, exc_tb):
        print('exiting context')
        if exc_type:
            print(f"*** Error occured: {exc_type}, {exc_value}")
        return True

# %%
ctx = MyContext()
print("created context...")

with ctx as obj:
    print('inside with block:', obj)
    raise ValueError('custom message')
# Out:
# init running
# created context...
# entering context...
# inside with block: the Return object
# exiting context
# *** Error occured: <class 'ValueError'>, custom message

# %%
class Resource:
    def __init__(self, name):
        self.name = name
        self.state = None

# %%
class ResourceManager:
    def __init__(self, name):
        self.name = name
        self.resource = None
        
    def __enter__(self):
        print("entering context")
        self.resource = Resource(self.name)
        self.resource.state = "Created"
        return self.resource
    
    def __exit__(self, exc_type, exc_value, exc_tb):
        print("exiting context")
        self.resource.state = "Destroyed"
        
        if exc_type:
            print("error occurred")
            
        return False

# %%
with ResourceManager('spam') as res:
    print(f"{res.name} = {res.state}")
    
print(f"{res.name} = {res.state}")
# Out:
# entering context
# spam = Created
# exiting context
# spam = Destroyed

# %%
res_mgr = ResourceManager('spammer')
print("-----------------------------")

with res_mgr as res:
    print(f"{res.name} = {res.state}")
    
print(f"{res.name} = {res.state}")
# Out:
# -----------------------------
# entering context
# spammer = Created
# exiting context
# spammer = Destroyed

# %%
'res' in globals()
# Out:
# True

# %%
res.state
# Out:
# 'Destroyed'

# %%
class File:
    def __init__(self, name, mode):
        self.name = name
        self.mode = mode
        
    def __enter__(self):
        print('opening file')
        self.file = open(self.name, self.mode)
        return self.file
    
    def __exit__(self, type_, value, tb):
        print("closing file")
        self.file.close()
        
        return False

# %%
with File('test.txt', 'w') as f:
    f.write('this is a late parrot')
# Out:
# opening file
# closing file

# %%
with File('test.txt', 'r') as f:
    print(f.readlines())
# Out:
# opening file
# ['this is a late parrot']
# closing file

# %%
def test():
    with File('test.txt', 'w') as f:
        f.write('this is a late parrot')
        return f

# %%
f = test()
# Out:
# opening file
# closing file

# %%
def test():
    with File('test.txt', 'w') as f:
        f.write('this is a late parrot')
        raise ValueError

# %%
f = test()
# Out:
# opening file
# closing file
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-c4230729f609> in <module>
# ----> 1 f = test()
#
# <ipython-input-44-294c6bd74d0a> in test()
#       2     with File('test.txt', 'w') as f:
#       3         f.write('this is a late parrot')
# ----> 4         raise ValueError
#
# ValueError:

# %%
class File:
    def __init__(self, name, mode):
        self.name = name
        self.mode = mode
        
    def __enter__(self):
        print('opening file')
        self.file = open(self.name, self.mode)
        return self
    
    def __exit__(self, type_, value, tb):
        print("closing file")
        self.file.close()
        return False

# %%
with File('test.txt', 'r') as file_ctx:
    print(next(file_ctx.file))
    print(file_ctx.name)
    print(file_ctx.mode)
# Out:
# opening file
# this is a late parrot
# test.txt
# r
# closing file

# %% [markdown]
# #### Caveat with Lazy Iterators

# %%
import csv

def read_data():
    with open ('nyc_parking_tickets_extract.csv') as f:
        return csv.reader(f, delimiter=',',quotechar='"')

# %%
reader = read_data()

# %%
type(reader)
# Out:
# _csv.reader

# %%
for row in reader:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-fe15a5ecf0b9> in <module>
# ----> 1 for row in reader:
#       2     print(row)
#
# ValueError: I/O operation on closed file.

# %%
import csv

def read_data():
    with open ('nyc_parking_tickets_extract.csv') as f:
        yield from csv.reader(f, delimiter=',',quotechar='"')

# %%
reader = read_data()

# %%
for row in reader:
    print(row)
# Out:
# ['Summons Number', 'Plate ID', 'Registration State', 'Plate Type', 'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make', 'Violation Description']
# ['4006478550', 'VAD7274', 'VA', 'PAS', '10/5/2016', '5', '4D', 'BMW', 'BUS LANE VIOLATION']
# ['4006462396', '22834JK', 'NY', 'COM', '9/30/2016', '5', 'VAN', 'CHEVR', 'BUS LANE VIOLATION']
# ['4007117810', '21791MG', 'NY', 'COM', '4/10/2017', '5', 'VAN', 'DODGE', 'BUS LANE VIOLATION']
# ['4006265037', 'FZX9232', 'NY', 'PAS', '8/23/2016', '5', 'SUBN', 'FORD', 'BUS LANE VIOLATION']
# ['4006535600', 'N203399C', 'NY', 'OMT', '10/19/2016', '5', 'SUBN', 'FORD', 'BUS LANE VIOLATION']
# ['4007156700', '92163MG', 'NY', 'COM', '4/13/2017', '5', 'VAN', 'FRUEH', 'BUS LANE VIOLATION']
# ['4006687989', 'MIQ600', 'SC', 'PAS', '11/21/2016', '5', 'VN', 'HONDA', 'BUS LANE VIOLATION']
# ['4006943052', '2AE3984', 'MD', 'PAS', '2/1/2017', '5', 'SW', 'LINCO', 'BUS LANE VIOLATION']
# ['4007306795', 'HLG4926', 'NY', 'PAS', '5/30/2017', '5', 'SUBN', 'TOYOT', 'BUS LANE VIOLATION']
# ['4007124590', 'T715907C', 'NY', 'OMT', '4/3/2017', '5', 'SUBN', 'TOYOT', 'BUS LANE VIOLATION']
# ['5096061966', 'HRC9475', 'NY', 'PAS', '4/18/2017', '7', 'SUBN', 'CADIL', 'FAILURE TO STOP AT RED LIGHT']
# ['5094070400', 'DYP8042', 'NY', 'PAS', '10/26/2016', '7', 'SUBN', 'CHEVR', 'FAILURE TO STOP AT RED LIGHT']
# ['5094906770', 'G30ESY', 'NJ', 'PAS', '1/1/2017', '7', 'WAGO', 'CHRYS', 'FAILURE TO STOP AT RED LIGHT']
# ['5093319363', 'GGT8868', 'NY', 'PAS', '9/6/2016', '7', 'SUBN', 'CHRYS', 'FAILURE TO STOP AT RED LIGHT']
# ['5092638849', '107DDD', 'NY', 'SPO', '7/20/2016', '7', 'SUBN', 'DODGE', 'FAILURE TO STOP AT RED LIGHT']
# ['5093455337', 'ENQT55', 'FL', 'PAS', '9/12/2016', '7', 'VN', 'DODGE', 'FAILURE TO STOP AT RED LIGHT']
# ['5094961366', 'GSU4156', 'OH', 'PAS', '1/7/2017', '7', '4S', 'DODGE', 'FAILURE TO STOP AT RED LIGHT']
# ['5092906534', 'V84FXV', 'NJ', 'PAS', '8/7/2016', '7', 'WAGO', 'FIR', 'FAILURE TO STOP AT RED LIGHT']
# ['5093620865', 'AD80228', 'AZ', 'PAS', '9/24/2016', '7', 'TK', 'FORD', 'FAILURE TO STOP AT RED LIGHT']
# ['5092733548', 'EVX4041', 'NY', 'PAS', '7/26/2016', '7', 'SUBN', 'FORD', 'FAILURE TO STOP AT RED LIGHT']
# ['5095995530', 'EMK5934', 'NY', 'PAS', '4/13/2017', '7', 'VAN', 'GMC', 'FAILURE TO STOP AT RED LIGHT']
# ['5092750364', 'DPH8955', 'NY', 'PAS', '7/27/2016', '7', 'SUBN', 'HONDA', 'FAILURE TO STOP AT RED LIGHT']
# ['5
# ['8488825948', 'HAU1278', 'NY', 'PAS', '3/31/2017', '14', 'SUBN', 'LEXUS', '14-No Standing']
# ['8559362496', 'HLW7798', 'NY', 'PAS', '6/13/2017', '14', '4DSD', 'LEXUS', '14-No Standing']
# ['8478353860', 'VUE95C', 'NJ', 'PAS', '12/6/2016', '14', '4DSD', 'LEXUS', '14-No Standing']
# ['8518911631', 'ZD53LE', 'NJ', 'PAS', '5/17/2017', '14', 'SUBN', 'LEXUS', '14-No Standing']
# ['1416091415', '75213MH', 'NY', 'COM', '11/28/2016', '14', 'VAN', 'ME/BE', '']
# ['8482374059', 'F96FBF', 'NJ', 'PAS', '4/23/2017', '14', '4DSD', 'ME/BE', '14-No Standing']
# ['8544960947', 'HMX8950', 'NY', 'PAS', '5/27/2017', '14', '4DSD', 'ME/BE', '14-No Standing']
# ['1418609274', '8P82H', 'NY', 'OMT', '12/21/2016', '14', 'TAXI', 'NISSA', '']
# ['1417565895', 'HEB8184', 'NY', 'PAS', '2/11/2017', '14', 'SDN', 'NISSA', '']
# ['8155550278', 'W56GSE', 'NJ', 'PAS', '10/22/2016', '14', '4DSD', 'NISSA', '14-No Standing']
# ['7433187960', '2330830', 'ME', 'PAS', '3/6/2017', '14', 'TRLR', 'NS/OT', '14-No Standing']
# ['7645052715', 'FRZ3573', 'NY', 'PAS', '1/7/2017', '14', 'SUBN', 'NS/OT', '14-No Standing']
# ['7922559173', 'XCYU94', 'NJ', 'PAS', '10/24/2016', '14', 'VAN', 'NS/OT', '14-No Standing']
# ['7767415582', 'XW915N', 'NJ', 'PAS', '3/29/2017', '14', 'DELV', 'NS/OT', '14-No Standing']
# ['8524350581', 'HGR5953', 'NY', 'PAS', '2/27/2017', '14', '4DSD', 'OLDSM', '14-No Standing']
# ['7499844705', 'GGT7948', 'NY', 'PAS', '8/22/2016', '14', 'SUBN', 'SUBAR', '14-No Standing']
# ['7150327266', 'HWE6388', 'PA', 'PAS', '8/5/2016', '14', 'SUBN', 'SUBAR', '14-No Standing']
# ['8537603818', 'ASG8770', 'NY', 'PAS', '3/26/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8210533952', 'GST8679', 'NY', 'PAS', '11/21/2016', '14', '2DSD', 'TOYOT', '14-No Standing']
# ['8555462198', 'HKT4222', 'NY', 'PAS', '6/12/2017', '14', 'SUBN', 'TOYOT', '14-No Standing']
# ['1404838156', 'R57AAE', 'NJ', 'PAS', '4/29/2017', '14', 'SUBN', 'TOYOT', '']
# ['8527806162', 'T659832C', 'NY', 'OMT', '6/4/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8513520615', '77026MG', 'NY', 'COM', '5/31/2017', '14', 'TRAC', 'VOLVO', '14-No Standing']
# ['8251031485', 'HJP5565', 'NY', 'PAS', '10/4/2016', '16', '4DSD', 'CHEVR', '16A-No Std (Com Veh) Non-COM']
# ['7813745231', 'GEL1890', 'NY', 'PAS', '9/19/2016', '16', 'SUBN', 'CHRYS', '16A-No Std (Com Veh) Non-COM']
# ['8444534183', '36598MH', 'NY', 'COM', '11/23/2016', '16', 'VAN', 'DODGE', '16-No Std (Com Veh) Com Plate']
# ['8061037749', 'HFG7121', 'NY', 'PAS', '8/22/2016', '16', 'SUBN', 'DODGE', '16A-No Std (Com Veh) Non-COM']
# ['8250539527', '24745ME', 'NY', 'COM', '11/9/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8308520170', '49033ME', 'NY', 'COM', '7/14/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8504915323', '57011ME', 'NY', 'COM', '4/6/2017', '16', 'SUBN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8339536023', 'XCEG93', 'NJ', 'PAS', '9/15/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8566405183', 'GJD5585', 'NY', 'PAS', '6/1/2017', '16', '4DSD', 'ME/BE', '16A-No Std (Com Veh) Non-COM']
# ['7051225662', 'N61GZN', 'NJ', 'PAS', '11/25/2016', '16', 'SUBN', 'SATUR', '16A-No Std (Com Veh) Non-COM']
# ['8149510126', 'GTP8988', 'NY', 'PAS', '8/10/2016', '16', '2DSD', 'SMART', '16A-No Std (Com Veh) Non-COM']
# ['7052028463', 'HGM9782', 'NY', 'PAS', '1/30/2017', '16', 'SUBN', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8474913706', 'T674455C', 'NY', 'OMT', '2/8/2017', '16', '4DSD', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8506607206', '18752MH', 'NY', 'COM', '3/16/2017', '17', 'VAN', 'CHEVR', '17-No Stand (exc auth veh)']
# ['8438519763', '89882JV', 'NY', 'COM', '10/13/2016', '17', 'VAN', 'GMC', '17-No Stand (exc auth veh)']
# ['8551111954', 'GCE9214', 'NY', 'PAS', '6/25/2017', '17', '4DSD', 'HONDA', '17-No Stand (exc auth veh)']
# ['8516654059', 'AP169V', 'NJ', 'PAS', '2/22/2017', '18', 'DELV', 'INTER', '18-No Stand (bus lane)']
# ['1368119141', 'BMLV150', 'ON', 'PAS', '7/16/2016', '19', 'SUBN', 'CHEVR', '']
# ['8528274184', 'EKF9820', 'NY', 'PAS', '5/1/2017', '19', 'SUBN', 'CHEVR', '19-No Stand (bus stop)']
# ['8522350073', '83290MD', 'NY', 'COM', '2/24/2017', '19', 'SUBN', 'DODGE', '19-No Stand (bus stop)']
# ['8070097437', 'T62GJP', 'NJ', 'PAS', '9/18/2016', '19', 'PICK', 'DODGE', '19-No Stand (bus stop)']
# ['8509409523', '35050JU', 'NY', 'COM', '2/24/2017', '19', 'PICK', 'FORD', '19-No Stand (bus stop)']
# ['1413553552', '41126BB', 'NY', 'OMT', '7/28/2016', '19', 'VAN', 'FORD', '']
# ['8514220482', '2588073', 'IN', 'PAS', '5/29/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['8485652319', '0480PRA', 'MN', 'PAS', '1/26/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['7014671406', 'B0951V', 'FL', 'PAS', '9/7/2016', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['1422732710', 'GMK4592', 'NY', 'PAS', '6/19/2017', '19', 'SDN', 'HONDA', '']
# ['7249114220', 'GPP7413', 'NY', 'PAS', '10/8/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['7499990163', 'HKT3209', 'NY', 'PAS', '12/13/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['8491667738', 'JPC4516', 'PA', 'PAS', '3/1/2017', '19', '4DSD', 'INFIN', '19-No Stand (bus stop)']
# ['8302046280', '63444JM', 'NY', 'COM', '1/26/2017', '19', 'VAN', 'INTER', '19-No Stand (bus stop)']
# ['8009901763', '13657MD', 'NY', 'COM', '9/27/2016', '19', 'DELV', 'KENWO', '19-No Stand (bus stop)']
# ['1424024420', 'HPD1970', 'NY', 'PAS', '6/10/2017', '19', 'SDN', 'KIA', '']
# ['8511718990', '50104MH', 'NY', 'COM', '6/9/2017', '19', 'VAN', 'ME/BE', '19-No Stand (bus stop)']
# ['1415429522', '17236MH', 'NY', 'COM', '3/3/2017', '19', 'SUBN', 'MITSU', '']
# ['8476355312', '47829MD', 'NY', 'COM', '2/14/2017', '19', 'DELV', 'PETER', '19-No Stand (bus stop)']
# ['1406918726', '5M39B', 'NY', 'OMT', '7/13/2016', '19', 'TAXI', 'TOYOT', '']
# ['7241990262', 'DVA1919', 'NY', 'PAS', '11/16/2016', '19', 'SUBN', 'TOYOT', '19-No Stand (bus stop)']
# ['8330511935', 'HBY7509', 'NY', 'PAS', '7/30/2016', '19', '4DSD', 'TOYOT', '19-No Stand (bus stop)']
# ['1423536058', 'HCS2336', 'NY', 'PAS', '1/27/2017', '19', 'SUBN', 'TOYOT', '']
# ['8519016595', 'QU655', 'RI', 'PAS', '6/12/2017', '19', '4DSD', 'TOYOT', '19-No Stand (bus stop)']
# ['8530522310', 'T640396C', 'NY', 'OMT', '5/27/2017', '19', '4DSD', 'TOYOT', '19-No Stand (bus stop)']
# ['1413358512', '54295PC', 'NY', 'APP', '8/9/2016', '19', 'BUS', '', '']
# ['8269048434', 'CDPE57', 'FL', 'PAS', '8/21/2016', '20', '4DSD', 'ACURA', '20A-No Parking (Non-COM)']
# ['7036998684', 'VML8110', 'VA', 'PAS', '2/21/2017', '20', '4DSD', 'BMW', '20A-No Parking (Non-COM)']
# ['8515215408', 'HFB1731', 'NY', 'PAS', '4/14/2017', '20', 'SUBN', 'CADIL', '20A-No Parking (Non-COM)']
# ['8470607042', 'MYSUMMER', 'NY', 'OMT', '7/27/2016', '20', 'SUBN', 'CADIL', '20A-No Parking (Non-COM)']
# ['1371960501', 'FEP2455', 'NY', 'PAS', '7/18/2016', '20', 'SUBN', 'CHEVR', '']
# ['8550963045', 'GSU8031', 'NY', 'PAS', '6/20/2017', '20', '4DSD', 'CHEVR', '20A-No Parking (Non-COM)']
# ['8358531096', 'FGN4109', 'NY', 'PAS', '11/14/2016', '20', 'SUBN', 'CHRYS', '20A-No Parking (Non-COM)']
# ['7623299300', '530LAW', 'FL', 'PAS', '7/23/2016', '20', 'SUBN', 'CITRO', '20A-No Parking (Non-COM)']
# ['1416638830', 'GLP367', 'NY', 'PAS', '4/30/2017', '20', 'SUBN', 'DODGE', '']
# ['7441946736', 'GMT8049', 'NY', 'PAS', '2/27/2017', '20', '4DSD', 'DODGE', '20A-No Parking (Non-COM)']
# ['8522913341', 'KHB4412', 'PA', 'PAS', '4/17/2017', '20', '4DSD', 'DODGE', '20A-No Parking (Non-COM)']
# ['8421057479', '64921JT', 'NY', 'COM', '1/27/2017', '20', 'VAN', 'FORD', '20-No Parking (Com Plate)']
 'TOYOT', '20A-No Parking (Non-COM)']
# ['8558202229', 'FRY1035', 'NY', 'PAS', '4/29/2017', '20', '4DSD', 'TOYOT', '20A-No Parking (Non-COM)']
# ['8564165960', 'FXK5768', 'NY', 'PAS', '6/24/2017', '20', '4DSD', 'TOYOT', '20A-No Parking (Non-COM)']
# ['8147540644', 'GXB8128', 'NY', 'PAS', '9/1/2016', '20', '4DSD', 'TOYOT', '20A-No Parking (Non-COM)']
# ['7606849481', 'T638216C', 'NY', 'OMT', '5/8/2017', '20', '4DSD', 'TOYOT', '20A-No Parking (Non-COM)']
# ['8293037179', 'GJU4869', 'NY', 'PAS', '8/26/2016', '21', '4DSD', 'ACURA', '21-No Parking (street clean)']
# ['8009559234', 'HBU6907', 'NY', 'PAS', '8/10/2016', '21', '4DSD', 'ACURA', '21-No Parking (street clean)']
# ['8545156546', 'EVM6598', 'NY', 'PAS', '5/3/2017', '21', '4DSD', 'AUDI', '21-No Parking (street clean)']
# ['8516050920', 'GXY1094', 'NY', 'PAS', '3/3/2017', '21', 'SUBN', 'AUDI', '21-No Parking (street clean)']
# ['8544889610', 'VVP9002', 'VA', 'PAS', '6/14/2017', '21', '4DSD', 'AUDI', '21-No Parking (street clean)']
# ['8318510150', '99H1010', 'TN', 'PAS', '8/2/2016', '21', '2DSD', 'BMW', '21-No Parking (street clean)']
# ['8491819083', 'FHY6755', 'NY', 'PAS', '3/3/2017', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['7725863710', 'GNF2877', 'NY', 'PAS', '9/26/2016', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['1412956201', 'GNR5598', 'NY', 'PAS', '7/20/2016', '21', 'SDN', 'BMW', '']
# ['7919376452', 'HAS5112', 'NY', 'PAS', '1/27/2017', '21', 'SUBN', 'BMW', '21-No Parking (street clean)']
# ['7970393330', 'HAT6686', 'NY', 'PAS', '8/17/2016', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['8537965042', 'HFP5029', 'NY', 'PAS', '5/16/2017', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['8581153938', 'X89HVW', 'NJ', 'PAS', '6/14/2017', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['8236569895', 'EPY9505', 'NY', 'PAS', '3/22/2017', '21', '4DSD', 'BUICK', '21-No Parking (street clean)']
# ['8502707383', 'JGL6885', 'PA', 'PAS', '1/24/2017', '21', 'SUBN', 'BUICK', '21-No Parking (street clean)']
# ['8511711946', '42283JZ', 'NY', 'COM', '4/27/2017', '21', 'VAN', 'CHEVR', '21-No Parking (street clean)']
# ['1418142980', '483TFM', 'TN', 'PAS', '12/19/2016', '21', 'VAN', 'CHEVR', '']
# ['1420029915', '53468JZ', '99', 'COM', '4/27/2017', '21', 'VAN', 'CHEVR', '']
# ['8539666996', '85121ME', 'NY', 'COM', '5/22/2017', '21', 'VAN', 'CHEVR', '21-No Parking (street clean)']
# ['1413709760', 'DGN6881', 'NY', 'PAS', '9/2/2016', '21', 'SDN', 'CHEVR', '']
# ['8473311693', 'DTG6286', 'NY', 'PAS', '11/23/2016', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['7658191050', 'GEL4496', 'NY', 'PAS', '7/22/2016', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['8478626049', 'GRU5176', 'NY', 'PAS', '5/15/2017', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['7369979570', 'GTC5499', 'NY', 'PAS', '7/20/2016', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['1400876217', 'GVB9839', 'NY', 'PAS', '9/19/2016', '21', 'P-U', 'CHEVR', '']
# ['1422284335', 'HHJ5747', 'NY', 'PAS', '6/3/2017', '21', 'SUBN', 'CHEVR', '']
# ['8556051480', 'M322307', 'NJ', 'PAS', '4/26/2017', '21', 'PICK', 'CHEVR', '21-No Parking (street clean)']
# ['8514570973', 'T738567C', 'NY', 'OMT', '6/21/2017', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['8357020770', 'Y56DLT', 'NJ', 'PAS', '1/20/2017', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['8523602306', 'GUG9349', 'NY', 'PAS', '3/25/2017', '21', '4DSD', 'CHRYS', '21-No Parking (street clean)']
# ['1410697290', 'HZ214', 'RI', 'PAS', '7/15/2016', '21', 'SUBN', 'CHRYS', '']
# ['8485267631', '80381MD', 'NY', 'COM', '3/2/2017', '21', 'VAN', 'DODGE', '21-No Parking (street clean)']
# ['7808365737', 'ETN7313', 'NY', 'PAS', '3/22/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8236558708', 'FLC9623', 'NY', 'PAS', '1/23/2017', '21', 'SUBN', 'DODGE', '21-No Parking (street clean)']
# ['8567100082', 'FTY1182', 'NY', 'PAS', '5/3/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8516402034', '88040MH', 'NY', 'COM', '5/26/2017', '21', 'DELV', 'FORD', '21-No Parking (street clean)']
# ['8237524573', 'CMD1897', 'NY', 'PAS', '10/19/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8490203982', 'DBZ7195', 'NY', 'PAS', '12/13/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8140540663', 'EHA1740', 'NY', 'PAS', '10/27/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8539702370', 'FYW7060', 'NY', 'PAS', '3/23/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8151587635', 'GFC5314', 'NY', 'PAS', '11/22/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8536979239', 'GKP5732', 'NY', 'PAS', '4/28/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8277588720', 'GYT3978', 'NY', 'PAS', '11/10/2016', '21', '2DSD', 'FORD', '21-No Parking (street clean)']
# ['8330514596', 'HDK4072', 'NY', 'PAS', '8/23/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8043823078', 'HHF5026', 'NY', 'PAS', '9/6/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8173039823', 'JLN1340', 'PA', 'PAS', '11/16/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8521903650', 'XAGW46', 'NJ', 'PAS', '3/27/2017', '21', 'VAN', 'FORD', '21-No Parking (street clean)']
# ['1420031892', '43601MG', 'NY', 'COM', '5/1/2017', '21', 'VAN', 'FRUEH', '']
# ['8431017041', '76130JH', 'NY', 'COM', '9/16/2016', '21', 'DELV', 'FRUEH', '21-No Parking (street clean)']
# ['8104561698', 'GAV2010', 'NY', 'PAS', '3/7/2017', '21', '4DSD', 'GEO', '21-No Parking (street clean)']
# ['1421330088', '12040MJ', 'NY', 'COM', '6/20/2017', '21', 'SUBN', 'GMC', '']
# ['8463512264', '20410AD', 'NY', 'COM', '10/28/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['8059052214', '36733JX', 'NY', 'COM', '11/14/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['1417865507', '77993JV', 'NY', 'COM', '2/6/2017', '21', 'VAN', 'GMC', '']
# ['7005104110', 'GYG7508', 'NY', 'PAS', '9/1/2016', '21', 'SUBN', 'GMC', '21-No Parking (street clean)']
# ['8077581614', 'XAYF77', 'NJ', 'PAS', '2/27/2017', '21', 'DELV', 'GMC', '21-No Parking (street clean)']
# ['8536832563', '1441', 'WY', 'PAS', '6/6/2017', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['
'21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8556351920', 'FCN6061', 'NY', 'PAS', '4/28/2017', '21', 'SUBN', 'MAZDA', '21-No Parking (street clean)']
# ['8563702300', 'GUY5928', 'NY', 'PAS', '5/18/2017', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8475466254', 'HWN1816', 'TX', 'PAS', '12/27/2016', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8349510500', '84302T', 'VA', 'PAS', '7/8/2016', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8327051209', 'ATE9889', 'NY', 'PAS', '12/20/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['7803990927', 'HCN1049', 'NY', 'PAS', '3/28/2017', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8514726985', 'HKB2413', 'NY', 'PAS', '5/22/2017', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['8360507120', 'OL4468J', 'NJ', 'PAS', '7/26/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['1419707358', 'V97GVE', 'NJ', 'PAS', '2/18/2017', '21', 'SUBN', 'ME/BE', '']
# ['8557255329', 'HFE4369', 'NY', 'PAS', '5/11/2017', '21', 'SUBN', 'MERCU', '21-No Parking (street clean)']
# ['8512671312', '8892CZ', 'CT', 'CMB', '6/6/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['7081940572', 'ATS3775', 'NY', 'PAS', '1/4/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8472183579', 'BNZF31', 'FL', 'PAS', '12/3/2016', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8190539723', 'DKT8358', 'NY', 'PAS', '9/8/2016', '21', '2DSD', 'NISSA', '21-No Parking (street clean)']
# ['1416492320', 'FGR5997', 'NY', 'PAS', '9/30/2016', '21', 'SDN', 'NISSA', '']
# ['8549705664', 'FYW4686', 'NY', 'PAS', '6/3/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['1420512468', 'GJH8815', 'NY', 'PAS', '4/8/2017', '21', 'SUBN', 'NISSA', '']
# ['8551204051', 'GNN9248', 'NY', 'PAS', '5/4/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8344027755', 'GUP8589', 'NY', 'PAS', '12/7/2016', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8539277086', 'GVH4035', 'PA', 'PAS', '5/26/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['1417861800', 'GYM6658', 'NY', 'PAS', '3/7/2017', '21', 'SDN', 'NISSA', '']
# ['7081508339', 'HCF7990', 'NY', 'PAS', '1/30/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8533396259', 'HCL5539', 'NY', 'PAS', '5/26/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8552758799', 'HDB8092', 'NY', 'PAS', '5/18/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8172060956', 'HJY5787', 'NY', 'PAS', '3/24/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8534828313', 'HSC8642', 'NY', 'PAS', '6/16/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['7803991737', 'FSJ1102', 'NY', 'PAS', '3/29/2017', '21', 'SUBN', 'PORSC', '21-No Parking (street clean)']
# ['8532875324', 'HKM6966', 'NY', 'OMS', '6/13/2017', '21', '2DSD', 'SMART', '21-No Parking (street clean)']
# ['7803916818', '2405692', 'PA', 'PAS', '9/30/2016', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8534565030', 'EEH3996', 'NY', 'PAS', '6/22/2017', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8345516518', 'EUX8678', 'NY', 'PAS', '9/27/2016', '21', '4DSD', 'SUBAR', '21-No Parking (street clean)']
# ['8198510771', 'FWP9546', 'NY', 'PAS', '8/30/2016', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8561603562', 'GUM5490', 'NY', 'PAS', '6/8/2017', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8260034475', 'HNR3840', 'NY', '999', '1/23/2017', '21', '4DSD', 'SUBAR', '21-No Parking (street clean)']
# ['8489005175', '450SEY', 'CT', 'PAS', '12/29/2016', '21', 'SUBN', 'TOYOT', '21-No Parking (street clean)']
# ['
# ['8566704320', 'L62FLC', 'NJ', 'PAS', '5/17/2017', '24', 'SUBN', 'CHEVR', '24-No Parking (exc auth veh)']
# ['8536961156', 'X92FSM', 'NJ', 'PAS', '3/28/2017', '24', 'SUBN', 'HYUND', '24-No Parking (exc auth veh)']
# ['1408122029', 'DSN6323', 'NY', 'PAS', '7/4/2016', '24', 'SUBN', 'JEEP', '']
# ['8266568753', 'F12GRE', 'NJ', 'PAS', '11/11/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8446524806', 'GYG8911', 'NY', 'PAS', '12/18/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8316519355', 'HDJ7785', 'PA', 'PAS', '7/14/2016', '24', '2DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8533035640', 'T687600C', 'NY', 'OMT', '5/31/2017', '24', '4DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8526732663', 'ASV2478', 'NY', 'PAS', '6/22/2017', '24', '4DSD', 'TOYOT', '24-No Parking (exc auth veh)']
# ['1410027223', 'ENS9253', 'NY', 'PAS', '10/31/2016', '24', 'SDN', 'VOLKS', '']
# ['8479824712', '58910MG', 'NY', 'COM', '4/21/2017', '26', 'DELV', 'ISUZU', '26-No Stnd (for-hire veh only)']
# ['1416527722', 'AHG9422', 'NY', 'PAS', '1/5/2017', '27', 'SUBN', 'TOYOT', '']
# ['8512270482', 'Y26CRJ', 'NJ', 'PAS', '6/3/2017', '31', 'SUBN', 'BSA', '31-No Stand (Com. Mtr. Zone)']
# ['8498706890', 'THANEDAR', 'NY', 'OMT', '3/22/2017', '31', 'SUBN', 'CADIL', '31-No Stand (Com. Mtr. Zone)']
# ['8328546632', 'HHP7446', 'NY', 'PAS', '12/2/2016', '31', '2DSD', 'CHEVR', '31-No Stand (Com. Mtr. Zone)']
# ['8496254203', 'GMW3411', 'NY', 'PAS', '5/26/2017', '31', 'PICK', 'DODGE', '31-No Stand (Com. Mtr. Zone)']
# ['8552002887', 'GTP5204', 'NY', 'PAS', '4/24/2017', '31', 'PICK', 'DODGE', '31-No Stand (Com. Mtr. Zone)']
# ['8480300255', 'GHG9797', 'NY', 'PAS', '11/18/2016', '31', '4DSD', 'HYUND', '31-No Stand (Com. Mtr. Zone)']
# ['8442517080', 'KCD4692', 'PA', 'PAS', '10/6/2016', '31', '4DSD', 'INFIN', '31-No Stand (Com. Mtr. Zone)']
# ['8482450256', 'GGN8817', 'NY', 'PAS', '11/18/2016', '31', '4DSD', 'LEXUS', '31-No Stand (Com. Mtr. Zone)']
# ['8480624486', '987536N', 'NJ', 'PAS', '6/19/2017', '31', 'SUBN', 'ME/BE', '31-No Stand (Com. Mtr. Zone)']
# ['7059132030', 'HLC5085', 'NY', 'PAS', '2/6/2017', '31', '4DSD', 'NISSA', '31-No Stand (Com. Mtr. Zone)']
# ['8482371824', 'Z317820', 'IL', 'PAS', '4/14/2017', '31', 'SUBN', 'NISSA', '31-No Stand (Com. Mtr. Zone)']
# ['1413231070', '28606MH', 'NY', 'COM', '8/19/2016', '48', 'VAN', 'FORD', '']
# ['8523502270', '41990JX', 'NY', 'COM', '3/3/2017', '48', 'VAN', 'FORD', '48-Bike Lane']
# ['8485655590', 'OYA8199', 'NJ', 'PAS', '2/16/2017', '48', 'BUS', 'FORD', '48-Bike Lane']
# ['1420960260', '66604MB', 'NY', 'COM', '5/11/2017', '48', 'VAN', 'GMCQ', '']
# ['8377006390', 'GCR2084', 'NY', 'PAS', '7/19/2016', '48', '4DSD', 'HONDA', '48-Bike Lane']
# ['7577859382', 'GRH9256', 'NY', 'PAS', '12/2/2016', '48', '4DSD', 'HONDA', '48-Bike Lane']
# ['8122530205', '95139JC', 'NY', 'COM', '1/5/2017', '48', 'DELV', 'INTER', '48-Bike Lane']
# ['8254538943', '390HRH', 'OR', 'PAS', '9/2/2016', '50', 'SUBN', 'FORD', '50-Crosswalk']
# ['8518670070', '96170MA', 'NY', 'COM', '6/5/2017', '50', 'VAN', 'FRUEH', '50-Crosswalk']
# ['1410899070', 'GWG5875', 'NY', 'PAS', '11/1/2016', '50', 'SDN', 'HONDA', '']
# ['1413790264', 'JFE0579', 'PA', 'PAS', '9/10/2016', '50', 'SDN', 'HONDA', '']
# ['1414785495', 'FJL6037', 'NY', 'PAS', '8/17/2016', '50', 'SDN', 'HYUND', '']
# ['7809507916', '34719MG', 'NY', 'COM', '12/8/2016', '50', 'DELV', 'INTER', '50-Crosswalk']
# ['7499593060', 'XBYW36', 'NJ', 'PAS', '7/22/2016', '50', 'DELV', 'ISUZU', '50-Crosswalk']
# ['8466021980', 'GSC6098', 'NY', 'PAS', '12/27/2016', '50', '4DSD', 'NISSA', '50-Crosswalk']
# ['8543401689', 'HCP8932', 'NY', 'PAS', '4/18/2017', '50', '4DSD', 'NISSA', '50-Crosswalk']
# ['8162015656', 'GSS803', 'VT', 'PAS', '9/1/2016', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8526919210', 'GZD7447', 'NY', 'PAS', '4/12/2017', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8506053195', '25868MB', 'NY', 'COM', '1/25/2017', '51', 'VAN', 'FORD', '51-Sidewalk']
# ['8520767310', 'GHN6806', 'NY', 'PAS', '5/26/2017', '51', 'SUBN', 'SAAB', '51-Sidewalk']
# ['7079854404', 'T656205C', 'NY', 'OMT', '1/28/2017', '51', '4DSD', 'TOYOT', '51-Sidewalk']
# ['1421055820', 'GAR2279', 'NY', 'PAS', '6/10/2017', '52', 'SDN', 'FORD', '']
# ['7085899554', 'GUZ4334', 'NY', 'PAS', '10/13/2016', '53', 'SUBN', 'ACURA', '53-Safety Zone']
# ['8478553514', 'XCMA58', 'NJ', 'PAS', '12/15/2016', '53', 'DELV', 'HINO', '53-Safety Zone']
# ['8546101425', 'DF932Z', 'NY', 'PAS', '4/10/2017', '53', 'SUBN', 'LEXUS', '53-Safety Zone']
# ['7007488663', 'VFP7291', 'VA', 'PAS', '3/2/2017', '53', '4DSD', 'ME/BE', '53-Safety Zone']
# ['1402409825', '869ZR9', 'MA', '999', '10/15/2016', '53', 'SUBN', 'SATUR', '']
# ['8506603031', '2383103', 'IN', 'PAS', '2/1/2017', '53', 'TRAC', 'VOLVO', '53-Safety Zone']
# ['8480309064', '51771JW', 'NY', 'COM', '1/26/2017', '64', 'VAN', 'INTER', '64-No STD Ex Con/DPL D/S Dec']
# ['8162054819', 'EW866X', 'NJ', 'PAS', '1/29/2017', '68', '4DSD', 'NISSA', '68-Not Pkg. Comp. w Psted Sign']
# ['8343032536', '4CMH482', 'CA', 'PAS', '10/3/2016', '68', 'SUBN', 'SUBAR', '68-Not Pkg. Comp. w Psted Sign']
# ['8084034959', 'ASW2109', 'NY', 'PAS', '12/20/2016', '68', '4DSD', 'TOYOT', '68-Not Pkg. Comp. w Psted Sign']
# ['8066506089', '12047JY', 'NY', 'COM', '7/1/2016', '69', 'VAN', 'CHEVR', '69-Failure to Disp Muni Recpt']
# ['8483275156', '57309ME', 'NY', 'COM', '6/7/2017', '69', 'PICK', 'DODGE', '69-Failure to Disp Muni Recpt']
# ['8481256500', '21530JX', 'NY', 'COM', '1/30/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8513914599', '65572JU', 'NY', 'COM', '6/9/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8479417420', 'AT459E', 'NJ', 'PAS', '4/13/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8479216670', 'D705HT', 'TN', 'PAS', '4/11/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8471301842', 'XZ223J', 'NJ', 'PAS', '8/30/2016', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['7268771216', '63383JT', 'NY', 'COM', '7/27/2016', '69', 'VAN', 'GMC', '69-Failure to Disp Muni Recpt']
# ['8476768746', '91599ME', 'NY', 'COM', '4/13/2017', '69', 'REFG', 'HIN', '69-Failure to Disp Muni Recpt']
# ['7868300310', '37033JV', 'NY', 'COM', '11/21/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8077552250', 'AS299T', 'NJ', 'PAS', '10/14/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8116524124', 'XDYD73', 'NJ', 'PAS', '10/6/2016', '69', 'DELV', 'ISUZU', '69-Failure to Disp Muni Recpt']
# ['7393476988', 'GGR9506', 'NY', 'PAS', '7/20/2016', '70', '4DSD', 'AUDI', '70A-Reg. Sticker Expired (NYS)']
# ['8527214490', 'GWG7018', 'NY', 'PAS', '5/16/2017', '70', 'SUBN', 'BMW', '70A-Reg. Sticker Expired (NYS)']
# ['7077031019', 'GNV8363', 'NY', 'PAS', '9/7/2016', '70', 'SUBN', 'CADIL', '70A-Reg. Sticker Expired (NYS)']
# ['8522772708', 'GWH8469', 'NY', 'PAS', '4/20/2017', '70', 'SUBN', 'CHRYS', '70A-Reg. Sticker Expired (NYS)']
# ['8535702763', 'GTE6420', 'NY', 'PAS', '3/24/2017', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['7705894520', 'GYP6735', 'NY', 'OMS', '10/2/2016', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['8535150079', 'HMC7627', 'NY', 'PAS', '3/8/2017', '70', '4DSD', 'HYUND', '70A-Reg. Sticker Expired (NYS)']
# ['7541990206', 'HGL9860', 'NY', 'PAS', '2/18/2017', '70', 'SUBN', 'JEEP', '70A-Reg. Sticker Expired (NYS)']
# ['7074250855', 'GBV6820', 'NY', 'PAS', '11/5/2016', '70', 'SUBN', 'ME/BE', '70A-Reg. Sticker Expired (NYS)']
# ['8419012245', 'GVM6317', 'NY', 'PAS', '1/27/2017', '70', '4DSD', 'ME/BE', '70A-Reg. Sticker Expired (NYS)']
# ['8552067018', 'ACS8210', 'NY', 'PAS', '6/23/2017', '70', 'SUBN', 'NISSA', '70A-Reg. Sticker Expired (NYS)']
# ['8490111753', 'GVH9098', 'NY', 'PAS', '1/25/2017', '70', '4DSD', 'NISSA', '70A-Reg. Sticker Expired (NYS)']
# ['1423568710', 'GPG1213', 'NY', 'PAS', '3/19/2017', '70', 'SDN', 'SUBAR', '']
# ['8363531900', 'GTC2970', 'NY', 'PAS', '2/8/2017', '70', '4DSD', 'TOYOT', '70A-Reg. Sticker Expired (NYS)']
# ['8282021635', 'FBD7363', 'NY', 'PAS', '9/10/2016', '71', '4DSD', 'ACURA', '71A-Insp Sticker Expired (NYS)']
# ['8551100002', 'HLA6845', 'NY', 'PAS', '4/5/2017', '71', '4DSD', 'BMW', '71-Insp. Sticker Missing (NYS']
# ['8471891440', '42530MG', 'NY', 'COM', '2/28/2017', '71', 'DELV', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8555150875', 'ETF9022', 'NY', 'PAS', '5/2/2017', '71', 'SUBN', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8188582906', 'GMT8516', 'NY', 'PAS', '11/1/2016', '71', 'PICK', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8206527321', 'HCD4100', 'NY', 'PAS', '11/1/2016', '71', 'SUBN', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8519013259', 'HNY7165', 'NY', 'PAS', '5/16/2017', '71', 'SUBN', 'CHEVR', '71-Insp. Sticker Missing (NYS']
# ['8145014311', 'HJV3061', 'NY', 'PAS', '12/13/2016', '71', 'SUBN', 'CHRYS', '71A-Insp Sticker Expired (NYS)']
# ['8548503257', 'GWB7005', 'NY', 'PAS', '5/1/2017', '71', '4DSD', 'DODGE', '71A-Insp Sticker Expired (NYS)']
# ['8235044468', 'FXX6545', 'NY', 'PAS', '10/19/2016', '71', 'SUBN', 'FORD', '71A-Insp Sticker Expired (NYS)']
# ['7491184224', 'GAM6902', 'NY', 'PAS', '4/7/2017', '71', 'SUBN', 'FORD', '71A-Insp Sticker Expired (NYS)']
# ['8559052999', 'GMR3386', 'NY', 'PAS', '5/13/2017', '71', 'SUBN', 'FORD', '71A-Insp Sticker Expired (NYS)']
# ['8514728416', 'GYP8889', 'NY', 'PAS', '5/28/2017', '71', 'SUBN', 'FORD', '71A-Insp Sticker Expired (NYS)']
# ['7162362357', 'GCE5560', 'NY', 'PAS', '8/5/2016', '71', '2DSD', 'HONDA', '71A-Insp Sticker Expired (NYS)']
# ['8486910511', 'GXC5916', 'NY', 'PAS', '2/13/2017', '71', '4DSD', 'HONDA', '71A-Insp Sticker Expired (NYS)']
# ['7959802142', 'HAE6612', 'NY', 'PAS', '11/22/2016', '71', '4DSD', 'HONDA', '71A-Insp Sticker Expired (NYS)']
# ['8474512311', 'HLA6246', 'NY', 'PAS', '12/15/2016', '71', '4DSD', 'HONDA', '71-Insp. Sticker Missing (NYS']
# ['1405823926', 'GDV1998', 'NY', 'PAS', '5/1/2017', '71', 'SUBN', 'HYUND', '']
# ['8467031128', 'R9D509', 'NY', 'PAS', '12/24/2016', '71', 'SUBN', 'HYUND', '71A-Insp Sticker Expired (NYS)']
# ['8378044166', 'HJV2326', 'NY', 'PAS', '10/18/2016', '71', '4DSD', 'INFIN', '71A-Insp Sticker Expired (NYS)']
# ['8535421774', 'EGZ5296', 'NY', 'PAS', '5/21/2017', '71', 'SUBN', 'JEEP', '71A-Insp Sticker Expired (NYS)']
# ['8263642668', 'HEA6308', 'NY', 'PAS', '2/16/2017', '71', 'SUBN', 'JEEP', '71A-Insp Sticker Expired (NYS)']
# ['7067047705', 'HFF1432', 'NY', 'PAS', '9/23/2016', '71', 'SUBN', 'JEEP', '71A-Insp Sticker Expired (NYS)']
# ['8168032202', 'GZN5776', 'NY', 'PAS', '8/3/2016', '71', '4DSD', 'LEXUS', '71A-Insp Sticker Expired (NYS)']
# ['8507861787', 'HMY3697', 'NY', 'PAS', '4/10/2017', '71', 'SUBN', 'LEXUS', '71A-Insp Sticker Expired (NYS)']
# ['8297047957', 'GUV7315', 'NY', 'PAS', '12/3/2016', '71', '4DSD', 'LINCO', '71A-Insp Sticker Expired (NYS)']
# ['8472853342', 'HJN6543', 'NY', 'PAS', '10/4/2016', '71', '2DSD', 'LINCO', '71A-Insp Sticker Expired (NYS)']
# ['8524860388', 'HGR2303', 'NY', 'PAS', '4/10/2017', '71', 'CONV', 'ME/BE', '71A-Insp Sticker Expired (NYS)']
# ['8561753377', 'GWY8527', 'NY', 'PAS', '5/26/2017', '71', 'SUBN', 'MERCU', '71A-Insp Sticker Expired (NYS)']
# ['8544876754', 'GBE4270', 'NY', 'PAS', '5/24/2017', '71', '4DSD', 'NISSA', '71A-Insp Sticker Expired (NYS)']
# ['7803960030', 'HBU4265', 'NY', 'PAS', '1/7/2017', '71', '4DSD', 'NISSA', '71A-Insp Sticker Expired (NYS)']
# ['7492597289', 'HDF5609', 'NY', 'PAS', '8/19/2016', '71', '4DSD', 'NISSA', '71A-Insp Sticker Expired (NYS)']
# ['8400523477', 'HKT1200', 'NY', 'PAS', '11/28/2016', '71', '4DSD', 'NISSA', '71-Insp. Sticker Missing (NYS']
# ['7646792536', 'T686872C', 'NY', 'OMT', '9/14/2016', '71', '4DSD', 'NISSA', '71A-Insp Sticker Expired (NYS)']
# ['8208026335', 'DHW7141', 'NY', 'PAS', '8/5/2016', '71', '2DSD', 'NS/OT', '71A-Insp Sticker Expired (NYS)']
# ['7959796476', 'GPY8489', 'NY', 'PAS', '10/6/2016', '71', 'SUBN', 'ROVER', '71A-Insp Sticker Expired (NYS)']
# ['8509455028', '34632BB', 'NY', 'OMR', '2/12/2017', '71', 'BUS', 'STAR', '71A-Insp Sticker Expired (NYS)']
# ['8393022400', 'HFP5696', 'NY', 'PAS', '11/16/2016', '71', 'SUBN', 'SUBAR', '71A-Insp Sticker Expired (NYS)']
# ['8525217207', 'HGM9849', 'NY', 'PAS', '5/3/2017', '71', 'SUBN', 'SUBAR', '71A-Insp Sticker Expired (NYS)']
# ['8562558047', 'CWP4893', 'NY', 'PAS', '6/1/2017', '71', 'SUBN', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['8236037095', 'GMR8112', 'NY', 'PAS', '9/17/2016', '71', '2DSD', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['8514463690', 'GMZ9712', 'NY', 'PAS', '3/30/2017', '71', '4DSD', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['8358550790', 'HDY4158', 'NY', 'PAS', '2/18/2017', '71', '4DSD', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['7959486440', 'GYF2052', 'NY', 'PAS', '7/7/2016', '71', '4DSD', 'VOLKS', '71-Insp. Sticker Missing (NYS']
# ['8300538318', 'HFR6545', 'NY', 'PAS', '10/31/2016', '71', '4DSD', 'VOLVO', '71-Insp. Sticker Missing (NYS']
# ['8523013120', 'HPN9774', 'NY', 'PAS', '4/6/2017', '74', '4DSD', 'CHEVR', '74-Missing Display Plate']
# ['7008336767', 'HWL4734', 'PA', 'PAS', '1/14/2017', '74', '4DSD', 'CHEVR', '74A-Improperly Displayed Plate']
# ['8397514636', 'FYW3850', 'NY', 'PAS', '10/22/2016', '74', 'SUBN', 'FORD', '74A-Improperly Displayed Plate']
# ['8528912840', 'HNY5206', 'NY', 'PAS', '4/21/2017', '74', 'SUBN', 'GMC', '74A-Improperly Displayed Plate']
# ['8511501113', 'FBP6836', 'NY', 'PAS', '2/16/2017', '74', 'SUBN', 'HONDA', '74-Missing Display Plate']
# ['8276551890', 'HJR4081', 'NY', 'PAS', '1/7/2017', '74', 'SUBN', 'HONDA', '74A-Improperly Displayed Plate']
# ['8214550531', 'HJY2207', 'NY', 'PAS', '3/9/2017', '74', '4DSD', 'HYUND', '74-Missing Display Plate']
# ['8487469012', '27527ME', 'NY', 'COM', '1/27/2017', '74', 'DELV', 'INTER', '74-Missing Display Plate']
# ['8034780236', 'HCD3158', 'NY', 'PAS', '9/2/2016', '74', 'SUBN', 'KIA', '74A-Improperly Displayed Plate']
# ['8545052455', 'HMK1149', 'NY', 'PAS', '6/7/2017', '74', '4DSD', 'ME/BE', '74-Missing Display Plate']
# ['1411263467', 'BLANKPLATE', '99', '999', '2/13/2017', '74', 'SDN', 'NISSA', '']
# ['8540001550', 'HLA4803', 'NY', 'PAS', '3/23/2017', '74', '4DSD', 'SAAB', '74-Missing Display Plate']
# ['8556155431', 'HFB9919', 'NY', 'PAS', '5/26/2017', '75', '4DSD', 'DODGE', '75-No Match-Plate/Reg. Sticker']
# ['8394016790', '31690BB', 'NY', 'OMR', '9/6/2016', '77', 'BUS', 'AM/T', '77-Parked Bus (exc desig area)']
# ['1419472306', '56090BA', 'NY', 'OMR', '2/20/2017', '77', 'BUS', 'INTER', '']
# ['8363508688', '97256', 'MA', 'APP', '8/13/2016', '77', 'BUS', 'NS/OT', '77-Parked Bus (exc desig area)']
# ['1407740258', '2513JMG', 'NY', 'COM', '1/11/2017', '78', 'DELV', 'FRUEH', '']
# ['8081047670', 'AG84195', 'AZ', 'PAS', '9/1/2016', '78', 'DELV', 'GMC', '78-Nighttime PKG on Res Street']
# ['8357010039', 'ZBK5659', 'PA', 'PAS', '9/16/2016', '78', 'FLAT', 'NS/OT', '78-Nighttime PKG on Res Street']
# ['1408164401', 'GCP8663', 'NY', 'PAS', '9/30/2016', '80', 'SUBN', 'CHEVR', '']
# ['7065087220', '35989MJ', 'NY', 'COM', '8/28/2016', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8472028628', '80921MH', 'NY', 'COM', '1/30/2017', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8413507250', 'XCGT11', 'NJ', 'PAS', '10/18/2016', '82', 'PICK', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8498413898', '2028133', 'IN', 'PAS', '5/24/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8484405837', '2028134', 'IN', 'PAS', '2/15/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8040125108', 'AT985A', 'NJ', 'PAS', '8/29/2016', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8521821979', 'XJX4470', 'PA', 'PAS', '5/18/2017', '84', 'TR/C', 'FRUEH', '84-Platform lifts in low posit']
# ['7662741072', 'XY237D', 'NJ', 'PAS', '8/9/2016', '84', 'DELV', 'HINO', '84-Platform lifts in low posit']
# ['8529157072', '2380604', 'IN', 'PAS', '3/29/2017', '84', 'DELV', 'INTER', '84-Platform lifts in low posit']
# ['8354508808', '21239MG', 'NY', 'COM', '9/9/2016', '84', 'DELV', 'MI/F', '84-Platform lifts in low posit']
# ['1414702700', 'AT785J', 'NJ', 'PAS', '11/27/2016', '85', 'TRAC', 'FRUEH', '']
# ['8466533837', 'XANK50', 'NJ', 'PAS', '4/29/2017', '85', 'DELV', 'HIN', '85-Storage-3 hour Commercial']
# ['8525168063', 'HBN8474', 'NY', 'PAS', '5/30/2017', '91', 'SUBN', 'HONDA', '91-Veh for Sale (Dealer Only)']
# ['1420730010', 'GFW3620', 'NY', 'PAS', '6/10/2017', '98', 'SUBN', 'CHEVR', '']
# ['1414049870', 'EJS4309', 'NY', 'PAS', '8/5/2016', '98', 'SDN', 'NISSA', '']
# ['1420795430', 'HBS5720', 'NY', 'PAS', '4/18/2017', '98', 'SDN', 'NISSA', '']

# %%
import csv

def read_data():
    with open ('nyc_parking_tickets_extract.csv') as f:
        return (list(csv.reader(f, delimiter=',',quotechar='"')))

# %%
reader = read_data()

# %%
for row in reader:
    print(row)
# Out:
# ['Summons Number', 'Plate ID', 'Registration State', 'Plate Type', 'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make', 'Violation Description']
# ['4006478550', 'VAD7274', 'VA', 'PAS', '10/5/2016', '5', '4D', 'BMW', 'BUS LANE VIOLATION']
# ['4006462396', '22834JK', 'NY', 'COM', '9/30/2016', '5', 'VAN', 'CHEVR', 'BUS LANE VIOLATION']
# ['4007117810', '21791MG', 'NY', 'COM', '4/10/2017', '5', 'VAN', 'DODGE', 'BUS LANE VIOLATION']
# ['4006265037', 'FZX9232', 'NY', 'PAS', '8/23/2016', '5', 'SUBN', 'FORD', 'BUS LANE VIOLATION']
# ['4006535600', 'N203399C', 'NY', 'OMT', '10/19/2016', '5', 'SUBN', 'FORD', 'BUS LANE VIOLATION']
# ['4007156700', '92163MG', 'NY', 'COM', '4/13/2017', '5', 'VAN', 'FRUEH', 'BUS LANE VIOLATION']
# ['4006687989', 'MIQ600', 'SC', 'PAS', '11/21/2016', '5', 'VN', 'HONDA', 'BUS LANE VIOLATION']
# ['4006943052', '2AE3984', 'MD', 'PAS', '2/1/2017', '5', 'SW', 'LINCO', 'BUS LANE VIOLATION']
# ['4007306795', 'HLG4926', 'NY', 'PAS', '5/30/2017', '5', 'SUBN', 'TOYOT', 'BUS LANE VIOLATION']
# ['4007124590', 'T715907C', 'NY', 'OMT', '4/3/2017', '5', 'SUBN', 'TOYOT', 'BUS LANE VIOLATION']
# ['5096061966', 'HRC9475', 'NY', 'PAS', '4/18/2017', '7', 'SUBN', 'CADIL', 'FAILURE TO STOP AT RED LIGHT']
# ['5094070400', 'DYP8042', 'NY', 'PAS', '10/26/2016', '7', 'SUBN', 'CHEVR', 'FAILURE TO STOP AT RED LIGHT']
', 'FAILURE TO STOP AT RED LIGHT']
# ['5094094166', 'CZM4111', 'NY', 'PAS', '10/28/2016', '7', '4DSD', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5096723768', 'EDN2797', 'NY', 'PAS', '6/2/2017', '7', '4DSD', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5093209120', 'FZT5005', 'NY', 'PAS', '8/28/2016', '7', '4DSD', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5092469481', 'GZH7067', 'NY', 'PAS', '7/10/2016', '7', 'SUBN', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5092451658', 'GZH7067', 'NY', 'PAS', '7/8/2016', '7', 'SUBN', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5095356545', 'GZM8254', 'NY', 'OMS', '2/18/2017', '7', 'SUBN', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['8410006650', 'D53AUUN', 'NJ', 'PAS', '10/21/2016', '9', '4DSD', 'LEXUS', '09-Blocking the Box']
# ['8534116519', 'CES6482', 'NY', 'PAS', '6/12/2017', '9', 'SUBN', 'TOYOT', '09-Blocking the Box']
# ['8485674984', 'T713160C', 'NY', 'OMT', '6/13/2017', '9', 'SUBN', 'TOYOT', '09-Blocking the Box']
# ['8556557405', '59622JW', 'NY', 'COM', '6/9/2017', '10', 'VAN', 'FORD', '10-No Stopping']
# ['8071038416', 'AM479F', 'NJ', 'PAS', '7/7/2016', '10', 'DELV', 'FRUEH', '10-No Stopping']
# ['8483087236', '76822MH', 'NY', 'COM', '5/19/2017', '10', 'DELV', 'HIN', '10-No Stopping']
# ['8481125088', '55179ME', 'NY', 'COM', '4/10/2017', '10', 'DELV', 'NS/OT', '10-No Stopping']
# ['8506822300', '55106MB', 'NY', 'COM', '5/31/2017', '10', 'VAN', 'WORKH', '10-No Stopping']
# ['8482331425', '86609MB', 'NY', 'COM', '6/18/2017', '13', 'VAN', 'CHEVR', '13-No Stand (taxi stand)']
# ['8028246722', 'T703619C', 'NY', 'OMT', '9/15/2016', '13', 'SUBN', 'CHEVR', '13-No Stand (taxi stand)']
# ['8378547530', 'FWZ8815', 'NY', 'PAS', '1/11/2017', '14', '2DSD', 'ACURA', '14-No Standing']
# ['8489750210', '6DQT356', 'CA', 'PAS', '11/28/2016', '14', '4DSD', 'AUDI', '14-No Standing']
# ['1410726095', 'DEP4792', 'NC', 'PAS', '7/15/2016', '14', '', 'BMW', '']
# ['8421031235', 'GGA4266', 'NY', 'PAS', '10/18/2016', '14', '4DSD', 'BMW', '14-No Standing']
# ['7730553259', 'DLZ8901', 'NY', 'PAS', '9/26/2016', '14', 'SUBN', 'CHEVR', '14-No Standing']
# ['8498520046', 'HKF6916', 'NY', 'PAS', '4/27/2017', '14', 'SUBN', 'CHEVR', '14-No Standing']
# ['8537807813', 'HNF6718', 'NY', 'PAS', '4/21/2017', '14', 'SUBN', 'CHEVR', '14-No Standing']
# ['8083571465', 'KCG9559', 'PA', 'PAS', '12/22/2016', '14', 'SUBN', 'CHEVR', '14-No Standing']
# ['7536689184', 'ZCL5723', 'PA', 'PAS', '1/26/2017', '14', 'VAN', 'CHEVR', '14-No Standing']
# ['8480505680', 'HCT2134', 'NY', 'PAS', '1/18/2017', '14', 'SUBN', 'CHRYS', '14-No Standing']
# ['8481973580', '28693MH', 'NY', 'COM', '6/13/2017', '14', 'VAN', 'DODGE', '14-No Standing']
# ['8460500214', '30408MC', 'NY', 'COM', '8/4/2016', '14', 'PICK', 'DODGE', '14-No Standing']
# ['8482817036', '50501JT', 'NY', 'COM', '4/11/2017', '14', 'VAN', 'DODGE', '14-No Standing']
# ['8117027999', '83317ME', 'NY', 'COM', '9/27/2016', '14', 'VAN', 'DODGE', '14-No Standing']
# ['
# ['7150327266', 'HWE6388', 'PA', 'PAS', '8/5/2016', '14', 'SUBN', 'SUBAR', '14-No Standing']
# ['8537603818', 'ASG8770', 'NY', 'PAS', '3/26/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8210533952', 'GST8679', 'NY', 'PAS', '11/21/2016', '14', '2DSD', 'TOYOT', '14-No Standing']
# ['8555462198', 'HKT4222', 'NY', 'PAS', '6/12/2017', '14', 'SUBN', 'TOYOT', '14-No Standing']
# ['1404838156', 'R57AAE', 'NJ', 'PAS', '4/29/2017', '14', 'SUBN', 'TOYOT', '']
# ['8527806162', 'T659832C', 'NY', 'OMT', '6/4/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8513520615', '77026MG', 'NY', 'COM', '5/31/2017', '14', 'TRAC', 'VOLVO', '14-No Standing']
# ['8251031485', 'HJP5565', 'NY', 'PAS', '10/4/2016', '16', '4DSD', 'CHEVR', '16A-No Std (Com Veh) Non-COM']
# ['7813745231', 'GEL1890', 'NY', 'PAS', '9/19/2016', '16', 'SUBN', 'CHRYS', '16A-No Std (Com Veh) Non-COM']
# ['8444534183', '36598MH', 'NY', 'COM', '11/23/2016', '16', 'VAN', 'DODGE', '16-No Std (Com Veh) Com Plate']
# ['8061037749', 'HFG7121', 'NY', 'PAS', '8/22/2016', '16', 'SUBN', 'DODGE', '16A-No Std (Com Veh) Non-COM']
# ['8250539527', '24745ME', 'NY', 'COM', '11/9/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8308520170', '49033ME', 'NY', 'COM', '7/14/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8504915323', '57011ME', 'NY', 'COM', '4/6/2017', '16', 'SUBN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8339536023', 'XCEG93', 'NJ', 'PAS', '9/15/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8566405183', 'GJD5585', 'NY', 'PAS', '6/1/2017', '16', '4DSD', 'ME/BE', '16A-No Std (Com Veh) Non-COM']
# ['7051225662', 'N61GZN', 'NJ', 'PAS', '11/25/2016', '16', 'SUBN', 'SATUR', '16A-No Std (Com Veh) Non-COM']
# ['8149510126', 'GTP8988', 'NY', 'PAS', '8/10/2016', '16', '2DSD', 'SMART', '16A-No Std (Com Veh) Non-COM']
# ['7052028463', 'HGM9782', 'NY', 'PAS', '1/30/2017', '16', 'SUBN', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8474913706', 'T674455C', 'NY', 'OMT', '2/8/2017', '16', '4DSD', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8506607206', '18752MH', 'NY', 'COM', '3/16/2017', '17', 'VAN', 'CHEVR', '17-No Stand (exc auth veh)']
# ['8438519763', '89882JV', 'NY', 'COM', '10/13/2016', '17', 'VAN', 'GMC', '17-No Stand (exc auth veh)']
# ['8551111954', 'GCE9214', 'NY', 'PAS', '6/25/2017', '17', '4DSD', 'HONDA', '17-No Stand (exc auth veh)']
# ['8516654059', 'AP169V', 'NJ', 'PAS', '2/22/2017', '18', 'DELV', 'INTER', '18-No Stand (bus lane)']
# ['1368119141', 'BMLV150', 'ON', 'PAS', '7/16/2016', '19', 'SUBN', 'CHEVR', '']
# ['8528274184', 'EKF9820', 'NY', 'PAS', '5/1/2017', '19', 'SUBN', 'CHEVR', '19-No Stand (bus stop)']
# ['8522350073', '83290MD', 'NY', 'COM', '2/24/2017', '19', 'SUBN', 'DODGE', '19-No Stand (bus stop)']
# ['8070097437', 'T62GJP', 'NJ', 'PAS', '9/18/2016', '19', 'PICK', 'DODGE', '19-No Stand (bus stop)']
# ['8509409523', '35050JU', 'NY', 'COM', '2/24/2017', '19', 'PICK', 'FORD', '19-No Stand (bus stop)']
# ['1413553552', '41126BB', 'NY', 'OMT', '7/28/2016', '19', 'VAN', 'FORD', '']
# ['8514220482', '2588073', 'IN', 'PAS', '5/29/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['8485652319', '0480PRA', 'MN', 'PAS', '1/26/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['7014671406', 'B0951V', 'FL', 'PAS', '9/7/2016', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['1422732710', 'GMK4592', 'NY', 'PAS', '6/19/2017', '19', 'SDN', 'HONDA', '']
# ['7249114220', 'GPP7413', 'NY', 'PAS', '10/8/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['7499990163', 'HKT3209', 'NY', 'PAS', '12/13/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['8491667738', 'JPC4516', 'PA', 'PAS', '3/1/2017', '19', '4DSD', 'INFIN', '19-No Stand (bus stop)']
# ['8302046280', '63444JM', 'NY', 'COM', '1/26/2017', '19', 'VAN', 'INTER', '19-No Stand (bus stop)']
# ['8009901763', '13657MD', 'NY', 'COM', '9/27/2016', '19', 'DELV', 'KENWO', '19-No Stand (bus stop)']
# ['1424024420', 'HPD1970', 'NY', 'PAS', '6/10/2017', '19', 'SDN', 'KIA', '']
# ['8511718990', '50104MH', 'NY', 'COM', '6/9/2017', '19', 'VAN', 'ME/BE', '19-No Stand (bus stop)']
# ['1415429522', '17236MH', 'NY', 'COM', '3/3/2017', '19', 'SUBN', 'MITSU', '']
# ['8476355312', '47829MD', 'NY', 'COM', '2/14/2017', '19', 'DELV', 'PETER', '19-No Stand (bus stop)']
# ['1406918726', '5M39B', 'NY', 'OMT', '7/13/2016', '19', 'TAXI', 'TOYOT', '']
# ['7241990262', 'DVA1919', 'NY', 'PAS', '11/16/2016', '19', 'SUBN', 'TOYOT', '19-No Stand (bus stop)']
# ['8330511935', 'HBY7509', 'NY', 'PAS', '7/30/2016', '19', '4DSD', 'TOYOT', '19-No Stand (bus stop)']
# ['1423536058', 'HCS2336', 'NY', 'PAS', '1/27/2017', '19', 'SUBN', 'TOYOT', '']
# ['8519016595', 'QU655', 'RI', 'PAS', '6/12/2017', '19', '4DSD', 'TOYOT', '19-No Stand (bus stop)']
# ['8530522310', 'T640396C', 'NY', 'OMT', '5/27/2017', '19', '4DSD', 'TOYOT', '19-No Stand (bus stop)']
# ['1413358512', '54295PC', 'NY', 'APP', '8/9/2016', '19', 'BUS', '', '']
# ['8269048434', 'CDPE57', 'FL', 'PAS', '8/21/2016', '20', '4DSD', 'ACURA', '20A-No Parking (Non-COM)']
# ['7036998684', 'VML8110', 'VA', 'PAS', '2/21/2017', '20', '4DSD', 'BMW', '20A-No Parking (Non-COM)']
# ['8515215408', 'HFB1731', 'NY', 'PAS', '4/14/2017', '20', 'SUBN', 'CADIL', '20A-No Parking (Non-COM)']
2017', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['8236569895', 'EPY9505', 'NY', 'PAS', '3/22/2017', '21', '4DSD', 'BUICK', '21-No Parking (street clean)']
# ['8502707383', 'JGL6885', 'PA', 'PAS', '1/24/2017', '21', 'SUBN', 'BUICK', '21-No Parking (street clean)']
# ['8511711946', '42283JZ', 'NY', 'COM', '4/27/2017', '21', 'VAN', 'CHEVR', '21-No Parking (street clean)']
# ['1418142980', '483TFM', 'TN', 'PAS', '12/19/2016', '21', 'VAN', 'CHEVR', '']
# ['1420029915', '53468JZ', '99', 'COM', '4/27/2017', '21', 'VAN', 'CHEVR', '']
# ['8539666996', '85121ME', 'NY', 'COM', '5/22/2017', '21', 'VAN', 'CHEVR', '21-No Parking (street clean)']
# ['1413709760', 'DGN6881', 'NY', 'PAS', '9/2/2016', '21', 'SDN', 'CHEVR', '']
# ['8473311693', 'DTG6286', 'NY', 'PAS', '11/23/2016', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['7658191050', 'GEL4496', 'NY', 'PAS', '7/22/2016', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['8478626049', 'GRU5176', 'NY', 'PAS', '5/15/2017', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['7369979570', 'GTC5499', 'NY', 'PAS', '7/20/2016', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['1400876217', 'GVB9839', 'NY', 'PAS', '9/19/2016', '21', 'P-U', 'CHEVR', '']
# ['1422284335', 'HHJ5747', 'NY', 'PAS', '6/3/2017', '21', 'SUBN', 'CHEVR', '']
# ['8556051480', 'M322307', 'NJ', 'PAS', '4/26/2017', '21', 'PICK', 'CHEVR', '21-No Parking (street clean)']
# ['8514570973', 'T738567C', 'NY', 'OMT', '6/21/2017', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['8357020770', 'Y56DLT', 'NJ', 'PAS', '1/20/2017', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['8523602306', 'GUG9349', 'NY', 'PAS', '3/25/2017', '21', '4DSD', 'CHRYS', '21-No Parking (street clean)']
# ['1410697290', 'HZ214', 'RI', 'PAS', '7/15/2016', '21', 'SUBN', 'CHRYS', '']
# ['8485267631', '80381MD', 'NY', 'COM', '3/2/2017', '21', 'VAN', 'DODGE', '21-No Parking (street clean)']
# ['7808365737', 'ETN7313', 'NY', 'PAS', '3/22/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8236558708', 'FLC9623', 'NY', 'PAS', '1/23/2017', '21', 'SUBN', 'DODGE', '21-No Parking (street clean)']
# ['8567100082', 'FTY1182', 'NY', 'PAS', '5/3/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8516402034', '88040MH', 'NY', 'COM', '5/26/2017', '21', 'DELV', 'FORD', '21-No Parking (street clean)']
# ['8237524573', 'CMD1897', 'NY', 'PAS', '10/19/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8490203982', 'DBZ7195', 'NY', 'PAS', '12/13/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8140540663', 'EHA1740', 'NY', 'PAS', '10/27/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8539702370', 'FYW7060', 'NY', 'PAS', '3/23/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8151587635', 'GFC5314', 'NY', 'PAS', '11/22/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8536979239', 'GKP5732', 'NY', 'PAS', '4/28/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8277588720', 'GYT3978', 'NY', 'PAS', '11/10/2016', '21', '2DSD', 'FORD', '21-No Parking (street clean)']
# ['8330514596', 'HDK4072', 'NY', 'PAS', '8/23/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8043823078', 'HHF5026', 'NY', 'PAS', '9/6/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8173039823', 'JLN1340', 'PA', 'PAS', '11/16/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8521903650', 'XAGW46', 'NJ', 'PAS', '3/27/2017', '21', 'VAN', 'FORD', '21-No Parking (street clean)']
# ['1420031892', '43601MG', 'NY', 'COM', '5/1/2017', '21', 'VAN', 'FRUEH', '']
# ['8431017041', '76130JH', 'NY', 'COM', '9/16/2016', '21', 'DELV', 'FRUEH', '21-No Parking (street clean)']
# ['8104561698', 'GAV2010', 'NY', 'PAS', '3/7/2017', '21', '4DSD', 'GEO', '21-No Parking (street clean)']
# ['1421330088', '12040MJ', 'NY', 'COM', '6/20/2017', '21', 'SUBN', 'GMC', '']
# ['8463512264', '20410AD', 'NY', 'COM', '10/28/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['8059052214', '36733JX', 'NY', 'COM', '11/14/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['1417865507', '77993JV', 'NY', 'COM', '2/6/2017', '21', 'VAN', 'GMC', '']
# ['7005104110', 'GYG7508', 'NY', 'PAS', '9/1/2016', '21', 'SUBN', 'GMC', '21-No Parking (street clean)']
# ['8077581614', 'XAYF77', 'NJ', 'PAS', '2/27/2017', '21', 'DELV', 'GMC', '21-No Parking (street clean)']
# ['8536832563', '1441', 'WY', 'PAS', '6/6/2017', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['8292013593', '601473', 'NY', 'PAS', '11/9/2016', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['8327066730', '38BR360', 'AL', 'PAS', '2/23/2017', '21', '2DSD', 'HONDA', '21-No Parking (street clean)']
# ['8432517677', '71WC47', 'MA', 'PAS', '11/14/2016', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['8511906897', 'CVG8394', 'NY', 'PAS', '3/21/2017', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['8523487694', 'D03SU', 'FL', 'PAS', '6/12/2017', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['7803577878', 'DRU6182', 'NY', 'PAS', '7/19/2016', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['8551867635', 'EJY9809', 'NY', 'PAS', '6/15/2017', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['8177030073', 'FPN6798', 'NY', 'PAS', '7/22/2016', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['7522710777', 'FTJ4934', 'NY', 'PAS', '8/2/2016', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['1415914771', 'FWY7687', 'NY', 'PAS', '11/5/2016', '21', 'SUBN', 'HONDA', '']
# ['8511777581', 'GBP8071', 'NY', 'PAS', '6/23/2017', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['8507224441', 'GHR1050', 'NY', 'PAS', '6/12/2017', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['1418138575', 'GML6346', 'NY', 'PAS', '12/19/2016', '21', 'SDN', 'HONDA', '']
# ['8494361650', 'GPR1060', 'NY', 'PAS', '1/19/2017', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['8532805115', 'GRH7130', 'NY', 'PAS', '3/30/2017', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['1420074817', 'GYX5626', 'NY', 'PAS', '3/23/2017', '21', 'SUBN', 'HONDA', '']
# ['8081038309', 'HGU5174', 'NY', 'PAS', '7/13/2016', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['8539658732', 'HLY9761', 'NY', 'PAS', '4/20/2017', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['8254043190', 'HMF6591', 'NY', 'PAS', '12/14/2016', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['1415902598', 'HPP349', 'DE', 'PAS', '10/8/2016', '21', 'SDN', 'HONDA', '']
# ['8035447610', 'JRV7796', 'PA', 'PAS', '8/25/2016', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['1416152180', 'KGM0645', 'PA', 'PAS', '11/3/2016', '21', '', 'HONDA', '']
# ['8270065079', 'L727629', 'NJ', 'PAS', '8/31/2016', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['1412424525', 'T6835420', 'NY', 'OMT', '7/27/2016', '21', 'SDN', 'HONDA', '']
# ['8054568940', 'C52DUH', 'NJ', 'PAS', '11/14/2016', '21', '4DSD', 'HYUND', '21-No Parking (street clean)']
# ['7381087881', 'ETP1967', 'NY', 'PAS', '8/4/2016', '21', '4DSD', 'HYUND', '21-No Parking (street clean)']
# ['7813942917', 'GZD3951', 'NY', 'PAS', '8/4/2016', '21', '4DSD', 'HYUND', '21-No Parking (street clean)']
# ['8522906415', 'HME3832', 'NY', 'PAS', '3/21/2017', '21', '4DSD', 'HYUND', '21-No Parking (street clean)']
# ['8303022775', 'AS972S', 'NJ', 'PAS', '7/19/2016', '21', 'DELV', 'INTER', '21-No Parking (street clean)']
# ['8556262995', 'HPL5772', 'NY', 'PAS', '6/12/2017', '21', '4DSD', 'JAGUA', '21-No Parking (street clean)']
# ['8533998533', 'GXR4859', 'NY', 'PAS', '6/12/2017', '21', 'SUBN', 'JEEP', '21-No Parking (street clean)']
# ['7807869367', 'HEE4014', 'NY', 'PAS', '11/22/2016', '21', 'SUBN', 'JEEP', '21-No Parking (street clean)']
# ['8170554482', 'GKB1444', 'NY', 'PAS', '8/31/2016', '21', 'SUBN', 'LEXUS', '21-No Parking (street clean)']
# ['8475485066', 'GYR5020', 'NY', 'PAS', '3/23/2017', '21', 'SUBN', 'LEXUS', '21-No Parking (street clean)']
# ['1415885734', 'GNN27768', 'NY', 'PAS', '9/30/2016', '21', 'SUBN', 'LINCO', '']
# ['8271048004', 'PDB2482', 'NC', 'PAS', '8/30/2016', '21', 'SUBN', 'LINCO', '21-No Parking (street clean)']
# ['8487768659', 'T639150C', 'NY', 'OMT', '2/3/2017', '21', 'SUBN', 'LINCO', '21-No Parking (street clean)']
# ['8196531606', '735ZVY', 'CT', 'PAS', '10/11/2016', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8556351920', 'FCN6061', 'NY', 'PAS', '4/28/2017', '21', 'SUBN', 'MAZDA', '21-No Parking (street clean)']
# ['8563702300', 'GUY5928', 'NY', 'PAS', '5/18/2017', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8475466254', 'HWN1816', 'TX', 'PAS', '12/27/2016', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8349510500', '84302T', 'VA', 'PAS', '7/8/2016', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8327051209', 'ATE9889', 'NY', 'PAS', '12/20/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['7803990927', 'HCN1049', 'NY', 'PAS', '3/28/2017', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8514726985', 'HKB2413', 'NY', 'PAS', '5/22/2017', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['8360507120', 'OL4468J', 'NJ', 'PAS', '7/26/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['1419707358', 'V97GVE', 'NJ', 'PAS', '2/18/2017', '21', 'SUBN', 'ME/BE', '']
# ['8557255329', 'HFE4369', 'NY', 'PAS', '5/11/2017', '21', 'SUBN', 'MERCU', '21-No Parking (street clean)']
# ['8512671312', '8892CZ', 'CT', 'CMB', '6/6/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['7081940572', 'ATS3775', 'NY', 'PAS', '1/4/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8472183579', 'BNZF31', 'FL', 'PAS', '12/3/2016', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8190539723', 'DKT8358', 'NY', 'PAS', '9/8/2016', '21', '2DSD', 'NISSA', '21-No Parking (street clean)']
# ['1416492320', 'FGR5997', 'NY', 'PAS', '9/30/2016', '21', 'SDN', 'NISSA', '']
# ['8549705664', 'FYW4686', 'NY', 'PAS', '6/3/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['1420512468', 'GJH8815', 'NY', 'PAS', '4/8/2017', '21', 'SUBN', 'NISSA', '']
# ['8551204051', 'GNN9248', 'NY', 'PAS', '5/4/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8344027755', 'GUP8589', 'NY', 'PAS', '12/7/2016', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8539277086', 'GVH4035', 'PA', 'PAS', '5/26/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# 
2017', '21', '4DSD', 'TOYOT', '21-No Parking (street clean)']
# ['1399238401', 'WLDB0SS', 'GA', 'PAS', '12/30/2016', '21', 'P-U', 'TOYOT', '']
# ['8538515603', '731762B', 'TX', 'PAS', '5/15/2017', '21', '4DSD', 'VOLKS', '21-No Parking (street clean)']
# ['8513583789', 'FLJ3099', 'NY', 'PAS', '6/22/2017', '21', '2DSD', 'VOLKS', '21-No Parking (street clean)']
# ['8273071844', 'GFM6245', 'NY', 'PAS', '10/20/2016', '21', '4DSD', 'VOLKS', '21-No Parking (street clean)']
# ['8532602563', 'CVU3012', 'NY', 'PAS', '3/23/2017', '21', '4DSD', 'VOLVO', '21-No Parking (street clean)']
# ['8478353227', '34SW77', 'NY', 'MOT', '12/2/2016', '21', 'MCY', 'YAMAH', '21-No Parking (street clean)']
# ['1418425369', 'JYW5248', 'PA', 'PAS', '3/21/2017', '21', 'SDN', '', '']
# ['8361518277', 'HCX7823', 'NY', 'PAS', '10/12/2016', '23', '4DSD', 'HYUND', '23-No Parking (taxi stand)']
# ['8154034347', 'CTX3627', 'NY', 'PAS', '9/6/2016', '24', 'SUBN', 'AUDI', '24-No Parking (exc auth veh)']
# ['7764794314', 'HFP4684', 'NY', 'PAS', '8/5/2016', '24', '4DSD', 'AUDI', '24-No Parking (exc auth veh)']
# ['8544611310', 'GTC4836', 'NY', 'PAS', '6/7/2017', '24', 'SUBN', 'CADIL', '24-No Parking (exc auth veh)']
# ['8566704320', 'L62FLC', 'NJ', 'PAS', '5/17/2017', '24', 'SUBN', 'CHEVR', '24-No Parking (exc auth veh)']
# ['8536961156', 'X92FSM', 'NJ', 'PAS', '3/28/2017', '24', 'SUBN', 'HYUND', '24-No Parking (exc auth veh)']
# ['1408122029', 'DSN6323', 'NY', 'PAS', '7/4/2016', '24', 'SUBN', 'JEEP', '']
# ['8266568753', 'F12GRE', 'NJ', 'PAS', '11/11/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8446524806', 'GYG8911', 'NY', 'PAS', '12/18/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8316519355', 'HDJ7785', 'PA', 'PAS', '7/14/2016', '24', '2DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8533035640', 'T687600C', 'NY', 'OMT', '5/31/2017', '24', '4DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8526732663', 'ASV2478', 'NY', 'PAS', '6/22/2017', '24', '4DSD', 'TOYOT', '24-No Parking (exc auth veh)']
# ['1410027223', 'ENS9253', 'NY', 'PAS', '10/31/2016', '24', 'SDN', 'VOLKS', '']
# ['8479824712', '58910MG', 'NY', 'COM', '4/21/2017', '26', 'DELV', 'ISUZU', '26-No Stnd (for-hire veh only)']
# ['1416527722', 'AHG9422', 'NY', 'PAS', '1/5/2017', '27', 'SUBN', 'TOYOT', '']
# ['8512270482', 'Y26CRJ', 'NJ', 'PAS', '6/3/2017', '31', 'SUBN', 'BSA', '31-No Stand (Com. Mtr. Zone)']
# ['8498706890', 'THANEDAR', 'NY', 'OMT', '3/22/2017', '31', 'SUBN', 'CADIL', '31-No Stand (Com. Mtr. Zone)']
# ['8328546632', 'HHP7446', 'NY', 'PAS', '12/2/2016', '31', '2DSD', 'CHEVR', '31-No Stand (Com. Mtr. Zone)']
# ['8162015656', 'GSS803', 'VT', 'PAS', '9/1/2016', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8526919210', 'GZD7447', 'NY', 'PAS', '4/12/2017', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8506053195', '25868MB', 'NY', 'COM', '1/25/2017', '51', 'VAN', 'FORD', '51-Sidewalk']
# ['8520767310', 'GHN6806', 'NY', 'PAS', '5/26/2017', '51', 'SUBN', 'SAAB', '51-Sidewalk']
# ['7079854404', 'T656205C', 'NY', 'OMT', '1/28/2017', '51', '4DSD', 'TOYOT', '51-Sidewalk']
# ['1421055820', 'GAR2279', 'NY', 'PAS', '6/10/2017', '52', 'SDN', 'FORD', '']
# ['7085899554', 'GUZ4334', 'NY', 'PAS', '10/13/2016', '53', 'SUBN', 'ACURA', '53-Safety Zone']
# ['8478553514', 'XCMA58', 'NJ', 'PAS', '12/15/2016', '53', 'DELV', 'HINO', '53-Safety Zone']
# ['8546101425', 'DF932Z', 'NY', 'PAS', '4/10/2017', '53', 'SUBN', 'LEXUS', '53-Safety Zone']
# ['7007488663', 'VFP7291', 'VA', 'PAS', '3/2/2017', '53', '4DSD', 'ME/BE', '53-Safety Zone']
# ['1402409825', '869ZR9', 'MA', '999', '10/15/2016', '53', 'SUBN', 'SATUR', '']
# ['8506603031', '2383103', 'IN', 'PAS', '2/1/2017', '53', 'TRAC', 'VOLVO', '53-Safety Zone']
# ['8480309064', '51771JW', 'NY', 'COM', '1/26/2017', '64', 'VAN', 'INTER', '64-No STD Ex Con/DPL D/S Dec']
# ['8162054819', 'EW866X', 'NJ', 'PAS', '1/29/2017', '68', '4DSD', 'NISSA', '68-Not Pkg. Comp. w Psted Sign']
# ['8343032536', '4CMH482', 'CA', 'PAS', '10/3/2016', '68', 'SUBN', 'SUBAR', '68-Not Pkg. Comp. w Psted Sign']
# ['8084034959', 'ASW2109', 'NY', 'PAS', '12/20/2016', '68', '4DSD', 'TOYOT', '68-Not Pkg. Comp. w Psted Sign']
# ['8066506089', '12047JY', 'NY', 'COM', '7/1/2016', '69', 'VAN', 'CHEVR', '69-Failure to Disp Muni Recpt']
# ['8483275156', '57309ME', 'NY', 'COM', '6/7/2017', '69', 'PICK', 'DODGE', '69-Failure to Disp Muni Recpt']
# ['8481256500', '21530JX', 'NY', 'COM', '1/30/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8513914599', '65572JU', 'NY', 'COM', '6/9/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8479417420', 'AT459E', 'NJ', 'PAS', '4/13/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8479216670', 'D705HT', 'TN', 'PAS', '4/11/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8471301842', 'XZ223J', 'NJ', 'PAS', '8/30/2016', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['7268771216', '63383JT', 'NY', 'COM', '7/27/2016', '69', 'VAN', 'GMC', '69-Failure to Disp Muni Recpt']
# ['8476768746', '91599ME', 'NY', 'COM', '4/13/2017', '69', 'REFG', 'HIN', '69-Failure to Disp Muni Recpt']
# ['7868300310', '37033JV', 'NY', 'COM', '11/21/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8077552250', 'AS299T', 'NJ', 'PAS', '10/14/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8116524124', 'XDYD73', 'NJ', 'PAS', '10/6/2016', '69', 'DELV', 'ISUZU', '69-Failure to Disp Muni Recpt']
# ['7393476988', 'GGR9506', 'NY', 'PAS', '7/20/2016', '70', '4DSD', 'AUDI', '70A-Reg. Sticker Expired (NYS)']
# ['8527214490', 'GWG7018', 'NY', 'PAS', '5/16/2017', '70', 'SUBN', 'BMW', '70A-Reg. Sticker Expired (NYS)']
# ['7077031019', 'GNV8363', 'NY', 'PAS', '9/7/2016', '70', 'SUBN', 'CADIL', '70A-Reg. Sticker Expired (NYS)']
# ['8522772708', 'GWH8469', 'NY', 'PAS', '4/20/2017', '70', 'SUBN', 'CHRYS', '70A-Reg. Sticker Expired (NYS)']
# ['8535702763', 'GTE6420', 'NY', 'PAS', '3/24/2017', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['7705894520', 'GYP6735', 'NY', 'OMS', '10/2/2016', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['8535150079', 'HMC7627', 'NY', 'PAS', '3/8/2017', '70', '4DSD', 'HYUND', '70A-Reg. Sticker Expired (NYS)']
# ['7541990206', 'HGL9860', 'NY', 'PAS', '2/18/2017', '70', 'SUBN', 'JEEP', '70A-Reg. Sticker Expired (NYS)']
# ['7074250855', 'GBV6820', 'NY', 'PAS', '11/5/2016', '70', 'SUBN', 'ME/BE', '70A-Reg. Sticker Expired (NYS)']
# ['8419012245', 'GVM6317', 'NY', 'PAS', '1/27/2017', '70', '4DSD', 'ME/BE', '70A-Reg. Sticker Expired (NYS)']
# ['8552067018', 'ACS8210', 'NY', 'PAS', '6/23/2017', '70', 'SUBN', 'NISSA', '70A-Reg. Sticker Expired (NYS)']
# ['8490111753', 'GVH9098', 'NY', 'PAS', '1/25/2017', '70', '4DSD', 'NISSA', '70A-Reg. Sticker Expired (NYS)']
# ['1423568710', 'GPG1213', 'NY', 'PAS', '3/19/2017', '70', 'SDN', 'SUBAR', '']
# ['8363531900', 'GTC2970', 'NY', 'PAS', '2/8/2017', '70', '4DSD', 'TOYOT', '70A-Reg. Sticker Expired (NYS)']
# ['8282021635', 'FBD7363', 'NY', 'PAS', '9/10/2016', '71', '4DSD', 'ACURA', '71A-Insp Sticker Expired (NYS)']
# ['8551100002', 'HLA6845', 'NY', 'PAS', '4/5/2017', '71', '4DSD', 'BMW', '71-Insp. Sticker Missing (NYS']
# ['8471891440', '42530MG', 'NY', 'COM', '2/28/2017', '71', 'DELV', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8555150875', 'ETF9022', 'NY', 'PAS', '5/2/2017', '71', 'SUBN', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8188582906', 'GMT8516', 'NY', 'PAS', '11/1/2016', '71', 'PICK', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8206527321', 'HCD4100', 'NY', 'PAS', '11/1/2016', '71', 'SUBN', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['
'71', '4DSD', 'NISSA', '71A-Insp Sticker Expired (NYS)']
# ['8208026335', 'DHW7141', 'NY', 'PAS', '8/5/2016', '71', '2DSD', 'NS/OT', '71A-Insp Sticker Expired (NYS)']
# ['7959796476', 'GPY8489', 'NY', 'PAS', '10/6/2016', '71', 'SUBN', 'ROVER', '71A-Insp Sticker Expired (NYS)']
# ['8509455028', '34632BB', 'NY', 'OMR', '2/12/2017', '71', 'BUS', 'STAR', '71A-Insp Sticker Expired (NYS)']
# ['8393022400', 'HFP5696', 'NY', 'PAS', '11/16/2016', '71', 'SUBN', 'SUBAR', '71A-Insp Sticker Expired (NYS)']
# ['8525217207', 'HGM9849', 'NY', 'PAS', '5/3/2017', '71', 'SUBN', 'SUBAR', '71A-Insp Sticker Expired (NYS)']
# ['8562558047', 'CWP4893', 'NY', 'PAS', '6/1/2017', '71', 'SUBN', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['8236037095', 'GMR8112', 'NY', 'PAS', '9/17/2016', '71', '2DSD', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['8514463690', 'GMZ9712', 'NY', 'PAS', '3/30/2017', '71', '4DSD', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['8358550790', 'HDY4158', 'NY', 'PAS', '2/18/2017', '71', '4DSD', 'TOYOT', '71A-Insp Sticker Expired (NYS)']
# ['7959486440', 'GYF2052', 'NY', 'PAS', '7/7/2016', '71', '4DSD', 'VOLKS', '71-Insp. Sticker Missing (NYS']
# ['8300538318', 'HFR6545', 'NY', 'PAS', '10/31/2016', '71', '4DSD', 'VOLVO', '71-Insp. Sticker Missing (NYS']
# ['8523013120', 'HPN9774', 'NY', 'PAS', '4/6/2017', '74', '4DSD', 'CHEVR', '74-Missing Display Plate']
# ['7008336767', 'HWL4734', 'PA', 'PAS', '1/14/2017', '74', '4DSD', 'CHEVR', '74A-Improperly Displayed Plate']
# ['8397514636', 'FYW3850', 'NY', 'PAS', '10/22/2016', '74', 'SUBN', 'FORD', '74A-Improperly Displayed Plate']
# ['8528912840', 'HNY5206', 'NY', 'PAS', '4/21/2017', '74', 'SUBN', 'GMC', '74A-Improperly Displayed Plate']
# ['8511501113', 'FBP6836', 'NY', 'PAS', '2/16/2017', '74', 'SUBN', 'HONDA', '74-Missing Display Plate']
# ['8276551890', 'HJR4081', 'NY', 'PAS', '1/7/2017', '74', 'SUBN', 'HONDA', '74A-Improperly Displayed Plate']
# ['8214550531', 'HJY2207', 'NY', 'PAS', '3/9/2017', '74', '4DSD', 'HYUND', '74-Missing Display Plate']
# ['8487469012', '27527ME', 'NY', 'COM', '1/27/2017', '74', 'DELV', 'INTER', '74-Missing Display Plate']
# ['8034780236', 'HCD3158', 'NY', 'PAS', '9/2/2016', '74', 'SUBN', 'KIA', '74A-Improperly Displayed Plate']
# ['8545052455', 'HMK1149', 'NY', 'PAS', '6/7/2017', '74', '4DSD', 'ME/BE', '74-Missing Display Plate']
# ['1411263467', 'BLANKPLATE', '99', '999', '2/13/2017', '74', 'SDN', 'NISSA', '']
# ['8540001550', 'HLA4803', 'NY', 'PAS', '3/23/2017', '74', '4DSD', 'SAAB', '74-Missing Display Plate']
# ['8556155431', 'HFB9919', 'NY', 'PAS', '5/26/2017', '75', '4DSD', 'DODGE', '75-No Match-Plate/Reg. Sticker']
# ['8394016790', '31690BB', 'NY', 'OMR', '9/6/2016', '77', 'BUS', 'AM/T', '77-Parked Bus (exc desig area)']
# ['1419472306', '56090BA', 'NY', 'OMR', '2/20/2017', '77', 'BUS', 'INTER', '']
# ['8363508688', '97256', 'MA', 'APP', '8/13/2016', '77', 'BUS', 'NS/OT', '77-Parked Bus (exc desig area)']
# ['1407740258', '2513JMG', 'NY', 'COM', '1/11/2017', '78', 'DELV', 'FRUEH', '']
# ['8081047670', 'AG84195', 'AZ', 'PAS', '9/1/2016', '78', 'DELV', 'GMC', '78-Nighttime PKG on Res Street']
# ['8357010039', 'ZBK5659', 'PA', 'PAS', '9/16/2016', '78', 'FLAT', 'NS/OT', '78-Nighttime PKG on Res Street']
# ['1408164401', 'GCP8663', 'NY', 'PAS', '9/30/2016', '80', 'SUBN', 'CHEVR', '']
# ['7065087220', '35989MJ', 'NY', 'COM', '8/28/2016', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8472028628', '80921MH', 'NY', 'COM', '1/30/2017', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8413507250', 'XCGT11', 'NJ', 'PAS', '10/18/2016', '82', 'PICK', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8498413898', '2028133', 'IN', 'PAS', '5/24/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8484405837', '2028134', 'IN', 'PAS', '2/15/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8040125108', 'AT985A', 'NJ', 'PAS', '8/29/2016', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8521821979', 'XJX4470', 'PA', 'PAS', '5/18/2017', '84', 'TR/C', 'FRUEH', '84-Platform lifts in low posit']
# ['7662741072', 'XY237D', 'NJ', 'PAS', '8/9/2016', '84', 'DELV', 'HINO', '84-Platform lifts in low posit']
# ['8529157072', '2380604', 'IN', 'PAS', '3/29/2017', '84', 'DELV', 'INTER', '84-Platform lifts in low posit']
# ['8354508808', '21239MG', 'NY', 'COM', '9/9/2016', '84', 'DELV', 'MI/F', '84-Platform lifts in low posit']
# ['1414702700', 'AT785J', 'NJ', 'PAS', '11/27/2016', '85', 'TRAC', 'FRUEH', '']
# ['8466533837', 'XANK50', 'NJ', 'PAS', '4/29/2017', '85', 'DELV', 'HIN', '85-Storage-3 hour Commercial']
# ['8525168063', 'HBN8474', 'NY', 'PAS', '5/30/2017', '91', 'SUBN', 'HONDA', '91-Veh for Sale (Dealer Only)']
# ['1420730010', 'GFW3620', 'NY', 'PAS', '6/10/2017', '98', 'SUBN', 'CHEVR', '']
# ['1414049870', 'EJS4309', 'NY', 'PAS', '8/5/2016', '98', 'SDN', 'NISSA', '']
# ['1420795430', 'HBS5720', 'NY', 'PAS', '4/18/2017', '98', 'SDN', 'NISSA', '']

# %% [markdown]
# #### Not just a Context Manager

# %%
with open('test.txt', 'w') as f:
    f.writelines('this is a test')

# %%
f = open('test.txt')

# %%
print(f.readlines())
# Out:
# ['this is a test']

# %%
f.close()

# %%
class DataIterator:
    def __init__(self, fname):
        self._fname = fname
        self._f = None
        
    def __iter__(self):
        return self
    
    def __next__(self):
        row = next(self._f)
        return row.strip('\n').split(',')
    
    def __enter__(self):
        self._f = open(self._fname)
        return self
    
    def __exit__(self, type_, value, tb):
        if not self._f.closed:
            self._f.close()
            
        return False

# %%
with DataIterator('nyc_parking_tickets_extract.csv') as file:
    for row in file:
        print(row)
# Out:
# ['Summons Number', 'Plate ID', 'Registration State', 'Plate Type', 'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make', 'Violation Description']
# ['8478353860', 'VUE95C', 'NJ', 'PAS', '12/6/2016', '14', '4DSD', 'LEXUS', '14-No Standing']
# ['8518911631', 'ZD53LE', 'NJ', 'PAS', '5/17/2017', '14', 'SUBN', 'LEXUS', '14-No Standing']
# ['1416091415', '75213MH', 'NY', 'COM', '11/28/2016', '14', 'VAN', 'ME/BE', '']
# ['8482374059', 'F96FBF', 'NJ', 'PAS', '4/23/2017', '14', '4DSD', 'ME/BE', '14-No Standing']
# ['8544960947', 'HMX8950', 'NY', 'PAS', '5/27/2017', '14', '4DSD', 'ME/BE', '14-No Standing']
# ['1418609274', '8P82H', 'NY', 'OMT', '12/21/2016', '14', 'TAXI', 'NISSA', '']
# ['1417565895', 'HEB8184', 'NY', 'PAS', '2/11/2017', '14', 'SDN', 'NISSA', '']
# ['8155550278', 'W56GSE', 'NJ', 'PAS', '10/22/2016', '14', '4DSD', 'NISSA', '14-No Standing']
# ['7433187960', '2330830', 'ME', 'PAS', '3/6/2017', '14', 'TRLR', 'NS/OT', '14-No Standing']
# ['7645052715', 'FRZ3573', 'NY', 'PAS', '1/7/2017', '14', 'SUBN', 'NS/OT', '14-No Standing']
# ['7922559173', 'XCYU94', 'NJ', 'PAS', '10/24/2016', '14', 'VAN', 'NS/OT', '14-No Standing']
# ['7767415582', 'XW915N', 'NJ', 'PAS', '3/29/2017', '14', 'DELV', 'NS/OT', '14-No Standing']
# ['8524350581', 'HGR5953', 'NY', 'PAS', '2/27/2017', '14', '4DSD', 'OLDSM', '14-No Standing']
# ['7499844705', 'GGT7948', 'NY', 'PAS', '8/22/2016', '14', 'SUBN', 'SUBAR', '14-No Standing']
# ['7150327266', 'HWE6388', 'PA', 'PAS', '8/5/2016', '14', 'SUBN', 'SUBAR', '14-No Standing']
# ['8537603818', 'ASG8770', 'NY', 'PAS', '3/26/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8210533952', 'GST8679', 'NY', 'PAS', '11/21/2016', '14', '2DSD', 'TOYOT', '14-No Standing']
# ['8555462198', 'HKT4222', 'NY', 'PAS', '6/12/2017', '14', 'SUBN', 'TOYOT', '14-No Standing']
# ['1404838156', 'R57AAE', 'NJ', 'PAS', '4/29/2017', '14', 'SUBN', 'TOYOT', '']
# ['8527806162', 'T659832C', 'NY', 'OMT', '6/4/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8513520615', '77026MG', 'NY', 'COM', '5/31/2017', '14', 'TRAC', 'VOLVO', '14-No Standing']
# ['8251031485', 'HJP5565', 'NY', 'PAS', '10/4/2016', '16', '4DSD', 'CHEVR', '16A-No Std (Com Veh) Non-COM']
# ['7813745231', 'GEL1890', 'NY', 'PAS', '9/19/2016', '16', 'SUBN', 'CHRYS', '16A-No Std (Com Veh) Non-COM']
# ['8444534183', '36598MH', 'NY', 'COM', '11/23/2016', '16', 'VAN', 'DODGE', '16-No Std (Com Veh) Com Plate']
# ['8061037749', 'HFG7121', 'NY', 'PAS', '8/22/2016', '16', 'SUBN', 'DODGE', '16A-No Std (Com Veh) Non-COM']
# ['8250539527', '24745ME', 'NY', 'COM', '11/9/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8308520170', '49033ME', 'NY', 'COM', '7/14/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8504915323', '57011ME', 'NY', 'COM', '4/6/2017', '16', 'SUBN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8339536023', 'XCEG93', 'NJ', 'PAS', '9/15/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8566405183', 'GJD5585', 'NY', 'PAS', '6/1/2017', '16', '4DSD', 'ME/BE', '16A-No Std (Com Veh) Non-COM']
# ['7051225662', 'N61GZN', 'NJ', 'PAS', '11/25/2016', '16', 'SUBN', 'SATUR', '16A-No Std (Com Veh) Non-COM']
# ['8149510126', 'GTP8988', 'NY', 'PAS', '8/10/2016', '16', '2DSD', 'SMART', '16A-No Std (Com Veh) Non-COM']
# ['7052028463', 'HGM9782', 'NY', 'PAS', '1/30/2017', '16', 'SUBN', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8474913706', 'T674455C', 'NY', 'OMT', '2/8/2017', '16', '4DSD', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8506607206', '18752MH', 'NY', 'COM', '3/16/2017', '17', 'VAN', 'CHEVR', '17-No Stand (exc auth veh)']
# ['8438519763', '89882JV', 'NY', 'COM', '10/13/2016', '17', 'VAN', 'GMC', '17-No Stand (exc auth veh)']
# ['8551111954', 'GCE9214', 'NY', 'PAS', '6/25/2017', '17', '4DSD', 'HONDA', '17-No Stand (exc auth veh)']
# ['8516654059', 'AP169V', 'NJ', 'PAS', '2/22/2017', '18', 'DELV', 'INTER', '18-No Stand (bus lane)']
# ['1368119141', 'BMLV150', 'ON', 'PAS', '7/16/2016', '19', 'SUBN', 'CHEVR', '']
# ['8528274184', 'EKF9820', 'NY', 'PAS', '5/1/2017', '19', 'SUBN', 'CHEVR', '19-No Stand (bus stop)']
# ['8522350073', '83290MD', 'NY', 'COM', '2/24/2017', '19', 'SUBN', 'DODGE', '19-No Stand (bus stop)']
# ['8070097437', 'T62GJP', 'NJ', 'PAS', '9/18/2016', '19', 'PICK', 'DODGE', '19-No Stand (bus stop)']
# ['8509409523', '35050JU', 'NY', 'COM', '2/24/2017', '19', 'PICK', 'FORD', '19-No Stand (bus stop)']
# ['1413553552', '41126BB', 'NY', 'OMT', '7/28/2016', '19', 'VAN', 'FORD', '']
# ['8514220482', '2588073', 'IN', 'PAS', '5/29/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['8485652319', '0480PRA', 'MN', 'PAS', '1/26/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['7014671406', 'B0951V', 'FL', 'PAS', '9/7/2016', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['1422732710', 'GMK4592', 'NY', 'PAS', '6/19/2017', '19', 'SDN', 'HONDA', '']
# ['7249114220', 'GPP7413', 'NY', 'PAS', '10/8/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['7499990163', 'HKT3209', 'NY', 'PAS', '12/13/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['8491667738', 'JPC4516', 'PA', 'PAS', '3/1/2017', '19', '4DSD', 'INFIN', '19-No Stand (bus stop)']
# ['8302046280', '63444JM', 'NY', 'COM', '1/26/2017', '19', 'VAN', 'INTER', '19-No Stand (bus stop)']
2017', '20', '4DSD', 'TOYOT', '20A-No Parking (Non-COM)']
# ['8147540644', 'GXB8128', 'NY', 'PAS', '9/1/2016', '20', '4DSD', 'TOYOT', '20A-No Parking (Non-COM)']
# ['7606849481', 'T638216C', 'NY', 'OMT', '5/8/2017', '20', '4DSD', 'TOYOT', '20A-No Parking (Non-COM)']
# ['8293037179', 'GJU4869', 'NY', 'PAS', '8/26/2016', '21', '4DSD', 'ACURA', '21-No Parking (street clean)']
# ['8009559234', 'HBU6907', 'NY', 'PAS', '8/10/2016', '21', '4DSD', 'ACURA', '21-No Parking (street clean)']
# ['8545156546', 'EVM6598', 'NY', 'PAS', '5/3/2017', '21', '4DSD', 'AUDI', '21-No Parking (street clean)']
# ['8516050920', 'GXY1094', 'NY', 'PAS', '3/3/2017', '21', 'SUBN', 'AUDI', '21-No Parking (street clean)']
# ['8544889610', 'VVP9002', 'VA', 'PAS', '6/14/2017', '21', '4DSD', 'AUDI', '21-No Parking (street clean)']
# ['8318510150', '99H1010', 'TN', 'PAS', '8/2/2016', '21', '2DSD', 'BMW', '21-No Parking (street clean)']
# ['8491819083', 'FHY6755', 'NY', 'PAS', '3/3/2017', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['7725863710', 'GNF2877', 'NY', 'PAS', '9/26/2016', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['1412956201', 'GNR5598', 'NY', 'PAS', '7/20/2016', '21', 'SDN', 'BMW', '']
# ['7919376452', 'HAS5112', 'NY', 'PAS', '1/27/2017', '21', 'SUBN', 'BMW', '21-No Parking (street clean)']
# ['7970393330', 'HAT6686', 'NY', 'PAS', '8/17/2016', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['8537965042', 'HFP5029', 'NY', 'PAS', '5/16/2017', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['8581153938', 'X89HVW', 'NJ', 'PAS', '6/14/2017', '21', '4DSD', 'BMW', '21-No Parking (street clean)']
# ['8236569895', 'EPY9505', 'NY', 'PAS', '3/22/2017', '21', '4DSD', 'BUICK', '21-No Parking (street clean)']
# ['8502707383', 'JGL6885', 'PA', 'PAS', '1/24/2017', '21', 'SUBN', 'BUICK', '21-No Parking (street clean)']
# ['8511711946', '42283JZ', 'NY', 'COM', '4/27/2017', '21', 'VAN', 'CHEVR', '21-No Parking (street clean)']
# ['1418142980', '483TFM', 'TN', 'PAS', '12/19/2016', '21', 'VAN', 'CHEVR', '']
# ['1420029915', '53468JZ', '99', 'COM', '4/27/2017', '21', 'VAN', 'CHEVR', '']
# ['8539666996', '85121ME', 'NY', 'COM', '5/22/2017', '21', 'VAN', 'CHEVR', '21-No Parking (street clean)']
# ['1413709760', 'DGN6881', 'NY', 'PAS', '9/2/2016', '21', 'SDN', 'CHEVR', '']
# ['8473311693', 'DTG6286', 'NY', 'PAS', '11/23/2016', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['7658191050', 'GEL4496', 'NY', 'PAS', '7/22/2016', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['8478626049', 'GRU5176', 'NY', 'PAS', '5/15/2017', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['7369979570', 'GTC5499', 'NY', 'PAS', '7/20/2016', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['1400876217', 'GVB9839', 'NY', 'PAS', '9/19/2016', '21', 'P-U', 'CHEVR', '']
# ['1422284335', 'HHJ5747', 'NY', 'PAS', '6/3/2017', '21', 'SUBN', 'CHEVR', '']
# ['8556051480', 'M322307', 'NJ', 'PAS', '4/26/2017', '21', 'PICK', 'CHEVR', '21-No Parking (street clean)']
# ['8514570973', 'T738567C', 'NY', 'OMT', '6/21/2017', '21', 'SUBN', 'CHEVR', '21-No Parking (street clean)']
# ['8357020770', 'Y56DLT', 'NJ', 'PAS', '1/20/2017', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['8523602306', 'GUG9349', 'NY', 'PAS', '3/25/2017', '21', '4DSD', 'CHRYS', '21-No Parking (street clean)']
# ['1410697290', 'HZ214', 'RI', 'PAS', '7/15/2016', '21', 'SUBN', 'CHRYS', '']
# ['8485267631', '80381MD', 'NY', 'COM', '3/2/2017', '21', 'VAN', 'DODGE', '21-No Parking (street clean)']
# ['7808365737', 'ETN7313', 'NY', 'PAS', '3/22/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8236558708', 'FLC9623', 'NY', 'PAS', '1/23/2017', '21', 'SUBN', 'DODGE', '21-No Parking (street clean)']
# ['8567100082', 'FTY1182', 'NY', 'PAS', '5/3/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8516402034', '88040MH', 'NY', 'COM', '5/26/2017', '21', 'DELV', 'FORD', '21-No Parking (street clean)']
# ['8237524573', 'CMD1897', 'NY', 'PAS', '10/19/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8490203982', 'DBZ7195', 'NY', 'PAS', '12/13/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8140540663', 'EHA1740', 'NY', 'PAS', '10/27/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8539702370', 'FYW7060', 'NY', 'PAS', '3/23/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8151587635', 'GFC5314', 'NY', 'PAS', '11/22/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8536979239', 'GKP5732', 'NY', 'PAS', '4/28/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8277588720', 'GYT3978', 'NY', 'PAS', '11/10/2016', '21', '2DSD', 'FORD', '21-No Parking (street clean)']
# ['8330514596', 'HDK4072', 'NY', 'PAS', '8/23/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8043823078', 'HHF5026', 'NY', 'PAS', '9/6/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8173039823', 'JLN1340', 'PA', 'PAS', '11/16/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8521903650', 'XAGW46', 'NJ', 'PAS', '3/27/2017', '21', 'VAN', 'FORD', '21-No Parking (street clean)']
# ['1420031892', '43601MG', 'NY', 'COM', '5/1/2017', '21', 'VAN', 'FRUEH', '']
# ['8431017041', '76130JH', 'NY', 'COM', '9/16/2016', '21', 'DELV', 'FRUEH', '21-No Parking (street clean)']
# ['8104561698', 'GAV2010', 'NY', 'PAS', '3/7/2017', '21', '4DSD', 'GEO', '21-No Parking (street clean)']
# ['1421330088', '12040MJ', 'NY', 'COM', '6/20/2017', '21', 'SUBN', 'GMC', '']
# ['8463512264', '20410AD', 'NY', 'COM', '10/28/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['8059052214', '36733JX', 'NY', 'COM', '11/14/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['1417865507', '77993JV', 'NY', 'COM', '2/6/2017', '21', 'VAN', 'GMC', '']
# ['7005104110', 'GYG7508', 'NY', 'PAS', '9/1/2016', '21', 'SUBN', 'GMC', '21-No Parking (street clean)']
# ['8077581614', 'XAYF77', 'NJ', 'PAS', '2/27/2017', '21', 'DELV', 'GMC', '21-No Parking (street clean)']
# ['8536832563', '1441', 'WY', 'PAS', '6/6/2017', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['8292013593', '601473', 'NY', 'PAS', '11/9/2016', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['8327066730', '38BR360', 'AL', 'PAS', '2/23/2017', '21', '2DSD', 'HONDA', '21-No Parking (street clean)']
# ['8432517677', '71WC47', 'MA', 'PAS', '11/14/2016', '21', 'SUBN', 'HONDA', '21-No Parking (street clean)']
# ['
'21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8475466254', 'HWN1816', 'TX', 'PAS', '12/27/2016', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8349510500', '84302T', 'VA', 'PAS', '7/8/2016', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8327051209', 'ATE9889', 'NY', 'PAS', '12/20/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['7803990927', 'HCN1049', 'NY', 'PAS', '3/28/2017', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8514726985', 'HKB2413', 'NY', 'PAS', '5/22/2017', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['8360507120', 'OL4468J', 'NJ', 'PAS', '7/26/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['1419707358', 'V97GVE', 'NJ', 'PAS', '2/18/2017', '21', 'SUBN', 'ME/BE', '']
# ['8557255329', 'HFE4369', 'NY', 'PAS', '5/11/2017', '21', 'SUBN', 'MERCU', '21-No Parking (street clean)']
# ['8512671312', '8892CZ', 'CT', 'CMB', '6/6/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['7081940572', 'ATS3775', 'NY', 'PAS', '1/4/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8472183579', 'BNZF31', 'FL', 'PAS', '12/3/2016', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8190539723', 'DKT8358', 'NY', 'PAS', '9/8/2016', '21', '2DSD', 'NISSA', '21-No Parking (street clean)']
# ['1416492320', 'FGR5997', 'NY', 'PAS', '9/30/2016', '21', 'SDN', 'NISSA', '']
# ['8549705664', 'FYW4686', 'NY', 'PAS', '6/3/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['1420512468', 'GJH8815', 'NY', 'PAS', '4/8/2017', '21', 'SUBN', 'NISSA', '']
# ['8551204051', 'GNN9248', 'NY', 'PAS', '5/4/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8344027755', 'GUP8589', 'NY', 'PAS', '12/7/2016', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8539277086', 'GVH4035', 'PA', 'PAS', '5/26/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['1417861800', 'GYM6658', 'NY', 'PAS', '3/7/2017', '21', 'SDN', 'NISSA', '']
# ['7081508339', 'HCF7990', 'NY', 'PAS', '1/30/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8533396259', 'HCL5539', 'NY', 'PAS', '5/26/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8552758799', 'HDB8092', 'NY', 'PAS', '5/18/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8172060956', 'HJY5787', 'NY', 'PAS', '3/24/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8534828313', 'HSC8642', 'NY', 'PAS', '6/16/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['7803991737', 'FSJ1102', 'NY', 'PAS', '3/29/2017', '21', 'SUBN', 'PORSC', '21-No Parking (street clean)']
# ['8532875324', 'HKM6966', 'NY', 'OMS', '6/13/2017', '21', '2DSD', 'SMART', '21-No Parking (street clean)']
# ['7803916818', '2405692', 'PA', 'PAS', '9/30/2016', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8534565030', 'EEH3996', 'NY', 'PAS', '6/22/2017', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8345516518', 'EUX8678', 'NY', 'PAS', '9/27/2016', '21', '4DSD', 'SUBAR', '21-No Parking (street clean)']
# ['8198510771', 'FWP9546', 'NY', 'PAS', '8/30/2016', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8561603562', 'GUM5490', 'NY', 'PAS', '6/8/2017', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['8260034475', 'HNR3840', 'NY', '999', '1/23/2017', '21', '4DSD', 'SUBAR', '21-No Parking (street clean)']
# ['8489005175', '450SEY', 'CT', 'PAS', '12/29/2016', '21', 'SUBN', 'TOYOT', '21-No Parking (street clean)']
# ['8327056311', '809RGE', 'FL', 'PAS', '1/11/2017', '21', 'SUBN', 'TOYOT', '21-No Parking (street clean)']
# ['8035390004', '853NG3', 'MA', 'PAS', '9/29/2016', '21', '4DSD', 'TOYOT', '21-No Parking (street clean)']
# ['8473630373', '923156N', 'NJ', 'PAS', '3/21/2017', '21', 'SUBN', 'TOYOT', '21-No Parking (street clean)']
# ['7431960360', 'ECL2156', 'NY', 'PAS', '7/19/2016', '21', 'SUBN', 'TOYOT', '21-No Parking (street clean)']
# 
# ['1408122029', 'DSN6323', 'NY', 'PAS', '7/4/2016', '24', 'SUBN', 'JEEP', '']
# ['8266568753', 'F12GRE', 'NJ', 'PAS', '11/11/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8446524806', 'GYG8911', 'NY', 'PAS', '12/18/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8316519355', 'HDJ7785', 'PA', 'PAS', '7/14/2016', '24', '2DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8533035640', 'T687600C', 'NY', 'OMT', '5/31/2017', '24', '4DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8526732663', 'ASV2478', 'NY', 'PAS', '6/22/2017', '24', '4DSD', 'TOYOT', '24-No Parking (exc auth veh)']
# ['1410027223', 'ENS9253', 'NY', 'PAS', '10/31/2016', '24', 'SDN', 'VOLKS', '']
# ['8479824712', '58910MG', 'NY', 'COM', '4/21/2017', '26', 'DELV', 'ISUZU', '26-No Stnd (for-hire veh only)']
# ['1416527722', 'AHG9422', 'NY', 'PAS', '1/5/2017', '27', 'SUBN', 'TOYOT', '']
# ['8512270482', 'Y26CRJ', 'NJ', 'PAS', '6/3/2017', '31', 'SUBN', 'BSA', '31-No Stand (Com. Mtr. Zone)']
# ['8498706890', 'THANEDAR', 'NY', 'OMT', '3/22/2017', '31', 'SUBN', 'CADIL', '31-No Stand (Com. Mtr. Zone)']
# ['8328546632', 'HHP7446', 'NY', 'PAS', '12/2/2016', '31', '2DSD', 'CHEVR', '31-No Stand (Com. Mtr. Zone)']
# ['8496254203', 'GMW3411', 'NY', 'PAS', '5/26/2017', '31', 'PICK', 'DODGE', '31-No Stand (Com. Mtr. Zone)']
# ['8552002887', 'GTP5204', 'NY', 'PAS', '4/24/2017', '31', 'PICK', 'DODGE', '31-No Stand (Com. Mtr. Zone)']
# ['8480300255', 'GHG9797', 'NY', 'PAS', '11/18/2016', '31', '4DSD', 'HYUND', '31-No Stand (Com. Mtr. Zone)']
# ['8442517080', 'KCD4692', 'PA', 'PAS', '10/6/2016', '31', '4DSD', 'INFIN', '31-No Stand (Com. Mtr. Zone)']
# ['8482450256', 'GGN8817', 'NY', 'PAS', '11/18/2016', '31', '4DSD', 'LEXUS', '31-No Stand (Com. Mtr. Zone)']
# ['8480624486', '987536N', 'NJ', 'PAS', '6/19/2017', '31', 'SUBN', 'ME/BE', '31-No Stand (Com. Mtr. Zone)']
# ['7059132030', 'HLC5085', 'NY', 'PAS', '2/6/2017', '31', '4DSD', 'NISSA', '31-No Stand (Com. Mtr. Zone)']
# ['8482371824', 'Z317820', 'IL', 'PAS', '4/14/2017', '31', 'SUBN', 'NISSA', '31-No Stand (Com. Mtr. Zone)']
# ['8477906040', 'DUMBO', 'NY', 'SRF', '3/8/2017', '31', 'SUBN', 'ROVER', '31-No Stand (Com. Mtr. Zone)']
# ['8431004010', 'GRZ1934', 'NY', 'PAS', '7/27/2016', '31', 'SUBN', 'VOLVO', '31-No Stand (Com. Mtr. Zone)']
# ['8480331896', '42648MG', 'NY', 'COM', '5/23/2017', '35', 'VAN', 'NS/OT', '35-Selling/Offer Merchandise']
# ['4631704810', 'HCR7297', 'NY', 'PAS', '3/15/2017', '36', '4DSD', 'AUDI', 'PHTO SCHOOL ZN SPEED VIOLATION']
# ['4
# ['8485655590', 'OYA8199', 'NJ', 'PAS', '2/16/2017', '48', 'BUS', 'FORD', '48-Bike Lane']
# ['1420960260', '66604MB', 'NY', 'COM', '5/11/2017', '48', 'VAN', 'GMCQ', '']
# ['8377006390', 'GCR2084', 'NY', 'PAS', '7/19/2016', '48', '4DSD', 'HONDA', '48-Bike Lane']
# ['7577859382', 'GRH9256', 'NY', 'PAS', '12/2/2016', '48', '4DSD', 'HONDA', '48-Bike Lane']
# ['8122530205', '95139JC', 'NY', 'COM', '1/5/2017', '48', 'DELV', 'INTER', '48-Bike Lane']
# ['8254538943', '390HRH', 'OR', 'PAS', '9/2/2016', '50', 'SUBN', 'FORD', '50-Crosswalk']
# ['8518670070', '96170MA', 'NY', 'COM', '6/5/2017', '50', 'VAN', 'FRUEH', '50-Crosswalk']
# ['1410899070', 'GWG5875', 'NY', 'PAS', '11/1/2016', '50', 'SDN', 'HONDA', '']
# ['1413790264', 'JFE0579', 'PA', 'PAS', '9/10/2016', '50', 'SDN', 'HONDA', '']
# ['1414785495', 'FJL6037', 'NY', 'PAS', '8/17/2016', '50', 'SDN', 'HYUND', '']
# ['7809507916', '34719MG', 'NY', 'COM', '12/8/2016', '50', 'DELV', 'INTER', '50-Crosswalk']
# ['7499593060', 'XBYW36', 'NJ', 'PAS', '7/22/2016', '50', 'DELV', 'ISUZU', '50-Crosswalk']
# ['8466021980', 'GSC6098', 'NY', 'PAS', '12/27/2016', '50', '4DSD', 'NISSA', '50-Crosswalk']
# ['8543401689', 'HCP8932', 'NY', 'PAS', '4/18/2017', '50', '4DSD', 'NISSA', '50-Crosswalk']
# ['8162015656', 'GSS803', 'VT', 'PAS', '9/1/2016', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8526919210', 'GZD7447', 'NY', 'PAS', '4/12/2017', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8506053195', '25868MB', 'NY', 'COM', '1/25/2017', '51', 'VAN', 'FORD', '51-Sidewalk']
# ['8520767310', 'GHN6806', 'NY', 'PAS', '5/26/2017', '51', 'SUBN', 'SAAB', '51-Sidewalk']
# ['7079854404', 'T656205C', 'NY', 'OMT', '1/28/2017', '51', '4DSD', 'TOYOT', '51-Sidewalk']
# ['1421055820', 'GAR2279', 'NY', 'PAS', '6/10/2017', '52', 'SDN', 'FORD', '']
# ['7085899554', 'GUZ4334', 'NY', 'PAS', '10/13/2016', '53', 'SUBN', 'ACURA', '53-Safety Zone']
# ['8478553514', 'XCMA58', 'NJ', 'PAS', '12/15/2016', '53', 'DELV', 'HINO', '53-Safety Zone']
# ['8546101425', 'DF932Z', 'NY', 'PAS', '4/10/2017', '53', 'SUBN', 'LEXUS', '53-Safety Zone']
# ['7007488663', 'VFP7291', 'VA', 'PAS', '3/2/2017', '53', '4DSD', 'ME/BE', '53-Safety Zone']
# ['1402409825', '869ZR9', 'MA', '999', '10/15/2016', '53', 'SUBN', 'SATUR', '']
# ['8506603031', '2383103', 'IN', 'PAS', '2/1/2017', '53', 'TRAC', 'VOLVO', '53-Safety Zone']
# ['8480309064', '51771JW', 'NY', 'COM', '1/26/2017', '64', 'VAN', 'INTER', '"64-No STD Ex Con/DPL D/S Dec"']
# ['8162054819', 'EW866X', 'NJ', 'PAS', '1/29/2017', '68', '4DSD', 'NISSA', '68-Not Pkg. Comp. w Psted Sign']
# ['8343032536', '4CMH482', 'CA', 'PAS', '10/3/2016', '68', 'SUBN', 'SUBAR', '68-Not Pkg. Comp. w Psted Sign']
# ['8084034959', 'ASW2109', 'NY', 'PAS', '12/20/2016', '68', '4DSD', 'TOYOT', '68-Not Pkg. Comp. w Psted Sign']
# ['8066506089', '12047JY', 'NY', 'COM', '7/1/2016', '69', 'VAN', 'CHEVR', '69-Failure to Disp Muni Recpt']
# ['8483275156', '57309ME', 'NY', 'COM', '6/7/2017', '69', 'PICK', 'DODGE', '69-Failure to Disp Muni Recpt']
# ['8481256500', '21530JX', 'NY', 'COM', '1/30/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8513914599', '65572JU', 'NY', 'COM', '6/9/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8479417420', 'AT459E', 'NJ', 'PAS', '4/13/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8479216670', 'D705HT', 'TN', 'PAS', '4/11/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8471301842', 'XZ223J', 'NJ', 'PAS', '8/30/2016', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['7268771216', '63383JT', 'NY', 'COM', '7/27/2016', '69', 'VAN', 'GMC', '69-Failure to Disp Muni Recpt']
# ['8476768746', '91599ME', 'NY', 'COM', '4/13/2017', '69', 'REFG', 'HIN', '69-Failure to Disp Muni Recpt']
# ['7868300310', '37033JV', 'NY', 'COM', '11/21/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8077552250', 'AS299T', 'NJ', 'PAS', '10/14/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8116524124', 'XDYD73', 'NJ', 'PAS', '10/6/2016', '69', 'DELV', 'ISUZU', '69-Failure to Disp Muni Recpt']
# ['7393476988', 'GGR9506', 'NY', 'PAS', '7/20/2016', '70', '4DSD', 'AUDI', '70A-Reg. Sticker Expired (NYS)']
# ['8527214490', 'GWG7018', 'NY', 'PAS', '5/16/2017', '70', 'SUBN', 'BMW', '70A-Reg. Sticker Expired (NYS)']
# ['7077031019', 'GNV8363', 'NY', 'PAS', '9/7/2016', '70', 'SUBN', 'CADIL', '70A-Reg. Sticker Expired (NYS)']
# ['8522772708', 'GWH8469', 'NY', 'PAS', '4/20/2017', '70', 'SUBN', 'CHRYS', '70A-Reg. Sticker Expired (NYS)']
# ['8535702763', 'GTE6420', 'NY', 'PAS', '3/24/2017', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['7705894520', 'GYP6735', 'NY', 'OMS', '10/2/2016', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['8535150079', 'HMC7627', 'NY', 'PAS', '3/8/2017', '70', '4DSD', 'HYUND', '70A-Reg. Sticker Expired (NYS)']
# ['8397514636', 'FYW3850', 'NY', 'PAS', '10/22/2016', '74', 'SUBN', 'FORD', '74A-Improperly Displayed Plate']
# ['8528912840', 'HNY5206', 'NY', 'PAS', '4/21/2017', '74', 'SUBN', 'GMC', '74A-Improperly Displayed Plate']
# ['8511501113', 'FBP6836', 'NY', 'PAS', '2/16/2017', '74', 'SUBN', 'HONDA', '74-Missing Display Plate']
# ['8276551890', 'HJR4081', 'NY', 'PAS', '1/7/2017', '74', 'SUBN', 'HONDA', '74A-Improperly Displayed Plate']
# ['8214550531', 'HJY2207', 'NY', 'PAS', '3/9/2017', '74', '4DSD', 'HYUND', '74-Missing Display Plate']
# ['8487469012', '27527ME', 'NY', 'COM', '1/27/2017', '74', 'DELV', 'INTER', '74-Missing Display Plate']
# ['8034780236', 'HCD3158', 'NY', 'PAS', '9/2/2016', '74', 'SUBN', 'KIA', '74A-Improperly Displayed Plate']
# ['8545052455', 'HMK1149', 'NY', 'PAS', '6/7/2017', '74', '4DSD', 'ME/BE', '74-Missing Display Plate']
# ['1411263467', 'BLANKPLATE', '99', '999', '2/13/2017', '74', 'SDN', 'NISSA', '']
# ['8540001550', 'HLA4803', 'NY', 'PAS', '3/23/2017', '74', '4DSD', 'SAAB', '74-Missing Display Plate']
# ['8556155431', 'HFB9919', 'NY', 'PAS', '5/26/2017', '75', '4DSD', 'DODGE', '75-No Match-Plate/Reg. Sticker']
# ['8394016790', '31690BB', 'NY', 'OMR', '9/6/2016', '77', 'BUS', 'AM/T', '77-Parked Bus (exc desig area)']
# ['1419472306', '56090BA', 'NY', 'OMR', '2/20/2017', '77', 'BUS', 'INTER', '']
# ['8363508688', '97256', 'MA', 'APP', '8/13/2016', '77', 'BUS', 'NS/OT', '77-Parked Bus (exc desig area)']
# ['1407740258', '2513JMG', 'NY', 'COM', '1/11/2017', '78', 'DELV', 'FRUEH', '']
# ['8081047670', 'AG84195', 'AZ', 'PAS', '9/1/2016', '78', 'DELV', 'GMC', '78-Nighttime PKG on Res Street']
# ['8357010039', 'ZBK5659', 'PA', 'PAS', '9/16/2016', '78', 'FLAT', 'NS/OT', '78-Nighttime PKG on Res Street']
# ['1408164401', 'GCP8663', 'NY', 'PAS', '9/30/2016', '80', 'SUBN', 'CHEVR', '']
# ['7065087220', '35989MJ', 'NY', 'COM', '8/28/2016', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8472028628', '80921MH', 'NY', 'COM', '1/30/2017', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8413507250', 'XCGT11', 'NJ', 'PAS', '10/18/2016', '82', 'PICK', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8498413898', '2028133', 'IN', 'PAS', '5/24/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8484405837', '2028134', 'IN', 'PAS', '2/15/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8040125108', 'AT985A', 'NJ', 'PAS', '8/29/2016', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8521821979', 'XJX4470', 'PA', 'PAS', '5/18/2017', '84', 'TR/C', 'FRUEH', '84-Platform lifts in low posit']
# ['7662741072', 'XY237D', 'NJ', 'PAS', '8/9/2016', '84', 'DELV', 'HINO', '84-Platform lifts in low posit']
# ['8529157072', '2380604', 'IN', 'PAS', '3/29/2017', '84', 'DELV', 'INTER', '84-Platform lifts in low posit']
# ['8354508808', '21239MG', 'NY', 'COM', '9/9/2016', '84', 'DELV', 'MI/F', '84-Platform lifts in low posit']
# ['1414702700', 'AT785J', 'NJ', 'PAS', '11/27/2016', '85', 'TRAC', 'FRUEH', '']
# ['8466533837', 'XANK50', 'NJ', 'PAS', '4/29/2017', '85', 'DELV', 'HIN', '85-Storage-3 hour Commercial']
# ['8525168063', 'HBN8474', 'NY', 'PAS', '5/30/2017', '91', 'SUBN', 'HONDA', '91-Veh for Sale (Dealer Only)']
# ['1420730010', 'GFW3620', 'NY', 'PAS', '6/10/2017', '98', 'SUBN', 'CHEVR', '']
# ['1414049870', 'EJS4309', 'NY', 'PAS', '8/5/2016', '98', 'SDN', 'NISSA', '']
# ['1420795430', 'HBS5720', 'NY', 'PAS', '4/18/2017', '98', 'SDN', 'NISSA', '']

# %%
data = DataIterator('nyc_parking_tickets_extract.csv')

# %%
for row in data:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-3a8da7bb7a3d> in <module>
# ----> 1 for row in data:
#       2     print(row)
#
# <ipython-input-66-d756f9019840> in __next__(self)
#       8
#       9     def __next__(self):
# ---> 10         row = next(self._f)
#      11         return row.strip('\n').split(',')
#      12
#
# TypeError: 'NoneType' object is not an iterator

# %%
with data as file:
    for line in file:
        print(line)
# Out:
# ['Summons Number', 'Plate ID', 'Registration State', 'Plate Type', 'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make', 'Violation Description']
# ['4006478550', 'VAD7274', 'VA', 'PAS', '10/5/2016', '5', '4D', 'BMW', 'BUS LANE VIOLATION']
# ['4006462396', '22834JK', 'NY', 'COM', '9/30/2016', '5', 'VAN', 'CHEVR', 'BUS LANE VIOLATION']
# ['4007117810', '21791MG', 'NY', 'COM', '4/10/2017', '5', 'VAN', 'DODGE', 'BUS LANE VIOLATION']
# ['4006265037', 'FZX9232', 'NY', 'PAS', '8/23/2016', '5', 'SUBN', 'FORD', 'BUS LANE VIOLATION']
# ['4006535600', 'N203399C', 'NY', 'OMT', '10/19/2016', '5', 'SUBN', 'FORD', 'BUS LANE VIOLATION']
# ['4007156700', '92163MG', 'NY', 'COM', '4/13/2017', '5', 'VAN', 'FRUEH', 'BUS LANE VIOLATION']
# ['4006687989', 'MIQ600', 'SC', 'PAS', '11/21/2016', '5', 'VN', 'HONDA', 'BUS LANE VIOLATION']
# ['4006943052', '2AE3984', 'MD', 'PAS', '2/1/2017', '5', 'SW', 'LINCO', 'BUS LANE VIOLATION']
# ['4007306795', 'HLG4926', 'NY', 'PAS', '5/30/2017', '5', 'SUBN', 'TOYOT', 'BUS LANE VIOLATION']
# ['4007124590', 'T715907C', 'NY', 'OMT', '4/3/2017', '5', 'SUBN', 'TOYOT', 'BUS LANE VIOLATION']
# ['5096061966', 'HRC9475', 'NY', 'PAS', '4/18/2017', '7', 'SUBN', 'CADIL', 'FAILURE TO STOP AT RED LIGHT']
# ['5094070400', 'DYP8042', 'NY', 'PAS', '10/26/2016', '7', 'SUBN', 'CHEVR', 'FAILURE TO STOP AT RED LIGHT']
 'ME/BE', 'FAILURE TO STOP AT RED LIGHT']
# ['5096249300', 'HEM8411', 'NY', 'PAS', '5/1/2017', '7', '4DSD', 'ME/BE', 'FAILURE TO STOP AT RED LIGHT']
# ['5096958772', '165TRX', 'CT', 'PAS', '6/16/2017', '7', '4W', 'MERCU', 'FAILURE TO STOP AT RED LIGHT']
# ['5093703217', 'HFG4313', 'NY', 'PAS', '9/30/2016', '7', '4DSD', 'MITSU', 'FAILURE TO STOP AT RED LIGHT']
# ['5094670736', 'AXU4790', 'NY', 'PAS', '12/11/2016', '7', '4DSD', 'NISSA', 'FAILURE TO STOP AT RED LIGHT']
# ['5094094166', 'CZM4111', 'NY', 'PAS', '10/28/2016', '7', '4DSD', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5096723768', 'EDN2797', 'NY', 'PAS', '6/2/2017', '7', '4DSD', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5093209120', 'FZT5005', 'NY', 'PAS', '8/28/2016', '7', '4DSD', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5092469481', 'GZH7067', 'NY', 'PAS', '7/10/2016', '7', 'SUBN', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5092451658', 'GZH7067', 'NY', 'PAS', '7/8/2016', '7', 'SUBN', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['5095356545', 'GZM8254', 'NY', 'OMS', '2/18/2017', '7', 'SUBN', 'TOYOT', 'FAILURE TO STOP AT RED LIGHT']
# ['8410006650', 'D53AUUN', 'NJ', 'PAS', '10/21/2016', '9', '4DSD', 'LEXUS', '09-Blocking the Box']
# ['8534116519', 'CES6482', 'NY', 'PAS', '6/12/2017', '9', 'SUBN', 'TOYOT', '09-Blocking the Box']
# ['8485674984', 'T713160C', 'NY', 'OMT', '6/13/2017', '9', 'SUBN', 'TOYOT', '09-Blocking the Box']
# ['8556557405', '59622JW', 'NY', 'COM', '6/9/2017', '10', 'VAN', 'FORD', '10-No Stopping']
# ['8071038416', 'AM479F', 'NJ', 'PAS', '7/7/2016', '10', 'DELV', 'FRUEH', '10-No Stopping']
# ['8483087236', '76822MH', 'NY', 'COM', '5/19/2017', '10', 'DELV', 'HIN', '10-No Stopping']
# ['8481125088', '55179ME', 'NY', 'COM', '4/10/2017', '10', 'DELV', 'NS/OT', '10-No Stopping']
# ['8506822300', '55106MB', 'NY', 'COM', '5/31/2017', '10', 'VAN', 'WORKH', '10-No Stopping']
# ['8482331425', '86609MB', 'NY', 'COM', '6/18/2017', '13', 'VAN', 'CHEVR', '13-No Stand (taxi stand)']
# ['8028246722', 'T703619C', 'NY', 'OMT', '9/15/2016', '13', 'SUBN', 'CHEVR', '13-No Stand (taxi stand)']
# ['8378547530', 'FWZ8815', 'NY', 'PAS', '1/11/2017', '14', '2DSD', 'ACURA', '14-No Standing']
# ['8489750210', '6DQT356', 'CA', 'PAS', '11/28/2016', '14', '4DSD', 'AUDI', '14-No Standing']
# ['1410726095', 'DEP4792', 'NC', 'PAS', '7/15/2016', '14', '', 'BMW', '']
# ['8421031235', 'GGA4266', 'NY', 'PAS', '10/18/2016', '14', '4DSD', 'BMW', '14-No Standing']
# ['7730553259', 'DLZ8901', 'NY', 'PAS', '9/26/2016', '14', 'SUBN', 'CHEVR', '14-No Standing']
# ['8498520046', 'HKF6916', 'NY', 'PAS', '4/27/2017', '14', 'SUBN', 'CHEVR', '14-No Standing']
# ['8537807813', 'HNF6718', 'NY', 'PAS', '4/21/2017', '14', 'SUBN', 'CHEVR', '14-No Standing']
# 
# ['1418609274', '8P82H', 'NY', 'OMT', '12/21/2016', '14', 'TAXI', 'NISSA', '']
# ['1417565895', 'HEB8184', 'NY', 'PAS', '2/11/2017', '14', 'SDN', 'NISSA', '']
# ['8155550278', 'W56GSE', 'NJ', 'PAS', '10/22/2016', '14', '4DSD', 'NISSA', '14-No Standing']
# ['7433187960', '2330830', 'ME', 'PAS', '3/6/2017', '14', 'TRLR', 'NS/OT', '14-No Standing']
# ['7645052715', 'FRZ3573', 'NY', 'PAS', '1/7/2017', '14', 'SUBN', 'NS/OT', '14-No Standing']
# ['7922559173', 'XCYU94', 'NJ', 'PAS', '10/24/2016', '14', 'VAN', 'NS/OT', '14-No Standing']
# ['7767415582', 'XW915N', 'NJ', 'PAS', '3/29/2017', '14', 'DELV', 'NS/OT', '14-No Standing']
# ['8524350581', 'HGR5953', 'NY', 'PAS', '2/27/2017', '14', '4DSD', 'OLDSM', '14-No Standing']
# ['7499844705', 'GGT7948', 'NY', 'PAS', '8/22/2016', '14', 'SUBN', 'SUBAR', '14-No Standing']
# ['7150327266', 'HWE6388', 'PA', 'PAS', '8/5/2016', '14', 'SUBN', 'SUBAR', '14-No Standing']
# ['8537603818', 'ASG8770', 'NY', 'PAS', '3/26/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8210533952', 'GST8679', 'NY', 'PAS', '11/21/2016', '14', '2DSD', 'TOYOT', '14-No Standing']
# ['8555462198', 'HKT4222', 'NY', 'PAS', '6/12/2017', '14', 'SUBN', 'TOYOT', '14-No Standing']
# ['1404838156', 'R57AAE', 'NJ', 'PAS', '4/29/2017', '14', 'SUBN', 'TOYOT', '']
# ['8527806162', 'T659832C', 'NY', 'OMT', '6/4/2017', '14', '4DSD', 'TOYOT', '14-No Standing']
# ['8513520615', '77026MG', 'NY', 'COM', '5/31/2017', '14', 'TRAC', 'VOLVO', '14-No Standing']
# ['8251031485', 'HJP5565', 'NY', 'PAS', '10/4/2016', '16', '4DSD', 'CHEVR', '16A-No Std (Com Veh) Non-COM']
# ['7813745231', 'GEL1890', 'NY', 'PAS', '9/19/2016', '16', 'SUBN', 'CHRYS', '16A-No Std (Com Veh) Non-COM']
# ['8444534183', '36598MH', 'NY', 'COM', '11/23/2016', '16', 'VAN', 'DODGE', '16-No Std (Com Veh) Com Plate']
# ['8061037749', 'HFG7121', 'NY', 'PAS', '8/22/2016', '16', 'SUBN', 'DODGE', '16A-No Std (Com Veh) Non-COM']
# ['8250539527', '24745ME', 'NY', 'COM', '11/9/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8308520170', '49033ME', 'NY', 'COM', '7/14/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8504915323', '57011ME', 'NY', 'COM', '4/6/2017', '16', 'SUBN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8339536023', 'XCEG93', 'NJ', 'PAS', '9/15/2016', '16', 'VAN', 'FORD', '16-No Std (Com Veh) Com Plate']
# ['8566405183', 'GJD5585', 'NY', 'PAS', '6/1/2017', '16', '4DSD', 'ME/BE', '16A-No Std (Com Veh) Non-COM']
# ['7051225662', 'N61GZN', 'NJ', 'PAS', '11/25/2016', '16', 'SUBN', 'SATUR', '16A-No Std (Com Veh) Non-COM']
# ['8149510126', 'GTP8988', 'NY', 'PAS', '8/10/2016', '16', '2DSD', 'SMART', '16A-No Std (Com Veh) Non-COM']
# ['7052028463', 'HGM9782', 'NY', 'PAS', '1/30/2017', '16', 'SUBN', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8474913706', 'T674455C', 'NY', 'OMT', '2/8/2017', '16', '4DSD', 'TOYOT', '16A-No Std (Com Veh) Non-COM']
# ['8506607206', '18752MH', 'NY', 'COM', '3/16/2017', '17', 'VAN', 'CHEVR', '17-No Stand (exc auth veh)']
# ['8438519763', '89882JV', 'NY', 'COM', '10/13/2016', '17', 'VAN', 'GMC', '17-No Stand (exc auth veh)']
# ['8551111954', 'GCE9214', 'NY', 'PAS', '6/25/2017', '17', '4DSD', 'HONDA', '17-No Stand (exc auth veh)']
# ['8516654059', 'AP169V', 'NJ', 'PAS', '2/22/2017', '18', 'DELV', 'INTER', '18-No Stand (bus lane)']
# ['1368119141', 'BMLV150', 'ON', 'PAS', '7/16/2016', '19', 'SUBN', 'CHEVR', '']
# ['8528274184', 'EKF9820', 'NY', 'PAS', '5/1/2017', '19', 'SUBN', 'CHEVR', '19-No Stand (bus stop)']
# ['8522350073', '83290MD', 'NY', 'COM', '2/24/2017', '19', 'SUBN', 'DODGE', '19-No Stand (bus stop)']
# ['8070097437', 'T62GJP', 'NJ', 'PAS', '9/18/2016', '19', 'PICK', 'DODGE', '19-No Stand (bus stop)']
# ['8509409523', '35050JU', 'NY', 'COM', '2/24/2017', '19', 'PICK', 'FORD', '19-No Stand (bus stop)']
# ['1413553552', '41126BB', 'NY', 'OMT', '7/28/2016', '19', 'VAN', 'FORD', '']
# ['8514220482', '2588073', 'IN', 'PAS', '5/29/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['8485652319', '0480PRA', 'MN', 'PAS', '1/26/2017', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['7014671406', 'B0951V', 'FL', 'PAS', '9/7/2016', '19', 'DELV', 'FRUEH', '19-No Stand (bus stop)']
# ['1422732710', 'GMK4592', 'NY', 'PAS', '6/19/2017', '19', 'SDN', 'HONDA', '']
# ['7249114220', 'GPP7413', 'NY', 'PAS', '10/8/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['7499990163', 'HKT3209', 'NY', 'PAS', '12/13/2016', '19', 'SUBN', 'HONDA', '19-No Stand (bus stop)']
# ['8491667738', 'JPC4516', 'PA', 'PAS', '3/1/2017', '19', '4DSD', 'INFIN', '19-No Stand (bus stop)']
# ['8302046280', '63444JM', 'NY', 'COM', '1/26/2017', '19', 'VAN', 'INTER', '19-No Stand (bus stop)']
# ['8009901763', '13657MD', 'NY', 'COM', '9/27/2016', '19', 'DELV', 'KENWO', '19-No Stand (bus stop)']
# ['1424024420', 'HPD1970', 'NY', 'PAS', '6/10/2017', '19', 'SDN', 'KIA', '']
# ['8511718990', '50104MH', 'NY', 'COM', '6/9/2017', '19', 'VAN', 'ME/BE', '19-No Stand (bus stop)']
# ['1415429522', '17236MH', 'NY', 'COM', '3/3/2017', '19', 'SUBN', 'MITSU', '']
# ['8357020770', 'Y56DLT', 'NJ', 'PAS', '1/20/2017', '21', '4DSD', 'CHEVR', '21-No Parking (street clean)']
# ['8523602306', 'GUG9349', 'NY', 'PAS', '3/25/2017', '21', '4DSD', 'CHRYS', '21-No Parking (street clean)']
# ['1410697290', 'HZ214', 'RI', 'PAS', '7/15/2016', '21', 'SUBN', 'CHRYS', '']
# ['8485267631', '80381MD', 'NY', 'COM', '3/2/2017', '21', 'VAN', 'DODGE', '21-No Parking (street clean)']
# ['7808365737', 'ETN7313', 'NY', 'PAS', '3/22/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8236558708', 'FLC9623', 'NY', 'PAS', '1/23/2017', '21', 'SUBN', 'DODGE', '21-No Parking (street clean)']
# ['8567100082', 'FTY1182', 'NY', 'PAS', '5/3/2017', '21', '4DSD', 'DODGE', '21-No Parking (street clean)']
# ['8516402034', '88040MH', 'NY', 'COM', '5/26/2017', '21', 'DELV', 'FORD', '21-No Parking (street clean)']
# ['8237524573', 'CMD1897', 'NY', 'PAS', '10/19/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8490203982', 'DBZ7195', 'NY', 'PAS', '12/13/2016', '21', '4DSD', 'FORD', '21-No Parking (street clean)']
# ['8140540663', 'EHA1740', 'NY', 'PAS', '10/27/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8539702370', 'FYW7060', 'NY', 'PAS', '3/23/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8151587635', 'GFC5314', 'NY', 'PAS', '11/22/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8536979239', 'GKP5732', 'NY', 'PAS', '4/28/2017', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8277588720', 'GYT3978', 'NY', 'PAS', '11/10/2016', '21', '2DSD', 'FORD', '21-No Parking (street clean)']
# ['8330514596', 'HDK4072', 'NY', 'PAS', '8/23/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8043823078', 'HHF5026', 'NY', 'PAS', '9/6/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8173039823', 'JLN1340', 'PA', 'PAS', '11/16/2016', '21', 'SUBN', 'FORD', '21-No Parking (street clean)']
# ['8521903650', 'XAGW46', 'NJ', 'PAS', '3/27/2017', '21', 'VAN', 'FORD', '21-No Parking (street clean)']
# ['1420031892', '43601MG', 'NY', 'COM', '5/1/2017', '21', 'VAN', 'FRUEH', '']
# ['8431017041', '76130JH', 'NY', 'COM', '9/16/2016', '21', 'DELV', 'FRUEH', '21-No Parking (street clean)']
# ['8104561698', 'GAV2010', 'NY', 'PAS', '3/7/2017', '21', '4DSD', 'GEO', '21-No Parking (street clean)']
# ['1421330088', '12040MJ', 'NY', 'COM', '6/20/2017', '21', 'SUBN', 'GMC', '']
# ['8463512264', '20410AD', 'NY', 'COM', '10/28/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['8059052214', '36733JX', 'NY', 'COM', '11/14/2016', '21', 'VAN', 'GMC', '21-No Parking (street clean)']
# ['1417865507', '77993JV', 'NY', 'COM', '2/6/2017', '21', 'VAN', 'GMC', '']
# ['7005104110', 'GYG7508', 'NY', 'PAS', '9/1/2016', '21', 'SUBN', 'GMC', '21-No Parking (street clean)']
# ['8077581614', 'XAYF77', 'NJ', 'PAS', '2/27/2017', '21', 'DELV', 'GMC', '21-No Parking (street clean)']
# ['8536832563', '1441', 'WY', 'PAS', '6/6/2017', '21', '4DSD', 'HONDA', '21-No Parking (street clean)']
# ['
'21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8556351920', 'FCN6061', 'NY', 'PAS', '4/28/2017', '21', 'SUBN', 'MAZDA', '21-No Parking (street clean)']
# ['8563702300', 'GUY5928', 'NY', 'PAS', '5/18/2017', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8475466254', 'HWN1816', 'TX', 'PAS', '12/27/2016', '21', '4DSD', 'MAZDA', '21-No Parking (street clean)']
# ['8349510500', '84302T', 'VA', 'PAS', '7/8/2016', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8327051209', 'ATE9889', 'NY', 'PAS', '12/20/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['7803990927', 'HCN1049', 'NY', 'PAS', '3/28/2017', '21', 'SUBN', 'ME/BE', '21-No Parking (street clean)']
# ['8514726985', 'HKB2413', 'NY', 'PAS', '5/22/2017', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['8360507120', 'OL4468J', 'NJ', 'PAS', '7/26/2016', '21', '4DSD', 'ME/BE', '21-No Parking (street clean)']
# ['1419707358', 'V97GVE', 'NJ', 'PAS', '2/18/2017', '21', 'SUBN', 'ME/BE', '']
# ['8557255329', 'HFE4369', 'NY', 'PAS', '5/11/2017', '21', 'SUBN', 'MERCU', '21-No Parking (street clean)']
# ['8512671312', '8892CZ', 'CT', 'CMB', '6/6/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['7081940572', 'ATS3775', 'NY', 'PAS', '1/4/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8472183579', 'BNZF31', 'FL', 'PAS', '12/3/2016', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['8190539723', 'DKT8358', 'NY', 'PAS', '9/8/2016', '21', '2DSD', 'NISSA', '21-No Parking (street clean)']
# ['1416492320', 'FGR5997', 'NY', 'PAS', '9/30/2016', '21', 'SDN', 'NISSA', '']
# ['8549705664', 'FYW4686', 'NY', 'PAS', '6/3/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['1420512468', 'GJH8815', 'NY', 'PAS', '4/8/2017', '21', 'SUBN', 'NISSA', '']
# ['8551204051', 'GNN9248', 'NY', 'PAS', '5/4/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8344027755', 'GUP8589', 'NY', 'PAS', '12/7/2016', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8539277086', 'GVH4035', 'PA', 'PAS', '5/26/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['1417861800', 'GYM6658', 'NY', 'PAS', '3/7/2017', '21', 'SDN', 'NISSA', '']
# ['7081508339', 'HCF7990', 'NY', 'PAS', '1/30/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8533396259', 'HCL5539', 'NY', 'PAS', '5/26/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8552758799', 'HDB8092', 'NY', 'PAS', '5/18/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8172060956', 'HJY5787', 'NY', 'PAS', '3/24/2017', '21', 'SUBN', 'NISSA', '21-No Parking (street clean)']
# ['8534828313', 'HSC8642', 'NY', 'PAS', '6/16/2017', '21', '4DSD', 'NISSA', '21-No Parking (street clean)']
# ['7803991737', 'FSJ1102', 'NY', 'PAS', '3/29/2017', '21', 'SUBN', 'PORSC', '21-No Parking (street clean)']
# ['8532875324', 'HKM6966', 'NY', 'OMS', '6/13/2017', '21', '2DSD', 'SMART', '21-No Parking (street clean)']
# ['7803916818', '2405692', 'PA', 'PAS', '9/30/2016', '21', 'SUBN', 'SUBAR', '21-No Parking (street clean)']
# ['
SD', 'VOLKS', '21-No Parking (street clean)']
# ['8273071844', 'GFM6245', 'NY', 'PAS', '10/20/2016', '21', '4DSD', 'VOLKS', '21-No Parking (street clean)']
# ['8532602563', 'CVU3012', 'NY', 'PAS', '3/23/2017', '21', '4DSD', 'VOLVO', '21-No Parking (street clean)']
# ['8478353227', '34SW77', 'NY', 'MOT', '12/2/2016', '21', 'MCY', 'YAMAH', '21-No Parking (street clean)']
# ['1418425369', 'JYW5248', 'PA', 'PAS', '3/21/2017', '21', 'SDN', '', '']
# ['8361518277', 'HCX7823', 'NY', 'PAS', '10/12/2016', '23', '4DSD', 'HYUND', '23-No Parking (taxi stand)']
# ['8154034347', 'CTX3627', 'NY', 'PAS', '9/6/2016', '24', 'SUBN', 'AUDI', '24-No Parking (exc auth veh)']
# ['7764794314', 'HFP4684', 'NY', 'PAS', '8/5/2016', '24', '4DSD', 'AUDI', '24-No Parking (exc auth veh)']
# ['8544611310', 'GTC4836', 'NY', 'PAS', '6/7/2017', '24', 'SUBN', 'CADIL', '24-No Parking (exc auth veh)']
# ['8566704320', 'L62FLC', 'NJ', 'PAS', '5/17/2017', '24', 'SUBN', 'CHEVR', '24-No Parking (exc auth veh)']
# ['8536961156', 'X92FSM', 'NJ', 'PAS', '3/28/2017', '24', 'SUBN', 'HYUND', '24-No Parking (exc auth veh)']
# ['1408122029', 'DSN6323', 'NY', 'PAS', '7/4/2016', '24', 'SUBN', 'JEEP', '']
# ['8266568753', 'F12GRE', 'NJ', 'PAS', '11/11/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8446524806', 'GYG8911', 'NY', 'PAS', '12/18/2016', '24', 'SUBN', 'JEEP', '24-No Parking (exc auth veh)']
# ['8316519355', 'HDJ7785', 'PA', 'PAS', '7/14/2016', '24', '2DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8533035640', 'T687600C', 'NY', 'OMT', '5/31/2017', '24', '4DSD', 'NISSA', '24-No Parking (exc auth veh)']
# ['8526732663', 'ASV2478', 'NY', 'PAS', '6/22/2017', '24', '4DSD', 'TOYOT', '24-No Parking (exc auth veh)']
# ['1410027223', 'ENS9253', 'NY', 'PAS', '10/31/2016', '24', 'SDN', 'VOLKS', '']
# ['8479824712', '58910MG', 'NY', 'COM', '4/21/2017', '26', 'DELV', 'ISUZU', '26-No Stnd (for-hire veh only)']
# ['1416527722', 'AHG9422', 'NY', 'PAS', '1/5/2017', '27', 'SUBN', 'TOYOT', '']
# ['8512270482', 'Y26CRJ', 'NJ', 'PAS', '6/3/2017', '31', 'SUBN', 'BSA', '31-No Stand (Com. Mtr. Zone)']
# ['8498706890', 'THANEDAR', 'NY', 'OMT', '3/22/2017', '31', 'SUBN', 'CADIL', '31-No Stand (Com. Mtr. Zone)']
# ['8328546632', 'HHP7446', 'NY', 'PAS', '12/2/2016', '31', '2DSD', 'CHEVR', '31-No Stand (Com. Mtr. Zone)']
# ['8496254203', 'GMW3411', 'NY', 'PAS', '5/26/2017', '31', 'PICK', 'DODGE', '31-No Stand (Com. Mtr. Zone)']
# ['8552002887', 'GTP5204', 'NY', 'PAS', '4/24/2017', '31', 'PICK', 'DODGE', '31-No Stand (Com. Mtr. Zone)']
# ['8480300255', 'GHG9797', 'NY', 'PAS', '11/18/2016', '31', '4DSD', 'HYUND', '31-No Stand (Com. Mtr. Zone)']
# ['8162015656', 'GSS803', 'VT', 'PAS', '9/1/2016', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8526919210', 'GZD7447', 'NY', 'PAS', '4/12/2017', '50', '4DSD', 'TOYOT', '50-Crosswalk']
# ['8506053195', '25868MB', 'NY', 'COM', '1/25/2017', '51', 'VAN', 'FORD', '51-Sidewalk']
# ['8520767310', 'GHN6806', 'NY', 'PAS', '5/26/2017', '51', 'SUBN', 'SAAB', '51-Sidewalk']
# ['7079854404', 'T656205C', 'NY', 'OMT', '1/28/2017', '51', '4DSD', 'TOYOT', '51-Sidewalk']
# ['1421055820', 'GAR2279', 'NY', 'PAS', '6/10/2017', '52', 'SDN', 'FORD', '']
# ['7085899554', 'GUZ4334', 'NY', 'PAS', '10/13/2016', '53', 'SUBN', 'ACURA', '53-Safety Zone']
# ['8478553514', 'XCMA58', 'NJ', 'PAS', '12/15/2016', '53', 'DELV', 'HINO', '53-Safety Zone']
# ['8546101425', 'DF932Z', 'NY', 'PAS', '4/10/2017', '53', 'SUBN', 'LEXUS', '53-Safety Zone']
# ['7007488663', 'VFP7291', 'VA', 'PAS', '3/2/2017', '53', '4DSD', 'ME/BE', '53-Safety Zone']
# ['1402409825', '869ZR9', 'MA', '999', '10/15/2016', '53', 'SUBN', 'SATUR', '']
# ['8506603031', '2383103', 'IN', 'PAS', '2/1/2017', '53', 'TRAC', 'VOLVO', '53-Safety Zone']
# ['8480309064', '51771JW', 'NY', 'COM', '1/26/2017', '64', 'VAN', 'INTER', '"64-No STD Ex Con/DPL D/S Dec"']
# ['8162054819', 'EW866X', 'NJ', 'PAS', '1/29/2017', '68', '4DSD', 'NISSA', '68-Not Pkg. Comp. w Psted Sign']
# ['8343032536', '4CMH482', 'CA', 'PAS', '10/3/2016', '68', 'SUBN', 'SUBAR', '68-Not Pkg. Comp. w Psted Sign']
# ['8084034959', 'ASW2109', 'NY', 'PAS', '12/20/2016', '68', '4DSD', 'TOYOT', '68-Not Pkg. Comp. w Psted Sign']
# ['8066506089', '12047JY', 'NY', 'COM', '7/1/2016', '69', 'VAN', 'CHEVR', '69-Failure to Disp Muni Recpt']
# ['8483275156', '57309ME', 'NY', 'COM', '6/7/2017', '69', 'PICK', 'DODGE', '69-Failure to Disp Muni Recpt']
# ['8481256500', '21530JX', 'NY', 'COM', '1/30/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8513914599', '65572JU', 'NY', 'COM', '6/9/2017', '69', 'VAN', 'FORD', '69-Failure to Disp Muni Recpt']
# ['8479417420', 'AT459E', 'NJ', 'PAS', '4/13/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8479216670', 'D705HT', 'TN', 'PAS', '4/11/2017', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['8471301842', 'XZ223J', 'NJ', 'PAS', '8/30/2016', '69', 'DELV', 'FRUEH', '69-Failure to Disp Muni Recpt']
# ['7268771216', '63383JT', 'NY', 'COM', '7/27/2016', '69', 'VAN', 'GMC', '69-Failure to Disp Muni Recpt']
# ['8476768746', '91599ME', 'NY', 'COM', '4/13/2017', '69', 'REFG', 'HIN', '69-Failure to Disp Muni Recpt']
# ['7868300310', '37033JV', 'NY', 'COM', '11/21/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8077552250', 'AS299T', 'NJ', 'PAS', '10/14/2016', '69', 'DELV', 'INTER', '69-Failure to Disp Muni Recpt']
# ['8116524124', 'XDYD73', 'NJ', 'PAS', '10/6/2016', '69', 'DELV', 'ISUZU', '69-Failure to Disp Muni Recpt']
# ['7393476988', 'GGR9506', 'NY', 'PAS', '7/20/2016', '70', '4DSD', 'AUDI', '70A-Reg. Sticker Expired (NYS)']
# ['8527214490', 'GWG7018', 'NY', 'PAS', '5/16/2017', '70', 'SUBN', 'BMW', '70A-Reg. Sticker Expired (NYS)']
# ['7077031019', 'GNV8363', 'NY', 'PAS', '9/7/2016', '70', 'SUBN', 'CADIL', '70A-Reg. Sticker Expired (NYS)']
# ['8522772708', 'GWH8469', 'NY', 'PAS', '4/20/2017', '70', 'SUBN', 'CHRYS', '70A-Reg. Sticker Expired (NYS)']
# ['8535702763', 'GTE6420', 'NY', 'PAS', '3/24/2017', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['7705894520', 'GYP6735', 'NY', 'OMS', '10/2/2016', '70', 'SUBN', 'FORD', '70A-Reg. Sticker Expired (NYS)']
# ['8535150079', 'HMC7627', 'NY', 'PAS', '3/8/2017', '70', '4DSD', 'HYUND', '70A-Reg. Sticker Expired (NYS)']
# ['7541990206', 'HGL9860', 'NY', 'PAS', '2/18/2017', '70', 'SUBN', 'JEEP', '70A-Reg. Sticker Expired (NYS)']
# ['7074250855', 'GBV6820', 'NY', 'PAS', '11/5/2016', '70', 'SUBN', 'ME/BE', '70A-Reg. Sticker Expired (NYS)']
# ['8419012245', 'GVM6317', 'NY', 'PAS', '1/27/2017', '70', '4DSD', 'ME/BE', '70A-Reg. Sticker Expired (NYS)']
# ['8552067018', 'ACS8210', 'NY', 'PAS', '6/23/2017', '70', 'SUBN', 'NISSA', '70A-Reg. Sticker Expired (NYS)']
# ['8490111753', 'GVH9098', 'NY', 'PAS', '1/25/2017', '70', '4DSD', 'NISSA', '70A-Reg. Sticker Expired (NYS)']
# ['1423568710', 'GPG1213', 'NY', 'PAS', '3/19/2017', '70', 'SDN', 'SUBAR', '']
# ['8363531900', 'GTC2970', 'NY', 'PAS', '2/8/2017', '70', '4DSD', 'TOYOT', '70A-Reg. Sticker Expired (NYS)']
# ['8282021635', 'FBD7363', 'NY', 'PAS', '9/10/2016', '71', '4DSD', 'ACURA', '71A-Insp Sticker Expired (NYS)']
# ['8551100002', 'HLA6845', 'NY', 'PAS', '4/5/2017', '71', '4DSD', 'BMW', '71-Insp. Sticker Missing (NYS']
# ['8471891440', '42530MG', 'NY', 'COM', '2/28/2017', '71', 'DELV', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8555150875', 'ETF9022', 'NY', 'PAS', '5/2/2017', '71', 'SUBN', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['8188582906', 'GMT8516', 'NY', 'PAS', '11/1/2016', '71', 'PICK', 'CHEVR', '71A-Insp Sticker Expired (NYS)']
# ['
# ['8540001550', 'HLA4803', 'NY', 'PAS', '3/23/2017', '74', '4DSD', 'SAAB', '74-Missing Display Plate']
# ['8556155431', 'HFB9919', 'NY', 'PAS', '5/26/2017', '75', '4DSD', 'DODGE', '75-No Match-Plate/Reg. Sticker']
# ['8394016790', '31690BB', 'NY', 'OMR', '9/6/2016', '77', 'BUS', 'AM/T', '77-Parked Bus (exc desig area)']
# ['1419472306', '56090BA', 'NY', 'OMR', '2/20/2017', '77', 'BUS', 'INTER', '']
# ['8363508688', '97256', 'MA', 'APP', '8/13/2016', '77', 'BUS', 'NS/OT', '77-Parked Bus (exc desig area)']
# ['1407740258', '2513JMG', 'NY', 'COM', '1/11/2017', '78', 'DELV', 'FRUEH', '']
# ['8081047670', 'AG84195', 'AZ', 'PAS', '9/1/2016', '78', 'DELV', 'GMC', '78-Nighttime PKG on Res Street']
# ['8357010039', 'ZBK5659', 'PA', 'PAS', '9/16/2016', '78', 'FLAT', 'NS/OT', '78-Nighttime PKG on Res Street']
# ['1408164401', 'GCP8663', 'NY', 'PAS', '9/30/2016', '80', 'SUBN', 'CHEVR', '']
# ['7065087220', '35989MJ', 'NY', 'COM', '8/28/2016', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8472028628', '80921MH', 'NY', 'COM', '1/30/2017', '82', 'VAN', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8413507250', 'XCGT11', 'NJ', 'PAS', '10/18/2016', '82', 'PICK', 'CHEVR', '82-Unaltered Commerc Vehicle']
# ['8498413898', '2028133', 'IN', 'PAS', '5/24/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8484405837', '2028134', 'IN', 'PAS', '2/15/2017', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8040125108', 'AT985A', 'NJ', 'PAS', '8/29/2016', '84', 'DELV', 'FRUEH', '84-Platform lifts in low posit']
# ['8521821979', 'XJX4470', 'PA', 'PAS', '5/18/2017', '84', 'TR/C', 'FRUEH', '84-Platform lifts in low posit']
# ['7662741072', 'XY237D', 'NJ', 'PAS', '8/9/2016', '84', 'DELV', 'HINO', '84-Platform lifts in low posit']
# ['8529157072', '2380604', 'IN', 'PAS', '3/29/2017', '84', 'DELV', 'INTER', '84-Platform lifts in low posit']
# ['8354508808', '21239MG', 'NY', 'COM', '9/9/2016', '84', 'DELV', 'MI/F', '84-Platform lifts in low posit']
# ['1414702700', 'AT785J', 'NJ', 'PAS', '11/27/2016', '85', 'TRAC', 'FRUEH', '']
# ['8466533837', 'XANK50', 'NJ', 'PAS', '4/29/2017', '85', 'DELV', 'HIN', '85-Storage-3 hour Commercial']
# ['8525168063', 'HBN8474', 'NY', 'PAS', '5/30/2017', '91', 'SUBN', 'HONDA', '91-Veh for Sale (Dealer Only)']
# ['1420730010', 'GFW3620', 'NY', 'PAS', '6/10/2017', '98', 'SUBN', 'CHEVR', '']
# ['1414049870', 'EJS4309', 'NY', 'PAS', '8/5/2016', '98', 'SDN', 'NISSA', '']
# ['1420795430', 'HBS5720', 'NY', 'PAS', '4/18/2017', '98', 'SDN', 'NISSA', '']

# %% [markdown]
# #### Additional Uses

# %%
import decimal

# %%
decimal.getcontext()
# Out:
# Context(prec=28, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])

# %%
decimal.getcontext().prec = 14

# %%
decimal.getcontext()
# Out:
# Context(prec=14, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])

# %%
decimal.getcontext().prec = 28

# %%
decimal.getcontext().prec = 28
old_prec = decimal.getcontext().prec
decimal.getcontext().prec = 4
print(decimal.Decimal(1)/decimal.Decimal(3))
decimal.getcontext().prec = old_prec
print(decimal.Decimal(1)/decimal.Decimal(3))
# Out:
# 0.3333
# 0.3333333333333333333333333333

# %%
class precision:
    def __init__(self, prec):
        self.prec = prec
        self.current_prec = decimal.getcontext().prec
        
    def __enter__(self):
        decimal.getcontext().prec = self.prec
    
    def __exit__(self, type_, value, tb):
        decimal.getcontext().prec = self.current_prec
        return False

# %%
with precision(3):
    print(decimal.Decimal(1)/decimal.Decimal(3))
    
print(decimal.Decimal(1)/decimal.Decimal(3))
# Out:
# 0.333
# 0.3333333333333333333333333333

# %%
with decimal.localcontext() as ctx:
    ctx.prec = 3
    print(decimal.Decimal(1)/decimal.Decimal(3))
print(decimal.Decimal(1)/decimal.Decimal(3))
# Out:
# 0.333
# 0.3333333333333333333333333333

# %%
from time import perf_counter, sleep

# %%
class Timer:
    def __init__(self):
        self.elapsed = 0
        
    def __enter__(self):
        self.start = perf_counter()
        return self
        
    def __exit__(self, type_, value, tb):
        self.stop = perf_counter()
        self.elapsed = self.stop - self.start
        return False

# %%
with Timer() as timer:
    sleep(1)
    
print(timer.elapsed)
# Out:
# 1.000596633002715

# %%
import sys

class OutToFile:
    def __init__(self, fname):
        self._fname = fname
        self._current_stdout = sys.stdout
        
    def __enter__(self):
        self._file = open(self._fname, "w")
        sys.stdout = self._file
        
    def __exit__(self, type_, value, tb):        
        sys.stdout = self._current_stdout
        self._file.close()
        return False

# %%
with OutToFile('test.txt'):
    print("Line 1")
    print("Line 2")
    file = sys.stdout

# %%
print("line 1")
# Out:
# line 1

# %%
with open('test.txt') as f:
    for line in f:
        print(line)
# Out:
# Line 1
#
# Line 2

# %%
file
# Out:
# <_io.TextIOWrapper name='test.txt' mode='w' encoding='cp1252'>

# %%
class Tag:
    def __init__(self, tag):
        self._tag = tag
        
    def __enter__(self):
        print(f"<{self._tag}>", end="")
        
    def __exit__(self, type_, value, tb):
        print(f"</{self._tag}>", end="")
        return False

# %%
with Tag('p'):
    print("some ", end='')
    with Tag('b'):
        print('bold', end='')
    print(' text', end='')
# Out:
# <p>some <b>bold</b> text</p>

# %%
class Tag:
    def __init__(self, tag):
        self._tag = tag
        
    def __enter__(self):
        print(f"<{self._tag}>", end="")
        
    def __exit__(self, type_, value, tb):
        print(f"</{self._tag}>", end="")
        return False

# %%
class ListMaker:
    def __init__(self, title, prefix='- ', indent=3):
        self._title = title
        self._prefix = prefix
        self._indent = indent
        self._current_indent = 0
        print(title)
        
    def __enter__(self):
        self._current_indent += self._indent
        return self
    
    def __exit__(self, type_, value, tb):
        self._current_indent -= self._indent
        return False
    
    def print(self, arg):
        line = ' ' * self._current_indent + self._prefix + str(arg)
        print(line)

# %%
with ListMaker('Items') as lm:
    lm.print("Item 1")
    with lm:
        lm.print("Sub item 1a")
        lm.print("Sub item 1b")
    lm.print("Item 2")
    with lm:
        lm.print("Sub item 2a")
        lm.print("Sub item 2b")
        
lm.print("Items")
# Out:
# Items
#    - Item 1
#       - Sub item 1a
#       - Sub item 1b
#    - Item 2
#       - Sub item 2a
#       - Sub item 2b
# - Items

# %%
with OutToFile('mylst.txt'):
    with ListMaker('Items') as lm:
        lm.print("Item 1")
    with lm:
        lm.print("Sub item 1a")
        lm.print("Sub item 1b")
    lm.print("Item 2")
    with lm:
        lm.print("Sub item 2a")
        lm.print("Sub item 2b")

# %%
with open('mylst.txt') as f:
    for row in f:
        print(row)
# Out:
# Items
#
#    - Item 1
#
#    - Sub item 1a
#
#    - Sub item 1b
#
# - Item 2
#
#    - Sub item 2a
#
#    - Sub item 2b

# %% [markdown]
# ##### Generators and Context Managers

# %%
def my_gen():
    try:
        print("Creating context and yielding object")
        yield [1, 2, 3, 4]
    finally:
        print("exiting context and cleaning up")

# %%
gen = my_gen()

# %%
lst = next(gen)
# Out:
# Creating context and yielding object

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
next(gen)
# Out:
# exiting context and cleaning up
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-137-6e72e47198db> in <module>
# ----> 1 next(gen)
#
# StopIteration:

# %%
gen = my_gen()
lst = next(gen)
print(lst)
try:
    next(gen)
except StopIteration:
    pass
# Out:
# Creating context and yielding object
# [1, 2, 3, 4]
# exiting context and cleaning up

# %%
class GenCtxManager:
    def __init__(self, gen_func):
        self._gen = gen_func()
        
    def __enter__(self):
        f = next(self._gen)
        return f
    
    def __exit__(self, type_, value, tb):
        try:
            next(self._gen)
        except StopIteration:
            pass
        return False

# %%
def my_gen():
    try:
        print("Creating context and yielding object")
        yield [1, 2, 3, 4]
    finally:
        print("exiting context and cleaning up")

# %%
with GenCtxManager(my_gen) as obj:
    print(obj)
# Out:
# Creating context and yielding object
# [1, 2, 3, 4]
# exiting context and cleaning up

# %%
class GenCtxManager:
    def __init__(self, gen_func, *args, **kwargs):
        self._gen = gen_func(*args, **kwargs)
        
    def __enter__(self):
        f = next(self._gen)
        return f
    
    def __exit__(self, type_, value, tb):
        try:
            next(self._gen)
        except StopIteration:
            pass
        return False

# %%
def open_file(fname, mode):
    f = open(fname, mode)
    try:
        print('opened file')
        yield f
    finally:
        f.close()
        print('closed file')

# %%
with GenCtxManager(open_file, 'test.txt', 'w') as f:
    f.writelines("testing")
# Out:
# opened file
# closed file

# %%
with GenCtxManager(open_file, 'test.txt', 'r') as f:
    print(f.readlines())
# Out:
# opened file
# ['testing']
# closed file

# %% [markdown]
# #### Context Manager Decorator

# %%
def open_file(fname, mode='r'):
    print('opening file...')
    f = open(fname, mode)
    try:
        yield f
    finally:
        print('closing file...')
        f.close()

# %%
class GenContextManager:
    def __init__(self, gen):
        self.gen = gen
    
    def __enter__(self):
        print("calling next to get the yielded value from generator")
        return next(self.gen)
    
    def __exit__(self, type_, value, tb):
        print('calling next to perform clean up in generator')
        try:
            next(self.gen)
        except StopIteration:
            pass
        return False

# %%
file_gen = open_file('test.txt', "w")
with GenContextManager(file_gen) as f:
    f.writelines("Sir Spamalot")
# Out:
# calling next to get the yielded value from generator
# opening file...
# calling next to perform clean up in generator
# closing file...

# %%
def context_manager_decarator(gen_fn):
    def helper(*args, **kwargs):
        gen = gen_fn(*args, **kwargs)
        ctx = GenContextManager(gen)
        return ctx
    return helper

# %%
@context_manager_decarator
def open_file(fname, mode='r'):
    print('opening file...')
    f = open(fname, mode)
    try:
        yield f
    finally:
        print('closing file...')
        f.close()

# %%
with open_file('test.txt', 'w') as f:
    f.writelines("Line 1")
# Out:
# calling next to get the yielded value from generator
# opening file...
# calling next to perform clean up in generator
# closing file...

# %%
with open_file('test.txt', 'r') as f:
    print(f.readlines())
# Out:
# calling next to get the yielded value from generator
# opening file...
# ['Line 1']
# calling next to perform clean up in generator
# closing file...

# %%
with open_file('test.txt') as f:
    print(f.readlines())
# Out:
# calling next to get the yielded value from generator
# opening file...
# ['Line 1']
# calling next to perform clean up in generator
# closing file...

# %%
from contextlib import contextmanager

# %%
@contextmanager
def open_file(fname, mode='r'):
    print('opening file...')
    f = open(fname, mode)
    try:
        yield f
    finally:
        print('closing file...')
        f.close()

# %%
with open_file('test.txt', 'r') as f:
    print(f.readlines())
# Out:
# opening file...
# ['Line 1']
# closing file...

# %%
from time import perf_counter, sleep

# %%
@contextmanager
def timer():
    stats = dict()
    start = perf_counter()
    stats['start'] = start
    try:
        yield stats
    finally:
        stop = perf_counter()
        stats['stop'] = stop
        stats['elapsed'] = stop - start

# %%
with timer() as stats:
    sleep(2)

# %%
print(stats)
# Out:
# {'start': 37102.56978045, 'stop': 37104.569956718, 'elapsed': 2.0001762679967214}

# %%
import sys

# %%
@contextmanager
def out_to_file(fname):
    current = sys.stdout
    file = open(fname, 'w')
    sys.stdout = file
    try:
        yield None
    finally:
        file.close()
        sys.stdout = current

# %%
with out_to_file('test.txt'):
    print('line 1')
    print('line 2')

# %%
print('hello')
# Out:
# hello

# %%
with open('test.txt') as f:
    print(f.readlines())
# Out:
# ['line 1\n', 'line 2\n']

# %%
from contextlib import redirect_stdout

# %%
with open('test.txt', 'w') as f:
    with redirect_stdout(f):
        print('Look on the bright side of the life')

# %%
with open('test.txt') as f:
    print(f.readlines())
# Out:
# ['Look on the bright side of the life\n']

# %% [markdown]
# #### Nested Context Managers

# %%
with open('file1.txt') as f:
    for row in f:
        print(row, end="")
print("\n-------------------------")
with open('file2.txt') as f:
    for row in f:
        print(row, end="")
print("\n-------------------------")
with open('file3.txt') as f:
    for row in f:
        print(row, end="")
# Out:
# file1_line1
# file1_line2
# file1_line3
# -------------------------
# file2_line1
# file2_line2
# file2_line3
# -------------------------
# file3_line1
# file3_line2
# file3_line3

# %%
with open('file1.txt') as f1, open('file2.txt') as f2, open('file3.txt') as f3:
    print(f1.readlines())
    print(f2.readlines())    
    print(f3.readlines())
# Out:
# ['file1_line1\n', 'file1_line2\n', 'file1_line3']
# ['file2_line1\n', 'file2_line2\n', 'file2_line3']
# ['file3_line1\n', 'file3_line2\n', 'file3_line3']

# %%
with open('file1.txt') as f1:
    with open('file2.txt') as f2:
        with open('file3.txt') as f3:
            print(f1.readlines())
            print(f2.readlines())   
            print(f3.readlines())
# Out:
# ['file1_line1\n', 'file1_line2\n', 'file1_line3']
# ['file2_line1\n', 'file2_line2\n', 'file2_line3']
# ['file3_line1\n', 'file3_line2\n', 'file3_line3']

# %%
from contextlib import contextmanager

# %%
@contextmanager
def open_file(fname):
    print(f"opening {fname}")
    f = open(fname)
    try:
        yield f
    finally:
        print(f"closing{fname}")
        f.close()

# %%
f_names = 'file1.txt', 'file2.txt', 'file3.txt'
exits = []
enters = []

for fname in f_names:
    ctx = open_file(fname)
    enters.append(ctx.__enter__)
    exits.append(ctx.__exit__)

# %%
files = [enter() for enter in enters]
# Out:
# opening file1.txt
# opening file2.txt
# opening file3.txt

# %%
while True:
    try:
        rows = [next(f).strip() for f in files]
    except StopIteration:
        break
    else:
        row = ','.join(rows)
        print(row)
# Out:
# file1_line1,file2_line1,file3_line1
# file1_line2,file2_line2,file3_line2
# file1_line3,file2_line3,file3_line3

# %%
for exit in exits[::-1]:
    exit(None, None, None)
# Out:
# closingfile3.txt
# closingfile2.txt
# closingfile1.txt

# %%
f_names = 'file1.txt', 'file2.txt', 'file3.txt'

# creating context managers
exits = []
enters = []

for fname in f_names:
    ctx = open_file(fname)
    enters.append(ctx.__enter__)
    exits.append(ctx.__exit__)
    
# entering context managers
files = [enter() for enter in enters]

# do work
while True:
    try:
        rows = [next(f).strip() for f in files]
    except StopIteration:
        break
    else:
        row = ','.join(rows)
        print(row)
        
for exit in exits[::-1]:
    exit(None, None, None)
# Out:
# opening file1.txt
# opening file2.txt
# opening file3.txt
# file1_line1,file2_line1,file3_line1
# file1_line2,file2_line2,file3_line2
# file1_line3,file2_line3,file3_line3
# closingfile3.txt
# closingfile2.txt
# closingfile1.txt

# %%
class NestedContexts:
    def __init__(self, *contexts):
        self._enters = []
        self._exits = []
        self._values = []
        
        for ctx in contexts:
            self._enters.append(ctx.__enter__)
            self._exits.append(ctx.__exit__)
            
    def __enter__(self):
        for enter in self._enters:
            self._values.append(enter())
        return self._values
        
    def __exit__(self, type_, value, tb):
        for exit in self._exits[::-1]:
            exit(type_, value, tb)
        return False

# %%
@contextmanager
def open_file(fname):
    print(f"opening {fname}")
    f = open(fname)
    try:
        yield f
    finally:
        print(f"closing{fname}")
        f.close()

# %%
with NestedContexts(open_file('file1.txt'),
                    open_file('file2.txt'),
                    open_file('file3.txt')) as files:
    while True:
        try:
            rows = [next(f).strip() for f in files]
        except StopIteration:
            break
        else:
            row = ','.join(rows)
            print(row)
# Out:
# opening file1.txt
# opening file2.txt
# opening file3.txt
# file1_line1,file2_line1,file3_line1
# file1_line2,file2_line2,file3_line2
# file1_line3,file2_line3,file3_line3
# closingfile3.txt
# closingfile2.txt
# closingfile1.txt

# %%
f_names = 'file1.txt', 'file2.txt', 'file3.txt'

contexts = [open_file(fname) for fname in f_names]

with NestedContexts(*contexts) as files:
    print('do work')
# Out:
# opening file1.txt
# opening file2.txt
# opening file3.txt
# do work
# closingfile3.txt
# closingfile2.txt
# closingfile1.txt

# %%
class NestedContexts:
    def __init__(self, *contexts):
        self._exits = []
            
    def __enter__(self):
        return self
    
    def enter_context(self, ctx):
        self._exits.append(ctx.__exit__)
        value = ctx.__enter__()
        return value
    
    def __exit__(self, type_, value, tb):
        for exit in self._exits[::-1]:
            exit(type_, value, tb)
        return False

# %%
f_names = 'file1.txt', 'file2.txt', 'file3.txt'

with NestedContexts() as stack:
    files = [stack.enter_context(open_file(f)) for f in f_names]
    
    # do work
    print("do work")
# Out:
# opening file1.txt
# opening file2.txt
# opening file3.txt
# do work
# closingfile3.txt
# closingfile2.txt
# closingfile1.txt

# %%
from contextlib import ExitStack

# %%
f_names = 'file1.txt', 'file2.txt', 'file3.txt'

with ExitStack() as stack:
    files = [stack.enter_context(open(f)) for f in f_names]
    
    # do work
    while True:
        try:
            rows = [next(f).strip() for f in files]
        except StopIteration:
            break
        else:
            row = ','.join(rows)
            print(row)
# Out:
# file1_line1,file2_line1,file3_line1
# file1_line2,file2_line2,file3_line2
# file1_line3,file2_line3,file3_line3

# %% [markdown]
# #### Project 5

# %% [markdown]
# ### Goal 1

# %%
from collections import namedtuple
import csv

CARS_FILE = 'cars.csv'
PERSONAL_INFO_FILE = 'personal_info.csv'
    
class FileParser:
    def __init__(self, fname):
        self._fname = fname
        self.delimiter = CSVContextManager.find_dialect(self._fname) 
        
    @staticmethod
    def find_dialect(csv_file):
        with open(csv_file, newline='') as csvfile:
            return csv.Sniffer().sniff(csvfile.read(1000)).delimiter
        
    def __enter__(self):
        self.file = open(self._fname)
        headers = [s.lower() for s in next(self.file).strip().split(self.delimiter)]
        self.InfoTuple = namedtuple('InfoTuple', headers)
        return self
    
    def __exit__(self, type_, value, trace):
        self.file.close()
        return False
        
    def __iter__(self):
        return self
    
    def __next__(self):
        if self.file.closed:
            raise StopIteration
            
        values = next(self.file).strip().split(self.delimiter)
        return self.InfoTuple(*values)

# %%
with FileParser('cars.csv') as cars:
    for car in cars:
        print(car)
# Out:
# InfoTuple(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# InfoTuple(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# InfoTuple(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# InfoTuple(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# InfoTuple(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# InfoTuple(car='Ford Galaxie 500', mpg='15.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4341.', acceleration='10.0', model='70', origin='US')
# InfoTuple(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='454.0', horsepower='220.0', weight='4354.', acceleration='9.0', model='70', origin='US')
# InfoTuple(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4312.', acceleration='8.5', model='70', origin='US')
# InfoTuple(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4425.', acceleration='10.0', model='70', origin='US')
# InfoTuple(car='AMC Ambassador DPL', mpg='15.0', cylinders='8', displacement='390.0', horsepower='190.0', weight='3850.', acceleration='8.5', model='70', origin='US')
# InfoTuple(car='Citroen DS-21 Pallas', mpg='0', cylinders='4', displacement='133.0', horsepower='115.0', weight='3090.', acceleration='17.5', model='70', origin='Europe')
# InfoTuple(car='Chevrolet Chevelle Concours (sw)', mpg='0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4142.', acceleration='11.5', model='70', origin='US')
# InfoTuple(car='Ford Torino (sw)', mpg='0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4034.', acceleration='11.0', model='70', origin='US')
# InfoTuple(car='Plymouth Satellite (sw)', mpg='0', cylinders='8', displacement='383.0', horsepower='175.0', weight='4166.', acceleration='10.5', model='70', origin='US')
# InfoTuple(car='AMC Rebel SST (sw)', mpg='0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3850.', acceleration='11.0', model='70', origin='US')
# InfoTuple(car='Dodge Challenger SE', mpg='15.0', cylinders='8', displacement='383.0', horsepower='170.0', weight='3563.', acceleration='10.0', model='70', origin='US')
# InfoTuple(car="Plymouth 'Cuda 340", mpg='14.0', cylinders='8', displacement='340.0', horsepower='160.0', weight='3609.', acceleration='8.0', model='70', origin='US')
# InfoTuple(car='Ford Mustang Boss 302', mpg='0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3353.', acceleration='8.0', model='70', origin='US')
# InfoTuple(car='Chevrolet Monte Carlo', mpg='15.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='3761.', acceleration='9.5', model='70', origin='US')
# InfoTuple(car='Buick Estate Wagon (sw)', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='3086.', acceleration='10.0', model='70', origin='US')
# InfoTuple(car='Toyota Corolla Mark ii', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2372.', acceleration='15.0', model='70', origin='Japan')
# InfoTuple(car='Plymouth Duster', mpg='22.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2833.', acceleration='15.5', model='70', origin='US')
# InfoTuple(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='199.0', horsepower='97.00', weight='2774.', acceleration='15.5', model='70', origin='US')
# InfoTuple(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='85.00', weight='2587.', acceleration='16.0', model='70', origin='US')
# InfoTuple(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='70', origin='Japan')
# InfoTuple(car='Volkswagen 1131 Deluxe Sedan', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1835.', acceleration='20.5', model='70', origin='Europe')
# InfoTuple(car='Peugeot 504', mpg='25.0', cylinders='4', displacement='110.0', horsepower='87.00', weight='2672.', acceleration='17.5', model='70', origin='Europe')
# InfoTuple(car='Audi 100 LS', mpg='24.0', cylinders='4', displacement='107.0', horsepower='90.00', weight='2430.', acceleration='14.5', model='70', origin='Europe')
# InfoTuple(car='Saab 99e', mpg='25.0', cylinders='4', displacement='104.0', horsepower='95.00', weight='2375.', acceleration='17.5', model='70', origin='Europe')
# InfoTuple(car='BMW 2002', mpg='26.0', cylinders='4', displacement='121.0', horsepower='113.0', weight='2234.', acceleration='12.5', model='70', origin='Europe')
# InfoTuple(car='AMC Gremlin', mpg='21.0', cylinders='6', displacement='199.0', horsepower='90.00', weight='2648.', acceleration='15.0', model='70', origin='US')
# InfoTuple(car='Ford F250', mpg='10.0', cylinders='8', displacement='360.0', horsepower='215.0', weight='4615.', acceleration='14.0', model='70', origin='US')
# InfoTuple(car='Chevy C20', mpg='10.0', cylinders='8', displacement='307.0', horsepower='200.0', weight='4376.', acceleration='15.0', model='70', origin='US')
# InfoTuple(car='Dodge D200', mpg='11.0', cylinders='8', displacement='318.0', horsepower='210.0', weight='4382.', acceleration='13.5', model='70', origin='US')
# InfoTuple(car='Hi 1200D', mpg='9.0', cylinders='8', displacement='304.0', horsepower='193.0', weight='4732.', acceleration='18.5', model='70', origin='US')
# InfoTuple(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='71', origin='Japan')
# InfoTuple(car='Chevrolet Vega 2300', mpg='28.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2264.', acceleration='15.5', model='71', origin='US')
# InfoTuple(car='Toyota Corolla', mpg='25.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2228.', acceleration='14.0', model='71', origin='Japan')
# InfoTuple(car='Ford Pinto', mpg='25.0', cylinders='4', displacement='98.00', horsepower='0', weight='2046.', acceleration='19.0', model='71', origin='US')
# InfoTuple(car='Volkswagen Super Beetle 117', mpg='0', cylinders='4', displacement='97.00', horsepower='48.00', weight='1978.', acceleration='20.0', model='71', origin='Europe')
# InfoTuple(car='AMC Gremlin', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2634.', acceleration='13.0', model='71', origin='US')
# InfoTuple(car='Plymouth Satellite Custom', mpg='16.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3439.', acceleration='15.5', model='71', origin='US')
# InfoTuple(car='Chevrolet Chevelle Malibu', mpg='17.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3329.', acceleration='15.5', model='71', origin='US')
# InfoTuple(car='Ford Torino 500', mpg='19.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3302.', acceleration='15.5', model='71', origin='US')
# InfoTuple(car='AMC Matador', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='3288.', acceleration='15.5', model='71', origin='US')
# InfoTuple(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4209.', acceleration='12.0', model='71', origin='US')
# InfoTuple(car='Pontiac Catalina Brougham', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4464.', acceleration='11.5', model='71', origin='US')
# InfoTuple(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4154.', acceleration='13.5', model='71', origin='US')
# InfoTuple(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4096.', acceleration='13.0', model='71', origin='US')
# InfoTuple(car='Dodge Monaco (sw)', mpg='12.0', cylinders='8', displacement='383.0', horsepower='180.0', weight='4955.', acceleration='11.5', model='71', origin='US')
# InfoTuple(car='Ford Country Squire (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4746.', acceleration='12.0', model='71', origin='US')
# InfoTuple(car='Pontiac Safari (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='5140.', acceleration='12.0', model='71', origin='US')
# InfoTuple(car='AMC Hornet Sportabout (sw)', mpg='18.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='2962.', acceleration='13.5', model='71', origin='US')
# InfoTuple(car='Chevrolet Vega (sw)', mpg='22.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2408.', acceleration='19.0', model='71', origin='US')
# InfoTuple(car='Pontiac Firebird', mpg='19.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3282.', acceleration='15.0', model='71', origin='US')
# InfoTuple(car='Ford Mustang', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3139.', acceleration='14.5', model='71', origin='US')
# InfoTuple(car='Mercury Capri 2000', mpg='23.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2220.', acceleration='14.0', model='71', origin='US')
# InfoTuple(car='Opel 1900', mpg='28.0', cylinders='4', displacement='116.0', horsepower='90.00', weight='2123.', acceleration='14.0', model='71', origin='Europe')
# InfoTuple(car='Peugeot 304', mpg='30.0', cylinders='4', displacement='79.00', horsepower='70.00', weight='2074.', acceleration='19.5', model='71', origin='Europe')
# InfoTuple(car='Fiat 124B', mpg='30.0', cylinders='4', displacement='88.00', horsepower='76.00', weight='2065.', acceleration='14.5', model='71', origin='Europe')
# InfoTuple(car='Toyota Corolla 1200', mpg='31.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1773.', acceleration='19.0', model='71', origin='Japan')
# InfoTuple(car='Datsun 1200', mpg='35.0', cylinders='4', displacement='72.00', horsepower='69.00', weight='1613.', acceleration='18.0', model='71', origin='Japan')
# InfoTuple(car='Volkswagen Model 111', mpg='27.0', cylinders='4', displacement='97.00', horsepower='60.00', weight='1834.', acceleration='19.0', model='71', origin='Europe')
# InfoTuple(car='Plymouth Cricket', mpg='26.0', cylinders='4', displacement='91.00', horsepower='70.00', weight='1955.', acceleration='20.5', model='71', origin='US')
# InfoTuple(car='Toyota Corolla Hardtop', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2278.', acceleration='15.5', model='72', origin='Japan')
# InfoTuple(car='Dodge Colt Hardtop', mpg='25.0', cylinders='4', displacement='97.50', horsepower='80.00', weight='2126.', acceleration='17.0', model='72', origin='US')
# InfoTuple(car='Volkswagen Type 3', mpg='23.0', cylinders='4', displacement='97.00', horsepower='54.00', weight='2254.', acceleration='23.5', model='72', origin='Europe')
# InfoTuple(car='Chevrolet Vega', mpg='20.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2408.', acceleration='19.5', model='72', origin='US')
# InfoTuple(car='Ford Pinto Runabout', mpg='21.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2226.', acceleration='16.5', model='72', origin='US')
# InfoTuple(car='Chevrolet Impala', mpg='13.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4274.', acceleration='12.0', model='72', origin='US')
# InfoTuple(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4385.', acceleration='12.0', model='72', origin='US')
# InfoTuple(car='Plymouth Fury III', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4135.', acceleration='13.5', model='72', origin='US')
# InfoTuple(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4129.', acceleration='13.0', model='72', origin='US')
# InfoTuple(car='AMC Ambassador SST', mpg='17.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='72', origin='US')
# InfoTuple(car='Mercury Marquis', mpg='11.0', cylinders='8', displacement='429.0', horsepower='208.0', weight='4633.', acceleration='11.0', model='72', origin='US')
# InfoTuple(car='Buick LeSabre Custom', mpg='13.0', cylinders='8', displacement='350.0', horsepower='155.0', weight='4502.', acceleration='13.5', model='72', origin='US')
# InfoTuple(car='Oldsmobile Delta 88 Royale', mpg='12.0', cylinders='8', displacement='350.0', horsepower='160.0', weight='4456.', acceleration='13.5', model='72', origin='US')
# InfoTuple(car='Chrysler Newport Royal', mpg='13.0', cylinders='8', displacement='400.0', horsepower='190.0', weight='4422.', acceleration='12.5', model='72', origin='US')
# InfoTuple(car='Mazda RX2 Coupe', mpg='19.0', cylinders='3', displacement='70.00', horsepower='97.00', weight='2330.', acceleration='13.5', model='72', origin='Japan')
# InfoTuple(car='AMC Matador (sw)', mpg='15.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3892.', acceleration='12.5', model='72', origin='US')
# InfoTuple(car='Chevrolet Chevelle Concours (sw)', mpg='13.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='4098.', acceleration='14.0', model='72', origin='US')
# InfoTuple(car='Ford Gran Torino (sw)', mpg='13.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4294.', acceleration='16.0', model='72', origin='US')
# InfoTuple(car='Plymouth Satellite Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4077.', acceleration='14.0', model='72', origin='US')
# InfoTuple(car='Volvo 145e (sw)', mpg='18.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2933.', acceleration='14.5', model='72', origin='Europe')
# InfoTuple(car='Volkswagen 411 (sw)', mpg='22.0', cylinders='4', displacement='121.0', horsepower='76.00', weight='2511.', acceleration='18.0', model='72', origin='Europe')
# InfoTuple(car='Peugeot 504 (sw)', mpg='21.0', cylinders='4', displacement='120.0', horsepower='87.00', weight='2979.', acceleration='19.5', model='72', origin='Europe')
# InfoTuple(car='Renault 12 (sw)', mpg='26.0', cylinders='4', displacement='96.00', horsepower='69.00', weight='2189.', acceleration='18.0', model='72', origin='Europe')
# InfoTuple(car='Ford Pinto (sw)', mpg='22.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2395.', acceleration='16.0', model='72', origin='US')
# InfoTuple(car='Datsun 510 (sw)', mpg='28.0', cylinders='4', displacement='97.00', horsepower='92.00', weight='2288.', acceleration='17.0', model='72', origin='Japan')
# InfoTuple(car='Toyota Corolla Mark II (sw)', mpg='23.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2506.', acceleration='14.5', model='72', origin='Japan')
# InfoTuple(car='Dodge Colt (sw)', mpg='28.0', cylinders='4', displacement='98.00', horsepower='80.00', weight='2164.', acceleration='15.0', model='72', origin='US')
# InfoTuple(car='Toyota Corolla 1600 (sw)', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2100.', acceleration='16.5', model='72', origin='Japan')
# InfoTuple(car='Buick Century 350', mpg='13.0', cylinders='8', displacement='350.0', horsepower='175.0', weight='4100.', acceleration='13.0', model='73', origin='US')
# InfoTuple(car='AMC Matador', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='73', origin='US')
# InfoTuple(car='Chevrolet Malibu', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='3988.', acceleration='13.0', model='73', origin='US')
# InfoTuple(car='Ford Gran Torino', mpg='14.0', cylinders='8', displacement='302.0', horsepower='137.0', weight='4042.', acceleration='14.5', model='73', origin='US')
# InfoTuple(car='Dodge Coronet Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3777.', acceleration='12.5', model='73', origin='US')
# InfoTuple(car='Mercury Marquis Brougham', mpg='12.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4952.', acceleration='11.5', model='73', origin='US')
# InfoTuple(car='Chevrolet Caprice Classic', mpg='13.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4464.', acceleration='12.0', model='73', origin='US')
# InfoTuple(car='Ford LTD', mpg='13.0', cylinders='8', displacement='351.0', horsepower='158.0', weight='4363.', acceleration='13.0', model='73', origin='US')
# InfoTuple(car='Plymouth Fury Gran Sedan', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4237.', acceleration='14.5', model='73', origin='US')
# InfoTuple(car='Chrysler New Yorker Brougham', mpg='13.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4735.', acceleration='11.0', model='73', origin='US')
# InfoTuple(car='Buick Electra 225 Custom', mpg='12.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4951.', acceleration='11.0', model='73', origin='US')
# InfoTuple(car='AMC Ambassador Brougham', mpg='13.0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3821.', acceleration='11.0', model='73', origin='US')
# InfoTuple(car='Plymouth Valiant', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3121.', acceleration='16.5', model='73', origin='US')
# InfoTuple(car='Chevrolet Nova Custom', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3278.', acceleration='18.0', model='73', origin='US')
# InfoTuple(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2945.', acceleration='16.0', model='73', origin='US')
# InfoTuple(car='Ford Maverick', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3021.', acceleration='16.5', model='73', origin='US')
# InfoTuple(car='Plymouth Duster', mpg='23.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2904.', acceleration='16.0', model='73', origin='US')
# InfoTuple(car='Volkswagen Super Beetle', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1950.', acceleration='21.0', model='73', origin='Europe')
# InfoTuple(car='Chevrolet Impala', mpg='11.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4997.', acceleration='14.0', model='73', origin='US')
# InfoTuple(car='Ford Country', mpg='12.0', cylinders='8', displacement='400.0', horsepower='167.0', weight='4906.', acceleration='12.5', model='73', origin='US')
# InfoTuple(car='Plymouth Custom Suburb', mpg='13.0', cylinders='8', displacement='360.0', horsepower='170.0', weight='4654.', acceleration='13.0', model='73', origin='US')
# InfoTuple(car='Oldsmobile Vista Cruiser', mpg='12.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='4499.', acceleration='12.5', model='73', origin='US')
# InfoTuple(car='AMC Gremlin', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2789.', acceleration='15.0', model='73', origin='US')
# InfoTuple(car='Toyota Camry', mpg='20.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2279.', acceleration='19.0', model='73', origin='Japan')
# InfoTuple(car='Chevrolet Vega', mpg='21.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2401.', acceleration='19.5', model='73', origin='US')
# InfoTuple(car='Datsun 610', mpg='22.0', cylinders='4', displacement='108.0', horsepower='94.00', weight='2379.', acceleration='16.5', model='73', origin='Japan')
# InfoTuple(car='Mazda RX3', mpg='18.0', cylinders='3', displacement='70.00', horsepower='90.00', weight='2124.', acceleration='13.5', model='73', origin='Japan')
# InfoTuple(car='Ford Pinto', mpg='19.0', cylinders='4', displacement='122.0', horsepower='85.00', weight='2310.', acceleration='18.5', model='73', origin='US')
# InfoTuple(car='Mercury Capri v6', mpg='21.0', cylinders='6', displacement='155.0', horsepower='107.0', weight='2472.', acceleration='14.0', model='73', origin='US')
# InfoTuple(car='Fiat 124 Sport Coupe', mpg='26.0', cylinders='4', displacement='98.00', horsepower='90.00', weight='2265.', acceleration='15.5', model='73', origin='Europe')
# InfoTuple(car='Chevrolet Monte Carlo S', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4082.', acceleration='13.0', model='73', origin='US')
# InfoTuple(car='Pontiac Grand Prix', mpg='16.0', cylinders='8', displacement='400.0', horsepower='230.0', weight='4278.', acceleration='9.50', model='73', origin='US')
# InfoTuple(car='Fiat 128', mpg='29.0', cylinders='4', displacement='68.00', horsepower='49.00', weight='1867.', acceleration='19.5', model='73', origin='Europe')
# InfoTuple(car='Opel Manta', mpg='24.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2158.', acceleration='15.5', model='73', origin='Europe')
# InfoTuple(car='Audi 100LS', mpg='20.0', cylinders='4', displacement='114.0', horsepower='91.00', weight='2582.', acceleration='14.0', model='73', origin='Europe')
# InfoTuple(car='Volvo 144ea', mpg='19.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2868.', acceleration='15.5', model='73', origin='Europe')
# InfoTuple(car='Dodge Dart Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3399.', acceleration='11.0', model='73', origin='US')
# InfoTuple(car='Saab 99le', mpg='24.0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2660.', acceleration='14.0', model='73', origin='Europe')
# InfoTuple(car='Toyota Mark II', mpg='20.0', cylinders='6', displacement='156.0', horsepower='122.0', weight='2807.', acceleration='13.5', model='73', origin='Japan')
# InfoTuple(car='Oldsmobile Omega', mpg='11.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='3664.', acceleration='11.0', model='73', origin='US')
# InfoTuple(car='Plymouth Duster', mpg='20.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='3102.', acceleration='16.5', model='74', origin='US')
# InfoTuple(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='0', weight='2875.', acceleration='17.0', model='74', origin='US')
# InfoTuple(car='AMC Hornet', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2901.', acceleration='16.0', model='74', origin='US')
# InfoTuple(car='Chevrolet Nova', mpg='15.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3336.', acceleration='17.0', model='74', origin='US')
# InfoTuple(car='Datsun B210', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1950.', acceleration='19.0', model='74', origin='Japan')
# InfoTuple(car='Ford Pinto', mpg='26.0', cylinders='4', displacement='122.0', horsepower='80.00', weight='2451.', acceleration='16.5', model='74', origin='US')
# InfoTuple(car='Toyota Corolla 1200', mpg='32.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1836.', acceleration='21.0', model='74', origin='Japan')
# InfoTuple(car='Chevrolet Vega', mpg='25.0', cylinders='4', displacement='140.0', horsepower='75.00', weight='2542.', acceleration='17.0', model='74', origin='US')
# InfoTuple(car='Chevrolet Chevelle Malibu Classic', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3781.', acceleration='17.0', model='74', origin='US')
# InfoTuple(car='AMC Matador', mpg='16.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3632.', acceleration='18.0', model='74', origin='US')
# InfoTuple(car='Plymouth Satellite Sebring', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3613.', acceleration='16.5', model='74', origin='US')
# InfoTuple(car='Ford Gran Torino', mpg='16.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4141.', acceleration='14.0', model='74', origin='US')
# InfoTuple(car='Buick Century Luxus (sw)', mpg='13.0', cylinders='8', displacement='350.0', horsepower='150.0', weight='4699.', acceleration='14.5', model='74', origin='US')
# InfoTuple(car='Dodge Coronet Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4457.', acceleration='13.5', model='74', origin='US')
# InfoTuple(car='Ford Gran Torino (sw)', mpg='14.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4638.', acceleration='16.0', model='74', origin='US')
# InfoTuple(car='AMC Matador (sw)', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='4257.', acceleration='15.5', model='74', origin='US')
# InfoTuple(car='Audi Fox', mpg='29.0', cylinders='4', displacement='98.00', horsepower='83.00', weight='2219.', acceleration='16.5', model='74', origin='Europe')
# InfoTuple(car='Volkswagen Dasher', mpg='26.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1963.', acceleration='15.5', model='74', origin='Europe')
# InfoTuple(car='Opel Manta', mpg='26.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='2300.', acceleration='14.5', model='74', origin='Europe')
# InfoTuple(car='Toyota Corolla', mpg='31.0', cylinders='4', displacement='76.00', horsepower='52.00', weight='1649.', acceleration='16.5', model='74', origin='Japan')
# InfoTuple(car='Datsun 710', mpg='32.0', cylinders='4', displacement='83.00', horsepower='61.00', weight='2003.', acceleration='19.0', model='74', origin='Japan')
# InfoTuple(car='Dodge Colt', mpg='28.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2125.', acceleration='14.5', model='74', origin='US')
# InfoTuple(car='Fiat 128', mpg='24.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2108.', acceleration='15.5', model='74', origin='Europe')
# InfoTuple(car='Fiat 124 TC', mpg='26.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2246.', acceleration='14.0', model='74', origin='Europe')
# InfoTuple(car='Honda Civic', mpg='24.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2489.', acceleration='15.0', model='74', origin='Japan')
# InfoTuple(car='Subaru', mpg='26.0', cylinders='4', displacement='108.0', horsepower='93.00', weight='2391.', acceleration='15.5', model='74', origin='Japan')
# InfoTuple(car='Fiat x1.9', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='2000.', acceleration='16.0', model='74', origin='Europe')
# InfoTuple(car='Plymouth Valiant Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3264.', acceleration='16.0', model='75', origin='US')
# InfoTuple(car='Chevrolet Nova', mpg='18.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3459.', acceleration='16.0', model='75', origin='US')
# InfoTuple(car='Mercury Monarch', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3432.', acceleration='21.0', model='75', origin='US')
# InfoTuple(car='Ford Maverick', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3158.', acceleration='19.5', model='75', origin='US')
# InfoTuple(car='Pontiac Catalina', mpg='16.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4668.', acceleration='11.5', model='75', origin='US')
# InfoTuple(car='Chevrolet Bel Air', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4440.', acceleration='14.0', model='75', origin='US')
# InfoTuple(car='Plymouth Grand Fury', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4498.', acceleration='14.5', model='75', origin='US')
# InfoTuple(car='Ford LTD', mpg='14.0', cylinders='8', displacement='351.0', horsepower='148.0', weight='4657.', acceleration='13.5', model='75', origin='US')
# InfoTuple(car='Buick Century', mpg='17.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3907.', acceleration='21.0', model='75', origin='US')
# InfoTuple(car='Chevrolete Chevelle Malibu', mpg='16.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3897.', acceleration='18.5', model='75', origin='US')
# InfoTuple(car='AMC Matador', mpg='15.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3730.', acceleration='19.0', model='75', origin='US')
# InfoTuple(car='Plymouth Fury', mpg='18.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3785.', acceleration='19.0', model='75', origin='US')
# InfoTuple(car='Buick Skyhawk', mpg='21.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3039.', acceleration='15.0', model='75', origin='US')
# InfoTuple(car='Chevrolet Monza 2+2', mpg='20.0', cylinders='8', displacement='262.0', horsepower='110.0', weight='3221.', acceleration='13.5', model='75', origin='US')
# InfoTuple(car='Ford Mustang II', mpg='13.0', cylinders='8', displacement='302.0', horsepower='129.0', weight='3169.', acceleration='12.0', model='75', origin='US')
# InfoTuple(car='Toyota Corolla', mpg='29.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2171.', acceleration='16.0', model='75', origin='Japan')
# InfoTuple(car='Ford Pinto', mpg='23.0', cylinders='4', displacement='140.0', horsepower='83.00', weight='2639.', acceleration='17.0', model='75', origin='US')
# InfoTuple(car='AMC Gremlin', mpg='20.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2914.', acceleration='16.0', model='75', origin='US')
# InfoTuple(car='Pontiac Astro', mpg='23.0', cylinders='4', displacement='140.0', horsepower='78.00', weight='2592.', acceleration='18.5', model='75', origin='US')
# InfoTuple(car='Toyota Corolla', mpg='24.0', cylinders='4', displacement='134.0', horsepower='96.00', weight='2702.', acceleration='13.5', model='75', origin='Japan')
# InfoTuple(car='Volkswagen Dasher', mpg='25.0', cylinders='4', displacement='90.00', horsepower='71.00', weight='2223.', acceleration='16.5', model='75', origin='Europe')
# InfoTuple(car='Datsun 710', mpg='24.0', cylinders='4', displacement='119.0', horsepower='97.00', weight='2545.', acceleration='17.0', model='75', origin='Japan')
# InfoTuple(car='Ford Pinto', mpg='18.0', cylinders='6', displacement='171.0', horsepower='97.00', weight='2984.', acceleration='14.5', model='75', origin='US')
# InfoTuple(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.0', model='75', origin='Europe')
# InfoTuple(car='AMC Pacer', mpg='19.0', cylinders='6', displacement='232.0', horsepower='90.00', weight='3211.', acceleration='17.0', model='75', origin='US')
# InfoTuple(car='Audi 100LS', mpg='23.0', cylinders='4', displacement='115.0', horsepower='95.00', weight='2694.', acceleration='15.0', model='75', origin='Europe')
# InfoTuple(car='Peugeot 504', mpg='23.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2957.', acceleration='17.0', model='75', origin='Europe')
# InfoTuple(car='Volvo 244DL', mpg='22.0', cylinders='4', displacement='121.0', horsepower='98.00', weight='2945.', acceleration='14.5', model='75', origin='Europe')
# InfoTuple(car='Saab 99LE', mpg='25.0', cylinders='4', displacement='121.0', horsepower='115.0', weight='2671.', acceleration='13.5', model='75', origin='Europe')
# InfoTuple(car='Honda Civic CVCC', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.5', model='75', origin='Japan')
# InfoTuple(car='Fiat 131', mpg='28.0', cylinders='4', displacement='107.0', horsepower='86.00', weight='2464.', acceleration='15.5', model='76', origin='Europe')
# InfoTuple(car='Opel 1900', mpg='25.0', cylinders='4', displacement='116.0', horsepower='81.00', weight='2220.', acceleration='16.9', model='76', origin='Europe')
# InfoTuple(car='Capri ii', mpg='25.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2572.', acceleration='14.9', model='76', origin='US')
# InfoTuple(car='Dodge Colt', mpg='26.0', cylinders='4', displacement='98.00', horsepower='79.00', weight='2255.', acceleration='17.7', model='76', origin='US')
# InfoTuple(car='Renault 12tl', mpg='27.0', cylinders='4', displacement='101.0', horsepower='83.00', weight='2202.', acceleration='15.3', model='76', origin='Europe')
# InfoTuple(car='Chevrolet Chevelle Malibu Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='140.0', weight='4215.', acceleration='13.0', model='76', origin='US')
# InfoTuple(car='Dodge Coronet Brougham', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4190.', acceleration='13.0', model='76', origin='US')
# InfoTuple(car='AMC Matador', mpg='15.5', cylinders='8', displacement='304.0', horsepower='120.0', weight='3962.', acceleration='13.9', model='76', origin='US')
# InfoTuple(car='Ford Gran Torino', mpg='14.5', cylinders='8', displacement='351.0', horsepower='152.0', weight='4215.', acceleration='12.8', model='76', origin='US')
# InfoTuple(car='Plymouth Valiant', mpg='22.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3233.', acceleration='15.4', model='76', origin='US')
# InfoTuple(car='Chevrolet Nova', mpg='22.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3353.', acceleration='14.5', model='76', origin='US')
# InfoTuple(car='Ford Maverick', mpg='24.0', cylinders='6', displacement='200.0', horsepower='81.00', weight='3012.', acceleration='17.6', model='76', origin='US')
# InfoTuple(car='AMC Hornet', mpg='22.5', cylinders='6', displacement='232.0', horsepower='90.00', weight='3085.', acceleration='17.6', model='76', origin='US')
# InfoTuple(car='Chevrolet Chevette', mpg='29.0', cylinders='4', displacement='85.00', horsepower='52.00', weight='2035.', acceleration='22.2', model='76', origin='US')
# InfoTuple(car='Chevrolet Woody', mpg='24.5', cylinders='4', displacement='98.00', horsepower='60.00', weight='2164.', acceleration='22.1', model='76', origin='US')
# InfoTuple(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.2', model='76', origin='Europe')
# InfoTuple(car='Honda Civic', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.4', model='76', origin='Japan')
# InfoTuple(car='Dodge Aspen SE', mpg='20.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3651.', acceleration='17.7', model='76', origin='US')
# InfoTuple(car='Ford Grenada ghia', mpg='18.0', cylinders='6', displacement='250.0', horsepower='78.00', weight='3574.', acceleration='21.0', model='76', origin='US')
# InfoTuple(car='Pontiac Ventura SJ', mpg='18.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3645.', acceleration='16.2', model='76', origin='US')
# InfoTuple(car='AMC Pacer d/l', mpg='17.5', cylinders='6', displacement='258.0', horsepower='95.00', weight='3193.', acceleration='17.8', model='76', origin='US')
# InfoTuple(car='Volkswagen Rabbit', mpg='29.5', cylinders='4', displacement='97.00', horsepower='71.00', weight='1825.', acceleration='12.2', model='76', origin='Europe')
# InfoTuple(car='Datsun B-210', mpg='32.0', cylinders='4', displacement='85.00', horsepower='70.00', weight='1990.', acceleration='17.0', model='76', origin='Japan')
# InfoTuple(car='Toyota Corolla', mpg='28.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2155.', acceleration='16.4', model='76', origin='Japan')
# InfoTuple(car='Ford Pinto', mpg='26.5', cylinders='4', displacement='140.0', horsepower='72.00', weight='2565.', acceleration='13.6', model='76', origin='US')
# InfoTuple(car='Volvo 245', mpg='20.0', cylinders='4', displacement='130.0', horsepower='102.0', weight='3150.', acceleration='15.7', model='76', origin='Europe')
# InfoTuple(car='Plymouth Volare Premier v8', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3940.', acceleration='13.2', model='76', origin='US')
# InfoTuple(car='Peugeot 504', mpg='19.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='3270.', acceleration='21.9', model='76', origin='Europe')
# InfoTuple(car='Toyota Mark II', mpg='19.0', cylinders='6', displacement='156.0', horsepower='108.0', weight='2930.', acceleration='15.5', model='76', origin='Japan')
# InfoTuple(car='Mercedes-Benz 280s', mpg='16.5', cylinders='6', displacement='168.0', horsepower='120.0', weight='3820.', acceleration='16.7', model='76', origin='Europe')
# InfoTuple(car='Cadillac Seville', mpg='16.5', cylinders='8', displacement='350.0', horsepower='180.0', weight='4380.', acceleration='12.1', model='76', origin='US')
# InfoTuple(car='Chevrolet C10', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4055.', acceleration='12.0', model='76', origin='US')
# InfoTuple(car='Ford F108', mpg='13.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='3870.', acceleration='15.0', model='76', origin='US')
# InfoTuple(car='Dodge D100', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3755.', acceleration='14.0', model='76', origin='US')
# InfoTuple(car='Honda Accord CVCC', mpg='31.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2045.', acceleration='18.5', model='77', origin='Japan')
# InfoTuple(car='Buick Opel Isuzu Deluxe', mpg='30.0', cylinders='4', displacement='111.0', horsepower='80.00', weight='2155.', acceleration='14.8', model='77', origin='US')
# InfoTuple(car='Renault 5 GTL', mpg='36.0', cylinders='4', displacement='79.00', horsepower='58.00', weight='1825.', acceleration='18.6', model='77', origin='Europe')
# InfoTuple(car='Plymouth Arrow GS', mpg='25.5', cylinders='4', displacement='122.0', horsepower='96.00', weight='2300.', acceleration='15.5', model='77', origin='US')
# InfoTuple(car='Datsun F-10 Hatchback', mpg='33.5', cylinders='4', displacement='85.00', horsepower='70.00', weight='1945.', acceleration='16.8', model='77', origin='Japan')
# InfoTuple(car='Chevrolet Caprice Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='145.0', weight='3880.', acceleration='12.5', model='77', origin='US')
# InfoTuple(car='Oldsmobile Cutlass Supreme', mpg='17.0', cylinders='8', displacement='260.0', horsepower='110.0', weight='4060.', acceleration='19.0', model='77', origin='US')
# InfoTuple(car='Dodge Monaco Brougham', mpg='15.5', cylinders='8', displacement='318.0', horsepower='145.0', weight='4140.', acceleration='13.7', model='77', origin='US')
# InfoTuple(car='Mercury Cougar Brougham', mpg='15.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='4295.', acceleration='14.9', model='77', origin='US')
# InfoTuple(car='Chevrolet Concours', mpg='17.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3520.', acceleration='16.4', model='77', origin='US')
# InfoTuple(car='Buick Skylark', mpg='20.5', cylinders='6', displacement='231.0', horsepower='105.0', weight='3425.', acceleration='16.9', model='77', origin='US')
# InfoTuple(car='Plymouth Volare Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3630.', acceleration='17.7', model='77', origin='US')
# InfoTuple(car='Ford Grenada', mpg='18.5', cylinders='6', displacement='250.0', horsepower='98.00', weight='3525.', acceleration='19.0', model='77', origin='US')
# InfoTuple(car='Pontiac Grand Prix LJ', mpg='16.0', cylinders='8', displacement='400.0', horsepower='180.0', weight='4220.', acceleration='11.1', model='77', origin='US')
# InfoTuple(car='Chevrolet Monte Carlo Landau', mpg='15.5', cylinders='8', displacement='350.0', horsepower='170.0', weight='4165.', acceleration='11.4', model='77', origin='US')
# InfoTuple(car='Chrysler Cordoba', mpg='15.5', cylinders='8', displacement='400.0', horsepower='190.0', weight='4325.', acceleration='12.2', model='77', origin='US')
# InfoTuple(car='Ford Thunderbird', mpg='16.0', cylinders='8', displacement='351.0', horsepower='149.0', weight='4335.', acceleration='14.5', model='77', origin='US')
# InfoTuple(car='Volkswagen Rabbit Custom', mpg='29.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='1940.', acceleration='14.5', model='77', origin='Europe')
# InfoTuple(car='Pontiac Sunbird Coupe', mpg='24.5', cylinders='4', displacement='151.0', horsepower='88.00', weight='2740.', acceleration='16.0', model='77', origin='US')
# InfoTuple(car='Toyota Corolla Liftback', mpg='26.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2265.', acceleration='18.2', model='77', origin='Japan')
# InfoTuple(car='Ford Mustang II 2+2', mpg='25.5', cylinders='4', displacement='140.0', horsepower='89.00', weight='2755.', acceleration='15.8', model='77', origin='US')
# InfoTuple(car='Chevrolet Chevette', mpg='30.5', cylinders='4', displacement='98.00', horsepower='63.00', weight='2051.', acceleration='17.0', model='77', origin='US')
# InfoTuple(car='Dodge Colt m/m', mpg='33.5', cylinders='4', displacement='98.00', horsepower='83.00', weight='2075.', acceleration='15.9', model='77', origin='US')
# InfoTuple(car='Subaru DL', mpg='30.0', cylinders='4', displacement='97.00', horsepower='67.00', weight='1985.', acceleration='16.4', model='77', origin='Japan')
# InfoTuple(car='Volkswagen Dasher', mpg='30.5', cylinders='4', displacement='97.00', horsepower='78.00', weight='2190.', acceleration='14.1', model='77', origin='Europe')
# InfoTuple(car='Datsun 810', mpg='22.0', cylinders='6', displacement='146.0', horsepower='97.00', weight='2815.', acceleration='14.5', model='77', origin='Japan')
# InfoTuple(car='BMW 320i', mpg='21.5', cylinders='4', displacement='121.0', horsepower='110.0', weight='2600.', acceleration='12.8', model='77', origin='Europe')
# InfoTuple(car='Mazda RX-4', mpg='21.5', cylinders='3', displacement='80.00', horsepower='110.0', weight='2720.', acceleration='13.5', model='77', origin='Japan')
# InfoTuple(car='Volkswagen Rabbit Custom Diesel', mpg='43.1', cylinders='4', displacement='90.00', horsepower='48.00', weight='1985.', acceleration='21.5', model='78', origin='Europe')
# InfoTuple(car='Ford Fiesta', mpg='36.1', cylinders='4', displacement='98.00', horsepower='66.00', weight='1800.', acceleration='14.4', model='78', origin='US')
# InfoTuple(car='Mazda GLC Deluxe', mpg='32.8', cylinders='4', displacement='78.00', horsepower='52.00', weight='1985.', acceleration='19.4', model='78', origin='Japan')
# InfoTuple(car='Datsun B210 GX', mpg='39.4', cylinders='4', displacement='85.00', horsepower='70.00', weight='2070.', acceleration='18.6', model='78', origin='Japan')
# InfoTuple(car='Honda Civic CVCC', mpg='36.1', cylinders='4', displacement='91.00', horsepower='60.00', weight='1800.', acceleration='16.4', model='78', origin='Japan')
# InfoTuple(car='Oldsmobile Cutlass Salon Brougham', mpg='19.9', cylinders='8', displacement='260.0', horsepower='110.0', weight='3365.', acceleration='15.5', model='78', origin='US')
# InfoTuple(car='Dodge Diplomat', mpg='19.4', cylinders='8', displacement='318.0', horsepower='140.0', weight='3735.', acceleration='13.2', model='78', origin='US')
# InfoTuple(car='Mercury Monarch ghia', mpg='20.2', cylinders='8', displacement='302.0', horsepower='139.0', weight='3570.', acceleration='12.8', model='78', origin='US')
# InfoTuple(car='Pontiac Phoenix LJ', mpg='19.2', cylinders='6', displacement='231.0', horsepower='105.0', weight='3535.', acceleration='19.2', model='78', origin='US')
# InfoTuple(car='Chevrolet Malibu', mpg='20.5', cylinders='6', displacement='200.0', horsepower='95.00', weight='3155.', acceleration='18.2', model='78', origin='US')
# InfoTuple(car='Ford Fairmont (auto)', mpg='20.2', cylinders='6', displacement='200.0', horsepower='85.00', weight='2965.', acceleration='15.8', model='78', origin='US')
# InfoTuple(car='Ford Fairmont (man)', mpg='25.1', cylinders='4', displacement='140.0', horsepower='88.00', weight='2720.', acceleration='15.4', model='78', origin='US')
# InfoTuple(car='Plymouth Volare', mpg='20.5', cylinders='6', displacement='225.0', horsepower='100.0', weight='3430.', acceleration='17.2', model='78', origin='US')
# InfoTuple(car='AMC Concord', mpg='19.4', cylinders='6', displacement='232.0', horsepower='90.00', weight='3210.', acceleration='17.2', model='78', origin='US')
# InfoTuple(car='Buick Century Special', mpg='20.6', cylinders='6', displacement='231.0', horsepower='105.0', weight='3380.', acceleration='15.8', model='78', origin='US')
# InfoTuple(car='Mercury Zephyr', mpg='20.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='3070.', acceleration='16.7', model='78', origin='US')
# InfoTuple(car='Dodge Aspen', mpg='18.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3620.', acceleration='18.7', model='78', origin='US')
# InfoTuple(car='AMC Concord d/l', mpg='18.1', cylinders='6', displacement='258.0', horsepower='120.0', weight='3410.', acceleration='15.1', model='78', origin='US')
# InfoTuple(car='Chevrolet Monte Carlo Landau', mpg='19.2', cylinders='8', displacement='305.0', horsepower='145.0', weight='3425.', acceleration='13.2', model='78', origin='US')
# InfoTuple(car='Buick Regal Sport Coupe (turbo)', mpg='17.7', cylinders='6', displacement='231.0', horsepower='165.0', weight='3445.', acceleration='13.4', model='78', origin='US')
# InfoTuple(car='Ford Futura', mpg='18.1', cylinders='8', displacement='302.0', horsepower='139.0', weight='3205.', acceleration='11.2', model='78', origin='US')
# InfoTuple(car='Dodge Magnum XE', mpg='17.5', cylinders='8', displacement='318.0', horsepower='140.0', weight='4080.', acceleration='13.7', model='78', origin='US')
# InfoTuple(car='Chevrolet Chevette', mpg='30.0', cylinders='4', displacement='98.00', horsepower='68.00', weight='2155.', acceleration='16.5', model='78', origin='US')
# InfoTuple(car='Toyota Corolla', mpg='27.5', cylinders='4', displacement='134.0', horsepower='95.00', weight='2560.', acceleration='14.2', model='78', origin='Japan')
# InfoTuple(car='Datsun 510', mpg='27.2', cylinders='4', displacement='119.0', horsepower='97.00', weight='2300.', acceleration='14.7', model='78', origin='Japan')
# InfoTuple(car='Dodge Omni', mpg='30.9', cylinders='4', displacement='105.0', horsepower='75.00', weight='2230.', acceleration='14.5', model='78', origin='US')
# InfoTuple(car='Toyota Celica GT Liftback', mpg='21.1', cylinders='4', displacement='134.0', horsepower='95.00', weight='2515.', acceleration='14.8', model='78', origin='Japan')
# InfoTuple(car='Plymouth Sapporo', mpg='23.2', cylinders='4', displacement='156.0', horsepower='105.0', weight='2745.', acceleration='16.7', model='78', origin='US')
# InfoTuple(car='Oldsmobile Starfire SX', mpg='23.8', cylinders='4', displacement='151.0', horsepower='85.00', weight='2855.', acceleration='17.6', model='78', origin='US')
# InfoTuple(car='Datsun 200-SX', mpg='23.9', cylinders='4', displacement='119.0', horsepower='97.00', weight='2405.', acceleration='14.9', model='78', origin='Japan')
# InfoTuple(car='Audi 5000', mpg='20.3', cylinders='5', displacement='131.0', horsepower='103.0', weight='2830.', acceleration='15.9', model='78', origin='Europe')
# InfoTuple(car='Volvo 264gl', mpg='17.0', cylinders='6', displacement='163.0', horsepower='125.0', weight='3140.', acceleration='13.6', model='78', origin='Europe')
# InfoTuple(car='Saab 99gle', mpg='21.6', cylinders='4', displacement='121.0', horsepower='115.0', weight='2795.', acceleration='15.7', model='78', origin='Europe')
# InfoTuple(car='Peugeot 604sl', mpg='16.2', cylinders='6', displacement='163.0', horsepower='133.0', weight='3410.', acceleration='15.8', model='78', origin='Europe')
# InfoTuple(car='Volkswagen Scirocco', mpg='31.5', cylinders='4', displacement='89.00', horsepower='71.00', weight='1990.', acceleration='14.9', model='78', origin='Europe')
# InfoTuple(car='Honda Accord LX', mpg='29.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2135.', acceleration='16.6', model='78', origin='Japan')
# InfoTuple(car='Pontiac Lemans V6', mpg='21.5', cylinders='6', displacement='231.0', horsepower='115.0', weight='3245.', acceleration='15.4', model='79', origin='US')
# ...
# InfoTuple(car='Datsun 210', mpg='31.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2020.', acceleration='19.2', model='79', origin='Japan')
# InfoTuple(car='Fiat Strada Custom', mpg='37.3', cylinders='4', displacement='91.00', horsepower='69.00', weight='2130.', acceleration='14.7', model='79', origin='Europe')
# InfoTuple(car='Buick Skylark Limited', mpg='28.4', cylinders='4', displacement='151.0', horsepower='90.00', weight='2670.', acceleration='16.0', model='79', origin='US')
# InfoTuple(car='Chevrolet Citation', mpg='28.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2595.', acceleration='11.3', model='79', origin='US')
# InfoTuple(car='Oldsmobile Omega Brougham', mpg='26.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2700.', acceleration='12.9', model='79', origin='US')
# InfoTuple(car='Pontiac Phoenix', mpg='33.5', cylinders='4', displacement='151.0', horsepower='90.00', weight='2556.', acceleration='13.2', model='79', origin='US')
# InfoTuple(car='Volkswagen Rabbit', mpg='41.5', cylinders='4', displacement='98.00', horsepower='76.00', weight='2144.', acceleration='14.7', model='80', origin='Europe')
# InfoTuple(car='Toyota Corolla Tercel', mpg='38.1', cylinders='4', displacement='89.00', horsepower='60.00', weight='1968.', acceleration='18.8', model='80', origin='Japan')
# InfoTuple(car='Chevrolet Chevette', mpg='32.1', cylinders='4', displacement='98.00', horsepower='70.00', weight='2120.', acceleration='15.5', model='80', origin='US')
# InfoTuple(car='Datsun 310', mpg='37.2', cylinders='4', displacement='86.00', horsepower='65.00', weight='2019.', acceleration='16.4', model='80', origin='Japan')
# InfoTuple(car='Chevrolet Citation', mpg='28.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2678.', acceleration='16.5', model='80', origin='US')
# InfoTuple(car='Ford Fairmont', mpg='26.4', cylinders='4', displacement='140.0', horsepower='88.00', weight='2870.', acceleration='18.1', model='80', origin='US')
# InfoTuple(car='AMC Concord', mpg='24.3', cylinders='4', displacement='151.0', horsepower='90.00', weight='3003.', acceleration='20.1', model='80', origin='US')
# InfoTuple(car='Dodge Aspen', mpg='19.1', cylinders='6', displacement='225.0', horsepower='90.00', weight='3381.', acceleration='18.7', model='80', origin='US')
# InfoTuple(car='Audi 4000', mpg='34.3', cylinders='4', displacement='97.00', horsepower='78.00', weight='2188.', acceleration='15.8', model='80', origin='Europe')
# InfoTuple(car='Toyota Corolla Liftback', mpg='29.8', cylinders='4', displacement='134.0', horsepower='90.00', weight='2711.', acceleration='15.5', model='80', origin='Japan')
# InfoTuple(car='Mazda 626', mpg='31.3', cylinders='4', displacement='120.0', horsepower='75.00', weight='2542.', acceleration='17.5', model='80', origin='Japan')
# InfoTuple(car='Datsun 510 Hatchback', mpg='37.0', cylinders='4', displacement='119.0', horsepower='92.00', weight='2434.', acceleration='15.0', model='80', origin='Japan')
# InfoTuple(car='Toyota Corolla', mpg='32.2', cylinders='4', displacement='108.0', horsepower='75.00', weight='2265.', acceleration='15.2', model='80', origin='Japan')
# InfoTuple(car='Mazda GLC', mpg='46.6', cylinders='4', displacement='86.00', horsepower='65.00', weight='2110.', acceleration='17.9', model='80', origin='Japan')
# InfoTuple(car='Dodge Colt', mpg='27.9', cylinders='4', displacement='156.0', horsepower='105.0', weight='2800.', acceleration='14.4', model='80', origin='US')
# InfoTuple(car='Datsun 210', mpg='40.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2110.', acceleration='19.2', model='80', origin='Japan')
# InfoTuple(car='Volkswagen Rabbit C (Diesel)', mpg='44.3', cylinders='4', displacement='90.00', horsepower='48.00', weight='2085.', acceleration='21.7', model='80', origin='Europe')
# InfoTuple(car='Volkswagen Dasher (diesel)', mpg='43.4', cylinders='4', displacement='90.00', horsepower='48.00', weight='2335.', acceleration='23.7', model='80', origin='Europe')
# InfoTuple(car='Audi 5000s (diesel)', mpg='36.4', cylinders='5', displacement='121.0', horsepower='67.00', weight='2950.', acceleration='19.9', model='80', origin='Europe')
# InfoTuple(car='Mercedes-Benz 240d', mpg='30.0', cylinders='4', displacement='146.0', horsepower='67.00', weight='3250.', acceleration='21.8', model='80', origin='Europe')
# InfoTuple(car='Honda Civic 1500 gl', mpg='44.6', cylinders='4', displacement='91.00', horsepower='67.00', weight='1850.', acceleration='13.8', model='80', origin='Japan')
# InfoTuple(car='Renault Lecar Deluxe', mpg='40.9', cylinders='4', displacement='85.00', horsepower='0', weight='1835.', acceleration='17.3', model='80', origin='Europe')
# InfoTuple(car='Subaru DL', mpg='33.8', cylinders='4', displacement='97.00', horsepower='67.00', weight='2145.', acceleration='18.0', model='80', origin='Japan')
# InfoTuple(car='Volkswagen Rabbit', mpg='29.8', cylinders='4', displacement='89.00', horsepower='62.00', weight='1845.', acceleration='15.3', model='80', origin='Europe')
# InfoTuple(car='Datsun 280-ZX', mpg='32.7', cylinders='6', displacement='168.0', horsepower='132.0', weight='2910.', acceleration='11.4', model='80', origin='Japan')
# InfoTuple(car='Mazda RX-7 GS', mpg='23.7', cylinders='3', displacement='70.00', horsepower='100.0', weight='2420.', acceleration='12.5', model='80', origin='Japan')
# InfoTuple(car='Triumph TR7 Coupe', mpg='35.0', cylinders='4', displacement='122.0', horsepower='88.00', weight='2500.', acceleration='15.1', model='80', origin='Europe')
# InfoTuple(car='Ford Mustang Cobra', mpg='23.6', cylinders='4', displacement='140.0', horsepower='0', weight='2905.', acceleration='14.3', model='80', origin='US')
# InfoTuple(car='Honda Accord', mpg='32.4', cylinders='4', displacement='107.0', horsepower='72.00', weight='2290.', acceleration='17.0', model='80', origin='Japan')
# InfoTuple(car='Plymouth Reliant', mpg='27.2', cylinders='4', displacement='135.0', horsepower='84.00', weight='2490.', acceleration='15.7', model='81', origin='US')
# InfoTuple(car='Buick Skylark', mpg='26.6', cylinders='4', displacement='151.0', horsepower='84.00', weight='2635.', acceleration='16.4', model='81', origin='US')
# InfoTuple(car='Dodge Aries Wagon (sw)', mpg='25.8', cylinders='4', displacement='156.0', horsepower='92.00', weight='2620.', acceleration='14.4', model='81', origin='US')
# InfoTuple(car='Chevrolet Citation', mpg='23.5', cylinders='6', displacement='173.0', horsepower='110.0', weight='2725.', acceleration='12.6', model='81', origin='US')
# InfoTuple(car='Plymouth Reliant', mpg='30.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2385.', acceleration='12.9', model='81', origin='US')
# InfoTuple(car='Toyota Starlet', mpg='39.1', cylinders='4', displacement='79.00', horsepower='58.00', weight='1755.', acceleration='16.9', model='81', origin='Japan')
# InfoTuple(car='Plymouth Champ', mpg='39.0', cylinders='4', displacement='86.00', horsepower='64.00', weight='1875.', acceleration='16.4', model='81', origin='US')
# InfoTuple(car='Honda Civic 1300', mpg='35.1', cylinders='4', displacement='81.00', horsepower='60.00', weight='1760.', acceleration='16.1', model='81', origin='Japan')
# InfoTuple(car='Subaru', mpg='32.3', cylinders='4', displacement='97.00', horsepower='67.00', weight='2065.', acceleration='17.8', model='81', origin='Japan')
# InfoTuple(car='Datsun 210 MPG', mpg='37.0', cylinders='4', displacement='85.00', horsepower='65.00', weight='1975.', acceleration='19.4', model='81', origin='Japan')
# InfoTuple(car='Toyota Tercel', mpg='37.7', cylinders='4', displacement='89.00', horsepower='62.00', weight='2050.', acceleration='17.3', model='81', origin='Japan')
# InfoTuple(car='Mazda GLC 4', mpg='34.1', cylinders='4', displacement='91.00', horsepower='68.00', weight='1985.', acceleration='16.0', model='81', origin='Japan')
# InfoTuple(car='Plymouth Horizon 4', mpg='34.7', cylinders='4', displacement='105.0', horsepower='63.00', weight='2215.', acceleration='14.9', model='81', origin='US')
# InfoTuple(car='Ford Escort 4W', mpg='34.4', cylinders='4', displacement='98.00', horsepower='65.00', weight='2045.', acceleration='16.2', model='81', origin='US')
# InfoTuple(car='Ford Escort 2H', mpg='29.9', cylinders='4', displacement='98.00', horsepower='65.00', weight='2380.', acceleration='20.7', model='81', origin='US')
# InfoTuple(car='Volkswagen Jetta', mpg='33.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='2190.', acceleration='14.2', model='81', origin='Europe')
# InfoTuple(car='Renault 18i', mpg='34.5', cylinders='4', displacement='100.0', horsepower='0', weight='2320.', acceleration='15.8', model='81', origin='Europe')
# InfoTuple(car='Honda Prelude', mpg='33.7', cylinders='4', displacement='107.0', horsepower='75.00', weight='2210.', acceleration='14.4', model='81', origin='Japan')
# InfoTuple(car='Toyota Corolla', mpg='32.4', cylinders='4', displacement='108.0', horsepower='75.00', weight='2350.', acceleration='16.8', model='81', origin='Japan')
# InfoTuple(car='Datsun 200SX', mpg='32.9', cylinders='4', displacement='119.0', horsepower='100.0', weight='2615.', acceleration='14.8', model='81', origin='Japan')
# InfoTuple(car='Mazda 626', mpg='31.6', cylinders='4', displacement='120.0', horsepower='74.00', weight='2635.', acceleration='18.3', model='81', origin='Japan')
# InfoTuple(car='Peugeot 505s Turbo Diesel', mpg='28.1', cylinders='4', displacement='141.0', horsepower='80.00', weight='3230.', acceleration='20.4', model='81', origin='Europe')
# InfoTuple(car='Saab 900s', mpg='0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2800.', acceleration='15.4', model='81', origin='Europe')
# InfoTuple(car='Volvo Diesel', mpg='30.7', cylinders='6', displacement='145.0', horsepower='76.00', weight='3160.', acceleration='19.6', model='81', origin='Europe')
# InfoTuple(car='Toyota Cressida', mpg='25.4', cylinders='6', displacement='168.0', horsepower='116.0', weight='2900.', acceleration='12.6', model='81', origin='Japan')
# InfoTuple(car='Datsun 810 Maxima', mpg='24.2', cylinders='6', displacement='146.0', horsepower='120.0', weight='2930.', acceleration='13.8', model='81', origin='Japan')
# InfoTuple(car='Buick Century', mpg='22.4', cylinders='6', displacement='231.0', horsepower='110.0', weight='3415.', acceleration='15.8', model='81', origin='US')
# InfoTuple(car='Oldsmobile Cutlass LS', mpg='26.6', cylinders='8', displacement='350.0', horsepower='105.0', weight='3725.', acceleration='19.0', model='81', origin='US')
# InfoTuple(car='Ford Grenada gl', mpg='20.2', cylinders='6', displacement='200.0', horsepower='88.00', weight='3060.', acceleration='17.1', model='81', origin='US')
# InfoTuple(car='Chrysler Lebaron Salon', mpg='17.6', cylinders='6', displacement='225.0', horsepower='85.00', weight='3465.', acceleration='16.6', model='81', origin='US')
# InfoTuple(car='Chevrolet Cavalier', mpg='28.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2605.', acceleration='19.6', model='82', origin='US')
# InfoTuple(car='Chevrolet Cavalier Wagon', mpg='27.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2640.', acceleration='18.6', model='82', origin='US')
# InfoTuple(car='Chevrolet Cavalier 2-door', mpg='34.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2395.', acceleration='18.0', model='82', origin='US')
# InfoTuple(car='Pontiac J2000 SE Hatchback', mpg='31.0', cylinders='4', displacement='112.0', horsepower='85.00', weight='2575.', acceleration='16.2', model='82', origin='US')
# InfoTuple(car='Dodge Aries SE', mpg='29.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2525.', acceleration='16.0', model='82', origin='US')
# InfoTuple(car='Pontiac Phoenix', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2735.', acceleration='18.0', model='82', origin='US')
# InfoTuple(car='Ford Fairmont Futura', mpg='24.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2865.', acceleration='16.4', model='82', origin='US')
# InfoTuple(car='AMC Concord DL', mpg='23.0', cylinders='4', displacement='151.0', horsepower='0', weight='3035.', acceleration='20.5', model='82', origin='US')
# InfoTuple(car='Volkswagen Rabbit l', mpg='36.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='1980.', acceleration='15.3', model='82', origin='Europe')
# InfoTuple(car='Mazda GLC Custom l', mpg='37.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='2025.', acceleration='18.2', model='82', origin='Japan')
# InfoTuple(car='Mazda GLC Custom', mpg='31.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='1970.', acceleration='17.6', model='82', origin='Japan')
# InfoTuple(car='Plymouth Horizon Miser', mpg='38.0', cylinders='4', displacement='105.0', horsepower='63.00', weight='2125.', acceleration='14.7', model='82', origin='US')
# InfoTuple(car='Mercury Lynx l', mpg='36.0', cylinders='4', displacement='98.00', horsepower='70.00', weight='2125.', acceleration='17.3', model='82', origin='US')
# InfoTuple(car='Nissan Stanza XE', mpg='36.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2160.', acceleration='14.5', model='82', origin='Japan')
# InfoTuple(car='Honda Accord', mpg='36.0', cylinders='4', displacement='107.0', horsepower='75.00', weight='2205.', acceleration='14.5', model='82', origin='Japan')
# InfoTuple(car='Toyota Corolla', mpg='34.0', cylinders='4', displacement='108.0', horsepower='70.00', weight='2245', acceleration='16.9', model='82', origin='Japan')
# InfoTuple(car='Honda Civic', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.0', model='82', origin='Japan')
# InfoTuple(car='Honda Civic (auto)', mpg='32.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.7', model='82', origin='Japan')
# InfoTuple(car='Datsun 310 GX', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1995.', acceleration='16.2', model='82', origin='Japan')
# InfoTuple(car='Buick Century Limited', mpg='25.0', cylinders='6', displacement='181.0', horsepower='110.0', weight='2945.', acceleration='16.4', model='82', origin='US')
# InfoTuple(car='Oldsmobile Cutlass Ciera (diesel)', mpg='38.0', cylinders='6', displacement='262.0', horsepower='85.00', weight='3015.', acceleration='17.0', model='82', origin='US')
# InfoTuple(car='Chrysler Lebaron Medallion', mpg='26.0', cylinders='4', displacement='156.0', horsepower='92.00', weight='2585.', acceleration='14.5', model='82', origin='US')
# InfoTuple(car='Ford Grenada l', mpg='22.0', cylinders='6', displacement='232.0', horsepower='112.0', weight='2835', acceleration='14.7', model='82', origin='US')
# InfoTuple(car='Toyota Celica GT', mpg='32.0', cylinders='4', displacement='144.0', horsepower='96.00', weight='2665.', acceleration='13.9', model='82', origin='Japan')
# InfoTuple(car='Dodge Charger 2.2', mpg='36.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2370.', acceleration='13.0', model='82', origin='US')
# InfoTuple(car='Chevrolet Camaro', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2950.', acceleration='17.3', model='82', origin='US')
# InfoTuple(car='Ford Mustang GL', mpg='27.0', cylinders='4', displacement='140.0', horsepower='86.00', weight='2790.', acceleration='15.6', model='82', origin='US')
# InfoTuple(car='Volkswagen Pickup', mpg='44.0', cylinders='4', displacement='97.00', horsepower='52.00', weight='2130.', acceleration='24.6', model='82', origin='Europe')
# InfoTuple(car='Dodge Rampage', mpg='32.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2295.', acceleration='11.6', model='82', origin='US')
# InfoTuple(car='Ford Ranger', mpg='28.0', cylinders='4', displacement='120.0', horsepower='79.00', weight='2625.', acceleration='18.6', model='82', origin='US')
# InfoTuple(car='Chevy S-10', mpg='31.0', cylinders='4', displacement='119.0', horsepower='82.00', weight='2720.', acceleration='19.4', model='82', origin='US')

# %%
with FileParser('personal_info.csv') as persons:
    for person in persons:
        print(person)
# Out:
# InfoTuple(ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# InfoTuple(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# InfoTuple(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# InfoTuple(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# InfoTuple(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# InfoTuple(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese')
# InfoTuple(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi')
# InfoTuple(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian')
# InfoTuple(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian')
# InfoTuple(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish')
# InfoTuple(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin')
# InfoTuple(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento')
# InfoTuple(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz')
# InfoTuple(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch')
# InfoTuple(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian')
# InfoTuple(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic')
# InfoTuple(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari')
# InfoTuple(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian')
# InfoTuple(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili')
# InfoTuple(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew')
# InfoTuple(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish')
# InfoTuple(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian')
# InfoTuple(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian')
# InfoTuple(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian')
# InfoTuple(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi')
# InfoTuple(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh')
# InfoTuple(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian')
# InfoTuple(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian')
# InfoTuple(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik')
# InfoTuple(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish')
# InfoTuple(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian')
# InfoTuple(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole')
# InfoTuple(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara')
# InfoTuple(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic')
# InfoTuple(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao')
# InfoTuple(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian')
# InfoTuple(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian')
# InfoTuple(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish')
# InfoTuple(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian')
# InfoTuple(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech')
# InfoTuple(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha')
# InfoTuple(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish')
# InfoTuple(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi')
# InfoTuple(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino')
# InfoTuple(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz')
# InfoTuple(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama')
# InfoTuple(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish')
# InfoTuple(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama')
# InfoTuple(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese')
# InfoTuple(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian')
# InfoTuple(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole')
# InfoTuple(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi')
# InfoTuple(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian')
# InfoTuple(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori')
# InfoTuple(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin')
# InfoTuple(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana')
# InfoTuple(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese')
# InfoTuple(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik')
# InfoTuple(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek')
# InfoTuple(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese')
# InfoTuple(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi')
# InfoTuple(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian')
# InfoTuple(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew')
# InfoTuple(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento')
# InfoTuple(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati')
# InfoTuple(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin')
# InfoTuple(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer')
# InfoTuple(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento')
# InfoTuple(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian')
# InfoTuple(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian')
# InfoTuple(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha')
# InfoTuple(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali')
# InfoTuple(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy')
# InfoTuple(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho')
# InfoTuple(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish')
# InfoTuple(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French')
# InfoTuple(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi')
# InfoTuple(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian')
# InfoTuple(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic')
# InfoTuple(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish')
# InfoTuple(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans')
# InfoTuple(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi')
# InfoTuple(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish')
# InfoTuple(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz')
# InfoTuple(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino')
# InfoTuple(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian')
# InfoTuple(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian')
# InfoTuple(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama')
# InfoTuple(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese')
# InfoTuple(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik')
# InfoTuple(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian')
# InfoTuple(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara')
# InfoTuple(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum')
# InfoTuple(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese')
# InfoTuple(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao')
# InfoTuple(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz')
# InfoTuple(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French')
# InfoTuple(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian')
# InfoTuple(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish')
# InfoTuple(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu')
# InfoTuple(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz')
# InfoTuple(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati')
# InfoTuple(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian')
# InfoTuple(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai')
# InfoTuple(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan')
# InfoTuple(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese')
# InfoTuple(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan')
# InfoTuple(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan')
# InfoTuple(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German')
# InfoTuple(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili')
# InfoTuple(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish')
# InfoTuple(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian')
# InfoTuple(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin')
# InfoTuple(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara')
# InfoTuple(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian')
# InfoTuple(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati')
# InfoTuple(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua')
# InfoTuple(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho')
# InfoTuple(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi')
# InfoTuple(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai')
# InfoTuple(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu')
# InfoTuple(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin')
# InfoTuple(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua')
# InfoTuple(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian')
# InfoTuple(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili')
# InfoTuple(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai')
# InfoTuple(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori')
# InfoTuple(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew')
# InfoTuple(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic')
# InfoTuple(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese')
# InfoTuple(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya')
# InfoTuple(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian')
# InfoTuple(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana')
# InfoTuple(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali')
# InfoTuple(ssn='200-81-7151', first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali')
# InfoTuple(ssn='201-53-1249', first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish')
# InfoTuple(ssn='202-84-1146', first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans')
# InfoTuple(ssn='203-35-7648', first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian')
# InfoTuple(ssn='205-69-7375', first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian')
# InfoTuple(ssn='205-87-2423', first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu')
# InfoTuple(ssn='206-28-6674', first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole')
# InfoTuple(ssn='206-83-8848', first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz')
# InfoTuple(ssn='208-74-2166', first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian')
# InfoTuple(ssn='208-80-5879', first_name='Rockie', last_name='Fryd', gender='Male', language='Korean')
# InfoTuple(ssn='209-50-8146', first_name='Kenna', last_name='Meryett', gender='Female', language='Czech')
# InfoTuple(ssn='209-58-4708', first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian')
# InfoTuple(ssn='210-91-4729', first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek')
# InfoTuple(ssn='211-04-1734', first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha')
# InfoTuple(ssn='211-13-5247', first_name='Wes', last_name='Weinberg', gender='Male', language='French')
# InfoTuple(ssn='211-15-5182', first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish')
# InfoTuple(ssn='211-19-6826', first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese')
# InfoTuple(ssn='212-40-0215', first_name='Giffie', last_name='Strauss', gender='Male', language='Azeri')
# InfoTuple(ssn='212-41-1496', first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil')
# InfoTuple(ssn='213-28-1395', first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali')
# InfoTuple(ssn='214-29-1189', first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole')
# InfoTuple(ssn='214-96-8581', first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian')
# InfoTuple(ssn='214-99-7584', first_name='Barny', last_name='Witherden', gender='Male', language='Czech')
# InfoTuple(ssn='216-89-3812', first_name='Florian', last_name='Jaze', gender='Male', language='Croatian')
# InfoTuple(ssn='216-97-3104', first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama')
# InfoTuple(ssn='217-71-3922', first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali')
# InfoTuple(ssn='217-81-5416', first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga')
# InfoTuple(ssn='218-14-4448', first_name='Keary', last_name='Druhan', gender='Male', language='Dutch')
# InfoTuple(ssn='218-25-9873', first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian')
# InfoTuple(ssn='218-31-1615', first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari')
# InfoTuple(ssn='218-49-7300', first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English')
# InfoTuple(ssn='220-16-0476', first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz')
# InfoTuple(ssn='220-38-0208', first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz')
# InfoTuple(ssn='222-39-8571', first_name='Fidelia', last_name='Domonkos', gender='Female', language='Fijian')
# InfoTuple(ssn='223-67-9203', first_name='Markus', last_name='Radband', gender='Male', language='Bosnian')
# InfoTuple(ssn='223-98-0846', first_name='Josy', last_name='Hadwick', gender='Female', language='Papiamento')
# InfoTuple(ssn='224-12-3436', first_name='Alister', last_name='Eakle', gender='Male', language='Estonian')
# InfoTuple(ssn='224-30-9267', first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish')
# InfoTuple(ssn='224-54-6919', first_name='Kelly', last_name='Shipman', gender='Male', language='Icelandic')
# InfoTuple(ssn='224-84-2271', first_name='Weider', last_name='Carlisle', gender='Male', language='Swedish')
# InfoTuple(ssn='224-99-0668', first_name='Brandy', last_name='Steed', gender='Male', language='Croatian')
# InfoTuple(ssn='225-08-5789', first_name='Tamra', last_name='Becken', gender='Female', language='Telugu')
# InfoTuple(ssn='225-64-2735', first_name='Graig', last_name='Rasher', gender='Male', language='Maltese')
# InfoTuple(ssn='226-76-4452', first_name='Van', last_name='Gervaise', gender='Male', language='Greek')
# InfoTuple(ssn='227-72-7247', first_name='Mauricio', last_name='Gush', gender='Male', language='Tajik')
# InfoTuple(ssn='228-16-7922', first_name='Tabby', last_name='Chitty', gender='Male', language='Spanish')
# InfoTuple(ssn='228-55-2042', first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech')
# InfoTuple(ssn='228-90-5077', first_name='Jonathon', last_name='Klugel', gender='Male', language='Hindi')
# InfoTuple(ssn='229-44-9909', first_name='Barnabas', last_name='Heppenspall', gender='Male', language='Icelandic')
# InfoTuple(ssn='230-09-1794', first_name='Xerxes', last_name='Mathivon', gender='Male', language='Danish')
# InfoTuple(ssn='230-48-0684', first_name='Clay', last_name='Peaurt', gender='Male', language='Dhivehi')
# InfoTuple(ssn='230-99-1485', first_name='Markus', last_name='Revill', gender='Male', language='Moldovan')
# InfoTuple(ssn='231-66-9264', first_name='Gisele', last_name='Castelow', gender='Female', language='Hiri Motu')
# InfoTuple(ssn='232-18-5397', first_name='Clare', last_name='McGairl', gender='Female', language='Bengali')
# InfoTuple(ssn='233-27-2377', first_name='Arlyne', last_name='Stenning', gender='Female', language='Dari')
# InfoTuple(ssn='235-10-3518', first_name='Winfield', last_name='Purvis', gender='Male', language='Estonian')
# InfoTuple(ssn='236-31-8333', first_name='Wendeline', last_name='Millins', gender='Female', language='Kashmiri')
# InfoTuple(ssn='236-37-2567', first_name='Ariel', last_name='Murrigan', gender='Female', language='West Frisian')
# InfoTuple(ssn='237-48-6737', first_name='Eal', last_name='Ducastel', gender='Male', language='Indonesian')
# InfoTuple(ssn='237-80-7039', first_name='Ardyce', last_name='Hunn', gender='Female', language='Maltese')
# InfoTuple(ssn='238-13-8034', first_name='Estrellita', last_name='Heavy', gender='Female', language='Azeri')
# InfoTuple(ssn='238-39-9999', first_name='Pauly', last_name='Griffin', gender='Female', language='Georgian')
# InfoTuple(ssn='239-09-9133', first_name='Tom', last_name='Roggeman', gender='Male', language='Sotho')
# InfoTuple(ssn='239-37-4122', first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana')
# InfoTuple(ssn='240-08-8805', first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish')
# InfoTuple(ssn='240-32-8915', first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento')
# InfoTuple(ssn='240-67-6258', first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi')
# InfoTuple(ssn='242-22-9624', first_name='Felice', last_name='Surr', gender='Male', language='Afrikaans')
# InfoTuple(ssn='243-37-9496', first_name='Verine', last_name='Etchells', gender='Female', language='Burmese')
# InfoTuple(ssn='243-44-4611', first_name='Shani', last_name="O'Tierney", gender='Female', language='Aymara')
# InfoTuple(ssn='244-34-2210', first_name='Lek', last_name='Heino', gender='Male', language='New Zealand Sign Language')
# InfoTuple(ssn='244-52-7593', first_name='Erda', last_name='Paulusch', gender='Female', language='Gujarati')
# InfoTuple(ssn='244-79-3004', first_name='Renault', last_name='Stollard', gender='Male', language='Amharic')
# InfoTuple(ssn='244-81-0671', first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan')
# InfoTuple(ssn='245-60-5880', first_name='Oby', last_name='Hauxby', gender='Male', language='French')
# InfoTuple(ssn='245-77-4110', first_name='Alasdair', last_name='McAndrew', gender='Male', language='Czech')
# InfoTuple(ssn='247-08-9326', first_name='Minni', last_name='Scurman', gender='Female', language='Kannada')
# InfoTuple(ssn='247-86-5288', first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian')
# InfoTuple(ssn='248-07-9757', first_name='Sean', last_name='Ham', gender='Male', language='Luxembourgish')
# InfoTuple(ssn='248-23-0150', first_name='Welbie', last_name='Gilley', gender='Male', language='Korean')
# InfoTuple(ssn='249-19-5514', first_name='Yehudi', last_name='Pharoah', gender='Male', language='Latvian')
# InfoTuple(ssn='253-61-8401', first_name='Genny', last_name='Juara', gender='Female', language='Tswana')
# InfoTuple(ssn='254-10-6071', first_name='Dwight', last_name='Eastcourt', gender='Male', language='Oriya')
# InfoTuple(ssn='254-92-9669', first_name='Tom', last_name='Larking', gender='Male', language='Icelandic')
# InfoTuple(ssn='255-81-0958', first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian')
# InfoTuple(ssn='256-54-7507', first_name='Angus', last_name='Cullip', gender='Male', language='Spanish')
# InfoTuple(ssn='256-57-0666', first_name='Rip', last_name='Grube', gender='Male', language='Ndebele')
# InfoTuple(ssn='257-12-6834', first_name='Derward', last_name='Paladini', gender='Male', language='Thai')
# InfoTuple(ssn='257-59-8603', first_name='Cyrillus', last_name='Sanchiz', gender='Male', language='Romanian')
# InfoTuple(ssn='257-77-3669', first_name='Ynez', last_name='Hain', gender='Female', language='Kazakh')
# InfoTuple(ssn='258-22-6416', first_name='Veriee', last_name='Klein', gender='Female', language='Northern Sotho')
# InfoTuple(ssn='259-38-5920', first_name='Jethro', last_name='Rustidge', gender='Male', language='Fijian')
# InfoTuple(ssn='261-14-9490', first_name='Lorry', last_name='Boshere', gender='Male', language='Oriya')
# InfoTuple(ssn='262-09-2144', first_name='Leigh', last_name='Paxforde', gender='Male', language='Portuguese')
# InfoTuple(ssn='262-46-7573', first_name='Lorene', last_name='Vagg', gender='Female', language='Punjabi')
# InfoTuple(ssn='262-55-4066', first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian')
# InfoTuple(ssn='262-66-7030', first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer')
# InfoTuple(ssn='264-39-3910', first_name='Elysia', last_name='Favell', gender='Female', language='Hindi')
# InfoTuple(ssn='266-86-9980', first_name='Rita', last_name='Leving', gender='Female', language='Latvian')
# InfoTuple(ssn='267-75-6383', first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian')
# InfoTuple(ssn='269-01-2640', first_name='Russell', last_name='Dabner', gender='Male', language='Danish')
# InfoTuple(ssn='271-04-0134', first_name='Eadith', last_name='Jerg', gender='Female', language='Gagauz')
# InfoTuple(ssn='271-81-9938', first_name='James', last_name='Robbins', gender='Male', language='Bengali')
# InfoTuple(ssn='271-93-3051', first_name='Augustin', last_name='Agiolfinger', gender='Male', language='Latvian')
# InfoTuple(ssn='272-50-7309', first_name='Sig', last_name='Ather', gender='Male', language='Catalan')
# InfoTuple(ssn='272-81-7979', first_name='Sherlocke', last_name='Giddings', gender='Male', language='Georgian')
# InfoTuple(ssn='273-49-8218', first_name='Haze', last_name='Starkings', gender='Male', language='Portuguese')
# InfoTuple(ssn='274-50-3806', first_name='Shurlocke', last_name='Aron', gender='Male', language='Punjabi')
# InfoTuple(ssn='274-76-9883', first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali')
# InfoTuple(ssn='276-05-2973', first_name='Cly', last_name='Yerlett', gender='Male', language='Kazakh')
# InfoTuple(ssn='278-55-5842', first_name='Korie', last_name='Di Pietro', gender='Female', language='German')
# InfoTuple(ssn='278-64-4853', first_name='Diane-marie', last_name='Broggini', gender='Female', language='Tsonga')
# InfoTuple(ssn='279-12-7167', first_name='Elbertina', last_name='Alders', gender='Female', language='Amharic')
# InfoTuple(ssn='279-40-5540', first_name='Montague', last_name='Knowler', gender='Male', language='Chinese')
# InfoTuple(ssn='279-49-5682', first_name='Kleon', last_name='Tembridge', gender='Male', language='Gagauz')
# InfoTuple(ssn='280-53-7447', first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian')
# InfoTuple(ssn='280-98-4410', first_name='Ealasaid', last_name='Devon', gender='Female', language='Tok Pisin')
# InfoTuple(ssn='281-23-3458', first_name='Bettina', last_name='Danilov', gender='Female', language='Sotho')
# InfoTuple(ssn='282-83-9206', first_name='Jackie', last_name='McPhater', gender='Male', language='Gagauz')
# InfoTuple(ssn='283-04-6835', first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha')
# InfoTuple(ssn='286-26-4004', first_name='Augustus', last_name='Doodson', gender='Male', language='Romanian')
# InfoTuple(ssn='287-57-9688', first_name='Joachim', last_name='Moncreiff', gender='Male', language='Catalan')
# InfoTuple(ssn='287-66-2660', first_name='Larissa', last_name='Airy', gender='Female', language='Bislama')
# InfoTuple(ssn='288-54-7233', first_name='Hedy', last_name='Eaklee', gender='Female', language='English')
# InfoTuple(ssn='288-87-6462', first_name='Stanislaus', last_name='Haylor', gender='Male', language='Kannada')
# InfoTuple(ssn='289-03-9882', first_name='Giusto', last_name='Baszniak', gender='Male', language='Yiddish')
# InfoTuple(ssn='289-09-8686', first_name='Heath', last_name='Stallan', gender='Male', language='Malayalam')
# InfoTuple(ssn='290-25-7300', first_name='Bowie', last_name='Bancroft', gender='Male', language='Thai')
# InfoTuple(ssn='290-82-4968', first_name='Ingram', last_name='Kincade', gender='Male', language='Moldovan')
# InfoTuple(ssn='293-54-3694', first_name='Theodora', last_name='Geddes', gender='Female', language='Maori')
# InfoTuple(ssn='294-27-9936', first_name='Cari', last_name='Bradane', gender='Female', language='Japanese')
# InfoTuple(ssn='294-53-1911', first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian')
# InfoTuple(ssn='295-63-7693', first_name='Fonzie', last_name='Fattorini', gender='Male', language='Estonian')
# InfoTuple(ssn='296-32-7910', first_name='Harlene', last_name='Morrill', gender='Female', language='Swati')
# InfoTuple(ssn='296-88-0097', first_name='Herculie', last_name='Branthwaite', gender='Male', language='Hungarian')
# InfoTuple(ssn='296-90-4908', first_name='Holt', last_name='Angel', gender='Male', language='Tamil')
# InfoTuple(ssn='297-63-1154', first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin')
# InfoTuple(ssn='298-06-3497', first_name='Moshe', last_name='Thomassin', gender='Male', language='Polish')
# InfoTuple(ssn='298-69-9168', first_name='Shea', last_name='Canon', gender='Male', language='Finnish')
# InfoTuple(ssn='298-70-6018', first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans')
# InfoTuple(ssn='298-79-7640', first_name='Mycah', last_name='Hillam', gender='Male', language='Swahili')
# InfoTuple(ssn='299-03-6911', first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz')
# InfoTuple(ssn='299-38-0483', first_name='Robb', last_name='Posner', gender='Male', language='Italian')
# InfoTuple(ssn='299-77-1060', first_name='Bellina', last_name='Galbreth', gender='Female', language='Norwegian')
# InfoTuple(ssn='300-59-3610', first_name='Tam', last_name='Howles', gender='Male', language='Pashto')
# InfoTuple(ssn='300-76-8770', first_name='Danielle', last_name='Rowth', gender='Female', language='Italian')
# InfoTuple(ssn='300-80-7209', first_name='Gabbie', last_name='Burney', gender='Female', language='Dutch')
# InfoTuple(ssn='301-26-4306', first_name='Emmye', last_name='Whelpdale', gender='Female', language='Tajik')
# InfoTuple(ssn='301-51-0522', first_name='Kenneth', last_name='Methley', gender='Male', language='Papiamento')
# InfoTuple(ssn='302-64-4858', first_name='Hakeem', last_name='Zelley', gender='Male', language='Afrikaans')
# InfoTuple(ssn='304-48-4312', first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin')
# InfoTuple(ssn='305-07-1498', first_name='Ruddy', last_name="O'Crotty", gender='Male', language='Spanish')
# InfoTuple(ssn='306-23-2423', first_name='Ree', last_name='Meader', gender='Female', language='Polish')
# InfoTuple(ssn='306-86-2930', first_name='Kassie', last_name='Neaverson', gender='Female', language='Luxembourgish')
# InfoTuple(ssn='308-58-0964', first_name='Talbert', last_name='Osipov', gender='Male', language='Tetum')
# InfoTuple(ssn='309-04-0364', first_name='Dov', last_name='Speight', gender='Male', language='Tajik')
# InfoTuple(ssn='309-38-8085', first_name='Nell', last_name='Scrigmour', gender='Female', language='Persian')
# InfoTuple(ssn='310-60-2027', first_name='Zacherie', last_name='Parken', gender='Male', language='Albanian')
# InfoTuple(ssn='311-46-9296', first_name='Alic', last_name='Pabel', gender='Male', language='Fijian')
# InfoTuple(ssn='312-38-7084', first_name='Ezri', last_name='Paolicchi', gender='Male', language='Malagasy')
# InfoTuple(ssn='312-59-3476', first_name='Sadye', last_name='Beloe', gender='Female', language='Icelandic')
# InfoTuple(ssn='312-77-3647', first_name='Hussein', last_name='Blything', gender='Male', language='Hebrew')
# InfoTuple(ssn='313-02-7822', first_name='Spence', last_name='Climer', gender='Male', language='Maori')
# InfoTuple(ssn='313-52-7312', first_name='Farrand', last_name='MacKenzie', gender='Female', language='French')
# InfoTuple(ssn='315-12-5664', first_name='Vere', last_name='Morlon', gender='Female', language='German')
# InfoTuple(ssn='315-26-2241', first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian')
# InfoTuple(ssn='315-44-9671', first_name='Ximenez', last_name='Maghull', gender='Male', language='Macedonian')
# InfoTuple(ssn='315-78-5587', first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin')
# InfoTuple(ssn='317-28-1600', first_name='Rodrick', last_name='Abrahams', gender='Male', language='Assamese')
# InfoTuple(ssn='317-43-2055', first_name='Jocelyn', last_name='Gildroy', gender='Female', language='Punjabi')
# InfoTuple(ssn='318-58-5314', first_name='Stephan', last_name='Peatt', gender='Male', language='New Zealand Sign Language')
# InfoTuple(ssn='319-43-0465', first_name='Boothe', last_name='Vanin', gender='Male', language='West Frisian')
# InfoTuple(ssn='320-90-1419', first_name='Em', last_name='Darwood', gender='Male', language='Icelandic')
# InfoTuple(ssn='320-97-9147', first_name='Roch', last_name='Wahlberg', gender='Female', language='Thai')
# InfoTuple(ssn='323-28-6705', first_name='Christiano', last_name='Stoffler', gender='Male', language='Kyrgyz')
# InfoTuple(ssn='323-33-8689', first_name='Dulcinea', last_name='Lundberg', gender='Female', language='Dutch')
# InfoTuple(ssn='324-39-5230', first_name='Alexandrina', last_name='Dahlbom', gender='Female', language='Moldovan')
# InfoTuple(ssn='324-73-8895', first_name='Walliw', last_name='Alstead', gender='Female', language='Guarana')
# InfoTuple(ssn='324-75-6098', first_name='Rafael', last_name='Robinett', gender='Male', language='Portuguese')
# InfoTuple(ssn='326-64-9957', first_name='Jorgan', last_name='Renowden', gender='Male', language='Swati')
# InfoTuple(ssn='327-52-0546', first_name='Carlota', last_name='Hovey', gender='Female', language='English')
# InfoTuple(ssn='327-88-7554', first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili')
# InfoTuple(ssn='330-99-3055', first_name='Marinna', last_name='Dally', gender='Female', language='Azeri')
# InfoTuple(ssn='332-83-6591', first_name='Forrester', last_name='Cullabine', gender='Male', language='Dzongkha')
# InfoTuple(ssn='333-52-5097', first_name='Florentia', last_name='Espinazo', gender='Female', language='Tetum')
# InfoTuple(ssn='333-95-5025', first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu')
# InfoTuple(ssn='335-35-1520', first_name='Ervin', last_name='Hugues', gender='Male', language='Armenian')
# InfoTuple(ssn='336-48-2579', first_name='Renee', last_name='Crank', gender='Female', language='Armenian')
# InfoTuple(ssn='339-27-8046', first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian')
# InfoTuple(ssn='339-71-2687', first_name='Marlie', last_name='Corpe', gender='Female', language='Persian')
# InfoTuple(ssn='341-10-6840', first_name='Cyrille', last_name='Critchlow', gender='Male', language='Portuguese')
# InfoTuple(ssn='342-05-9057', first_name='Beatrix', last_name='Relton', gender='Female', language='Latvian')
# InfoTuple(ssn='342-55-0538', first_name='Hilliary', last_name='Suddards', gender='Female', language='Dzongkha')
# InfoTuple(ssn='342-90-9333', first_name='Geri', last_name='Yesinov', gender='Male', language='Norwegian')
# InfoTuple(ssn='343-20-8407', first_name='Bradford', last_name='Niemiec', gender='Male', language='Chinese')
# InfoTuple(ssn='343-81-3179', first_name='Reinhard', last_name='Bortolutti', gender='Male', language='Kannada')
# InfoTuple(ssn='345-74-2160', first_name='Camile', last_name='Pengelly', gender='Female', language='Lao')
# InfoTuple(ssn='347-09-3254', first_name='Dulciana', last_name='Hexum', gender='Female', language='Lao')
# InfoTuple(ssn='347-64-8652', first_name='Dusty', last_name='Morat', gender='Female', language='Japanese')
# InfoTuple(ssn='348-73-4312', first_name='Elberta', last_name='Howden', gender='Female', language='Khmer')
# InfoTuple(ssn='348-74-3224', first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian')
# InfoTuple(ssn='349-53-8864', first_name='Muffin', last_name='Lord', gender='Female', language='Georgian')
# InfoTuple(ssn='349-67-7502', first_name='Ari', last_name='Yitzhakov', gender='Male', language='Zulu')
# InfoTuple(ssn='350-20-9593', first_name='Eldridge', last_name='Crispin', gender='Male', language='Dutch')
# InfoTuple(ssn='350-80-4646', first_name='Harp', last_name='Du Plantier', gender='Male', language='Dutch')
# InfoTuple(ssn='351-73-2802', first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian')
# InfoTuple(ssn='355-21-9711', first_name='Daryn', last_name='Battin', gender='Female', language='Georgian')
# InfoTuple(ssn='355-52-9767', first_name='Kacy', last_name='Offen', gender='Female', language='Kurdish')
# InfoTuple(ssn='355-96-7706', first_name='Lauritz', last_name='Lucock', gender='Male', language='Mongolian')
# InfoTuple(ssn='356-39-9199', first_name='Arney', last_name='Polglaze', gender='Male', language='Marathi')
# InfoTuple(ssn='357-37-6094', first_name='Chrisse', last_name='Kirton', gender='Male', language='Latvian')
# InfoTuple(ssn='358-84-7049', first_name='Emalee', last_name='McCleary', gender='Female', language='Thai')
# InfoTuple(ssn='360-69-6230', first_name='Grannie', last_name='Champ', gender='Male', language='Belarusian')
# InfoTuple(ssn='361-06-1530', first_name='Luis', last_name='Ashborne', gender='Male', language='Mongolian')
# InfoTuple(ssn='361-42-7068', first_name='Ashia', last_name='Ferran', gender='Female', language='West Frisian')
# InfoTuple(ssn='361-49-4597', first_name='Adan', last_name='Janssen', gender='Male', language='Swedish')
# InfoTuple(ssn='361-83-5004', first_name='Wilona', last_name='Sink', gender='Female', language='Sotho')
# InfoTuple(ssn='362-09-8563', first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic')
# InfoTuple(ssn='362-12-7902', first_name='Weber', last_name='Legrand', gender='Male', language='Swahili')
# InfoTuple(ssn='364-25-0166', first_name='Arnuad', last_name='Planque', gender='Male', language='Hindi')
# InfoTuple(ssn='364-65-2174', first_name='Bernarr', last_name='Wollard', gender='Male', language='Irish Gaelic')
# InfoTuple(ssn='366-61-0607', first_name='Bethena', last_name='Joicey', gender='Female', language='Haitian Creole')
# InfoTuple(ssn='367-22-8998', first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz')
# InfoTuple(ssn='367-62-4426', first_name='Sigismondo', last_name='Lerohan', gender='Male', language='Georgian')
# InfoTuple(ssn='370-01-6977', first_name='Hugues', last_name='Jeffryes', gender='Male', language='Georgian')
# InfoTuple(ssn='370-24-5876', first_name='Sergei', last_name='Risby', gender='Male', language='Bulgarian')
# InfoTuple(ssn='370-72-6509', first_name='Wrennie', last_name='McCrorie', gender='Female', language='Papiamento')
# InfoTuple(ssn='371-28-5892', first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga')
# InfoTuple(ssn='371-44-0582', first_name='Clemmy', last_name='Cogzell', gender='Male', language='Estonian')
# InfoTuple(ssn='371-62-3727', first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch')
# InfoTuple(ssn='371-88-9249', first_name='Nealon', last_name='Oxtaby', gender='Male', language='German')
# InfoTuple(ssn='372-44-7487', first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan')
# InfoTuple(ssn='372-62-7057', first_name='Eleanora', last_name='Vazquez', gender='Female', language='Gujarati')
# InfoTuple(ssn='373-67-2734', first_name='Ileana', last_name='Luty', gender='Female', language='Italian')
# InfoTuple(ssn='374-47-0262', first_name='Bank', last_name='Evitts', gender='Male', language='Aymara')
# InfoTuple(ssn='378-08-0805', first_name='Carroll', last_name='Harty', gender='Female', language='Swedish')
# InfoTuple(ssn='378-60-2472', first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian')
# InfoTuple(ssn='378-66-0449', first_name='Kelby', last_name='Wincer', gender='Male', language='Pashto')
# InfoTuple(ssn='378-79-0193', first_name='Kenny', last_name='Josefsen', gender='Male', language='Danish')
# InfoTuple(ssn='378-88-6805', first_name='Vittoria', last_name='Oldroyd', gender='Female', language='Moldovan')
# InfoTuple(ssn='379-07-8748', first_name='Dyanna', last_name='Noto', gender='Female', language='Polish')
# InfoTuple(ssn='380-33-9730', first_name='Katinka', last_name='Piet', gender='Female', language='Malay')
# InfoTuple(ssn='380-35-3854', first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama')
# InfoTuple(ssn='383-18-4058', first_name='Frederigo', last_name='Cooksey', gender='Male', language='Indonesian')
# InfoTuple(ssn='384-30-6793', first_name='Kipp', last_name='Burnyate', gender='Male', language='English')
# InfoTuple(ssn='384-94-2772', first_name='Ramsay', last_name='Dolbey', gender='Male', language='Tok Pisin')
# InfoTuple(ssn='385-30-1777', first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana')
# InfoTuple(ssn='385-34-7828', first_name='Dori', last_name='Quogan', gender='Female', language='Afrikaans')
# InfoTuple(ssn='385-98-0431', first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana')
# InfoTuple(ssn='386-15-7960', first_name='Steffie', last_name='Tedahl', gender='Female', language='Punjabi')
# InfoTuple(ssn='386-34-4088', first_name='Adamo', last_name='Wogden', gender='Male', language='Arabic')
# InfoTuple(ssn='386-68-9884', first_name='Francis', last_name='Foch', gender='Male', language='Dzongkha')
# InfoTuple(ssn='386-97-3523', first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish')
# InfoTuple(ssn='389-31-0910', first_name='Mac', last_name='Westrey', gender='Male', language='Armenian')
# InfoTuple(ssn='389-51-1424', first_name='Isadore', last_name='Orbine', gender='Male', language='Pashto')
# InfoTuple(ssn='389-84-8254', first_name='Chiquita', last_name='Jolliman', gender='Female', language='Marathi')
# InfoTuple(ssn='390-74-3062', first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian')
# InfoTuple(ssn='391-14-9280', first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin')
# InfoTuple(ssn='391-47-4578', first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese')
# InfoTuple(ssn='391-73-2830', first_name='Padget', last_name='Manthorpe', gender='Male', language='Marathi')
# InfoTuple(ssn='393-22-6585', first_name='Reinold', last_name='Ellif', gender='Male', language='Nepali')
# InfoTuple(ssn='396-51-1559', first_name='Natasha', last_name='Dafter', gender='Female', language='Maori')
# InfoTuple(ssn='397-16-5372', first_name='Alonzo', last_name='Mc Mechan', gender='Male', language='Polish')
# InfoTuple(ssn='397-29-8349', first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin')
# InfoTuple(ssn='397-87-8282', first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian')
# InfoTuple(ssn='399-31-2815', first_name='Durward', last_name='Giamitti', gender='Male', language='Tok Pisin')
# InfoTuple(ssn='399-63-8810', first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento')
# InfoTuple(ssn='399-81-6133', first_name='Viv', last_name='Borsay', gender='Female', language='Chinese')
# InfoTuple(ssn='400-21-8654', first_name='Travus', last_name='Miranda', gender='Male', language='Kannada')
# InfoTuple(ssn='400-77-6007', first_name='Dannie', last_name='Shurmer', gender='Male', language='Tajik')
# InfoTuple(ssn='402-61-3479', first_name='Mariele', last_name='Meyrick', gender='Female', language='Telugu')
# InfoTuple(ssn='402-65-2055', first_name='Martie', last_name='Crawshaw', gender='Male', language='Marathi')
# InfoTuple(ssn='402-88-5570', first_name='Torry', last_name='Bossons', gender='Male', language='Chinese')
# InfoTuple(ssn='403-65-1535', first_name='Cathy', last_name='Gabe', gender='Female', language='Hiri Motu')
# InfoTuple(ssn='404-57-4023', first_name='Pattin', last_name='Jarmain', gender='Male', language='Hindi')
# InfoTuple(ssn='405-25-1422', first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati')
# InfoTuple(ssn='406-15-5123', first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari')
# InfoTuple(ssn='406-24-4867', first_name='Renaud', last_name='Fleetwood', gender='Male', language='Papiamento')
# InfoTuple(ssn='406-49-0634', first_name='Lolita', last_name='Dailey', gender='Female', language='Czech')
# InfoTuple(ssn='407-30-0910', first_name='Gerhard', last_name='Crielly', gender='Male', language='Bislama')
# InfoTuple(ssn='407-80-7367', first_name='Sigismundo', last_name='Pothbury', gender='Male', language='Latvian')
# InfoTuple(ssn='407-99-6159', first_name='Flynn', last_name='Jirasek', gender='Male', language='Afrikaans')
# InfoTuple(ssn='408-83-7943', first_name='Wallie', last_name='Klosterman', gender='Male', language='Hungarian')
# InfoTuple(ssn='408-98-3291', first_name='Karia', last_name='Riquet', gender='Female', language='Italian')
# InfoTuple(ssn='409-58-2034', first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili')
# InfoTuple(ssn='409-90-8946', first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian')
# InfoTuple(ssn='410-38-4237', first_name='Gibbie', last_name='Seamer', gender='Male', language='Tok Pisin')
# InfoTuple(ssn='410-76-5092', first_name='Spencer', last_name='Dallon', gender='Male', language='Swati')
# InfoTuple(ssn='411-21-4276', first_name='Mari', last_name='Livick', gender='Female', language='Pashto')
# InfoTuple(ssn='411-43-4217', first_name='Cull', last_name='Noddle', gender='Male', language='Spanish')
# InfoTuple(ssn='411-79-4655', first_name='Caterina', last_name='Coey', gender='Female', language='French')
# InfoTuple(ssn='412-50-9133', first_name='Dianemarie', last_name='Withey', gender='Female', language='Czech')
# InfoTuple(ssn='412-59-0452', first_name='Seamus', last_name='Petrusch', gender='Male', language='Spanish')
# InfoTuple(ssn='412-59-8022', first_name='Brenna', last_name='Follin', gender='Female', language='Gagauz')
# InfoTuple(ssn='412-79-8951', first_name='Giorgi', last_name='Sisnett', gender='Male', language='Tamil')
# InfoTuple(ssn='413-14-3928', first_name='Shaine', last_name='Liebrecht', gender='Male', language='Sotho')
# InfoTuple(ssn='413-56-5613', first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali')
# InfoTuple(ssn='415-42-0898', first_name='Karlik', last_name='Adlam', gender='Male', language='Mongolian')
# InfoTuple(ssn='415-74-2251', first_name='Pattin', last_name='Greson', gender='Male', language='Italian')
# InfoTuple(ssn='416-37-7763', first_name='Emelia', last_name='Hancell', gender='Female', language='German')
# InfoTuple(ssn='416-38-3607', first_name='Jerry', last_name='Christin', gender='Male', language='Hebrew')
# InfoTuple(ssn='416-80-6367', first_name='Myrna', last_name='Christoffe', gender='Female', language='Tok Pisin')
# InfoTuple(ssn='416-87-0469', first_name='Dannel', last_name='Whyffen', gender='Male', language='Estonian')
# InfoTuple(ssn='418-72-1888', first_name='Roddy', last_name='Worman', gender='Male', language='Bosnian')
# InfoTuple(ssn='418-99-6659', first_name='Grenville', last_name='Gulliver', gender='Male', language='Ndebele')
# InfoTuple(ssn='420-46-7789', first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language')
# InfoTuple(ssn='420-52-3813', first_name='Arnaldo', last_name='Balsdone', gender='Male', language='Zulu')
# InfoTuple(ssn='421-01-2511', first_name='Mikaela', last_name='Andrivot', gender='Female', language='English')
# InfoTuple(ssn='421-13-9794', first_name='Minne', last_name='Measey', gender='Female', language='Danish')
# InfoTuple(ssn='421-20-3448', first_name='Alie', last_name='Gerauld', gender='Female', language='Khmer')
# InfoTuple(ssn='421-88-7316', first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch')
# InfoTuple(ssn='422-67-4000', first_name='Corby', last_name='Boyington', gender='Male', language='Sotho')
# InfoTuple(ssn='423-62-1820', first_name='Ruddy', last_name='Ingerson', gender='Male', language='Maori')
# ...
# InfoTuple(ssn='775-09-9949', first_name='Orlando', last_name='Gresley', gender='Male', language='Danish')
# InfoTuple(ssn='777-05-1491', first_name='Devora', last_name='Ashbridge', gender='Female', language='Somali')
# InfoTuple(ssn='777-68-2978', first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho')
# InfoTuple(ssn='777-94-4586', first_name='Siward', last_name='Blues', gender='Male', language='Thai')
# InfoTuple(ssn='778-74-8262', first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian')
# InfoTuple(ssn='779-59-1449', first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian')
# InfoTuple(ssn='780-69-8282', first_name='Sibeal', last_name='Dawney', gender='Female', language='Czech')
# InfoTuple(ssn='781-88-2076', first_name='Gelya', last_name='Stell', gender='Female', language='Czech')
# InfoTuple(ssn='782-46-9660', first_name='Malina', last_name='Julyan', gender='Female', language='Burmese')
# InfoTuple(ssn='782-60-6848', first_name='Jehu', last_name='Scholig', gender='Male', language='Polish')
# InfoTuple(ssn='783-22-9258', first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese')
# InfoTuple(ssn='784-88-0730', first_name='Baxie', last_name='Judd', gender='Male', language='Maltese')
# InfoTuple(ssn='785-14-5978', first_name='Trista', last_name='Watkinson', gender='Female', language='Moldovan')
# InfoTuple(ssn='786-56-3561', first_name='Wait', last_name='Boyda', gender='Male', language='Norwegian')
# InfoTuple(ssn='786-63-6223', first_name='Adham', last_name='Toope', gender='Male', language='Belarusian')
# InfoTuple(ssn='787-05-9008', first_name='Ricki', last_name='Jurges', gender='Female', language='Arabic')
# InfoTuple(ssn='787-09-5697', first_name='Chelsea', last_name='Pashby', gender='Female', language='Northern Sotho')
# InfoTuple(ssn='787-10-7877', first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu')
# InfoTuple(ssn='788-15-2625', first_name='Drusilla', last_name='Bannester', gender='Female', language='Gujarati')
# InfoTuple(ssn='789-70-1821', first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri')
# InfoTuple(ssn='790-04-1283', first_name='Christyna', last_name='Morrissey', gender='Female', language='Quechua')
# InfoTuple(ssn='792-71-8046', first_name='Carly', last_name='Hazley', gender='Female', language='Guarana')
# InfoTuple(ssn='794-24-3802', first_name='Esther', last_name='Sayton', gender='Female', language='Somali')
# InfoTuple(ssn='795-56-6486', first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz')
# InfoTuple(ssn='795-77-5263', first_name='Burty', last_name='Frosdick', gender='Male', language='Marathi')
# InfoTuple(ssn='797-05-2289', first_name='Fanchon', last_name='Petrushanko', gender='Female', language='Finnish')
# InfoTuple(ssn='797-25-9814', first_name='Aleksandr', last_name='Swalwell', gender='Male', language='Pashto')
# InfoTuple(ssn='797-65-2382', first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish')
# InfoTuple(ssn='797-87-7992', first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian')
# InfoTuple(ssn='798-34-1082', first_name='Henka', last_name='Synder', gender='Female', language='Italian')
# InfoTuple(ssn='798-65-5644', first_name='Irita', last_name='Heady', gender='Female', language='Montenegrin')
# InfoTuple(ssn='800-06-9721', first_name='Carter', last_name='Waldron', gender='Male', language='Estonian')
# InfoTuple(ssn='801-08-8313', first_name='Aida', last_name='Whitemarsh', gender='Female', language='Chinese')
# InfoTuple(ssn='801-92-6460', first_name='Levi', last_name='Downgate', gender='Male', language='Belarusian')
# InfoTuple(ssn='801-99-2773', first_name='Justinian', last_name='Carlesso', gender='Male', language='Japanese')
# InfoTuple(ssn='804-46-0617', first_name='Geneva', last_name='Crinion', gender='Female', language='Hungarian')
# InfoTuple(ssn='807-13-5922', first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho')
# InfoTuple(ssn='807-24-6202', first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu')
# InfoTuple(ssn='807-25-6136', first_name='Sammy', last_name='Linnard', gender='Female', language='Dutch')
# InfoTuple(ssn='807-35-8936', first_name='Georgi', last_name='Widd', gender='Male', language='Afrikaans')
# InfoTuple(ssn='807-50-8539', first_name='Jaquith', last_name='Erdes', gender='Female', language='Dhivehi')
# InfoTuple(ssn='807-60-5615', first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi')
# InfoTuple(ssn='808-55-8658', first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese')
# InfoTuple(ssn='808-80-2542', first_name='Gustaf', last_name='Hullot', gender='Male', language='Persian')
# InfoTuple(ssn='811-65-2750', first_name='Minetta', last_name='Dusting', gender='Female', language='Spanish')
# InfoTuple(ssn='812-11-9403', first_name='Carmina', last_name='Turnell', gender='Female', language='West Frisian')
# InfoTuple(ssn='813-42-4142', first_name='Killy', last_name='Threadgould', gender='Male', language='Polish')
# InfoTuple(ssn='813-47-5215', first_name='Willi', last_name='Collet', gender='Male', language='Gujarati')
# InfoTuple(ssn='815-83-0300', first_name='Romeo', last_name='Rayworth', gender='Male', language='Thai')
# InfoTuple(ssn='816-31-3858', first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin')
# InfoTuple(ssn='816-47-4782', first_name='Wilmer', last_name='Maides', gender='Male', language='Aymara')
# InfoTuple(ssn='816-90-2049', first_name='Berry', last_name='Delagnes', gender='Female', language='Bengali')
# InfoTuple(ssn='817-04-1950', first_name='Fletcher', last_name='McGrouther', gender='Male', language='Albanian')
# InfoTuple(ssn='817-25-7437', first_name='Randall', last_name='Fibbitts', gender='Male', language='Yiddish')
# InfoTuple(ssn='817-80-8930', first_name='Lib', last_name='Skein', gender='Female', language='Arabic')
# InfoTuple(ssn='818-61-0770', first_name='Stanly', last_name='Casseldine', gender='Male', language='Belarusian')
# InfoTuple(ssn='819-52-5886', first_name='Paulette', last_name='McAree', gender='Female', language='Arabic')
# InfoTuple(ssn='819-64-1414', first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino')
# InfoTuple(ssn='820-96-1105', first_name='Andy', last_name='Sayce', gender='Female', language='Pashto')
# InfoTuple(ssn='822-05-9037', first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan')
# InfoTuple(ssn='822-30-4861', first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian')
# InfoTuple(ssn='823-27-0762', first_name='Marten', last_name='McCord', gender='Male', language='Indonesian')
# InfoTuple(ssn='823-75-5753', first_name='Thibaut', last_name='Van Schafflaer', gender='Male', language='Chinese')
# InfoTuple(ssn='824-89-4169', first_name='Tamqrah', last_name='Goroni', gender='Female', language='Swedish')
# InfoTuple(ssn='826-97-8029', first_name='Llewellyn', last_name='Shimwell', gender='Male', language='Belarusian')
# InfoTuple(ssn='827-62-4599', first_name='Phyllys', last_name='Akast', gender='Female', language='Armenian')
# InfoTuple(ssn='830-23-1573', first_name='Carine', last_name='Abramin', gender='Female', language='Bislama')
# InfoTuple(ssn='831-44-3286', first_name='Leesa', last_name='Finci', gender='Female', language='Nepali')
# InfoTuple(ssn='833-01-1428', first_name='Ashlan', last_name='Zannotti', gender='Female', language='Finnish')
# InfoTuple(ssn='835-54-3785', first_name='Nathaniel', last_name='Wegman', gender='Male', language='Azeri')
# InfoTuple(ssn='836-40-1837', first_name='Brocky', last_name='Kewzick', gender='Male', language='Armenian')
# InfoTuple(ssn='836-99-3309', first_name='Cobby', last_name='Mutter', gender='Male', language='Georgian')
# InfoTuple(ssn='837-76-5619', first_name='Alleyn', last_name='Parade', gender='Male', language='Croatian')
# InfoTuple(ssn='838-69-1351', first_name='Alwin', last_name='Hazzard', gender='Male', language='Kannada')
# InfoTuple(ssn='840-41-7929', first_name='Sherlock', last_name='Pinshon', gender='Male', language='Khmer')
# InfoTuple(ssn='841-64-8517', first_name='Hugues', last_name='Kenealy', gender='Male', language='Korean')
# InfoTuple(ssn='842-90-7557', first_name='Brit', last_name='Weall', gender='Female', language='West Frisian')
# InfoTuple(ssn='844-15-4668', first_name='Eleonora', last_name='Delete', gender='Female', language='Hiri Motu')
# InfoTuple(ssn='844-50-7305', first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian')
# InfoTuple(ssn='846-07-1407', first_name='Tobias', last_name='Blakelock', gender='Male', language='German')
# InfoTuple(ssn='846-09-9851', first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language')
# InfoTuple(ssn='846-59-9961', first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian')
# InfoTuple(ssn='847-34-4817', first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish')
# InfoTuple(ssn='847-61-7656', first_name='Brit', last_name='Lodovichi', gender='Male', language='Bislama')
# InfoTuple(ssn='848-58-3386', first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese')
# InfoTuple(ssn='848-74-2886', first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama')
# InfoTuple(ssn='848-76-8808', first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali')
# InfoTuple(ssn='849-31-1551', first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German')
# InfoTuple(ssn='849-64-6624', first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian')
# InfoTuple(ssn='849-98-2973', first_name='Hurley', last_name='Newart', gender='Male', language='Hindi')
# InfoTuple(ssn='851-94-2162', first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan')
# InfoTuple(ssn='852-15-7707', first_name='Mario', last_name='Lelande', gender='Male', language='Nepali')
# InfoTuple(ssn='853-11-8953', first_name='Brice', last_name='Kyd', gender='Male', language='Dari')
# InfoTuple(ssn='853-47-3648', first_name='Olag', last_name='Belhome', gender='Male', language='Maltese')
# InfoTuple(ssn='854-68-7635', first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan')
# InfoTuple(ssn='854-71-2983', first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch')
# InfoTuple(ssn='854-79-5334', first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili')
# InfoTuple(ssn='856-18-3980', first_name='Neale', last_name='Sesser', gender='Male', language='Maltese')
# InfoTuple(ssn='856-27-9112', first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto')
# InfoTuple(ssn='856-67-4080', first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi')
# InfoTuple(ssn='857-37-5902', first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi')
# InfoTuple(ssn='858-03-7735', first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh')
# InfoTuple(ssn='858-27-9190', first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian')
# InfoTuple(ssn='860-67-0256', first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik')
# InfoTuple(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish')
# InfoTuple(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian')
# InfoTuple(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish')
# InfoTuple(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian')
# InfoTuple(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama')
# InfoTuple(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento')
# InfoTuple(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian')
# InfoTuple(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam')
# InfoTuple(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian')
# InfoTuple(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha')
# InfoTuple(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian')
# InfoTuple(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana')
# InfoTuple(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew')
# InfoTuple(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic')
# InfoTuple(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese')
# InfoTuple(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish')
# InfoTuple(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan')
# InfoTuple(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu')
# InfoTuple(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish')
# InfoTuple(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi')
# InfoTuple(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri')
# InfoTuple(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho')
# InfoTuple(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga')
# InfoTuple(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian')
# InfoTuple(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian')
# InfoTuple(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian')
# InfoTuple(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil')
# InfoTuple(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin')
# InfoTuple(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha')
# InfoTuple(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian')
# InfoTuple(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic')
# InfoTuple(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua')
# InfoTuple(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya')
# InfoTuple(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz')
# InfoTuple(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana')
# InfoTuple(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic')
# InfoTuple(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho')
# InfoTuple(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali')
# InfoTuple(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic')
# InfoTuple(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz')
# InfoTuple(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino')
# InfoTuple(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek')
# InfoTuple(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian')
# InfoTuple(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum')

# %% [markdown]
# #### Goal 2

# %%
def parsed_data_iterator(data_iter, nt):
    for row in data_iter:
        yield nt(*row)

# %%
from contextlib import contextmanager

# %%
def find_dialect(csv_file):
        with open(csv_file, newline='') as csvfile:
            return csv.Sniffer().sniff(csvfile.read(1000))
        
@contextmanager
def parsed_data(f_name):
    f = open(f_name)
    try:
        reader = csv.reader(f, find_dialect(f_name))
        headers = map(lambda s: s.lower(), next(reader))
        nt = namedtuple('Data', headers)        
        yield parsed_data_iterator(reader, nt)
    finally:
        f.close()

# %%
with parsed_data('personal_info.csv') as data:
    for row in data:
        print(row)
# Out:
# Data(ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# Data(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# Data(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# Data(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# Data(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# Data(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese')
# Data(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi')
# Data(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian')
# Data(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian')
# Data(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish')
# Data(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin')
# Data(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento')
# Data(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz')
# Data(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch')
# Data(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian')
# Data(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic')
# Data(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari')
# Data(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian')
# Data(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili')
# Data(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew')
# Data(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish')
# Data(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian')
# Data(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian')
# Data(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian')
# Data(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi')
# Data(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh')
# Data(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian')
# Data(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian')
# Data(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik')
# Data(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish')
# Data(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian')
# Data(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole')
# Data(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara')
# Data(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic')
# Data(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao')
# Data(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian')
# Data(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian')
# Data(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish')
# Data(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian')
# Data(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech')
# Data(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha')
# Data(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish')
# Data(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi')
# Data(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino')
# Data(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz')
# Data(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama')
# Data(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish')
# Data(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama')
# Data(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese')
# Data(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian')
# Data(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole')
# Data(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi')
# Data(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian')
# Data(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori')
# Data(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin')
# Data(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana')
# Data(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese')
# Data(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik')
# Data(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek')
# Data(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese')
# Data(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi')
# Data(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian')
# Data(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew')
# Data(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento')
# Data(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati')
# Data(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin')
# Data(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer')
# Data(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento')
# Data(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian')
# Data(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian')
# Data(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha')
# Data(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali')
# Data(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy')
# Data(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho')
# Data(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish')
# Data(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French')
# Data(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi')
# Data(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian')
# Data(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic')
# Data(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish')
# Data(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans')
# Data(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi')
# Data(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish')
# Data(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz')
# Data(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino')
# Data(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian')
# Data(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian')
# Data(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama')
# Data(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese')
# Data(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik')
# Data(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian')
# Data(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara')
# Data(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum')
# Data(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese')
# Data(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao')
# Data(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz')
# Data(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French')
# Data(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian')
# Data(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish')
# Data(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu')
# Data(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz')
# Data(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati')
# Data(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian')
# Data(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai')
# Data(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan')
# Data(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese')
# Data(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan')
# Data(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan')
# Data(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German')
# Data(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili')
# Data(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish')
# Data(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian')
# Data(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin')
# Data(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara')
# Data(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian')
# Data(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati')
# Data(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua')
# Data(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho')
# Data(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi')
# Data(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai')
# Data(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu')
# Data(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin')
# Data(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua')
# Data(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian')
# Data(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili')
# Data(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai')
# Data(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori')
# Data(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew')
# Data(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic')
# Data(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese')
# Data(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya')
# Data(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian')
# Data(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana')
# Data(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali')
# Data(ssn='200-81-7151', first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali')
# Data(ssn='201-53-1249', first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish')
# Data(ssn='202-84-1146', first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans')
# Data(ssn='203-35-7648', first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian')
# Data(ssn='205-69-7375', first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian')
# Data(ssn='205-87-2423', first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu')
# Data(ssn='206-28-6674', first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole')
# Data(ssn='206-83-8848', first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz')
# Data(ssn='208-74-2166', first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian')
# Data(ssn='208-80-5879', first_name='Rockie', last_name='Fryd', gender='Male', language='Korean')
# Data(ssn='209-50-8146', first_name='Kenna', last_name='Meryett', gender='Female', language='Czech')
# Data(ssn='209-58-4708', first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian')
# Data(ssn='210-91-4729', first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek')
# Data(ssn='211-04-1734', first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha')
# Data(ssn='211-13-5247', first_name='Wes', last_name='Weinberg', gender='Male', language='French')
# Data(ssn='211-15-5182', first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish')
# Data(ssn='211-19-6826', first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese')
# Data(ssn='212-40-0215', first_name='Giffie', last_name='Strauss', gender='Male', language='Azeri')
# Data(ssn='212-41-1496', first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil')
# Data(ssn='213-28-1395', first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali')
# Data(ssn='214-29-1189', first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole')
# Data(ssn='214-96-8581', first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian')
# Data(ssn='214-99-7584', first_name='Barny', last_name='Witherden', gender='Male', language='Czech')
# Data(ssn='216-89-3812', first_name='Florian', last_name='Jaze', gender='Male', language='Croatian')
# Data(ssn='216-97-3104', first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama')
# Data(ssn='217-71-3922', first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali')
# Data(ssn='217-81-5416', first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga')
# Data(ssn='218-14-4448', first_name='Keary', last_name='Druhan', gender='Male', language='Dutch')
# Data(ssn='218-25-9873', first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian')
# Data(ssn='218-31-1615', first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari')
# Data(ssn='218-49-7300', first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English')
# Data(ssn='220-16-0476', first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz')
# Data(ssn='220-38-0208', first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz')
# Data(ssn='222-39-8571', first_name='Fidelia', last_name='Domonkos', gender='Female', language='Fijian')
# Data(ssn='223-67-9203', first_name='Markus', last_name='Radband', gender='Male', language='Bosnian')
# Data(ssn='223-98-0846', first_name='Josy', last_name='Hadwick', gender='Female', language='Papiamento')
# Data(ssn='224-12-3436', first_name='Alister', last_name='Eakle', gender='Male', language='Estonian')
# Data(ssn='224-30-9267', first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish')
# Data(ssn='224-54-6919', first_name='Kelly', last_name='Shipman', gender='Male', language='Icelandic')
# Data(ssn='224-84-2271', first_name='Weider', last_name='Carlisle', gender='Male', language='Swedish')
# Data(ssn='224-99-0668', first_name='Brandy', last_name='Steed', gender='Male', language='Croatian')
# Data(ssn='225-08-5789', first_name='Tamra', last_name='Becken', gender='Female', language='Telugu')
# Data(ssn='225-64-2735', first_name='Graig', last_name='Rasher', gender='Male', language='Maltese')
# Data(ssn='226-76-4452', first_name='Van', last_name='Gervaise', gender='Male', language='Greek')
# Data(ssn='227-72-7247', first_name='Mauricio', last_name='Gush', gender='Male', language='Tajik')
# Data(ssn='228-16-7922', first_name='Tabby', last_name='Chitty', gender='Male', language='Spanish')
# Data(ssn='228-55-2042', first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech')
# Data(ssn='228-90-5077', first_name='Jonathon', last_name='Klugel', gender='Male', language='Hindi')
# Data(ssn='229-44-9909', first_name='Barnabas', last_name='Heppenspall', gender='Male', language='Icelandic')
# Data(ssn='230-09-1794', first_name='Xerxes', last_name='Mathivon', gender='Male', language='Danish')
# Data(ssn='230-48-0684', first_name='Clay', last_name='Peaurt', gender='Male', language='Dhivehi')
# Data(ssn='230-99-1485', first_name='Markus', last_name='Revill', gender='Male', language='Moldovan')
# Data(ssn='231-66-9264', first_name='Gisele', last_name='Castelow', gender='Female', language='Hiri Motu')
# Data(ssn='232-18-5397', first_name='Clare', last_name='McGairl', gender='Female', language='Bengali')
# Data(ssn='233-27-2377', first_name='Arlyne', last_name='Stenning', gender='Female', language='Dari')
# Data(ssn='235-10-3518', first_name='Winfield', last_name='Purvis', gender='Male', language='Estonian')
# Data(ssn='236-31-8333', first_name='Wendeline', last_name='Millins', gender='Female', language='Kashmiri')
# Data(ssn='236-37-2567', first_name='Ariel', last_name='Murrigan', gender='Female', language='West Frisian')
# Data(ssn='237-48-6737', first_name='Eal', last_name='Ducastel', gender='Male', language='Indonesian')
# Data(ssn='237-80-7039', first_name='Ardyce', last_name='Hunn', gender='Female', language='Maltese')
# Data(ssn='238-13-8034', first_name='Estrellita', last_name='Heavy', gender='Female', language='Azeri')
# Data(ssn='238-39-9999', first_name='Pauly', last_name='Griffin', gender='Female', language='Georgian')
# Data(ssn='239-09-9133', first_name='Tom', last_name='Roggeman', gender='Male', language='Sotho')
# Data(ssn='239-37-4122', first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana')
# Data(ssn='240-08-8805', first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish')
# Data(ssn='240-32-8915', first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento')
# Data(ssn='240-67-6258', first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi')
# Data(ssn='242-22-9624', first_name='Felice', last_name='Surr', gender='Male', language='Afrikaans')
# Data(ssn='243-37-9496', first_name='Verine', last_name='Etchells', gender='Female', language='Burmese')
# Data(ssn='243-44-4611', first_name='Shani', last_name="O'Tierney", gender='Female', language='Aymara')
# Data(ssn='244-34-2210', first_name='Lek', last_name='Heino', gender='Male', language='New Zealand Sign Language')
# Data(ssn='244-52-7593', first_name='Erda', last_name='Paulusch', gender='Female', language='Gujarati')
# Data(ssn='244-79-3004', first_name='Renault', last_name='Stollard', gender='Male', language='Amharic')
# Data(ssn='244-81-0671', first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan')
# Data(ssn='245-60-5880', first_name='Oby', last_name='Hauxby', gender='Male', language='French')
# Data(ssn='245-77-4110', first_name='Alasdair', last_name='McAndrew', gender='Male', language='Czech')
# Data(ssn='247-08-9326', first_name='Minni', last_name='Scurman', gender='Female', language='Kannada')
# Data(ssn='247-86-5288', first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian')
# Data(ssn='248-07-9757', first_name='Sean', last_name='Ham', gender='Male', language='Luxembourgish')
# Data(ssn='248-23-0150', first_name='Welbie', last_name='Gilley', gender='Male', language='Korean')
# Data(ssn='249-19-5514', first_name='Yehudi', last_name='Pharoah', gender='Male', language='Latvian')
# Data(ssn='253-61-8401', first_name='Genny', last_name='Juara', gender='Female', language='Tswana')
# Data(ssn='254-10-6071', first_name='Dwight', last_name='Eastcourt', gender='Male', language='Oriya')
# Data(ssn='254-92-9669', first_name='Tom', last_name='Larking', gender='Male', language='Icelandic')
# Data(ssn='255-81-0958', first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian')
# Data(ssn='256-54-7507', first_name='Angus', last_name='Cullip', gender='Male', language='Spanish')
# Data(ssn='256-57-0666', first_name='Rip', last_name='Grube', gender='Male', language='Ndebele')
# Data(ssn='257-12-6834', first_name='Derward', last_name='Paladini', gender='Male', language='Thai')
# Data(ssn='257-59-8603', first_name='Cyrillus', last_name='Sanchiz', gender='Male', language='Romanian')
# Data(ssn='257-77-3669', first_name='Ynez', last_name='Hain', gender='Female', language='Kazakh')
# Data(ssn='258-22-6416', first_name='Veriee', last_name='Klein', gender='Female', language='Northern Sotho')
# Data(ssn='259-38-5920', first_name='Jethro', last_name='Rustidge', gender='Male', language='Fijian')
# Data(ssn='261-14-9490', first_name='Lorry', last_name='Boshere', gender='Male', language='Oriya')
# Data(ssn='262-09-2144', first_name='Leigh', last_name='Paxforde', gender='Male', language='Portuguese')
# Data(ssn='262-46-7573', first_name='Lorene', last_name='Vagg', gender='Female', language='Punjabi')
# Data(ssn='262-55-4066', first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian')
# Data(ssn='262-66-7030', first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer')
# Data(ssn='264-39-3910', first_name='Elysia', last_name='Favell', gender='Female', language='Hindi')
# Data(ssn='266-86-9980', first_name='Rita', last_name='Leving', gender='Female', language='Latvian')
# Data(ssn='267-75-6383', first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian')
# Data(ssn='269-01-2640', first_name='Russell', last_name='Dabner', gender='Male', language='Danish')
# Data(ssn='271-04-0134', first_name='Eadith', last_name='Jerg', gender='Female', language='Gagauz')
# Data(ssn='271-81-9938', first_name='James', last_name='Robbins', gender='Male', language='Bengali')
# Data(ssn='271-93-3051', first_name='Augustin', last_name='Agiolfinger', gender='Male', language='Latvian')
# Data(ssn='272-50-7309', first_name='Sig', last_name='Ather', gender='Male', language='Catalan')
# Data(ssn='272-81-7979', first_name='Sherlocke', last_name='Giddings', gender='Male', language='Georgian')
# Data(ssn='273-49-8218', first_name='Haze', last_name='Starkings', gender='Male', language='Portuguese')
# Data(ssn='274-50-3806', first_name='Shurlocke', last_name='Aron', gender='Male', language='Punjabi')
# Data(ssn='274-76-9883', first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali')
# Data(ssn='276-05-2973', first_name='Cly', last_name='Yerlett', gender='Male', language='Kazakh')
# Data(ssn='278-55-5842', first_name='Korie', last_name='Di Pietro', gender='Female', language='German')
# Data(ssn='278-64-4853', first_name='Diane-marie', last_name='Broggini', gender='Female', language='Tsonga')
# Data(ssn='279-12-7167', first_name='Elbertina', last_name='Alders', gender='Female', language='Amharic')
# Data(ssn='279-40-5540', first_name='Montague', last_name='Knowler', gender='Male', language='Chinese')
# Data(ssn='279-49-5682', first_name='Kleon', last_name='Tembridge', gender='Male', language='Gagauz')
# Data(ssn='280-53-7447', first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian')
# Data(ssn='280-98-4410', first_name='Ealasaid', last_name='Devon', gender='Female', language='Tok Pisin')
# Data(ssn='281-23-3458', first_name='Bettina', last_name='Danilov', gender='Female', language='Sotho')
# Data(ssn='282-83-9206', first_name='Jackie', last_name='McPhater', gender='Male', language='Gagauz')
# Data(ssn='283-04-6835', first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha')
# Data(ssn='286-26-4004', first_name='Augustus', last_name='Doodson', gender='Male', language='Romanian')
# Data(ssn='287-57-9688', first_name='Joachim', last_name='Moncreiff', gender='Male', language='Catalan')
# Data(ssn='287-66-2660', first_name='Larissa', last_name='Airy', gender='Female', language='Bislama')
# Data(ssn='288-54-7233', first_name='Hedy', last_name='Eaklee', gender='Female', language='English')
# Data(ssn='288-87-6462', first_name='Stanislaus', last_name='Haylor', gender='Male', language='Kannada')
# Data(ssn='289-03-9882', first_name='Giusto', last_name='Baszniak', gender='Male', language='Yiddish')
# Data(ssn='289-09-8686', first_name='Heath', last_name='Stallan', gender='Male', language='Malayalam')
# Data(ssn='290-25-7300', first_name='Bowie', last_name='Bancroft', gender='Male', language='Thai')
# Data(ssn='290-82-4968', first_name='Ingram', last_name='Kincade', gender='Male', language='Moldovan')
# Data(ssn='293-54-3694', first_name='Theodora', last_name='Geddes', gender='Female', language='Maori')
# Data(ssn='294-27-9936', first_name='Cari', last_name='Bradane', gender='Female', language='Japanese')
# Data(ssn='294-53-1911', first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian')
# Data(ssn='295-63-7693', first_name='Fonzie', last_name='Fattorini', gender='Male', language='Estonian')
# Data(ssn='296-32-7910', first_name='Harlene', last_name='Morrill', gender='Female', language='Swati')
# Data(ssn='296-88-0097', first_name='Herculie', last_name='Branthwaite', gender='Male', language='Hungarian')
# Data(ssn='296-90-4908', first_name='Holt', last_name='Angel', gender='Male', language='Tamil')
# Data(ssn='297-63-1154', first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin')
# Data(ssn='298-06-3497', first_name='Moshe', last_name='Thomassin', gender='Male', language='Polish')
# Data(ssn='298-69-9168', first_name='Shea', last_name='Canon', gender='Male', language='Finnish')
# Data(ssn='298-70-6018', first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans')
# Data(ssn='298-79-7640', first_name='Mycah', last_name='Hillam', gender='Male', language='Swahili')
# Data(ssn='299-03-6911', first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz')
# Data(ssn='299-38-0483', first_name='Robb', last_name='Posner', gender='Male', language='Italian')
# Data(ssn='299-77-1060', first_name='Bellina', last_name='Galbreth', gender='Female', language='Norwegian')
# Data(ssn='300-59-3610', first_name='Tam', last_name='Howles', gender='Male', language='Pashto')
# Data(ssn='300-76-8770', first_name='Danielle', last_name='Rowth', gender='Female', language='Italian')
# Data(ssn='300-80-7209', first_name='Gabbie', last_name='Burney', gender='Female', language='Dutch')
# Data(ssn='301-26-4306', first_name='Emmye', last_name='Whelpdale', gender='Female', language='Tajik')
# Data(ssn='301-51-0522', first_name='Kenneth', last_name='Methley', gender='Male', language='Papiamento')
# Data(ssn='302-64-4858', first_name='Hakeem', last_name='Zelley', gender='Male', language='Afrikaans')
# Data(ssn='304-48-4312', first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin')
# Data(ssn='305-07-1498', first_name='Ruddy', last_name="O'Crotty", gender='Male', language='Spanish')
# Data(ssn='306-23-2423', first_name='Ree', last_name='Meader', gender='Female', language='Polish')
# Data(ssn='306-86-2930', first_name='Kassie', last_name='Neaverson', gender='Female', language='Luxembourgish')
# Data(ssn='308-58-0964', first_name='Talbert', last_name='Osipov', gender='Male', language='Tetum')
# Data(ssn='309-04-0364', first_name='Dov', last_name='Speight', gender='Male', language='Tajik')
# Data(ssn='309-38-8085', first_name='Nell', last_name='Scrigmour', gender='Female', language='Persian')
# Data(ssn='310-60-2027', first_name='Zacherie', last_name='Parken', gender='Male', language='Albanian')
# Data(ssn='311-46-9296', first_name='Alic', last_name='Pabel', gender='Male', language='Fijian')
# Data(ssn='312-38-7084', first_name='Ezri', last_name='Paolicchi', gender='Male', language='Malagasy')
# Data(ssn='312-59-3476', first_name='Sadye', last_name='Beloe', gender='Female', language='Icelandic')
# Data(ssn='312-77-3647', first_name='Hussein', last_name='Blything', gender='Male', language='Hebrew')
# Data(ssn='313-02-7822', first_name='Spence', last_name='Climer', gender='Male', language='Maori')
# Data(ssn='313-52-7312', first_name='Farrand', last_name='MacKenzie', gender='Female', language='French')
# Data(ssn='315-12-5664', first_name='Vere', last_name='Morlon', gender='Female', language='German')
# Data(ssn='315-26-2241', first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian')
# Data(ssn='315-44-9671', first_name='Ximenez', last_name='Maghull', gender='Male', language='Macedonian')
# Data(ssn='315-78-5587', first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin')
# Data(ssn='317-28-1600', first_name='Rodrick', last_name='Abrahams', gender='Male', language='Assamese')
# Data(ssn='317-43-2055', first_name='Jocelyn', last_name='Gildroy', gender='Female', language='Punjabi')
# Data(ssn='318-58-5314', first_name='Stephan', last_name='Peatt', gender='Male', language='New Zealand Sign Language')
# Data(ssn='319-43-0465', first_name='Boothe', last_name='Vanin', gender='Male', language='West Frisian')
# Data(ssn='320-90-1419', first_name='Em', last_name='Darwood', gender='Male', language='Icelandic')
# Data(ssn='320-97-9147', first_name='Roch', last_name='Wahlberg', gender='Female', language='Thai')
# Data(ssn='323-28-6705', first_name='Christiano', last_name='Stoffler', gender='Male', language='Kyrgyz')
# Data(ssn='323-33-8689', first_name='Dulcinea', last_name='Lundberg', gender='Female', language='Dutch')
# Data(ssn='324-39-5230', first_name='Alexandrina', last_name='Dahlbom', gender='Female', language='Moldovan')
# Data(ssn='324-73-8895', first_name='Walliw', last_name='Alstead', gender='Female', language='Guarana')
# Data(ssn='324-75-6098', first_name='Rafael', last_name='Robinett', gender='Male', language='Portuguese')
# Data(ssn='326-64-9957', first_name='Jorgan', last_name='Renowden', gender='Male', language='Swati')
# Data(ssn='327-52-0546', first_name='Carlota', last_name='Hovey', gender='Female', language='English')
# Data(ssn='327-88-7554', first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili')
# Data(ssn='330-99-3055', first_name='Marinna', last_name='Dally', gender='Female', language='Azeri')
# Data(ssn='332-83-6591', first_name='Forrester', last_name='Cullabine', gender='Male', language='Dzongkha')
# Data(ssn='333-52-5097', first_name='Florentia', last_name='Espinazo', gender='Female', language='Tetum')
# Data(ssn='333-95-5025', first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu')
# Data(ssn='335-35-1520', first_name='Ervin', last_name='Hugues', gender='Male', language='Armenian')
# Data(ssn='336-48-2579', first_name='Renee', last_name='Crank', gender='Female', language='Armenian')
# Data(ssn='339-27-8046', first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian')
# Data(ssn='339-71-2687', first_name='Marlie', last_name='Corpe', gender='Female', language='Persian')
# Data(ssn='341-10-6840', first_name='Cyrille', last_name='Critchlow', gender='Male', language='Portuguese')
# Data(ssn='342-05-9057', first_name='Beatrix', last_name='Relton', gender='Female', language='Latvian')
# Data(ssn='342-55-0538', first_name='Hilliary', last_name='Suddards', gender='Female', language='Dzongkha')
# Data(ssn='342-90-9333', first_name='Geri', last_name='Yesinov', gender='Male', language='Norwegian')
# Data(ssn='343-20-8407', first_name='Bradford', last_name='Niemiec', gender='Male', language='Chinese')
# Data(ssn='343-81-3179', first_name='Reinhard', last_name='Bortolutti', gender='Male', language='Kannada')
# Data(ssn='345-74-2160', first_name='Camile', last_name='Pengelly', gender='Female', language='Lao')
# Data(ssn='347-09-3254', first_name='Dulciana', last_name='Hexum', gender='Female', language='Lao')
# Data(ssn='347-64-8652', first_name='Dusty', last_name='Morat', gender='Female', language='Japanese')
# Data(ssn='348-73-4312', first_name='Elberta', last_name='Howden', gender='Female', language='Khmer')
# Data(ssn='348-74-3224', first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian')
# Data(ssn='349-53-8864', first_name='Muffin', last_name='Lord', gender='Female', language='Georgian')
# Data(ssn='349-67-7502', first_name='Ari', last_name='Yitzhakov', gender='Male', language='Zulu')
# Data(ssn='350-20-9593', first_name='Eldridge', last_name='Crispin', gender='Male', language='Dutch')
# Data(ssn='350-80-4646', first_name='Harp', last_name='Du Plantier', gender='Male', language='Dutch')
# Data(ssn='351-73-2802', first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian')
# Data(ssn='355-21-9711', first_name='Daryn', last_name='Battin', gender='Female', language='Georgian')
# Data(ssn='355-52-9767', first_name='Kacy', last_name='Offen', gender='Female', language='Kurdish')
# Data(ssn='355-96-7706', first_name='Lauritz', last_name='Lucock', gender='Male', language='Mongolian')
# Data(ssn='356-39-9199', first_name='Arney', last_name='Polglaze', gender='Male', language='Marathi')
# Data(ssn='357-37-6094', first_name='Chrisse', last_name='Kirton', gender='Male', language='Latvian')
# Data(ssn='358-84-7049', first_name='Emalee', last_name='McCleary', gender='Female', language='Thai')
# Data(ssn='360-69-6230', first_name='Grannie', last_name='Champ', gender='Male', language='Belarusian')
# Data(ssn='361-06-1530', first_name='Luis', last_name='Ashborne', gender='Male', language='Mongolian')
# Data(ssn='361-42-7068', first_name='Ashia', last_name='Ferran', gender='Female', language='West Frisian')
# Data(ssn='361-49-4597', first_name='Adan', last_name='Janssen', gender='Male', language='Swedish')
# Data(ssn='361-83-5004', first_name='Wilona', last_name='Sink', gender='Female', language='Sotho')
# Data(ssn='362-09-8563', first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic')
# Data(ssn='362-12-7902', first_name='Weber', last_name='Legrand', gender='Male', language='Swahili')
# Data(ssn='364-25-0166', first_name='Arnuad', last_name='Planque', gender='Male', language='Hindi')
# Data(ssn='364-65-2174', first_name='Bernarr', last_name='Wollard', gender='Male', language='Irish Gaelic')
# Data(ssn='366-61-0607', first_name='Bethena', last_name='Joicey', gender='Female', language='Haitian Creole')
# Data(ssn='367-22-8998', first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz')
# Data(ssn='367-62-4426', first_name='Sigismondo', last_name='Lerohan', gender='Male', language='Georgian')
# Data(ssn='370-01-6977', first_name='Hugues', last_name='Jeffryes', gender='Male', language='Georgian')
# Data(ssn='370-24-5876', first_name='Sergei', last_name='Risby', gender='Male', language='Bulgarian')
# Data(ssn='370-72-6509', first_name='Wrennie', last_name='McCrorie', gender='Female', language='Papiamento')
# Data(ssn='371-28-5892', first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga')
# Data(ssn='371-44-0582', first_name='Clemmy', last_name='Cogzell', gender='Male', language='Estonian')
# Data(ssn='371-62-3727', first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch')
# Data(ssn='371-88-9249', first_name='Nealon', last_name='Oxtaby', gender='Male', language='German')
# Data(ssn='372-44-7487', first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan')
# Data(ssn='372-62-7057', first_name='Eleanora', last_name='Vazquez', gender='Female', language='Gujarati')
# Data(ssn='373-67-2734', first_name='Ileana', last_name='Luty', gender='Female', language='Italian')
# Data(ssn='374-47-0262', first_name='Bank', last_name='Evitts', gender='Male', language='Aymara')
# Data(ssn='378-08-0805', first_name='Carroll', last_name='Harty', gender='Female', language='Swedish')
# Data(ssn='378-60-2472', first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian')
# Data(ssn='378-66-0449', first_name='Kelby', last_name='Wincer', gender='Male', language='Pashto')
# Data(ssn='378-79-0193', first_name='Kenny', last_name='Josefsen', gender='Male', language='Danish')
# Data(ssn='378-88-6805', first_name='Vittoria', last_name='Oldroyd', gender='Female', language='Moldovan')
# Data(ssn='379-07-8748', first_name='Dyanna', last_name='Noto', gender='Female', language='Polish')
# Data(ssn='380-33-9730', first_name='Katinka', last_name='Piet', gender='Female', language='Malay')
# Data(ssn='380-35-3854', first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama')
# Data(ssn='383-18-4058', first_name='Frederigo', last_name='Cooksey', gender='Male', language='Indonesian')
# Data(ssn='384-30-6793', first_name='Kipp', last_name='Burnyate', gender='Male', language='English')
# Data(ssn='384-94-2772', first_name='Ramsay', last_name='Dolbey', gender='Male', language='Tok Pisin')
# Data(ssn='385-30-1777', first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana')
# Data(ssn='385-34-7828', first_name='Dori', last_name='Quogan', gender='Female', language='Afrikaans')
# Data(ssn='385-98-0431', first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana')
# Data(ssn='386-15-7960', first_name='Steffie', last_name='Tedahl', gender='Female', language='Punjabi')
# Data(ssn='386-34-4088', first_name='Adamo', last_name='Wogden', gender='Male', language='Arabic')
# Data(ssn='386-68-9884', first_name='Francis', last_name='Foch', gender='Male', language='Dzongkha')
# Data(ssn='386-97-3523', first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish')
# Data(ssn='389-31-0910', first_name='Mac', last_name='Westrey', gender='Male', language='Armenian')
# Data(ssn='389-51-1424', first_name='Isadore', last_name='Orbine', gender='Male', language='Pashto')
# Data(ssn='389-84-8254', first_name='Chiquita', last_name='Jolliman', gender='Female', language='Marathi')
# Data(ssn='390-74-3062', first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian')
# Data(ssn='391-14-9280', first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin')
# Data(ssn='391-47-4578', first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese')
# Data(ssn='391-73-2830', first_name='Padget', last_name='Manthorpe', gender='Male', language='Marathi')
# Data(ssn='393-22-6585', first_name='Reinold', last_name='Ellif', gender='Male', language='Nepali')
# Data(ssn='396-51-1559', first_name='Natasha', last_name='Dafter', gender='Female', language='Maori')
# Data(ssn='397-16-5372', first_name='Alonzo', last_name='Mc Mechan', gender='Male', language='Polish')
# Data(ssn='397-29-8349', first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin')
# Data(ssn='397-87-8282', first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian')
# Data(ssn='399-31-2815', first_name='Durward', last_name='Giamitti', gender='Male', language='Tok Pisin')
# Data(ssn='399-63-8810', first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento')
# Data(ssn='399-81-6133', first_name='Viv', last_name='Borsay', gender='Female', language='Chinese')
# Data(ssn='400-21-8654', first_name='Travus', last_name='Miranda', gender='Male', language='Kannada')
# Data(ssn='400-77-6007', first_name='Dannie', last_name='Shurmer', gender='Male', language='Tajik')
# Data(ssn='402-61-3479', first_name='Mariele', last_name='Meyrick', gender='Female', language='Telugu')
# Data(ssn='402-65-2055', first_name='Martie', last_name='Crawshaw', gender='Male', language='Marathi')
# Data(ssn='402-88-5570', first_name='Torry', last_name='Bossons', gender='Male', language='Chinese')
# Data(ssn='403-65-1535', first_name='Cathy', last_name='Gabe', gender='Female', language='Hiri Motu')
# Data(ssn='404-57-4023', first_name='Pattin', last_name='Jarmain', gender='Male', language='Hindi')
# Data(ssn='405-25-1422', first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati')
# Data(ssn='406-15-5123', first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari')
# Data(ssn='406-24-4867', first_name='Renaud', last_name='Fleetwood', gender='Male', language='Papiamento')
# Data(ssn='406-49-0634', first_name='Lolita', last_name='Dailey', gender='Female', language='Czech')
# Data(ssn='407-30-0910', first_name='Gerhard', last_name='Crielly', gender='Male', language='Bislama')
# Data(ssn='407-80-7367', first_name='Sigismundo', last_name='Pothbury', gender='Male', language='Latvian')
# Data(ssn='407-99-6159', first_name='Flynn', last_name='Jirasek', gender='Male', language='Afrikaans')
# Data(ssn='408-83-7943', first_name='Wallie', last_name='Klosterman', gender='Male', language='Hungarian')
# Data(ssn='408-98-3291', first_name='Karia', last_name='Riquet', gender='Female', language='Italian')
# Data(ssn='409-58-2034', first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili')
# Data(ssn='409-90-8946', first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian')
# Data(ssn='410-38-4237', first_name='Gibbie', last_name='Seamer', gender='Male', language='Tok Pisin')
# Data(ssn='410-76-5092', first_name='Spencer', last_name='Dallon', gender='Male', language='Swati')
# Data(ssn='411-21-4276', first_name='Mari', last_name='Livick', gender='Female', language='Pashto')
# Data(ssn='411-43-4217', first_name='Cull', last_name='Noddle', gender='Male', language='Spanish')
# Data(ssn='411-79-4655', first_name='Caterina', last_name='Coey', gender='Female', language='French')
# Data(ssn='412-50-9133', first_name='Dianemarie', last_name='Withey', gender='Female', language='Czech')
# Data(ssn='412-59-0452', first_name='Seamus', last_name='Petrusch', gender='Male', language='Spanish')
# Data(ssn='412-59-8022', first_name='Brenna', last_name='Follin', gender='Female', language='Gagauz')
# Data(ssn='412-79-8951', first_name='Giorgi', last_name='Sisnett', gender='Male', language='Tamil')
# Data(ssn='413-14-3928', first_name='Shaine', last_name='Liebrecht', gender='Male', language='Sotho')
# Data(ssn='413-56-5613', first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali')
# Data(ssn='415-42-0898', first_name='Karlik', last_name='Adlam', gender='Male', language='Mongolian')
# Data(ssn='415-74-2251', first_name='Pattin', last_name='Greson', gender='Male', language='Italian')
# Data(ssn='416-37-7763', first_name='Emelia', last_name='Hancell', gender='Female', language='German')
# Data(ssn='416-38-3607', first_name='Jerry', last_name='Christin', gender='Male', language='Hebrew')
# Data(ssn='416-80-6367', first_name='Myrna', last_name='Christoffe', gender='Female', language='Tok Pisin')
# Data(ssn='416-87-0469', first_name='Dannel', last_name='Whyffen', gender='Male', language='Estonian')
# Data(ssn='418-72-1888', first_name='Roddy', last_name='Worman', gender='Male', language='Bosnian')
# Data(ssn='418-99-6659', first_name='Grenville', last_name='Gulliver', gender='Male', language='Ndebele')
# Data(ssn='420-46-7789', first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language')
# Data(ssn='420-52-3813', first_name='Arnaldo', last_name='Balsdone', gender='Male', language='Zulu')
# Data(ssn='421-01-2511', first_name='Mikaela', last_name='Andrivot', gender='Female', language='English')
# Data(ssn='421-13-9794', first_name='Minne', last_name='Measey', gender='Female', language='Danish')
# Data(ssn='421-20-3448', first_name='Alie', last_name='Gerauld', gender='Female', language='Khmer')
# Data(ssn='421-88-7316', first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch')
# Data(ssn='422-67-4000', first_name='Corby', last_name='Boyington', gender='Male', language='Sotho')
# Data(ssn='423-62-1820', first_name='Ruddy', last_name='Ingerson', gender='Male', language='Maori')
# Data(ssn='423-88-4721', first_name='Trip', last_name='Postlewhite', gender='Male', language='Polish')
# Data(ssn='424-22-9138', first_name='Farand', last_name='Huggon', gender='Female', language='Indonesian')
# Data(ssn='424-91-0692', first_name='Jeanie', last_name='Titchard', gender='Female', language='Swati')
# Data(ssn='424-92-0863', first_name='Halley', last_name='Mendenhall', gender='Female', language='Thai')
# Data(ssn='426-09-8331', first_name='Enrico', last_name='Balentyne', gender='Male', language='Arabic')
# Data(ssn='426-33-4523', first_name='Bibbie', last_name='Lardge', gender='Female', language='Spanish')
# Data(ssn='426-52-3410', first_name='Deeyn', last_name='Feldberg', gender='Female', language='Lithuanian')
# Data(ssn='426-61-5374', first_name='Adolph', last_name='Effemy', gender='Male', language='Norwegian')
# Data(ssn='427-12-4625', first_name='Ethelin', last_name='Huck', gender='Female', language='Bosnian')
# Data(ssn='427-36-0095', first_name='Shandee', last_name='Hawthorne', gender='Female', language='Gujarati')
# Data(ssn='427-96-6355', first_name='Fidel', last_name='Gutierrez', gender='Male', language='Yiddish')
# Data(ssn='428-19-2946', first_name='Dionne', last_name='Bibb', gender='Female', language='Moldovan')
# Data(ssn='428-79-0781', first_name='Mame', last_name='Criag', gender='Female', language='Catalan')
# Data(ssn='429-43-7811', first_name='Felice', last_name='Mound', gender='Male', language='Ndebele')
# Data(ssn='430-27-6236', first_name='Sergent', last_name='Tomich', gender='Male', language='Tajik')
# Data(ssn='430-27-8349', first_name='Boigie', last_name='Balsdon', gender='Male', language='German')
# Data(ssn='432-25-8923', first_name='Violetta', last_name='Remmer', gender='Female', language='Swati')
# Data(ssn='433-08-7855', first_name='Cleo', last_name='Sivior', gender='Female', language='Latvian')
# Data(ssn='434-41-2365', first_name='Obed', last_name='Podmore', gender='Male', language='Georgian')
# Data(ssn='435-34-0115', first_name='Chicky', last_name='Carlos', gender='Male', language='Tamil')
# Data(ssn='438-80-0430', first_name='Gunilla', last_name='Navan', gender='Female', language='Moldovan')
# Data(ssn='438-82-1280', first_name='Salvatore', last_name='Noirel', gender='Male', language='Somali')
# ...
# Data(ssn='770-61-8252', first_name='Elbertina', last_name='Colls', gender='Female', language='Chinese')
# Data(ssn='771-20-6900', first_name='Alejandra', last_name='Tevlin', gender='Female', language='Greek')
# Data(ssn='771-71-0505', first_name='Romona', last_name='Meikle', gender='Female', language='New Zealand Sign Language')
# Data(ssn='773-21-9639', first_name='Brittney', last_name='Byart', gender='Female', language='Tok Pisin')
# Data(ssn='773-53-7438', first_name='Flo', last_name='Sirmond', gender='Female', language='Khmer')
# Data(ssn='773-82-1734', first_name='Maris', last_name='Currin', gender='Female', language='Armenian')
# Data(ssn='774-08-5376', first_name='Pam', last_name='Matterface', gender='Female', language='Swahili')
# Data(ssn='775-09-9949', first_name='Orlando', last_name='Gresley', gender='Male', language='Danish')
# Data(ssn='777-05-1491', first_name='Devora', last_name='Ashbridge', gender='Female', language='Somali')
# Data(ssn='777-68-2978', first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho')
# Data(ssn='777-94-4586', first_name='Siward', last_name='Blues', gender='Male', language='Thai')
# Data(ssn='778-74-8262', first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian')
# Data(ssn='779-59-1449', first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian')
# Data(ssn='780-69-8282', first_name='Sibeal', last_name='Dawney', gender='Female', language='Czech')
# Data(ssn='781-88-2076', first_name='Gelya', last_name='Stell', gender='Female', language='Czech')
# Data(ssn='782-46-9660', first_name='Malina', last_name='Julyan', gender='Female', language='Burmese')
# Data(ssn='782-60-6848', first_name='Jehu', last_name='Scholig', gender='Male', language='Polish')
# Data(ssn='783-22-9258', first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese')
# Data(ssn='784-88-0730', first_name='Baxie', last_name='Judd', gender='Male', language='Maltese')
# Data(ssn='785-14-5978', first_name='Trista', last_name='Watkinson', gender='Female', language='Moldovan')
# Data(ssn='786-56-3561', first_name='Wait', last_name='Boyda', gender='Male', language='Norwegian')
# Data(ssn='786-63-6223', first_name='Adham', last_name='Toope', gender='Male', language='Belarusian')
# Data(ssn='787-05-9008', first_name='Ricki', last_name='Jurges', gender='Female', language='Arabic')
# Data(ssn='787-09-5697', first_name='Chelsea', last_name='Pashby', gender='Female', language='Northern Sotho')
# Data(ssn='787-10-7877', first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu')
# Data(ssn='788-15-2625', first_name='Drusilla', last_name='Bannester', gender='Female', language='Gujarati')
# Data(ssn='789-70-1821', first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri')
# Data(ssn='790-04-1283', first_name='Christyna', last_name='Morrissey', gender='Female', language='Quechua')
# Data(ssn='792-71-8046', first_name='Carly', last_name='Hazley', gender='Female', language='Guarana')
# Data(ssn='794-24-3802', first_name='Esther', last_name='Sayton', gender='Female', language='Somali')
# Data(ssn='795-56-6486', first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz')
# Data(ssn='795-77-5263', first_name='Burty', last_name='Frosdick', gender='Male', language='Marathi')
# Data(ssn='797-05-2289', first_name='Fanchon', last_name='Petrushanko', gender='Female', language='Finnish')
# Data(ssn='797-25-9814', first_name='Aleksandr', last_name='Swalwell', gender='Male', language='Pashto')
# Data(ssn='797-65-2382', first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish')
# Data(ssn='797-87-7992', first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian')
# Data(ssn='798-34-1082', first_name='Henka', last_name='Synder', gender='Female', language='Italian')
# Data(ssn='798-65-5644', first_name='Irita', last_name='Heady', gender='Female', language='Montenegrin')
# Data(ssn='800-06-9721', first_name='Carter', last_name='Waldron', gender='Male', language='Estonian')
# Data(ssn='801-08-8313', first_name='Aida', last_name='Whitemarsh', gender='Female', language='Chinese')
# Data(ssn='801-92-6460', first_name='Levi', last_name='Downgate', gender='Male', language='Belarusian')
# Data(ssn='801-99-2773', first_name='Justinian', last_name='Carlesso', gender='Male', language='Japanese')
# Data(ssn='804-46-0617', first_name='Geneva', last_name='Crinion', gender='Female', language='Hungarian')
# Data(ssn='807-13-5922', first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho')
# Data(ssn='807-24-6202', first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu')
# Data(ssn='807-25-6136', first_name='Sammy', last_name='Linnard', gender='Female', language='Dutch')
# Data(ssn='807-35-8936', first_name='Georgi', last_name='Widd', gender='Male', language='Afrikaans')
# Data(ssn='807-50-8539', first_name='Jaquith', last_name='Erdes', gender='Female', language='Dhivehi')
# Data(ssn='807-60-5615', first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi')
# Data(ssn='808-55-8658', first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese')
# Data(ssn='808-80-2542', first_name='Gustaf', last_name='Hullot', gender='Male', language='Persian')
# Data(ssn='811-65-2750', first_name='Minetta', last_name='Dusting', gender='Female', language='Spanish')
# Data(ssn='812-11-9403', first_name='Carmina', last_name='Turnell', gender='Female', language='West Frisian')
# Data(ssn='813-42-4142', first_name='Killy', last_name='Threadgould', gender='Male', language='Polish')
# Data(ssn='813-47-5215', first_name='Willi', last_name='Collet', gender='Male', language='Gujarati')
# Data(ssn='815-83-0300', first_name='Romeo', last_name='Rayworth', gender='Male', language='Thai')
# Data(ssn='816-31-3858', first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin')
# Data(ssn='816-47-4782', first_name='Wilmer', last_name='Maides', gender='Male', language='Aymara')
# Data(ssn='816-90-2049', first_name='Berry', last_name='Delagnes', gender='Female', language='Bengali')
# Data(ssn='817-04-1950', first_name='Fletcher', last_name='McGrouther', gender='Male', language='Albanian')
# Data(ssn='817-25-7437', first_name='Randall', last_name='Fibbitts', gender='Male', language='Yiddish')
# Data(ssn='817-80-8930', first_name='Lib', last_name='Skein', gender='Female', language='Arabic')
# Data(ssn='818-61-0770', first_name='Stanly', last_name='Casseldine', gender='Male', language='Belarusian')
# Data(ssn='819-52-5886', first_name='Paulette', last_name='McAree', gender='Female', language='Arabic')
# Data(ssn='819-64-1414', first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino')
# Data(ssn='820-96-1105', first_name='Andy', last_name='Sayce', gender='Female', language='Pashto')
# Data(ssn='822-05-9037', first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan')
# Data(ssn='822-30-4861', first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian')
# Data(ssn='823-27-0762', first_name='Marten', last_name='McCord', gender='Male', language='Indonesian')
# Data(ssn='823-75-5753', first_name='Thibaut', last_name='Van Schafflaer', gender='Male', language='Chinese')
# Data(ssn='824-89-4169', first_name='Tamqrah', last_name='Goroni', gender='Female', language='Swedish')
# Data(ssn='826-97-8029', first_name='Llewellyn', last_name='Shimwell', gender='Male', language='Belarusian')
# Data(ssn='827-62-4599', first_name='Phyllys', last_name='Akast', gender='Female', language='Armenian')
# Data(ssn='830-23-1573', first_name='Carine', last_name='Abramin', gender='Female', language='Bislama')
# Data(ssn='831-44-3286', first_name='Leesa', last_name='Finci', gender='Female', language='Nepali')
# Data(ssn='833-01-1428', first_name='Ashlan', last_name='Zannotti', gender='Female', language='Finnish')
# Data(ssn='835-54-3785', first_name='Nathaniel', last_name='Wegman', gender='Male', language='Azeri')
# Data(ssn='836-40-1837', first_name='Brocky', last_name='Kewzick', gender='Male', language='Armenian')
# Data(ssn='836-99-3309', first_name='Cobby', last_name='Mutter', gender='Male', language='Georgian')
# Data(ssn='837-76-5619', first_name='Alleyn', last_name='Parade', gender='Male', language='Croatian')
# Data(ssn='838-69-1351', first_name='Alwin', last_name='Hazzard', gender='Male', language='Kannada')
# Data(ssn='840-41-7929', first_name='Sherlock', last_name='Pinshon', gender='Male', language='Khmer')
# Data(ssn='841-64-8517', first_name='Hugues', last_name='Kenealy', gender='Male', language='Korean')
# Data(ssn='842-90-7557', first_name='Brit', last_name='Weall', gender='Female', language='West Frisian')
# Data(ssn='844-15-4668', first_name='Eleonora', last_name='Delete', gender='Female', language='Hiri Motu')
# Data(ssn='844-50-7305', first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian')
# Data(ssn='846-07-1407', first_name='Tobias', last_name='Blakelock', gender='Male', language='German')
# Data(ssn='846-09-9851', first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language')
# Data(ssn='846-59-9961', first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian')
# Data(ssn='847-34-4817', first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish')
# Data(ssn='847-61-7656', first_name='Brit', last_name='Lodovichi', gender='Male', language='Bislama')
# Data(ssn='848-58-3386', first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese')
# Data(ssn='848-74-2886', first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama')
# Data(ssn='848-76-8808', first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali')
# Data(ssn='849-31-1551', first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German')
# Data(ssn='849-64-6624', first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian')
# Data(ssn='849-98-2973', first_name='Hurley', last_name='Newart', gender='Male', language='Hindi')
# Data(ssn='851-94-2162', first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan')
# Data(ssn='852-15-7707', first_name='Mario', last_name='Lelande', gender='Male', language='Nepali')
# Data(ssn='853-11-8953', first_name='Brice', last_name='Kyd', gender='Male', language='Dari')
# Data(ssn='853-47-3648', first_name='Olag', last_name='Belhome', gender='Male', language='Maltese')
# Data(ssn='854-68-7635', first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan')
# Data(ssn='854-71-2983', first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch')
# Data(ssn='854-79-5334', first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili')
# Data(ssn='856-18-3980', first_name='Neale', last_name='Sesser', gender='Male', language='Maltese')
# Data(ssn='856-27-9112', first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto')
# Data(ssn='856-67-4080', first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi')
# Data(ssn='857-37-5902', first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi')
# Data(ssn='858-03-7735', first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh')
# Data(ssn='858-27-9190', first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian')
# Data(ssn='860-67-0256', first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik')
# Data(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish')
# Data(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian')
# Data(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish')
# Data(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian')
# Data(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama')
# Data(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento')
# Data(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian')
# Data(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam')
# Data(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian')
# Data(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha')
# Data(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian')
# Data(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana')
# Data(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew')
# Data(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic')
# Data(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese')
# Data(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish')
# Data(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan')
# Data(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu')
# Data(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish')
# Data(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi')
# Data(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri')
# Data(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho')
# Data(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga')
# Data(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian')
# Data(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian')
# Data(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian')
# Data(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil')
# Data(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin')
# Data(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha')
# Data(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian')
# Data(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic')
# Data(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua')
# Data(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya')
# Data(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz')
# Data(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana')
# Data(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic')
# Data(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho')
# Data(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali')
# Data(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic')
# Data(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz')
# Data(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino')
# Data(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek')
# Data(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian')
# Data(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum')

# %%
with parsed_data('cars.csv') as data:
    for row in data:
        print(row)
# Out:
# Data(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# Data(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# Data(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# Data(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# Data(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# Data(car='Ford Galaxie 500', mpg='15.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4341.', acceleration='10.0', model='70', origin='US')
# Data(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='454.0', horsepower='220.0', weight='4354.', acceleration='9.0', model='70', origin='US')
# Data(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4312.', acceleration='8.5', model='70', origin='US')
# Data(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4425.', acceleration='10.0', model='70', origin='US')
# Data(car='AMC Ambassador DPL', mpg='15.0', cylinders='8', displacement='390.0', horsepower='190.0', weight='3850.', acceleration='8.5', model='70', origin='US')
# Data(car='Citroen DS-21 Pallas', mpg='0', cylinders='4', displacement='133.0', horsepower='115.0', weight='3090.', acceleration='17.5', model='70', origin='Europe')
# Data(car='Chevrolet Chevelle Concours (sw)', mpg='0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4142.', acceleration='11.5', model='70', origin='US')
# Data(car='Ford Torino (sw)', mpg='0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4034.', acceleration='11.0', model='70', origin='US')
# Data(car='Plymouth Satellite (sw)', mpg='0', cylinders='8', displacement='383.0', horsepower='175.0', weight='4166.', acceleration='10.5', model='70', origin='US')
# Data(car='AMC Rebel SST (sw)', mpg='0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3850.', acceleration='11.0', model='70', origin='US')
# Data(car='Dodge Challenger SE', mpg='15.0', cylinders='8', displacement='383.0', horsepower='170.0', weight='3563.', acceleration='10.0', model='70', origin='US')
# Data(car="Plymouth 'Cuda 340", mpg='14.0', cylinders='8', displacement='340.0', horsepower='160.0', weight='3609.', acceleration='8.0', model='70', origin='US')
# Data(car='Ford Mustang Boss 302', mpg='0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3353.', acceleration='8.0', model='70', origin='US')
# Data(car='Chevrolet Monte Carlo', mpg='15.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='3761.', acceleration='9.5', model='70', origin='US')
# Data(car='Buick Estate Wagon (sw)', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='3086.', acceleration='10.0', model='70', origin='US')
# Data(car='Toyota Corolla Mark ii', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2372.', acceleration='15.0', model='70', origin='Japan')
# Data(car='Plymouth Duster', mpg='22.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2833.', acceleration='15.5', model='70', origin='US')
# Data(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='199.0', horsepower='97.00', weight='2774.', acceleration='15.5', model='70', origin='US')
# Data(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='85.00', weight='2587.', acceleration='16.0', model='70', origin='US')
# Data(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='70', origin='Japan')
# Data(car='Volkswagen 1131 Deluxe Sedan', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1835.', acceleration='20.5', model='70', origin='Europe')
# Data(car='Peugeot 504', mpg='25.0', cylinders='4', displacement='110.0', horsepower='87.00', weight='2672.', acceleration='17.5', model='70', origin='Europe')
# Data(car='Audi 100 LS', mpg='24.0', cylinders='4', displacement='107.0', horsepower='90.00', weight='2430.', acceleration='14.5', model='70', origin='Europe')
# Data(car='Saab 99e', mpg='25.0', cylinders='4', displacement='104.0', horsepower='95.00', weight='2375.', acceleration='17.5', model='70', origin='Europe')
# Data(car='BMW 2002', mpg='26.0', cylinders='4', displacement='121.0', horsepower='113.0', weight='2234.', acceleration='12.5', model='70', origin='Europe')
# Data(car='AMC Gremlin', mpg='21.0', cylinders='6', displacement='199.0', horsepower='90.00', weight='2648.', acceleration='15.0', model='70', origin='US')
# Data(car='Ford F250', mpg='10.0', cylinders='8', displacement='360.0', horsepower='215.0', weight='4615.', acceleration='14.0', model='70', origin='US')
# Data(car='Chevy C20', mpg='10.0', cylinders='8', displacement='307.0', horsepower='200.0', weight='4376.', acceleration='15.0', model='70', origin='US')
# Data(car='Dodge D200', mpg='11.0', cylinders='8', displacement='318.0', horsepower='210.0', weight='4382.', acceleration='13.5', model='70', origin='US')
# Data(car='Hi 1200D', mpg='9.0', cylinders='8', displacement='304.0', horsepower='193.0', weight='4732.', acceleration='18.5', model='70', origin='US')
# Data(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='71', origin='Japan')
# Data(car='Chevrolet Vega 2300', mpg='28.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2264.', acceleration='15.5', model='71', origin='US')
# Data(car='Toyota Corolla', mpg='25.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2228.', acceleration='14.0', model='71', origin='Japan')
# Data(car='Ford Pinto', mpg='25.0', cylinders='4', displacement='98.00', horsepower='0', weight='2046.', acceleration='19.0', model='71', origin='US')
# Data(car='Volkswagen Super Beetle 117', mpg='0', cylinders='4', displacement='97.00', horsepower='48.00', weight='1978.', acceleration='20.0', model='71', origin='Europe')
# Data(car='AMC Gremlin', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2634.', acceleration='13.0', model='71', origin='US')
# Data(car='Plymouth Satellite Custom', mpg='16.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3439.', acceleration='15.5', model='71', origin='US')
# Data(car='Chevrolet Chevelle Malibu', mpg='17.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3329.', acceleration='15.5', model='71', origin='US')
# Data(car='Ford Torino 500', mpg='19.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3302.', acceleration='15.5', model='71', origin='US')
# Data(car='AMC Matador', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='3288.', acceleration='15.5', model='71', origin='US')
# Data(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4209.', acceleration='12.0', model='71', origin='US')
# Data(car='Pontiac Catalina Brougham', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4464.', acceleration='11.5', model='71', origin='US')
# Data(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4154.', acceleration='13.5', model='71', origin='US')
# Data(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4096.', acceleration='13.0', model='71', origin='US')
# Data(car='Dodge Monaco (sw)', mpg='12.0', cylinders='8', displacement='383.0', horsepower='180.0', weight='4955.', acceleration='11.5', model='71', origin='US')
# Data(car='Ford Country Squire (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4746.', acceleration='12.0', model='71', origin='US')
# Data(car='Pontiac Safari (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='5140.', acceleration='12.0', model='71', origin='US')
# Data(car='AMC Hornet Sportabout (sw)', mpg='18.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='2962.', acceleration='13.5', model='71', origin='US')
# Data(car='Chevrolet Vega (sw)', mpg='22.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2408.', acceleration='19.0', model='71', origin='US')
# Data(car='Pontiac Firebird', mpg='19.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3282.', acceleration='15.0', model='71', origin='US')
# Data(car='Ford Mustang', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3139.', acceleration='14.5', model='71', origin='US')
# Data(car='Mercury Capri 2000', mpg='23.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2220.', acceleration='14.0', model='71', origin='US')
# Data(car='Opel 1900', mpg='28.0', cylinders='4', displacement='116.0', horsepower='90.00', weight='2123.', acceleration='14.0', model='71', origin='Europe')
# Data(car='Peugeot 304', mpg='30.0', cylinders='4', displacement='79.00', horsepower='70.00', weight='2074.', acceleration='19.5', model='71', origin='Europe')
# Data(car='Fiat 124B', mpg='30.0', cylinders='4', displacement='88.00', horsepower='76.00', weight='2065.', acceleration='14.5', model='71', origin='Europe')
# Data(car='Toyota Corolla 1200', mpg='31.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1773.', acceleration='19.0', model='71', origin='Japan')
# Data(car='Datsun 1200', mpg='35.0', cylinders='4', displacement='72.00', horsepower='69.00', weight='1613.', acceleration='18.0', model='71', origin='Japan')
# Data(car='Volkswagen Model 111', mpg='27.0', cylinders='4', displacement='97.00', horsepower='60.00', weight='1834.', acceleration='19.0', model='71', origin='Europe')
# Data(car='Plymouth Cricket', mpg='26.0', cylinders='4', displacement='91.00', horsepower='70.00', weight='1955.', acceleration='20.5', model='71', origin='US')
# Data(car='Toyota Corolla Hardtop', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2278.', acceleration='15.5', model='72', origin='Japan')
# Data(car='Dodge Colt Hardtop', mpg='25.0', cylinders='4', displacement='97.50', horsepower='80.00', weight='2126.', acceleration='17.0', model='72', origin='US')
# Data(car='Volkswagen Type 3', mpg='23.0', cylinders='4', displacement='97.00', horsepower='54.00', weight='2254.', acceleration='23.5', model='72', origin='Europe')
# Data(car='Chevrolet Vega', mpg='20.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2408.', acceleration='19.5', model='72', origin='US')
# Data(car='Ford Pinto Runabout', mpg='21.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2226.', acceleration='16.5', model='72', origin='US')
# Data(car='Chevrolet Impala', mpg='13.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4274.', acceleration='12.0', model='72', origin='US')
# Data(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4385.', acceleration='12.0', model='72', origin='US')
# Data(car='Plymouth Fury III', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4135.', acceleration='13.5', model='72', origin='US')
# Data(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4129.', acceleration='13.0', model='72', origin='US')
# Data(car='AMC Ambassador SST', mpg='17.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='72', origin='US')
# Data(car='Mercury Marquis', mpg='11.0', cylinders='8', displacement='429.0', horsepower='208.0', weight='4633.', acceleration='11.0', model='72', origin='US')
# Data(car='Buick LeSabre Custom', mpg='13.0', cylinders='8', displacement='350.0', horsepower='155.0', weight='4502.', acceleration='13.5', model='72', origin='US')
# Data(car='Oldsmobile Delta 88 Royale', mpg='12.0', cylinders='8', displacement='350.0', horsepower='160.0', weight='4456.', acceleration='13.5', model='72', origin='US')
# Data(car='Chrysler Newport Royal', mpg='13.0', cylinders='8', displacement='400.0', horsepower='190.0', weight='4422.', acceleration='12.5', model='72', origin='US')
# Data(car='Mazda RX2 Coupe', mpg='19.0', cylinders='3', displacement='70.00', horsepower='97.00', weight='2330.', acceleration='13.5', model='72', origin='Japan')
# Data(car='AMC Matador (sw)', mpg='15.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3892.', acceleration='12.5', model='72', origin='US')
# Data(car='Chevrolet Chevelle Concours (sw)', mpg='13.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='4098.', acceleration='14.0', model='72', origin='US')
# Data(car='Ford Gran Torino (sw)', mpg='13.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4294.', acceleration='16.0', model='72', origin='US')
# Data(car='Plymouth Satellite Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4077.', acceleration='14.0', model='72', origin='US')
# Data(car='Volvo 145e (sw)', mpg='18.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2933.', acceleration='14.5', model='72', origin='Europe')
# Data(car='Volkswagen 411 (sw)', mpg='22.0', cylinders='4', displacement='121.0', horsepower='76.00', weight='2511.', acceleration='18.0', model='72', origin='Europe')
# Data(car='Peugeot 504 (sw)', mpg='21.0', cylinders='4', displacement='120.0', horsepower='87.00', weight='2979.', acceleration='19.5', model='72', origin='Europe')
# Data(car='Renault 12 (sw)', mpg='26.0', cylinders='4', displacement='96.00', horsepower='69.00', weight='2189.', acceleration='18.0', model='72', origin='Europe')
# Data(car='Ford Pinto (sw)', mpg='22.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2395.', acceleration='16.0', model='72', origin='US')
# Data(car='Datsun 510 (sw)', mpg='28.0', cylinders='4', displacement='97.00', horsepower='92.00', weight='2288.', acceleration='17.0', model='72', origin='Japan')
# Data(car='Toyota Corolla Mark II (sw)', mpg='23.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2506.', acceleration='14.5', model='72', origin='Japan')
# Data(car='Dodge Colt (sw)', mpg='28.0', cylinders='4', displacement='98.00', horsepower='80.00', weight='2164.', acceleration='15.0', model='72', origin='US')
# Data(car='Toyota Corolla 1600 (sw)', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2100.', acceleration='16.5', model='72', origin='Japan')
# Data(car='Buick Century 350', mpg='13.0', cylinders='8', displacement='350.0', horsepower='175.0', weight='4100.', acceleration='13.0', model='73', origin='US')
# Data(car='AMC Matador', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='73', origin='US')
# Data(car='Chevrolet Malibu', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='3988.', acceleration='13.0', model='73', origin='US')
# Data(car='Ford Gran Torino', mpg='14.0', cylinders='8', displacement='302.0', horsepower='137.0', weight='4042.', acceleration='14.5', model='73', origin='US')
# Data(car='Dodge Coronet Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3777.', acceleration='12.5', model='73', origin='US')
# Data(car='Mercury Marquis Brougham', mpg='12.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4952.', acceleration='11.5', model='73', origin='US')
# Data(car='Chevrolet Caprice Classic', mpg='13.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4464.', acceleration='12.0', model='73', origin='US')
# Data(car='Ford LTD', mpg='13.0', cylinders='8', displacement='351.0', horsepower='158.0', weight='4363.', acceleration='13.0', model='73', origin='US')
# Data(car='Plymouth Fury Gran Sedan', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4237.', acceleration='14.5', model='73', origin='US')
# Data(car='Chrysler New Yorker Brougham', mpg='13.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4735.', acceleration='11.0', model='73', origin='US')
# Data(car='Buick Electra 225 Custom', mpg='12.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4951.', acceleration='11.0', model='73', origin='US')
# Data(car='AMC Ambassador Brougham', mpg='13.0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3821.', acceleration='11.0', model='73', origin='US')
# Data(car='Plymouth Valiant', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3121.', acceleration='16.5', model='73', origin='US')
# Data(car='Chevrolet Nova Custom', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3278.', acceleration='18.0', model='73', origin='US')
# Data(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2945.', acceleration='16.0', model='73', origin='US')
# Data(car='Ford Maverick', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3021.', acceleration='16.5', model='73', origin='US')
# Data(car='Plymouth Duster', mpg='23.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2904.', acceleration='16.0', model='73', origin='US')
# Data(car='Volkswagen Super Beetle', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1950.', acceleration='21.0', model='73', origin='Europe')
# Data(car='Chevrolet Impala', mpg='11.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4997.', acceleration='14.0', model='73', origin='US')
# Data(car='Ford Country', mpg='12.0', cylinders='8', displacement='400.0', horsepower='167.0', weight='4906.', acceleration='12.5', model='73', origin='US')
# Data(car='Plymouth Custom Suburb', mpg='13.0', cylinders='8', displacement='360.0', horsepower='170.0', weight='4654.', acceleration='13.0', model='73', origin='US')
# Data(car='Oldsmobile Vista Cruiser', mpg='12.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='4499.', acceleration='12.5', model='73', origin='US')
# Data(car='AMC Gremlin', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2789.', acceleration='15.0', model='73', origin='US')
# Data(car='Toyota Camry', mpg='20.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2279.', acceleration='19.0', model='73', origin='Japan')
# Data(car='Chevrolet Vega', mpg='21.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2401.', acceleration='19.5', model='73', origin='US')
# Data(car='Datsun 610', mpg='22.0', cylinders='4', displacement='108.0', horsepower='94.00', weight='2379.', acceleration='16.5', model='73', origin='Japan')
# Data(car='Mazda RX3', mpg='18.0', cylinders='3', displacement='70.00', horsepower='90.00', weight='2124.', acceleration='13.5', model='73', origin='Japan')
# Data(car='Ford Pinto', mpg='19.0', cylinders='4', displacement='122.0', horsepower='85.00', weight='2310.', acceleration='18.5', model='73', origin='US')
# Data(car='Mercury Capri v6', mpg='21.0', cylinders='6', displacement='155.0', horsepower='107.0', weight='2472.', acceleration='14.0', model='73', origin='US')
# Data(car='Fiat 124 Sport Coupe', mpg='26.0', cylinders='4', displacement='98.00', horsepower='90.00', weight='2265.', acceleration='15.5', model='73', origin='Europe')
# Data(car='Chevrolet Monte Carlo S', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4082.', acceleration='13.0', model='73', origin='US')
# Data(car='Pontiac Grand Prix', mpg='16.0', cylinders='8', displacement='400.0', horsepower='230.0', weight='4278.', acceleration='9.50', model='73', origin='US')
# Data(car='Fiat 128', mpg='29.0', cylinders='4', displacement='68.00', horsepower='49.00', weight='1867.', acceleration='19.5', model='73', origin='Europe')
# Data(car='Opel Manta', mpg='24.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2158.', acceleration='15.5', model='73', origin='Europe')
# Data(car='Audi 100LS', mpg='20.0', cylinders='4', displacement='114.0', horsepower='91.00', weight='2582.', acceleration='14.0', model='73', origin='Europe')
# Data(car='Volvo 144ea', mpg='19.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2868.', acceleration='15.5', model='73', origin='Europe')
# Data(car='Dodge Dart Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3399.', acceleration='11.0', model='73', origin='US')
# Data(car='Saab 99le', mpg='24.0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2660.', acceleration='14.0', model='73', origin='Europe')
# Data(car='Toyota Mark II', mpg='20.0', cylinders='6', displacement='156.0', horsepower='122.0', weight='2807.', acceleration='13.5', model='73', origin='Japan')
# Data(car='Oldsmobile Omega', mpg='11.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='3664.', acceleration='11.0', model='73', origin='US')
# Data(car='Plymouth Duster', mpg='20.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='3102.', acceleration='16.5', model='74', origin='US')
# Data(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='0', weight='2875.', acceleration='17.0', model='74', origin='US')
# Data(car='AMC Hornet', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2901.', acceleration='16.0', model='74', origin='US')
# Data(car='Chevrolet Nova', mpg='15.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3336.', acceleration='17.0', model='74', origin='US')
# Data(car='Datsun B210', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1950.', acceleration='19.0', model='74', origin='Japan')
# Data(car='Ford Pinto', mpg='26.0', cylinders='4', displacement='122.0', horsepower='80.00', weight='2451.', acceleration='16.5', model='74', origin='US')
# Data(car='Toyota Corolla 1200', mpg='32.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1836.', acceleration='21.0', model='74', origin='Japan')
# Data(car='Chevrolet Vega', mpg='25.0', cylinders='4', displacement='140.0', horsepower='75.00', weight='2542.', acceleration='17.0', model='74', origin='US')
# Data(car='Chevrolet Chevelle Malibu Classic', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3781.', acceleration='17.0', model='74', origin='US')
# Data(car='AMC Matador', mpg='16.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3632.', acceleration='18.0', model='74', origin='US')
# Data(car='Plymouth Satellite Sebring', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3613.', acceleration='16.5', model='74', origin='US')
# Data(car='Ford Gran Torino', mpg='16.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4141.', acceleration='14.0', model='74', origin='US')
# Data(car='Buick Century Luxus (sw)', mpg='13.0', cylinders='8', displacement='350.0', horsepower='150.0', weight='4699.', acceleration='14.5', model='74', origin='US')
# Data(car='Dodge Coronet Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4457.', acceleration='13.5', model='74', origin='US')
# Data(car='Ford Gran Torino (sw)', mpg='14.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4638.', acceleration='16.0', model='74', origin='US')
# Data(car='AMC Matador (sw)', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='4257.', acceleration='15.5', model='74', origin='US')
# Data(car='Audi Fox', mpg='29.0', cylinders='4', displacement='98.00', horsepower='83.00', weight='2219.', acceleration='16.5', model='74', origin='Europe')
# Data(car='Volkswagen Dasher', mpg='26.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1963.', acceleration='15.5', model='74', origin='Europe')
# Data(car='Opel Manta', mpg='26.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='2300.', acceleration='14.5', model='74', origin='Europe')
# Data(car='Toyota Corolla', mpg='31.0', cylinders='4', displacement='76.00', horsepower='52.00', weight='1649.', acceleration='16.5', model='74', origin='Japan')
# Data(car='Datsun 710', mpg='32.0', cylinders='4', displacement='83.00', horsepower='61.00', weight='2003.', acceleration='19.0', model='74', origin='Japan')
# Data(car='Dodge Colt', mpg='28.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2125.', acceleration='14.5', model='74', origin='US')
# Data(car='Fiat 128', mpg='24.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2108.', acceleration='15.5', model='74', origin='Europe')
# Data(car='Fiat 124 TC', mpg='26.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2246.', acceleration='14.0', model='74', origin='Europe')
# Data(car='Honda Civic', mpg='24.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2489.', acceleration='15.0', model='74', origin='Japan')
# Data(car='Subaru', mpg='26.0', cylinders='4', displacement='108.0', horsepower='93.00', weight='2391.', acceleration='15.5', model='74', origin='Japan')
# Data(car='Fiat x1.9', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='2000.', acceleration='16.0', model='74', origin='Europe')
# Data(car='Plymouth Valiant Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3264.', acceleration='16.0', model='75', origin='US')
# Data(car='Chevrolet Nova', mpg='18.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3459.', acceleration='16.0', model='75', origin='US')
# Data(car='Mercury Monarch', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3432.', acceleration='21.0', model='75', origin='US')
# Data(car='Ford Maverick', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3158.', acceleration='19.5', model='75', origin='US')
# Data(car='Pontiac Catalina', mpg='16.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4668.', acceleration='11.5', model='75', origin='US')
# Data(car='Chevrolet Bel Air', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4440.', acceleration='14.0', model='75', origin='US')
# Data(car='Plymouth Grand Fury', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4498.', acceleration='14.5', model='75', origin='US')
# Data(car='Ford LTD', mpg='14.0', cylinders='8', displacement='351.0', horsepower='148.0', weight='4657.', acceleration='13.5', model='75', origin='US')
# Data(car='Buick Century', mpg='17.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3907.', acceleration='21.0', model='75', origin='US')
# Data(car='Chevrolete Chevelle Malibu', mpg='16.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3897.', acceleration='18.5', model='75', origin='US')
# Data(car='AMC Matador', mpg='15.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3730.', acceleration='19.0', model='75', origin='US')
# Data(car='Plymouth Fury', mpg='18.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3785.', acceleration='19.0', model='75', origin='US')
# Data(car='Buick Skyhawk', mpg='21.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3039.', acceleration='15.0', model='75', origin='US')
# Data(car='Chevrolet Monza 2+2', mpg='20.0', cylinders='8', displacement='262.0', horsepower='110.0', weight='3221.', acceleration='13.5', model='75', origin='US')
# Data(car='Ford Mustang II', mpg='13.0', cylinders='8', displacement='302.0', horsepower='129.0', weight='3169.', acceleration='12.0', model='75', origin='US')
# Data(car='Toyota Corolla', mpg='29.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2171.', acceleration='16.0', model='75', origin='Japan')
# Data(car='Ford Pinto', mpg='23.0', cylinders='4', displacement='140.0', horsepower='83.00', weight='2639.', acceleration='17.0', model='75', origin='US')
# Data(car='AMC Gremlin', mpg='20.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2914.', acceleration='16.0', model='75', origin='US')
# Data(car='Pontiac Astro', mpg='23.0', cylinders='4', displacement='140.0', horsepower='78.00', weight='2592.', acceleration='18.5', model='75', origin='US')
# Data(car='Toyota Corolla', mpg='24.0', cylinders='4', displacement='134.0', horsepower='96.00', weight='2702.', acceleration='13.5', model='75', origin='Japan')
# Data(car='Volkswagen Dasher', mpg='25.0', cylinders='4', displacement='90.00', horsepower='71.00', weight='2223.', acceleration='16.5', model='75', origin='Europe')
# Data(car='Datsun 710', mpg='24.0', cylinders='4', displacement='119.0', horsepower='97.00', weight='2545.', acceleration='17.0', model='75', origin='Japan')
# Data(car='Ford Pinto', mpg='18.0', cylinders='6', displacement='171.0', horsepower='97.00', weight='2984.', acceleration='14.5', model='75', origin='US')
# Data(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.0', model='75', origin='Europe')
# Data(car='AMC Pacer', mpg='19.0', cylinders='6', displacement='232.0', horsepower='90.00', weight='3211.', acceleration='17.0', model='75', origin='US')
# Data(car='Audi 100LS', mpg='23.0', cylinders='4', displacement='115.0', horsepower='95.00', weight='2694.', acceleration='15.0', model='75', origin='Europe')
# Data(car='Peugeot 504', mpg='23.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2957.', acceleration='17.0', model='75', origin='Europe')
# Data(car='Volvo 244DL', mpg='22.0', cylinders='4', displacement='121.0', horsepower='98.00', weight='2945.', acceleration='14.5', model='75', origin='Europe')
# Data(car='Saab 99LE', mpg='25.0', cylinders='4', displacement='121.0', horsepower='115.0', weight='2671.', acceleration='13.5', model='75', origin='Europe')
# Data(car='Honda Civic CVCC', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.5', model='75', origin='Japan')
# Data(car='Fiat 131', mpg='28.0', cylinders='4', displacement='107.0', horsepower='86.00', weight='2464.', acceleration='15.5', model='76', origin='Europe')
# Data(car='Opel 1900', mpg='25.0', cylinders='4', displacement='116.0', horsepower='81.00', weight='2220.', acceleration='16.9', model='76', origin='Europe')
# Data(car='Capri ii', mpg='25.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2572.', acceleration='14.9', model='76', origin='US')
# Data(car='Dodge Colt', mpg='26.0', cylinders='4', displacement='98.00', horsepower='79.00', weight='2255.', acceleration='17.7', model='76', origin='US')
# Data(car='Renault 12tl', mpg='27.0', cylinders='4', displacement='101.0', horsepower='83.00', weight='2202.', acceleration='15.3', model='76', origin='Europe')
# Data(car='Chevrolet Chevelle Malibu Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='140.0', weight='4215.', acceleration='13.0', model='76', origin='US')
# Data(car='Dodge Coronet Brougham', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4190.', acceleration='13.0', model='76', origin='US')
# Data(car='AMC Matador', mpg='15.5', cylinders='8', displacement='304.0', horsepower='120.0', weight='3962.', acceleration='13.9', model='76', origin='US')
# Data(car='Ford Gran Torino', mpg='14.5', cylinders='8', displacement='351.0', horsepower='152.0', weight='4215.', acceleration='12.8', model='76', origin='US')
# Data(car='Plymouth Valiant', mpg='22.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3233.', acceleration='15.4', model='76', origin='US')
# Data(car='Chevrolet Nova', mpg='22.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3353.', acceleration='14.5', model='76', origin='US')
# Data(car='Ford Maverick', mpg='24.0', cylinders='6', displacement='200.0', horsepower='81.00', weight='3012.', acceleration='17.6', model='76', origin='US')
# Data(car='AMC Hornet', mpg='22.5', cylinders='6', displacement='232.0', horsepower='90.00', weight='3085.', acceleration='17.6', model='76', origin='US')
# Data(car='Chevrolet Chevette', mpg='29.0', cylinders='4', displacement='85.00', horsepower='52.00', weight='2035.', acceleration='22.2', model='76', origin='US')
# Data(car='Chevrolet Woody', mpg='24.5', cylinders='4', displacement='98.00', horsepower='60.00', weight='2164.', acceleration='22.1', model='76', origin='US')
# Data(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.2', model='76', origin='Europe')
# Data(car='Honda Civic', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.4', model='76', origin='Japan')
# Data(car='Dodge Aspen SE', mpg='20.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3651.', acceleration='17.7', model='76', origin='US')
# Data(car='Ford Grenada ghia', mpg='18.0', cylinders='6', displacement='250.0', horsepower='78.00', weight='3574.', acceleration='21.0', model='76', origin='US')
# Data(car='Pontiac Ventura SJ', mpg='18.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3645.', acceleration='16.2', model='76', origin='US')
# Data(car='AMC Pacer d/l', mpg='17.5', cylinders='6', displacement='258.0', horsepower='95.00', weight='3193.', acceleration='17.8', model='76', origin='US')
# Data(car='Volkswagen Rabbit', mpg='29.5', cylinders='4', displacement='97.00', horsepower='71.00', weight='1825.', acceleration='12.2', model='76', origin='Europe')
# Data(car='Datsun B-210', mpg='32.0', cylinders='4', displacement='85.00', horsepower='70.00', weight='1990.', acceleration='17.0', model='76', origin='Japan')
# Data(car='Toyota Corolla', mpg='28.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2155.', acceleration='16.4', model='76', origin='Japan')
# Data(car='Ford Pinto', mpg='26.5', cylinders='4', displacement='140.0', horsepower='72.00', weight='2565.', acceleration='13.6', model='76', origin='US')
# Data(car='Volvo 245', mpg='20.0', cylinders='4', displacement='130.0', horsepower='102.0', weight='3150.', acceleration='15.7', model='76', origin='Europe')
# Data(car='Plymouth Volare Premier v8', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3940.', acceleration='13.2', model='76', origin='US')
# Data(car='Peugeot 504', mpg='19.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='3270.', acceleration='21.9', model='76', origin='Europe')
# Data(car='Toyota Mark II', mpg='19.0', cylinders='6', displacement='156.0', horsepower='108.0', weight='2930.', acceleration='15.5', model='76', origin='Japan')
# Data(car='Mercedes-Benz 280s', mpg='16.5', cylinders='6', displacement='168.0', horsepower='120.0', weight='3820.', acceleration='16.7', model='76', origin='Europe')
# Data(car='Cadillac Seville', mpg='16.5', cylinders='8', displacement='350.0', horsepower='180.0', weight='4380.', acceleration='12.1', model='76', origin='US')
# Data(car='Chevrolet C10', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4055.', acceleration='12.0', model='76', origin='US')
# Data(car='Ford F108', mpg='13.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='3870.', acceleration='15.0', model='76', origin='US')
# Data(car='Dodge D100', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3755.', acceleration='14.0', model='76', origin='US')
# Data(car='Honda Accord CVCC', mpg='31.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2045.', acceleration='18.5', model='77', origin='Japan')
# Data(car='Buick Opel Isuzu Deluxe', mpg='30.0', cylinders='4', displacement='111.0', horsepower='80.00', weight='2155.', acceleration='14.8', model='77', origin='US')
# Data(car='Renault 5 GTL', mpg='36.0', cylinders='4', displacement='79.00', horsepower='58.00', weight='1825.', acceleration='18.6', model='77', origin='Europe')
# Data(car='Plymouth Arrow GS', mpg='25.5', cylinders='4', displacement='122.0', horsepower='96.00', weight='2300.', acceleration='15.5', model='77', origin='US')
# Data(car='Datsun F-10 Hatchback', mpg='33.5', cylinders='4', displacement='85.00', horsepower='70.00', weight='1945.', acceleration='16.8', model='77', origin='Japan')
# Data(car='Chevrolet Caprice Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='145.0', weight='3880.', acceleration='12.5', model='77', origin='US')
# Data(car='Oldsmobile Cutlass Supreme', mpg='17.0', cylinders='8', displacement='260.0', horsepower='110.0', weight='4060.', acceleration='19.0', model='77', origin='US')
# Data(car='Dodge Monaco Brougham', mpg='15.5', cylinders='8', displacement='318.0', horsepower='145.0', weight='4140.', acceleration='13.7', model='77', origin='US')
# Data(car='Mercury Cougar Brougham', mpg='15.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='4295.', acceleration='14.9', model='77', origin='US')
# Data(car='Chevrolet Concours', mpg='17.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3520.', acceleration='16.4', model='77', origin='US')
# Data(car='Buick Skylark', mpg='20.5', cylinders='6', displacement='231.0', horsepower='105.0', weight='3425.', acceleration='16.9', model='77', origin='US')
# Data(car='Plymouth Volare Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3630.', acceleration='17.7', model='77', origin='US')
# Data(car='Ford Grenada', mpg='18.5', cylinders='6', displacement='250.0', horsepower='98.00', weight='3525.', acceleration='19.0', model='77', origin='US')
# Data(car='Pontiac Grand Prix LJ', mpg='16.0', cylinders='8', displacement='400.0', horsepower='180.0', weight='4220.', acceleration='11.1', model='77', origin='US')
# Data(car='Chevrolet Monte Carlo Landau', mpg='15.5', cylinders='8', displacement='350.0', horsepower='170.0', weight='4165.', acceleration='11.4', model='77', origin='US')
# Data(car='Chrysler Cordoba', mpg='15.5', cylinders='8', displacement='400.0', horsepower='190.0', weight='4325.', acceleration='12.2', model='77', origin='US')
# Data(car='Ford Thunderbird', mpg='16.0', cylinders='8', displacement='351.0', horsepower='149.0', weight='4335.', acceleration='14.5', model='77', origin='US')
# Data(car='Volkswagen Rabbit Custom', mpg='29.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='1940.', acceleration='14.5', model='77', origin='Europe')
# Data(car='Pontiac Sunbird Coupe', mpg='24.5', cylinders='4', displacement='151.0', horsepower='88.00', weight='2740.', acceleration='16.0', model='77', origin='US')
# Data(car='Toyota Corolla Liftback', mpg='26.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2265.', acceleration='18.2', model='77', origin='Japan')
# Data(car='Ford Mustang II 2+2', mpg='25.5', cylinders='4', displacement='140.0', horsepower='89.00', weight='2755.', acceleration='15.8', model='77', origin='US')
# Data(car='Chevrolet Chevette', mpg='30.5', cylinders='4', displacement='98.00', horsepower='63.00', weight='2051.', acceleration='17.0', model='77', origin='US')
# Data(car='Dodge Colt m/m', mpg='33.5', cylinders='4', displacement='98.00', horsepower='83.00', weight='2075.', acceleration='15.9', model='77', origin='US')
# Data(car='Subaru DL', mpg='30.0', cylinders='4', displacement='97.00', horsepower='67.00', weight='1985.', acceleration='16.4', model='77', origin='Japan')
# Data(car='Volkswagen Dasher', mpg='30.5', cylinders='4', displacement='97.00', horsepower='78.00', weight='2190.', acceleration='14.1', model='77', origin='Europe')
# Data(car='Datsun 810', mpg='22.0', cylinders='6', displacement='146.0', horsepower='97.00', weight='2815.', acceleration='14.5', model='77', origin='Japan')
# Data(car='BMW 320i', mpg='21.5', cylinders='4', displacement='121.0', horsepower='110.0', weight='2600.', acceleration='12.8', model='77', origin='Europe')
# Data(car='Mazda RX-4', mpg='21.5', cylinders='3', displacement='80.00', horsepower='110.0', weight='2720.', acceleration='13.5', model='77', origin='Japan')
# Data(car='Volkswagen Rabbit Custom Diesel', mpg='43.1', cylinders='4', displacement='90.00', horsepower='48.00', weight='1985.', acceleration='21.5', model='78', origin='Europe')
# Data(car='Ford Fiesta', mpg='36.1', cylinders='4', displacement='98.00', horsepower='66.00', weight='1800.', acceleration='14.4', model='78', origin='US')
# Data(car='Mazda GLC Deluxe', mpg='32.8', cylinders='4', displacement='78.00', horsepower='52.00', weight='1985.', acceleration='19.4', model='78', origin='Japan')
# Data(car='Datsun B210 GX', mpg='39.4', cylinders='4', displacement='85.00', horsepower='70.00', weight='2070.', acceleration='18.6', model='78', origin='Japan')
# Data(car='Honda Civic CVCC', mpg='36.1', cylinders='4', displacement='91.00', horsepower='60.00', weight='1800.', acceleration='16.4', model='78', origin='Japan')
# Data(car='Oldsmobile Cutlass Salon Brougham', mpg='19.9', cylinders='8', displacement='260.0', horsepower='110.0', weight='3365.', acceleration='15.5', model='78', origin='US')
# Data(car='Dodge Diplomat', mpg='19.4', cylinders='8', displacement='318.0', horsepower='140.0', weight='3735.', acceleration='13.2', model='78', origin='US')
# Data(car='Mercury Monarch ghia', mpg='20.2', cylinders='8', displacement='302.0', horsepower='139.0', weight='3570.', acceleration='12.8', model='78', origin='US')
# Data(car='Pontiac Phoenix LJ', mpg='19.2', cylinders='6', displacement='231.0', horsepower='105.0', weight='3535.', acceleration='19.2', model='78', origin='US')
# Data(car='Chevrolet Malibu', mpg='20.5', cylinders='6', displacement='200.0', horsepower='95.00', weight='3155.', acceleration='18.2', model='78', origin='US')
# Data(car='Ford Fairmont (auto)', mpg='20.2', cylinders='6', displacement='200.0', horsepower='85.00', weight='2965.', acceleration='15.8', model='78', origin='US')
# Data(car='Ford Fairmont (man)', mpg='25.1', cylinders='4', displacement='140.0', horsepower='88.00', weight='2720.', acceleration='15.4', model='78', origin='US')
# Data(car='Plymouth Volare', mpg='20.5', cylinders='6', displacement='225.0', horsepower='100.0', weight='3430.', acceleration='17.2', model='78', origin='US')
# Data(car='AMC Concord', mpg='19.4', cylinders='6', displacement='232.0', horsepower='90.00', weight='3210.', acceleration='17.2', model='78', origin='US')
# Data(car='Buick Century Special', mpg='20.6', cylinders='6', displacement='231.0', horsepower='105.0', weight='3380.', acceleration='15.8', model='78', origin='US')
# Data(car='Mercury Zephyr', mpg='20.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='3070.', acceleration='16.7', model='78', origin='US')
# Data(car='Dodge Aspen', mpg='18.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3620.', acceleration='18.7', model='78', origin='US')
# Data(car='AMC Concord d/l', mpg='18.1', cylinders='6', displacement='258.0', horsepower='120.0', weight='3410.', acceleration='15.1', model='78', origin='US')
# Data(car='Chevrolet Monte Carlo Landau', mpg='19.2', cylinders='8', displacement='305.0', horsepower='145.0', weight='3425.', acceleration='13.2', model='78', origin='US')
# Data(car='Buick Regal Sport Coupe (turbo)', mpg='17.7', cylinders='6', displacement='231.0', horsepower='165.0', weight='3445.', acceleration='13.4', model='78', origin='US')
# Data(car='Ford Futura', mpg='18.1', cylinders='8', displacement='302.0', horsepower='139.0', weight='3205.', acceleration='11.2', model='78', origin='US')
# Data(car='Dodge Magnum XE', mpg='17.5', cylinders='8', displacement='318.0', horsepower='140.0', weight='4080.', acceleration='13.7', model='78', origin='US')
# Data(car='Chevrolet Chevette', mpg='30.0', cylinders='4', displacement='98.00', horsepower='68.00', weight='2155.', acceleration='16.5', model='78', origin='US')
# Data(car='Toyota Corolla', mpg='27.5', cylinders='4', displacement='134.0', horsepower='95.00', weight='2560.', acceleration='14.2', model='78', origin='Japan')
# Data(car='Datsun 510', mpg='27.2', cylinders='4', displacement='119.0', horsepower='97.00', weight='2300.', acceleration='14.7', model='78', origin='Japan')
# Data(car='Dodge Omni', mpg='30.9', cylinders='4', displacement='105.0', horsepower='75.00', weight='2230.', acceleration='14.5', model='78', origin='US')
# Data(car='Toyota Celica GT Liftback', mpg='21.1', cylinders='4', displacement='134.0', horsepower='95.00', weight='2515.', acceleration='14.8', model='78', origin='Japan')
# Data(car='Plymouth Sapporo', mpg='23.2', cylinders='4', displacement='156.0', horsepower='105.0', weight='2745.', acceleration='16.7', model='78', origin='US')
# Data(car='Oldsmobile Starfire SX', mpg='23.8', cylinders='4', displacement='151.0', horsepower='85.00', weight='2855.', acceleration='17.6', model='78', origin='US')
# Data(car='Datsun 200-SX', mpg='23.9', cylinders='4', displacement='119.0', horsepower='97.00', weight='2405.', acceleration='14.9', model='78', origin='Japan')
# Data(car='Audi 5000', mpg='20.3', cylinders='5', displacement='131.0', horsepower='103.0', weight='2830.', acceleration='15.9', model='78', origin='Europe')
# Data(car='Volvo 264gl', mpg='17.0', cylinders='6', displacement='163.0', horsepower='125.0', weight='3140.', acceleration='13.6', model='78', origin='Europe')
# Data(car='Saab 99gle', mpg='21.6', cylinders='4', displacement='121.0', horsepower='115.0', weight='2795.', acceleration='15.7', model='78', origin='Europe')
# Data(car='Peugeot 604sl', mpg='16.2', cylinders='6', displacement='163.0', horsepower='133.0', weight='3410.', acceleration='15.8', model='78', origin='Europe')
# Data(car='Volkswagen Scirocco', mpg='31.5', cylinders='4', displacement='89.00', horsepower='71.00', weight='1990.', acceleration='14.9', model='78', origin='Europe')
# Data(car='Honda Accord LX', mpg='29.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2135.', acceleration='16.6', model='78', origin='Japan')
# Data(car='Pontiac Lemans V6', mpg='21.5', cylinders='6', displacement='231.0', horsepower='115.0', weight='3245.', acceleration='15.4', model='79', origin='US')
# Data(car='Mercury Zephyr 6', mpg='19.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='2990.', acceleration='18.2', model='79', origin='US')
# Data(car='Ford Fairmont 4', mpg='22.3', cylinders='4', displacement='140.0', horsepower='88.00', weight='2890.', acceleration='17.3', model='79', origin='US')
# Data(car='AMC Concord DL 6', mpg='20.2', cylinders='6', displacement='232.0', horsepower='90.00', weight='3265.', acceleration='18.2', model='79', origin='US')
# Data(car='Dodge Aspen 6', mpg='20.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3360.', acceleration='16.6', model='79', origin='US')
# Data(car='Chevrolet Caprice Classic', mpg='17.0', cylinders='8', displacement='305.0', horsepower='130.0', weight='3840.', acceleration='15.4', model='79', origin='US')
# Data(car='Ford LTD Landau', mpg='17.6', cylinders='8', displacement='302.0', horsepower='129.0', weight='3725.', acceleration='13.4', model='79', origin='US')
# Data(car='Mercury Grand Marquis', mpg='16.5', cylinders='8', displacement='351.0', horsepower='138.0', weight='3955.', acceleration='13.2', model='79', origin='US')
# Data(car='Dodge St. Regis', mpg='18.2', cylinders='8', displacement='318.0', horsepower='135.0', weight='3830.', acceleration='15.2', model='79', origin='US')
# Data(car='Buick Estate Wagon (sw)', mpg='16.9', cylinders='8', displacement='350.0', horsepower='155.0', weight='4360.', acceleration='14.9', model='79', origin='US')
# ...
# Data(car='Plymouth Horizon', mpg='34.2', cylinders='4', displacement='105.0', horsepower='70.00', weight='2200.', acceleration='13.2', model='79', origin='US')
# Data(car='Plymouth Horizon TC3', mpg='34.5', cylinders='4', displacement='105.0', horsepower='70.00', weight='2150.', acceleration='14.9', model='79', origin='US')
# Data(car='Datsun 210', mpg='31.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2020.', acceleration='19.2', model='79', origin='Japan')
# Data(car='Fiat Strada Custom', mpg='37.3', cylinders='4', displacement='91.00', horsepower='69.00', weight='2130.', acceleration='14.7', model='79', origin='Europe')
# Data(car='Buick Skylark Limited', mpg='28.4', cylinders='4', displacement='151.0', horsepower='90.00', weight='2670.', acceleration='16.0', model='79', origin='US')
# Data(car='Chevrolet Citation', mpg='28.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2595.', acceleration='11.3', model='79', origin='US')
# Data(car='Oldsmobile Omega Brougham', mpg='26.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2700.', acceleration='12.9', model='79', origin='US')
# Data(car='Pontiac Phoenix', mpg='33.5', cylinders='4', displacement='151.0', horsepower='90.00', weight='2556.', acceleration='13.2', model='79', origin='US')
# Data(car='Volkswagen Rabbit', mpg='41.5', cylinders='4', displacement='98.00', horsepower='76.00', weight='2144.', acceleration='14.7', model='80', origin='Europe')
# Data(car='Toyota Corolla Tercel', mpg='38.1', cylinders='4', displacement='89.00', horsepower='60.00', weight='1968.', acceleration='18.8', model='80', origin='Japan')
# Data(car='Chevrolet Chevette', mpg='32.1', cylinders='4', displacement='98.00', horsepower='70.00', weight='2120.', acceleration='15.5', model='80', origin='US')
# Data(car='Datsun 310', mpg='37.2', cylinders='4', displacement='86.00', horsepower='65.00', weight='2019.', acceleration='16.4', model='80', origin='Japan')
# Data(car='Chevrolet Citation', mpg='28.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2678.', acceleration='16.5', model='80', origin='US')
# Data(car='Ford Fairmont', mpg='26.4', cylinders='4', displacement='140.0', horsepower='88.00', weight='2870.', acceleration='18.1', model='80', origin='US')
# Data(car='AMC Concord', mpg='24.3', cylinders='4', displacement='151.0', horsepower='90.00', weight='3003.', acceleration='20.1', model='80', origin='US')
# Data(car='Dodge Aspen', mpg='19.1', cylinders='6', displacement='225.0', horsepower='90.00', weight='3381.', acceleration='18.7', model='80', origin='US')
# Data(car='Audi 4000', mpg='34.3', cylinders='4', displacement='97.00', horsepower='78.00', weight='2188.', acceleration='15.8', model='80', origin='Europe')
# Data(car='Toyota Corolla Liftback', mpg='29.8', cylinders='4', displacement='134.0', horsepower='90.00', weight='2711.', acceleration='15.5', model='80', origin='Japan')
# Data(car='Mazda 626', mpg='31.3', cylinders='4', displacement='120.0', horsepower='75.00', weight='2542.', acceleration='17.5', model='80', origin='Japan')
# Data(car='Datsun 510 Hatchback', mpg='37.0', cylinders='4', displacement='119.0', horsepower='92.00', weight='2434.', acceleration='15.0', model='80', origin='Japan')
# Data(car='Toyota Corolla', mpg='32.2', cylinders='4', displacement='108.0', horsepower='75.00', weight='2265.', acceleration='15.2', model='80', origin='Japan')
# Data(car='Mazda GLC', mpg='46.6', cylinders='4', displacement='86.00', horsepower='65.00', weight='2110.', acceleration='17.9', model='80', origin='Japan')
# Data(car='Dodge Colt', mpg='27.9', cylinders='4', displacement='156.0', horsepower='105.0', weight='2800.', acceleration='14.4', model='80', origin='US')
# Data(car='Datsun 210', mpg='40.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2110.', acceleration='19.2', model='80', origin='Japan')
# Data(car='Volkswagen Rabbit C (Diesel)', mpg='44.3', cylinders='4', displacement='90.00', horsepower='48.00', weight='2085.', acceleration='21.7', model='80', origin='Europe')
# Data(car='Volkswagen Dasher (diesel)', mpg='43.4', cylinders='4', displacement='90.00', horsepower='48.00', weight='2335.', acceleration='23.7', model='80', origin='Europe')
# Data(car='Audi 5000s (diesel)', mpg='36.4', cylinders='5', displacement='121.0', horsepower='67.00', weight='2950.', acceleration='19.9', model='80', origin='Europe')
# Data(car='Mercedes-Benz 240d', mpg='30.0', cylinders='4', displacement='146.0', horsepower='67.00', weight='3250.', acceleration='21.8', model='80', origin='Europe')
# Data(car='Honda Civic 1500 gl', mpg='44.6', cylinders='4', displacement='91.00', horsepower='67.00', weight='1850.', acceleration='13.8', model='80', origin='Japan')
# Data(car='Renault Lecar Deluxe', mpg='40.9', cylinders='4', displacement='85.00', horsepower='0', weight='1835.', acceleration='17.3', model='80', origin='Europe')
# Data(car='Subaru DL', mpg='33.8', cylinders='4', displacement='97.00', horsepower='67.00', weight='2145.', acceleration='18.0', model='80', origin='Japan')
# Data(car='Volkswagen Rabbit', mpg='29.8', cylinders='4', displacement='89.00', horsepower='62.00', weight='1845.', acceleration='15.3', model='80', origin='Europe')
# Data(car='Datsun 280-ZX', mpg='32.7', cylinders='6', displacement='168.0', horsepower='132.0', weight='2910.', acceleration='11.4', model='80', origin='Japan')
# Data(car='Mazda RX-7 GS', mpg='23.7', cylinders='3', displacement='70.00', horsepower='100.0', weight='2420.', acceleration='12.5', model='80', origin='Japan')
# Data(car='Triumph TR7 Coupe', mpg='35.0', cylinders='4', displacement='122.0', horsepower='88.00', weight='2500.', acceleration='15.1', model='80', origin='Europe')
# Data(car='Ford Mustang Cobra', mpg='23.6', cylinders='4', displacement='140.0', horsepower='0', weight='2905.', acceleration='14.3', model='80', origin='US')
# Data(car='Honda Accord', mpg='32.4', cylinders='4', displacement='107.0', horsepower='72.00', weight='2290.', acceleration='17.0', model='80', origin='Japan')
# Data(car='Plymouth Reliant', mpg='27.2', cylinders='4', displacement='135.0', horsepower='84.00', weight='2490.', acceleration='15.7', model='81', origin='US')
# Data(car='Buick Skylark', mpg='26.6', cylinders='4', displacement='151.0', horsepower='84.00', weight='2635.', acceleration='16.4', model='81', origin='US')
# Data(car='Dodge Aries Wagon (sw)', mpg='25.8', cylinders='4', displacement='156.0', horsepower='92.00', weight='2620.', acceleration='14.4', model='81', origin='US')
# Data(car='Chevrolet Citation', mpg='23.5', cylinders='6', displacement='173.0', horsepower='110.0', weight='2725.', acceleration='12.6', model='81', origin='US')
# Data(car='Plymouth Reliant', mpg='30.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2385.', acceleration='12.9', model='81', origin='US')
# Data(car='Toyota Starlet', mpg='39.1', cylinders='4', displacement='79.00', horsepower='58.00', weight='1755.', acceleration='16.9', model='81', origin='Japan')
# Data(car='Plymouth Champ', mpg='39.0', cylinders='4', displacement='86.00', horsepower='64.00', weight='1875.', acceleration='16.4', model='81', origin='US')
# Data(car='Honda Civic 1300', mpg='35.1', cylinders='4', displacement='81.00', horsepower='60.00', weight='1760.', acceleration='16.1', model='81', origin='Japan')
# Data(car='Subaru', mpg='32.3', cylinders='4', displacement='97.00', horsepower='67.00', weight='2065.', acceleration='17.8', model='81', origin='Japan')
# Data(car='Datsun 210 MPG', mpg='37.0', cylinders='4', displacement='85.00', horsepower='65.00', weight='1975.', acceleration='19.4', model='81', origin='Japan')
# Data(car='Toyota Tercel', mpg='37.7', cylinders='4', displacement='89.00', horsepower='62.00', weight='2050.', acceleration='17.3', model='81', origin='Japan')
# Data(car='Mazda GLC 4', mpg='34.1', cylinders='4', displacement='91.00', horsepower='68.00', weight='1985.', acceleration='16.0', model='81', origin='Japan')
# Data(car='Plymouth Horizon 4', mpg='34.7', cylinders='4', displacement='105.0', horsepower='63.00', weight='2215.', acceleration='14.9', model='81', origin='US')
# Data(car='Ford Escort 4W', mpg='34.4', cylinders='4', displacement='98.00', horsepower='65.00', weight='2045.', acceleration='16.2', model='81', origin='US')
# Data(car='Ford Escort 2H', mpg='29.9', cylinders='4', displacement='98.00', horsepower='65.00', weight='2380.', acceleration='20.7', model='81', origin='US')
# Data(car='Volkswagen Jetta', mpg='33.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='2190.', acceleration='14.2', model='81', origin='Europe')
# Data(car='Renault 18i', mpg='34.5', cylinders='4', displacement='100.0', horsepower='0', weight='2320.', acceleration='15.8', model='81', origin='Europe')
# Data(car='Honda Prelude', mpg='33.7', cylinders='4', displacement='107.0', horsepower='75.00', weight='2210.', acceleration='14.4', model='81', origin='Japan')
# Data(car='Toyota Corolla', mpg='32.4', cylinders='4', displacement='108.0', horsepower='75.00', weight='2350.', acceleration='16.8', model='81', origin='Japan')
# Data(car='Datsun 200SX', mpg='32.9', cylinders='4', displacement='119.0', horsepower='100.0', weight='2615.', acceleration='14.8', model='81', origin='Japan')
# Data(car='Mazda 626', mpg='31.6', cylinders='4', displacement='120.0', horsepower='74.00', weight='2635.', acceleration='18.3', model='81', origin='Japan')
# Data(car='Peugeot 505s Turbo Diesel', mpg='28.1', cylinders='4', displacement='141.0', horsepower='80.00', weight='3230.', acceleration='20.4', model='81', origin='Europe')
# Data(car='Saab 900s', mpg='0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2800.', acceleration='15.4', model='81', origin='Europe')
# Data(car='Volvo Diesel', mpg='30.7', cylinders='6', displacement='145.0', horsepower='76.00', weight='3160.', acceleration='19.6', model='81', origin='Europe')
# Data(car='Toyota Cressida', mpg='25.4', cylinders='6', displacement='168.0', horsepower='116.0', weight='2900.', acceleration='12.6', model='81', origin='Japan')
# Data(car='Datsun 810 Maxima', mpg='24.2', cylinders='6', displacement='146.0', horsepower='120.0', weight='2930.', acceleration='13.8', model='81', origin='Japan')
# Data(car='Buick Century', mpg='22.4', cylinders='6', displacement='231.0', horsepower='110.0', weight='3415.', acceleration='15.8', model='81', origin='US')
# Data(car='Oldsmobile Cutlass LS', mpg='26.6', cylinders='8', displacement='350.0', horsepower='105.0', weight='3725.', acceleration='19.0', model='81', origin='US')
# Data(car='Ford Grenada gl', mpg='20.2', cylinders='6', displacement='200.0', horsepower='88.00', weight='3060.', acceleration='17.1', model='81', origin='US')
# Data(car='Chrysler Lebaron Salon', mpg='17.6', cylinders='6', displacement='225.0', horsepower='85.00', weight='3465.', acceleration='16.6', model='81', origin='US')
# Data(car='Chevrolet Cavalier', mpg='28.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2605.', acceleration='19.6', model='82', origin='US')
# Data(car='Chevrolet Cavalier Wagon', mpg='27.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2640.', acceleration='18.6', model='82', origin='US')
# Data(car='Chevrolet Cavalier 2-door', mpg='34.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2395.', acceleration='18.0', model='82', origin='US')
# Data(car='Pontiac J2000 SE Hatchback', mpg='31.0', cylinders='4', displacement='112.0', horsepower='85.00', weight='2575.', acceleration='16.2', model='82', origin='US')
# Data(car='Dodge Aries SE', mpg='29.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2525.', acceleration='16.0', model='82', origin='US')
# Data(car='Pontiac Phoenix', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2735.', acceleration='18.0', model='82', origin='US')
# Data(car='Ford Fairmont Futura', mpg='24.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2865.', acceleration='16.4', model='82', origin='US')
# Data(car='AMC Concord DL', mpg='23.0', cylinders='4', displacement='151.0', horsepower='0', weight='3035.', acceleration='20.5', model='82', origin='US')
# Data(car='Volkswagen Rabbit l', mpg='36.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='1980.', acceleration='15.3', model='82', origin='Europe')
# Data(car='Mazda GLC Custom l', mpg='37.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='2025.', acceleration='18.2', model='82', origin='Japan')
# Data(car='Mazda GLC Custom', mpg='31.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='1970.', acceleration='17.6', model='82', origin='Japan')
# Data(car='Plymouth Horizon Miser', mpg='38.0', cylinders='4', displacement='105.0', horsepower='63.00', weight='2125.', acceleration='14.7', model='82', origin='US')
# Data(car='Mercury Lynx l', mpg='36.0', cylinders='4', displacement='98.00', horsepower='70.00', weight='2125.', acceleration='17.3', model='82', origin='US')
# Data(car='Nissan Stanza XE', mpg='36.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2160.', acceleration='14.5', model='82', origin='Japan')
# Data(car='Honda Accord', mpg='36.0', cylinders='4', displacement='107.0', horsepower='75.00', weight='2205.', acceleration='14.5', model='82', origin='Japan')
# Data(car='Toyota Corolla', mpg='34.0', cylinders='4', displacement='108.0', horsepower='70.00', weight='2245', acceleration='16.9', model='82', origin='Japan')
# Data(car='Honda Civic', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.0', model='82', origin='Japan')
# Data(car='Honda Civic (auto)', mpg='32.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.7', model='82', origin='Japan')
# Data(car='Datsun 310 GX', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1995.', acceleration='16.2', model='82', origin='Japan')
# Data(car='Buick Century Limited', mpg='25.0', cylinders='6', displacement='181.0', horsepower='110.0', weight='2945.', acceleration='16.4', model='82', origin='US')
# Data(car='Oldsmobile Cutlass Ciera (diesel)', mpg='38.0', cylinders='6', displacement='262.0', horsepower='85.00', weight='3015.', acceleration='17.0', model='82', origin='US')
# Data(car='Chrysler Lebaron Medallion', mpg='26.0', cylinders='4', displacement='156.0', horsepower='92.00', weight='2585.', acceleration='14.5', model='82', origin='US')
# Data(car='Ford Grenada l', mpg='22.0', cylinders='6', displacement='232.0', horsepower='112.0', weight='2835', acceleration='14.7', model='82', origin='US')
# Data(car='Toyota Celica GT', mpg='32.0', cylinders='4', displacement='144.0', horsepower='96.00', weight='2665.', acceleration='13.9', model='82', origin='Japan')
# Data(car='Dodge Charger 2.2', mpg='36.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2370.', acceleration='13.0', model='82', origin='US')
# Data(car='Chevrolet Camaro', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2950.', acceleration='17.3', model='82', origin='US')
# Data(car='Ford Mustang GL', mpg='27.0', cylinders='4', displacement='140.0', horsepower='86.00', weight='2790.', acceleration='15.6', model='82', origin='US')
# Data(car='Volkswagen Pickup', mpg='44.0', cylinders='4', displacement='97.00', horsepower='52.00', weight='2130.', acceleration='24.6', model='82', origin='Europe')
# Data(car='Dodge Rampage', mpg='32.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2295.', acceleration='11.6', model='82', origin='US')
# Data(car='Ford Ranger', mpg='28.0', cylinders='4', displacement='120.0', horsepower='79.00', weight='2625.', acceleration='18.6', model='82', origin='US')
# Data(car='Chevy S-10', mpg='31.0', cylinders='4', displacement='119.0', horsepower='82.00', weight='2720.', acceleration='19.4', model='82', origin='US')

# %%
@contextmanager
def parsed_data(f_name):        
    f = open(f_name)
    try:
        dialect = csv.Sniffer().sniff(f.read(1000))
        f.seek(0)
        reader = csv.reader(f, dialect)
        headers = map(lambda s: s.lower(), next(reader))
        nt = namedtuple('Data', headers)
        yield (nt(*row) for row in reader)
    finally:
        f.close()

# %%
with parsed_data('cars.csv') as data:
    for row in data:
        print(row)
# Out:
# Data(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# Data(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# Data(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# Data(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# Data(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# Data(car='Ford Galaxie 500', mpg='15.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4341.', acceleration='10.0', model='70', origin='US')
# Data(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='454.0', horsepower='220.0', weight='4354.', acceleration='9.0', model='70', origin='US')
# Data(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4312.', acceleration='8.5', model='70', origin='US')
# Data(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4425.', acceleration='10.0', model='70', origin='US')
# Data(car='AMC Ambassador DPL', mpg='15.0', cylinders='8', displacement='390.0', horsepower='190.0', weight='3850.', acceleration='8.5', model='70', origin='US')
# Data(car='Citroen DS-21 Pallas', mpg='0', cylinders='4', displacement='133.0', horsepower='115.0', weight='3090.', acceleration='17.5', model='70', origin='Europe')
# Data(car='Chevrolet Chevelle Concours (sw)', mpg='0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4142.', acceleration='11.5', model='70', origin='US')
# Data(car='Ford Torino (sw)', mpg='0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4034.', acceleration='11.0', model='70', origin='US')
# Data(car='Plymouth Satellite (sw)', mpg='0', cylinders='8', displacement='383.0', horsepower='175.0', weight='4166.', acceleration='10.5', model='70', origin='US')
# Data(car='AMC Rebel SST (sw)', mpg='0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3850.', acceleration='11.0', model='70', origin='US')
# Data(car='Dodge Challenger SE', mpg='15.0', cylinders='8', displacement='383.0', horsepower='170.0', weight='3563.', acceleration='10.0', model='70', origin='US')
# Data(car="Plymouth 'Cuda 340", mpg='14.0', cylinders='8', displacement='340.0', horsepower='160.0', weight='3609.', acceleration='8.0', model='70', origin='US')
# Data(car='Ford Mustang Boss 302', mpg='0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3353.', acceleration='8.0', model='70', origin='US')
# Data(car='Chevrolet Monte Carlo', mpg='15.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='3761.', acceleration='9.5', model='70', origin='US')
# Data(car='Buick Estate Wagon (sw)', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='3086.', acceleration='10.0', model='70', origin='US')
# Data(car='Toyota Corolla Mark ii', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2372.', acceleration='15.0', model='70', origin='Japan')
# Data(car='Plymouth Duster', mpg='22.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2833.', acceleration='15.5', model='70', origin='US')
# Data(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='199.0', horsepower='97.00', weight='2774.', acceleration='15.5', model='70', origin='US')
# Data(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='85.00', weight='2587.', acceleration='16.0', model='70', origin='US')
# Data(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='70', origin='Japan')
# Data(car='Volkswagen 1131 Deluxe Sedan', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1835.', acceleration='20.5', model='70', origin='Europe')
# Data(car='Peugeot 504', mpg='25.0', cylinders='4', displacement='110.0', horsepower='87.00', weight='2672.', acceleration='17.5', model='70', origin='Europe')
# Data(car='Audi 100 LS', mpg='24.0', cylinders='4', displacement='107.0', horsepower='90.00', weight='2430.', acceleration='14.5', model='70', origin='Europe')
# Data(car='Saab 99e', mpg='25.0', cylinders='4', displacement='104.0', horsepower='95.00', weight='2375.', acceleration='17.5', model='70', origin='Europe')
# Data(car='BMW 2002', mpg='26.0', cylinders='4', displacement='121.0', horsepower='113.0', weight='2234.', acceleration='12.5', model='70', origin='Europe')
# Data(car='AMC Gremlin', mpg='21.0', cylinders='6', displacement='199.0', horsepower='90.00', weight='2648.', acceleration='15.0', model='70', origin='US')
# Data(car='Ford F250', mpg='10.0', cylinders='8', displacement='360.0', horsepower='215.0', weight='4615.', acceleration='14.0', model='70', origin='US')
# Data(car='Chevy C20', mpg='10.0', cylinders='8', displacement='307.0', horsepower='200.0', weight='4376.', acceleration='15.0', model='70', origin='US')
# Data(car='Dodge D200', mpg='11.0', cylinders='8', displacement='318.0', horsepower='210.0', weight='4382.', acceleration='13.5', model='70', origin='US')
# Data(car='Hi 1200D', mpg='9.0', cylinders='8', displacement='304.0', horsepower='193.0', weight='4732.', acceleration='18.5', model='70', origin='US')
# Data(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='71', origin='Japan')
# Data(car='Chevrolet Vega 2300', mpg='28.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2264.', acceleration='15.5', model='71', origin='US')
# Data(car='Toyota Corolla', mpg='25.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2228.', acceleration='14.0', model='71', origin='Japan')
# Data(car='Ford Pinto', mpg='25.0', cylinders='4', displacement='98.00', horsepower='0', weight='2046.', acceleration='19.0', model='71', origin='US')
# Data(car='Volkswagen Super Beetle 117', mpg='0', cylinders='4', displacement='97.00', horsepower='48.00', weight='1978.', acceleration='20.0', model='71', origin='Europe')
# Data(car='AMC Gremlin', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2634.', acceleration='13.0', model='71', origin='US')
# Data(car='Plymouth Satellite Custom', mpg='16.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3439.', acceleration='15.5', model='71', origin='US')
# Data(car='Chevrolet Chevelle Malibu', mpg='17.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3329.', acceleration='15.5', model='71', origin='US')
# Data(car='Ford Torino 500', mpg='19.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3302.', acceleration='15.5', model='71', origin='US')
# Data(car='AMC Matador', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='3288.', acceleration='15.5', model='71', origin='US')
# Data(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4209.', acceleration='12.0', model='71', origin='US')
# Data(car='Pontiac Catalina Brougham', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4464.', acceleration='11.5', model='71', origin='US')
# Data(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4154.', acceleration='13.5', model='71', origin='US')
# Data(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4096.', acceleration='13.0', model='71', origin='US')
# Data(car='Dodge Monaco (sw)', mpg='12.0', cylinders='8', displacement='383.0', horsepower='180.0', weight='4955.', acceleration='11.5', model='71', origin='US')
# Data(car='Ford Country Squire (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4746.', acceleration='12.0', model='71', origin='US')
# Data(car='Pontiac Safari (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='5140.', acceleration='12.0', model='71', origin='US')
# Data(car='AMC Hornet Sportabout (sw)', mpg='18.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='2962.', acceleration='13.5', model='71', origin='US')
# Data(car='Chevrolet Vega (sw)', mpg='22.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2408.', acceleration='19.0', model='71', origin='US')
# Data(car='Pontiac Firebird', mpg='19.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3282.', acceleration='15.0', model='71', origin='US')
# Data(car='Ford Mustang', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3139.', acceleration='14.5', model='71', origin='US')
# Data(car='Mercury Capri 2000', mpg='23.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2220.', acceleration='14.0', model='71', origin='US')
# Data(car='Opel 1900', mpg='28.0', cylinders='4', displacement='116.0', horsepower='90.00', weight='2123.', acceleration='14.0', model='71', origin='Europe')
# Data(car='Peugeot 304', mpg='30.0', cylinders='4', displacement='79.00', horsepower='70.00', weight='2074.', acceleration='19.5', model='71', origin='Europe')
# Data(car='Fiat 124B', mpg='30.0', cylinders='4', displacement='88.00', horsepower='76.00', weight='2065.', acceleration='14.5', model='71', origin='Europe')
# Data(car='Toyota Corolla 1200', mpg='31.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1773.', acceleration='19.0', model='71', origin='Japan')
# Data(car='Datsun 1200', mpg='35.0', cylinders='4', displacement='72.00', horsepower='69.00', weight='1613.', acceleration='18.0', model='71', origin='Japan')
# Data(car='Volkswagen Model 111', mpg='27.0', cylinders='4', displacement='97.00', horsepower='60.00', weight='1834.', acceleration='19.0', model='71', origin='Europe')
# Data(car='Plymouth Cricket', mpg='26.0', cylinders='4', displacement='91.00', horsepower='70.00', weight='1955.', acceleration='20.5', model='71', origin='US')
# Data(car='Toyota Corolla Hardtop', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2278.', acceleration='15.5', model='72', origin='Japan')
# Data(car='Dodge Colt Hardtop', mpg='25.0', cylinders='4', displacement='97.50', horsepower='80.00', weight='2126.', acceleration='17.0', model='72', origin='US')
# Data(car='Volkswagen Type 3', mpg='23.0', cylinders='4', displacement='97.00', horsepower='54.00', weight='2254.', acceleration='23.5', model='72', origin='Europe')
# Data(car='Chevrolet Vega', mpg='20.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2408.', acceleration='19.5', model='72', origin='US')
# Data(car='Ford Pinto Runabout', mpg='21.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2226.', acceleration='16.5', model='72', origin='US')
# Data(car='Chevrolet Impala', mpg='13.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4274.', acceleration='12.0', model='72', origin='US')
# Data(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4385.', acceleration='12.0', model='72', origin='US')
# Data(car='Plymouth Fury III', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4135.', acceleration='13.5', model='72', origin='US')
# Data(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4129.', acceleration='13.0', model='72', origin='US')
# Data(car='AMC Ambassador SST', mpg='17.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='72', origin='US')
# Data(car='Mercury Marquis', mpg='11.0', cylinders='8', displacement='429.0', horsepower='208.0', weight='4633.', acceleration='11.0', model='72', origin='US')
# Data(car='Buick LeSabre Custom', mpg='13.0', cylinders='8', displacement='350.0', horsepower='155.0', weight='4502.', acceleration='13.5', model='72', origin='US')
# Data(car='Oldsmobile Delta 88 Royale', mpg='12.0', cylinders='8', displacement='350.0', horsepower='160.0', weight='4456.', acceleration='13.5', model='72', origin='US')
# Data(car='Chrysler Newport Royal', mpg='13.0', cylinders='8', displacement='400.0', horsepower='190.0', weight='4422.', acceleration='12.5', model='72', origin='US')
# Data(car='Mazda RX2 Coupe', mpg='19.0', cylinders='3', displacement='70.00', horsepower='97.00', weight='2330.', acceleration='13.5', model='72', origin='Japan')
# Data(car='AMC Matador (sw)', mpg='15.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3892.', acceleration='12.5', model='72', origin='US')
# Data(car='Chevrolet Chevelle Concours (sw)', mpg='13.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='4098.', acceleration='14.0', model='72', origin='US')
# Data(car='Ford Gran Torino (sw)', mpg='13.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4294.', acceleration='16.0', model='72', origin='US')
# Data(car='Plymouth Satellite Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4077.', acceleration='14.0', model='72', origin='US')
# Data(car='Volvo 145e (sw)', mpg='18.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2933.', acceleration='14.5', model='72', origin='Europe')
# Data(car='Volkswagen 411 (sw)', mpg='22.0', cylinders='4', displacement='121.0', horsepower='76.00', weight='2511.', acceleration='18.0', model='72', origin='Europe')
# Data(car='Peugeot 504 (sw)', mpg='21.0', cylinders='4', displacement='120.0', horsepower='87.00', weight='2979.', acceleration='19.5', model='72', origin='Europe')
# Data(car='Renault 12 (sw)', mpg='26.0', cylinders='4', displacement='96.00', horsepower='69.00', weight='2189.', acceleration='18.0', model='72', origin='Europe')
# Data(car='Ford Pinto (sw)', mpg='22.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2395.', acceleration='16.0', model='72', origin='US')
# Data(car='Datsun 510 (sw)', mpg='28.0', cylinders='4', displacement='97.00', horsepower='92.00', weight='2288.', acceleration='17.0', model='72', origin='Japan')
# Data(car='Toyota Corolla Mark II (sw)', mpg='23.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2506.', acceleration='14.5', model='72', origin='Japan')
# Data(car='Dodge Colt (sw)', mpg='28.0', cylinders='4', displacement='98.00', horsepower='80.00', weight='2164.', acceleration='15.0', model='72', origin='US')
# Data(car='Toyota Corolla 1600 (sw)', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2100.', acceleration='16.5', model='72', origin='Japan')
# Data(car='Buick Century 350', mpg='13.0', cylinders='8', displacement='350.0', horsepower='175.0', weight='4100.', acceleration='13.0', model='73', origin='US')
# Data(car='AMC Matador', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='73', origin='US')
# Data(car='Chevrolet Malibu', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='3988.', acceleration='13.0', model='73', origin='US')
# Data(car='Ford Gran Torino', mpg='14.0', cylinders='8', displacement='302.0', horsepower='137.0', weight='4042.', acceleration='14.5', model='73', origin='US')
# Data(car='Dodge Coronet Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3777.', acceleration='12.5', model='73', origin='US')
# Data(car='Mercury Marquis Brougham', mpg='12.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4952.', acceleration='11.5', model='73', origin='US')
# Data(car='Chevrolet Caprice Classic', mpg='13.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4464.', acceleration='12.0', model='73', origin='US')
# Data(car='Ford LTD', mpg='13.0', cylinders='8', displacement='351.0', horsepower='158.0', weight='4363.', acceleration='13.0', model='73', origin='US')
# Data(car='Plymouth Fury Gran Sedan', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4237.', acceleration='14.5', model='73', origin='US')
# Data(car='Chrysler New Yorker Brougham', mpg='13.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4735.', acceleration='11.0', model='73', origin='US')
# Data(car='Buick Electra 225 Custom', mpg='12.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4951.', acceleration='11.0', model='73', origin='US')
# Data(car='AMC Ambassador Brougham', mpg='13.0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3821.', acceleration='11.0', model='73', origin='US')
# Data(car='Plymouth Valiant', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3121.', acceleration='16.5', model='73', origin='US')
# Data(car='Chevrolet Nova Custom', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3278.', acceleration='18.0', model='73', origin='US')
# Data(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2945.', acceleration='16.0', model='73', origin='US')
# Data(car='Ford Maverick', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3021.', acceleration='16.5', model='73', origin='US')
# Data(car='Plymouth Duster', mpg='23.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2904.', acceleration='16.0', model='73', origin='US')
# Data(car='Volkswagen Super Beetle', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1950.', acceleration='21.0', model='73', origin='Europe')
# Data(car='Chevrolet Impala', mpg='11.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4997.', acceleration='14.0', model='73', origin='US')
# Data(car='Ford Country', mpg='12.0', cylinders='8', displacement='400.0', horsepower='167.0', weight='4906.', acceleration='12.5', model='73', origin='US')
# Data(car='Plymouth Custom Suburb', mpg='13.0', cylinders='8', displacement='360.0', horsepower='170.0', weight='4654.', acceleration='13.0', model='73', origin='US')
# Data(car='Oldsmobile Vista Cruiser', mpg='12.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='4499.', acceleration='12.5', model='73', origin='US')
# Data(car='AMC Gremlin', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2789.', acceleration='15.0', model='73', origin='US')
# Data(car='Toyota Camry', mpg='20.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2279.', acceleration='19.0', model='73', origin='Japan')
# Data(car='Chevrolet Vega', mpg='21.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2401.', acceleration='19.5', model='73', origin='US')
# Data(car='Datsun 610', mpg='22.0', cylinders='4', displacement='108.0', horsepower='94.00', weight='2379.', acceleration='16.5', model='73', origin='Japan')
# Data(car='Mazda RX3', mpg='18.0', cylinders='3', displacement='70.00', horsepower='90.00', weight='2124.', acceleration='13.5', model='73', origin='Japan')
# Data(car='Ford Pinto', mpg='19.0', cylinders='4', displacement='122.0', horsepower='85.00', weight='2310.', acceleration='18.5', model='73', origin='US')
# Data(car='Mercury Capri v6', mpg='21.0', cylinders='6', displacement='155.0', horsepower='107.0', weight='2472.', acceleration='14.0', model='73', origin='US')
# Data(car='Fiat 124 Sport Coupe', mpg='26.0', cylinders='4', displacement='98.00', horsepower='90.00', weight='2265.', acceleration='15.5', model='73', origin='Europe')
# Data(car='Chevrolet Monte Carlo S', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4082.', acceleration='13.0', model='73', origin='US')
# Data(car='Pontiac Grand Prix', mpg='16.0', cylinders='8', displacement='400.0', horsepower='230.0', weight='4278.', acceleration='9.50', model='73', origin='US')
# Data(car='Fiat 128', mpg='29.0', cylinders='4', displacement='68.00', horsepower='49.00', weight='1867.', acceleration='19.5', model='73', origin='Europe')
# Data(car='Opel Manta', mpg='24.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2158.', acceleration='15.5', model='73', origin='Europe')
# Data(car='Audi 100LS', mpg='20.0', cylinders='4', displacement='114.0', horsepower='91.00', weight='2582.', acceleration='14.0', model='73', origin='Europe')
# Data(car='Volvo 144ea', mpg='19.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2868.', acceleration='15.5', model='73', origin='Europe')
# Data(car='Dodge Dart Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3399.', acceleration='11.0', model='73', origin='US')
# Data(car='Saab 99le', mpg='24.0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2660.', acceleration='14.0', model='73', origin='Europe')
# Data(car='Toyota Mark II', mpg='20.0', cylinders='6', displacement='156.0', horsepower='122.0', weight='2807.', acceleration='13.5', model='73', origin='Japan')
# Data(car='Oldsmobile Omega', mpg='11.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='3664.', acceleration='11.0', model='73', origin='US')
# Data(car='Plymouth Duster', mpg='20.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='3102.', acceleration='16.5', model='74', origin='US')
# Data(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='0', weight='2875.', acceleration='17.0', model='74', origin='US')
# Data(car='AMC Hornet', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2901.', acceleration='16.0', model='74', origin='US')
# Data(car='Chevrolet Nova', mpg='15.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3336.', acceleration='17.0', model='74', origin='US')
# Data(car='Datsun B210', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1950.', acceleration='19.0', model='74', origin='Japan')
# Data(car='Ford Pinto', mpg='26.0', cylinders='4', displacement='122.0', horsepower='80.00', weight='2451.', acceleration='16.5', model='74', origin='US')
# Data(car='Toyota Corolla 1200', mpg='32.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1836.', acceleration='21.0', model='74', origin='Japan')
# Data(car='Chevrolet Vega', mpg='25.0', cylinders='4', displacement='140.0', horsepower='75.00', weight='2542.', acceleration='17.0', model='74', origin='US')
# Data(car='Chevrolet Chevelle Malibu Classic', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3781.', acceleration='17.0', model='74', origin='US')
# Data(car='AMC Matador', mpg='16.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3632.', acceleration='18.0', model='74', origin='US')
# Data(car='Plymouth Satellite Sebring', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3613.', acceleration='16.5', model='74', origin='US')
# Data(car='Ford Gran Torino', mpg='16.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4141.', acceleration='14.0', model='74', origin='US')
# Data(car='Buick Century Luxus (sw)', mpg='13.0', cylinders='8', displacement='350.0', horsepower='150.0', weight='4699.', acceleration='14.5', model='74', origin='US')
# Data(car='Dodge Coronet Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4457.', acceleration='13.5', model='74', origin='US')
# Data(car='Ford Gran Torino (sw)', mpg='14.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4638.', acceleration='16.0', model='74', origin='US')
# Data(car='AMC Matador (sw)', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='4257.', acceleration='15.5', model='74', origin='US')
# Data(car='Audi Fox', mpg='29.0', cylinders='4', displacement='98.00', horsepower='83.00', weight='2219.', acceleration='16.5', model='74', origin='Europe')
# Data(car='Volkswagen Dasher', mpg='26.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1963.', acceleration='15.5', model='74', origin='Europe')
# Data(car='Opel Manta', mpg='26.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='2300.', acceleration='14.5', model='74', origin='Europe')
# Data(car='Toyota Corolla', mpg='31.0', cylinders='4', displacement='76.00', horsepower='52.00', weight='1649.', acceleration='16.5', model='74', origin='Japan')
# Data(car='Datsun 710', mpg='32.0', cylinders='4', displacement='83.00', horsepower='61.00', weight='2003.', acceleration='19.0', model='74', origin='Japan')
# Data(car='Dodge Colt', mpg='28.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2125.', acceleration='14.5', model='74', origin='US')
# Data(car='Fiat 128', mpg='24.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2108.', acceleration='15.5', model='74', origin='Europe')
# Data(car='Fiat 124 TC', mpg='26.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2246.', acceleration='14.0', model='74', origin='Europe')
# Data(car='Honda Civic', mpg='24.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2489.', acceleration='15.0', model='74', origin='Japan')
# Data(car='Subaru', mpg='26.0', cylinders='4', displacement='108.0', horsepower='93.00', weight='2391.', acceleration='15.5', model='74', origin='Japan')
# Data(car='Fiat x1.9', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='2000.', acceleration='16.0', model='74', origin='Europe')
# Data(car='Plymouth Valiant Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3264.', acceleration='16.0', model='75', origin='US')
# Data(car='Chevrolet Nova', mpg='18.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3459.', acceleration='16.0', model='75', origin='US')
# Data(car='Mercury Monarch', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3432.', acceleration='21.0', model='75', origin='US')
# Data(car='Ford Maverick', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3158.', acceleration='19.5', model='75', origin='US')
# Data(car='Pontiac Catalina', mpg='16.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4668.', acceleration='11.5', model='75', origin='US')
# Data(car='Chevrolet Bel Air', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4440.', acceleration='14.0', model='75', origin='US')
# Data(car='Plymouth Grand Fury', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4498.', acceleration='14.5', model='75', origin='US')
# Data(car='Ford LTD', mpg='14.0', cylinders='8', displacement='351.0', horsepower='148.0', weight='4657.', acceleration='13.5', model='75', origin='US')
# Data(car='Buick Century', mpg='17.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3907.', acceleration='21.0', model='75', origin='US')
# Data(car='Chevrolete Chevelle Malibu', mpg='16.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3897.', acceleration='18.5', model='75', origin='US')
# Data(car='AMC Matador', mpg='15.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3730.', acceleration='19.0', model='75', origin='US')
# Data(car='Plymouth Fury', mpg='18.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3785.', acceleration='19.0', model='75', origin='US')
# Data(car='Buick Skyhawk', mpg='21.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3039.', acceleration='15.0', model='75', origin='US')
# Data(car='Chevrolet Monza 2+2', mpg='20.0', cylinders='8', displacement='262.0', horsepower='110.0', weight='3221.', acceleration='13.5', model='75', origin='US')
# Data(car='Ford Mustang II', mpg='13.0', cylinders='8', displacement='302.0', horsepower='129.0', weight='3169.', acceleration='12.0', model='75', origin='US')
# Data(car='Toyota Corolla', mpg='29.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2171.', acceleration='16.0', model='75', origin='Japan')
# Data(car='Ford Pinto', mpg='23.0', cylinders='4', displacement='140.0', horsepower='83.00', weight='2639.', acceleration='17.0', model='75', origin='US')
# Data(car='AMC Gremlin', mpg='20.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2914.', acceleration='16.0', model='75', origin='US')
# Data(car='Pontiac Astro', mpg='23.0', cylinders='4', displacement='140.0', horsepower='78.00', weight='2592.', acceleration='18.5', model='75', origin='US')
# Data(car='Toyota Corolla', mpg='24.0', cylinders='4', displacement='134.0', horsepower='96.00', weight='2702.', acceleration='13.5', model='75', origin='Japan')
# Data(car='Volkswagen Dasher', mpg='25.0', cylinders='4', displacement='90.00', horsepower='71.00', weight='2223.', acceleration='16.5', model='75', origin='Europe')
# Data(car='Datsun 710', mpg='24.0', cylinders='4', displacement='119.0', horsepower='97.00', weight='2545.', acceleration='17.0', model='75', origin='Japan')
# Data(car='Ford Pinto', mpg='18.0', cylinders='6', displacement='171.0', horsepower='97.00', weight='2984.', acceleration='14.5', model='75', origin='US')
# Data(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.0', model='75', origin='Europe')
# Data(car='AMC Pacer', mpg='19.0', cylinders='6', displacement='232.0', horsepower='90.00', weight='3211.', acceleration='17.0', model='75', origin='US')
# Data(car='Audi 100LS', mpg='23.0', cylinders='4', displacement='115.0', horsepower='95.00', weight='2694.', acceleration='15.0', model='75', origin='Europe')
# Data(car='Peugeot 504', mpg='23.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2957.', acceleration='17.0', model='75', origin='Europe')
# Data(car='Volvo 244DL', mpg='22.0', cylinders='4', displacement='121.0', horsepower='98.00', weight='2945.', acceleration='14.5', model='75', origin='Europe')
# Data(car='Saab 99LE', mpg='25.0', cylinders='4', displacement='121.0', horsepower='115.0', weight='2671.', acceleration='13.5', model='75', origin='Europe')
# Data(car='Honda Civic CVCC', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.5', model='75', origin='Japan')
# Data(car='Fiat 131', mpg='28.0', cylinders='4', displacement='107.0', horsepower='86.00', weight='2464.', acceleration='15.5', model='76', origin='Europe')
# Data(car='Opel 1900', mpg='25.0', cylinders='4', displacement='116.0', horsepower='81.00', weight='2220.', acceleration='16.9', model='76', origin='Europe')
# Data(car='Capri ii', mpg='25.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2572.', acceleration='14.9', model='76', origin='US')
# Data(car='Dodge Colt', mpg='26.0', cylinders='4', displacement='98.00', horsepower='79.00', weight='2255.', acceleration='17.7', model='76', origin='US')
# Data(car='Renault 12tl', mpg='27.0', cylinders='4', displacement='101.0', horsepower='83.00', weight='2202.', acceleration='15.3', model='76', origin='Europe')
# Data(car='Chevrolet Chevelle Malibu Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='140.0', weight='4215.', acceleration='13.0', model='76', origin='US')
# Data(car='Dodge Coronet Brougham', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4190.', acceleration='13.0', model='76', origin='US')
# Data(car='AMC Matador', mpg='15.5', cylinders='8', displacement='304.0', horsepower='120.0', weight='3962.', acceleration='13.9', model='76', origin='US')
# Data(car='Ford Gran Torino', mpg='14.5', cylinders='8', displacement='351.0', horsepower='152.0', weight='4215.', acceleration='12.8', model='76', origin='US')
# Data(car='Plymouth Valiant', mpg='22.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3233.', acceleration='15.4', model='76', origin='US')
# Data(car='Chevrolet Nova', mpg='22.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3353.', acceleration='14.5', model='76', origin='US')
# Data(car='Ford Maverick', mpg='24.0', cylinders='6', displacement='200.0', horsepower='81.00', weight='3012.', acceleration='17.6', model='76', origin='US')
# Data(car='AMC Hornet', mpg='22.5', cylinders='6', displacement='232.0', horsepower='90.00', weight='3085.', acceleration='17.6', model='76', origin='US')
# Data(car='Chevrolet Chevette', mpg='29.0', cylinders='4', displacement='85.00', horsepower='52.00', weight='2035.', acceleration='22.2', model='76', origin='US')
# Data(car='Chevrolet Woody', mpg='24.5', cylinders='4', displacement='98.00', horsepower='60.00', weight='2164.', acceleration='22.1', model='76', origin='US')
# Data(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.2', model='76', origin='Europe')
# Data(car='Honda Civic', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.4', model='76', origin='Japan')
# Data(car='Dodge Aspen SE', mpg='20.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3651.', acceleration='17.7', model='76', origin='US')
# Data(car='Ford Grenada ghia', mpg='18.0', cylinders='6', displacement='250.0', horsepower='78.00', weight='3574.', acceleration='21.0', model='76', origin='US')
# Data(car='Pontiac Ventura SJ', mpg='18.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3645.', acceleration='16.2', model='76', origin='US')
# Data(car='AMC Pacer d/l', mpg='17.5', cylinders='6', displacement='258.0', horsepower='95.00', weight='3193.', acceleration='17.8', model='76', origin='US')
# Data(car='Volkswagen Rabbit', mpg='29.5', cylinders='4', displacement='97.00', horsepower='71.00', weight='1825.', acceleration='12.2', model='76', origin='Europe')
# Data(car='Datsun B-210', mpg='32.0', cylinders='4', displacement='85.00', horsepower='70.00', weight='1990.', acceleration='17.0', model='76', origin='Japan')
# Data(car='Toyota Corolla', mpg='28.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2155.', acceleration='16.4', model='76', origin='Japan')
# Data(car='Ford Pinto', mpg='26.5', cylinders='4', displacement='140.0', horsepower='72.00', weight='2565.', acceleration='13.6', model='76', origin='US')
# Data(car='Volvo 245', mpg='20.0', cylinders='4', displacement='130.0', horsepower='102.0', weight='3150.', acceleration='15.7', model='76', origin='Europe')
# Data(car='Plymouth Volare Premier v8', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3940.', acceleration='13.2', model='76', origin='US')
# Data(car='Peugeot 504', mpg='19.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='3270.', acceleration='21.9', model='76', origin='Europe')
# Data(car='Toyota Mark II', mpg='19.0', cylinders='6', displacement='156.0', horsepower='108.0', weight='2930.', acceleration='15.5', model='76', origin='Japan')
# Data(car='Mercedes-Benz 280s', mpg='16.5', cylinders='6', displacement='168.0', horsepower='120.0', weight='3820.', acceleration='16.7', model='76', origin='Europe')
# Data(car='Cadillac Seville', mpg='16.5', cylinders='8', displacement='350.0', horsepower='180.0', weight='4380.', acceleration='12.1', model='76', origin='US')
# Data(car='Chevrolet C10', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4055.', acceleration='12.0', model='76', origin='US')
# Data(car='Ford F108', mpg='13.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='3870.', acceleration='15.0', model='76', origin='US')
# Data(car='Dodge D100', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3755.', acceleration='14.0', model='76', origin='US')
# Data(car='Honda Accord CVCC', mpg='31.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2045.', acceleration='18.5', model='77', origin='Japan')
# Data(car='Buick Opel Isuzu Deluxe', mpg='30.0', cylinders='4', displacement='111.0', horsepower='80.00', weight='2155.', acceleration='14.8', model='77', origin='US')
# Data(car='Renault 5 GTL', mpg='36.0', cylinders='4', displacement='79.00', horsepower='58.00', weight='1825.', acceleration='18.6', model='77', origin='Europe')
# Data(car='Plymouth Arrow GS', mpg='25.5', cylinders='4', displacement='122.0', horsepower='96.00', weight='2300.', acceleration='15.5', model='77', origin='US')
# Data(car='Datsun F-10 Hatchback', mpg='33.5', cylinders='4', displacement='85.00', horsepower='70.00', weight='1945.', acceleration='16.8', model='77', origin='Japan')
# Data(car='Chevrolet Caprice Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='145.0', weight='3880.', acceleration='12.5', model='77', origin='US')
# Data(car='Oldsmobile Cutlass Supreme', mpg='17.0', cylinders='8', displacement='260.0', horsepower='110.0', weight='4060.', acceleration='19.0', model='77', origin='US')
# Data(car='Dodge Monaco Brougham', mpg='15.5', cylinders='8', displacement='318.0', horsepower='145.0', weight='4140.', acceleration='13.7', model='77', origin='US')
# Data(car='Mercury Cougar Brougham', mpg='15.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='4295.', acceleration='14.9', model='77', origin='US')
# Data(car='Chevrolet Concours', mpg='17.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3520.', acceleration='16.4', model='77', origin='US')
# Data(car='Buick Skylark', mpg='20.5', cylinders='6', displacement='231.0', horsepower='105.0', weight='3425.', acceleration='16.9', model='77', origin='US')
# Data(car='Plymouth Volare Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3630.', acceleration='17.7', model='77', origin='US')
# Data(car='Ford Grenada', mpg='18.5', cylinders='6', displacement='250.0', horsepower='98.00', weight='3525.', acceleration='19.0', model='77', origin='US')
# Data(car='Pontiac Grand Prix LJ', mpg='16.0', cylinders='8', displacement='400.0', horsepower='180.0', weight='4220.', acceleration='11.1', model='77', origin='US')
# Data(car='Chevrolet Monte Carlo Landau', mpg='15.5', cylinders='8', displacement='350.0', horsepower='170.0', weight='4165.', acceleration='11.4', model='77', origin='US')
# Data(car='Chrysler Cordoba', mpg='15.5', cylinders='8', displacement='400.0', horsepower='190.0', weight='4325.', acceleration='12.2', model='77', origin='US')
# Data(car='Ford Thunderbird', mpg='16.0', cylinders='8', displacement='351.0', horsepower='149.0', weight='4335.', acceleration='14.5', model='77', origin='US')
# Data(car='Volkswagen Rabbit Custom', mpg='29.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='1940.', acceleration='14.5', model='77', origin='Europe')
# Data(car='Pontiac Sunbird Coupe', mpg='24.5', cylinders='4', displacement='151.0', horsepower='88.00', weight='2740.', acceleration='16.0', model='77', origin='US')
# Data(car='Toyota Corolla Liftback', mpg='26.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2265.', acceleration='18.2', model='77', origin='Japan')
# Data(car='Ford Mustang II 2+2', mpg='25.5', cylinders='4', displacement='140.0', horsepower='89.00', weight='2755.', acceleration='15.8', model='77', origin='US')
# Data(car='Chevrolet Chevette', mpg='30.5', cylinders='4', displacement='98.00', horsepower='63.00', weight='2051.', acceleration='17.0', model='77', origin='US')
# Data(car='Dodge Colt m/m', mpg='33.5', cylinders='4', displacement='98.00', horsepower='83.00', weight='2075.', acceleration='15.9', model='77', origin='US')
# Data(car='Subaru DL', mpg='30.0', cylinders='4', displacement='97.00', horsepower='67.00', weight='1985.', acceleration='16.4', model='77', origin='Japan')
# Data(car='Volkswagen Dasher', mpg='30.5', cylinders='4', displacement='97.00', horsepower='78.00', weight='2190.', acceleration='14.1', model='77', origin='Europe')
# Data(car='Datsun 810', mpg='22.0', cylinders='6', displacement='146.0', horsepower='97.00', weight='2815.', acceleration='14.5', model='77', origin='Japan')
# Data(car='BMW 320i', mpg='21.5', cylinders='4', displacement='121.0', horsepower='110.0', weight='2600.', acceleration='12.8', model='77', origin='Europe')
# Data(car='Mazda RX-4', mpg='21.5', cylinders='3', displacement='80.00', horsepower='110.0', weight='2720.', acceleration='13.5', model='77', origin='Japan')
# Data(car='Volkswagen Rabbit Custom Diesel', mpg='43.1', cylinders='4', displacement='90.00', horsepower='48.00', weight='1985.', acceleration='21.5', model='78', origin='Europe')
# Data(car='Ford Fiesta', mpg='36.1', cylinders='4', displacement='98.00', horsepower='66.00', weight='1800.', acceleration='14.4', model='78', origin='US')
# Data(car='Mazda GLC Deluxe', mpg='32.8', cylinders='4', displacement='78.00', horsepower='52.00', weight='1985.', acceleration='19.4', model='78', origin='Japan')
# Data(car='Datsun B210 GX', mpg='39.4', cylinders='4', displacement='85.00', horsepower='70.00', weight='2070.', acceleration='18.6', model='78', origin='Japan')
# Data(car='Honda Civic CVCC', mpg='36.1', cylinders='4', displacement='91.00', horsepower='60.00', weight='1800.', acceleration='16.4', model='78', origin='Japan')
# Data(car='Oldsmobile Cutlass Salon Brougham', mpg='19.9', cylinders='8', displacement='260.0', horsepower='110.0', weight='3365.', acceleration='15.5', model='78', origin='US')
# Data(car='Dodge Diplomat', mpg='19.4', cylinders='8', displacement='318.0', horsepower='140.0', weight='3735.', acceleration='13.2', model='78', origin='US')
# Data(car='Mercury Monarch ghia', mpg='20.2', cylinders='8', displacement='302.0', horsepower='139.0', weight='3570.', acceleration='12.8', model='78', origin='US')
# Data(car='Pontiac Phoenix LJ', mpg='19.2', cylinders='6', displacement='231.0', horsepower='105.0', weight='3535.', acceleration='19.2', model='78', origin='US')
# Data(car='Chevrolet Malibu', mpg='20.5', cylinders='6', displacement='200.0', horsepower='95.00', weight='3155.', acceleration='18.2', model='78', origin='US')
# Data(car='Ford Fairmont (auto)', mpg='20.2', cylinders='6', displacement='200.0', horsepower='85.00', weight='2965.', acceleration='15.8', model='78', origin='US')
# Data(car='Ford Fairmont (man)', mpg='25.1', cylinders='4', displacement='140.0', horsepower='88.00', weight='2720.', acceleration='15.4', model='78', origin='US')
# Data(car='Plymouth Volare', mpg='20.5', cylinders='6', displacement='225.0', horsepower='100.0', weight='3430.', acceleration='17.2', model='78', origin='US')
# Data(car='AMC Concord', mpg='19.4', cylinders='6', displacement='232.0', horsepower='90.00', weight='3210.', acceleration='17.2', model='78', origin='US')
# Data(car='Buick Century Special', mpg='20.6', cylinders='6', displacement='231.0', horsepower='105.0', weight='3380.', acceleration='15.8', model='78', origin='US')
# Data(car='Mercury Zephyr', mpg='20.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='3070.', acceleration='16.7', model='78', origin='US')
# Data(car='Dodge Aspen', mpg='18.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3620.', acceleration='18.7', model='78', origin='US')
# Data(car='AMC Concord d/l', mpg='18.1', cylinders='6', displacement='258.0', horsepower='120.0', weight='3410.', acceleration='15.1', model='78', origin='US')
# Data(car='Chevrolet Monte Carlo Landau', mpg='19.2', cylinders='8', displacement='305.0', horsepower='145.0', weight='3425.', acceleration='13.2', model='78', origin='US')
# Data(car='Buick Regal Sport Coupe (turbo)', mpg='17.7', cylinders='6', displacement='231.0', horsepower='165.0', weight='3445.', acceleration='13.4', model='78', origin='US')
# Data(car='Ford Futura', mpg='18.1', cylinders='8', displacement='302.0', horsepower='139.0', weight='3205.', acceleration='11.2', model='78', origin='US')
# Data(car='Dodge Magnum XE', mpg='17.5', cylinders='8', displacement='318.0', horsepower='140.0', weight='4080.', acceleration='13.7', model='78', origin='US')
# Data(car='Chevrolet Chevette', mpg='30.0', cylinders='4', displacement='98.00', horsepower='68.00', weight='2155.', acceleration='16.5', model='78', origin='US')
# Data(car='Toyota Corolla', mpg='27.5', cylinders='4', displacement='134.0', horsepower='95.00', weight='2560.', acceleration='14.2', model='78', origin='Japan')
# Data(car='Datsun 510', mpg='27.2', cylinders='4', displacement='119.0', horsepower='97.00', weight='2300.', acceleration='14.7', model='78', origin='Japan')
# Data(car='Dodge Omni', mpg='30.9', cylinders='4', displacement='105.0', horsepower='75.00', weight='2230.', acceleration='14.5', model='78', origin='US')
# Data(car='Toyota Celica GT Liftback', mpg='21.1', cylinders='4', displacement='134.0', horsepower='95.00', weight='2515.', acceleration='14.8', model='78', origin='Japan')
# Data(car='Plymouth Sapporo', mpg='23.2', cylinders='4', displacement='156.0', horsepower='105.0', weight='2745.', acceleration='16.7', model='78', origin='US')
# Data(car='Oldsmobile Starfire SX', mpg='23.8', cylinders='4', displacement='151.0', horsepower='85.00', weight='2855.', acceleration='17.6', model='78', origin='US')
# Data(car='Datsun 200-SX', mpg='23.9', cylinders='4', displacement='119.0', horsepower='97.00', weight='2405.', acceleration='14.9', model='78', origin='Japan')
# Data(car='Audi 5000', mpg='20.3', cylinders='5', displacement='131.0', horsepower='103.0', weight='2830.', acceleration='15.9', model='78', origin='Europe')
# Data(car='Volvo 264gl', mpg='17.0', cylinders='6', displacement='163.0', horsepower='125.0', weight='3140.', acceleration='13.6', model='78', origin='Europe')
# Data(car='Saab 99gle', mpg='21.6', cylinders='4', displacement='121.0', horsepower='115.0', weight='2795.', acceleration='15.7', model='78', origin='Europe')
# Data(car='Peugeot 604sl', mpg='16.2', cylinders='6', displacement='163.0', horsepower='133.0', weight='3410.', acceleration='15.8', model='78', origin='Europe')
# Data(car='Volkswagen Scirocco', mpg='31.5', cylinders='4', displacement='89.00', horsepower='71.00', weight='1990.', acceleration='14.9', model='78', origin='Europe')
# Data(car='Honda Accord LX', mpg='29.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2135.', acceleration='16.6', model='78', origin='Japan')
# Data(car='Pontiac Lemans V6', mpg='21.5', cylinders='6', displacement='231.0', horsepower='115.0', weight='3245.', acceleration='15.4', model='79', origin='US')
# Data(car='Mercury Zephyr 6', mpg='19.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='2990.', acceleration='18.2', model='79', origin='US')
# Data(car='Ford Fairmont 4', mpg='22.3', cylinders='4', displacement='140.0', horsepower='88.00', weight='2890.', acceleration='17.3', model='79', origin='US')
# Data(car='AMC Concord DL 6', mpg='20.2', cylinders='6', displacement='232.0', horsepower='90.00', weight='3265.', acceleration='18.2', model='79', origin='US')
# Data(car='Dodge Aspen 6', mpg='20.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3360.', acceleration='16.6', model='79', origin='US')
# Data(car='Chevrolet Caprice Classic', mpg='17.0', cylinders='8', displacement='305.0', horsepower='130.0', weight='3840.', acceleration='15.4', model='79', origin='US')
# Data(car='Ford LTD Landau', mpg='17.6', cylinders='8', displacement='302.0', horsepower='129.0', weight='3725.', acceleration='13.4', model='79', origin='US')
# Data(car='Mercury Grand Marquis', mpg='16.5', cylinders='8', displacement='351.0', horsepower='138.0', weight='3955.', acceleration='13.2', model='79', origin='US')
# Data(car='Dodge St. Regis', mpg='18.2', cylinders='8', displacement='318.0', horsepower='135.0', weight='3830.', acceleration='15.2', model='79', origin='US')
# Data(car='Buick Estate Wagon (sw)', mpg='16.9', cylinders='8', displacement='350.0', horsepower='155.0', weight='4360.', acceleration='14.9', model='79', origin='US')
# ...
# Data(car='Plymouth Horizon', mpg='34.2', cylinders='4', displacement='105.0', horsepower='70.00', weight='2200.', acceleration='13.2', model='79', origin='US')
# Data(car='Plymouth Horizon TC3', mpg='34.5', cylinders='4', displacement='105.0', horsepower='70.00', weight='2150.', acceleration='14.9', model='79', origin='US')
# Data(car='Datsun 210', mpg='31.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2020.', acceleration='19.2', model='79', origin='Japan')
# Data(car='Fiat Strada Custom', mpg='37.3', cylinders='4', displacement='91.00', horsepower='69.00', weight='2130.', acceleration='14.7', model='79', origin='Europe')
# Data(car='Buick Skylark Limited', mpg='28.4', cylinders='4', displacement='151.0', horsepower='90.00', weight='2670.', acceleration='16.0', model='79', origin='US')
# Data(car='Chevrolet Citation', mpg='28.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2595.', acceleration='11.3', model='79', origin='US')
# Data(car='Oldsmobile Omega Brougham', mpg='26.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2700.', acceleration='12.9', model='79', origin='US')
# Data(car='Pontiac Phoenix', mpg='33.5', cylinders='4', displacement='151.0', horsepower='90.00', weight='2556.', acceleration='13.2', model='79', origin='US')
# Data(car='Volkswagen Rabbit', mpg='41.5', cylinders='4', displacement='98.00', horsepower='76.00', weight='2144.', acceleration='14.7', model='80', origin='Europe')
# Data(car='Toyota Corolla Tercel', mpg='38.1', cylinders='4', displacement='89.00', horsepower='60.00', weight='1968.', acceleration='18.8', model='80', origin='Japan')
# Data(car='Chevrolet Chevette', mpg='32.1', cylinders='4', displacement='98.00', horsepower='70.00', weight='2120.', acceleration='15.5', model='80', origin='US')
# Data(car='Datsun 310', mpg='37.2', cylinders='4', displacement='86.00', horsepower='65.00', weight='2019.', acceleration='16.4', model='80', origin='Japan')
# Data(car='Chevrolet Citation', mpg='28.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2678.', acceleration='16.5', model='80', origin='US')
# Data(car='Ford Fairmont', mpg='26.4', cylinders='4', displacement='140.0', horsepower='88.00', weight='2870.', acceleration='18.1', model='80', origin='US')
# Data(car='AMC Concord', mpg='24.3', cylinders='4', displacement='151.0', horsepower='90.00', weight='3003.', acceleration='20.1', model='80', origin='US')
# Data(car='Dodge Aspen', mpg='19.1', cylinders='6', displacement='225.0', horsepower='90.00', weight='3381.', acceleration='18.7', model='80', origin='US')
# Data(car='Audi 4000', mpg='34.3', cylinders='4', displacement='97.00', horsepower='78.00', weight='2188.', acceleration='15.8', model='80', origin='Europe')
# Data(car='Toyota Corolla Liftback', mpg='29.8', cylinders='4', displacement='134.0', horsepower='90.00', weight='2711.', acceleration='15.5', model='80', origin='Japan')
# Data(car='Mazda 626', mpg='31.3', cylinders='4', displacement='120.0', horsepower='75.00', weight='2542.', acceleration='17.5', model='80', origin='Japan')
# Data(car='Datsun 510 Hatchback', mpg='37.0', cylinders='4', displacement='119.0', horsepower='92.00', weight='2434.', acceleration='15.0', model='80', origin='Japan')
# Data(car='Toyota Corolla', mpg='32.2', cylinders='4', displacement='108.0', horsepower='75.00', weight='2265.', acceleration='15.2', model='80', origin='Japan')
# Data(car='Mazda GLC', mpg='46.6', cylinders='4', displacement='86.00', horsepower='65.00', weight='2110.', acceleration='17.9', model='80', origin='Japan')
# Data(car='Dodge Colt', mpg='27.9', cylinders='4', displacement='156.0', horsepower='105.0', weight='2800.', acceleration='14.4', model='80', origin='US')
# Data(car='Datsun 210', mpg='40.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2110.', acceleration='19.2', model='80', origin='Japan')
# Data(car='Volkswagen Rabbit C (Diesel)', mpg='44.3', cylinders='4', displacement='90.00', horsepower='48.00', weight='2085.', acceleration='21.7', model='80', origin='Europe')
# Data(car='Volkswagen Dasher (diesel)', mpg='43.4', cylinders='4', displacement='90.00', horsepower='48.00', weight='2335.', acceleration='23.7', model='80', origin='Europe')
# Data(car='Audi 5000s (diesel)', mpg='36.4', cylinders='5', displacement='121.0', horsepower='67.00', weight='2950.', acceleration='19.9', model='80', origin='Europe')
# Data(car='Mercedes-Benz 240d', mpg='30.0', cylinders='4', displacement='146.0', horsepower='67.00', weight='3250.', acceleration='21.8', model='80', origin='Europe')
# Data(car='Honda Civic 1500 gl', mpg='44.6', cylinders='4', displacement='91.00', horsepower='67.00', weight='1850.', acceleration='13.8', model='80', origin='Japan')
# Data(car='Renault Lecar Deluxe', mpg='40.9', cylinders='4', displacement='85.00', horsepower='0', weight='1835.', acceleration='17.3', model='80', origin='Europe')
# Data(car='Subaru DL', mpg='33.8', cylinders='4', displacement='97.00', horsepower='67.00', weight='2145.', acceleration='18.0', model='80', origin='Japan')
# Data(car='Volkswagen Rabbit', mpg='29.8', cylinders='4', displacement='89.00', horsepower='62.00', weight='1845.', acceleration='15.3', model='80', origin='Europe')
# Data(car='Datsun 280-ZX', mpg='32.7', cylinders='6', displacement='168.0', horsepower='132.0', weight='2910.', acceleration='11.4', model='80', origin='Japan')
# Data(car='Mazda RX-7 GS', mpg='23.7', cylinders='3', displacement='70.00', horsepower='100.0', weight='2420.', acceleration='12.5', model='80', origin='Japan')
# Data(car='Triumph TR7 Coupe', mpg='35.0', cylinders='4', displacement='122.0', horsepower='88.00', weight='2500.', acceleration='15.1', model='80', origin='Europe')
# Data(car='Ford Mustang Cobra', mpg='23.6', cylinders='4', displacement='140.0', horsepower='0', weight='2905.', acceleration='14.3', model='80', origin='US')
# Data(car='Honda Accord', mpg='32.4', cylinders='4', displacement='107.0', horsepower='72.00', weight='2290.', acceleration='17.0', model='80', origin='Japan')
# Data(car='Plymouth Reliant', mpg='27.2', cylinders='4', displacement='135.0', horsepower='84.00', weight='2490.', acceleration='15.7', model='81', origin='US')
# Data(car='Buick Skylark', mpg='26.6', cylinders='4', displacement='151.0', horsepower='84.00', weight='2635.', acceleration='16.4', model='81', origin='US')
# Data(car='Dodge Aries Wagon (sw)', mpg='25.8', cylinders='4', displacement='156.0', horsepower='92.00', weight='2620.', acceleration='14.4', model='81', origin='US')
# Data(car='Chevrolet Citation', mpg='23.5', cylinders='6', displacement='173.0', horsepower='110.0', weight='2725.', acceleration='12.6', model='81', origin='US')
# Data(car='Plymouth Reliant', mpg='30.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2385.', acceleration='12.9', model='81', origin='US')
# Data(car='Toyota Starlet', mpg='39.1', cylinders='4', displacement='79.00', horsepower='58.00', weight='1755.', acceleration='16.9', model='81', origin='Japan')
# Data(car='Plymouth Champ', mpg='39.0', cylinders='4', displacement='86.00', horsepower='64.00', weight='1875.', acceleration='16.4', model='81', origin='US')
# Data(car='Honda Civic 1300', mpg='35.1', cylinders='4', displacement='81.00', horsepower='60.00', weight='1760.', acceleration='16.1', model='81', origin='Japan')
# Data(car='Subaru', mpg='32.3', cylinders='4', displacement='97.00', horsepower='67.00', weight='2065.', acceleration='17.8', model='81', origin='Japan')
# Data(car='Datsun 210 MPG', mpg='37.0', cylinders='4', displacement='85.00', horsepower='65.00', weight='1975.', acceleration='19.4', model='81', origin='Japan')
# Data(car='Toyota Tercel', mpg='37.7', cylinders='4', displacement='89.00', horsepower='62.00', weight='2050.', acceleration='17.3', model='81', origin='Japan')
# Data(car='Mazda GLC 4', mpg='34.1', cylinders='4', displacement='91.00', horsepower='68.00', weight='1985.', acceleration='16.0', model='81', origin='Japan')
# Data(car='Plymouth Horizon 4', mpg='34.7', cylinders='4', displacement='105.0', horsepower='63.00', weight='2215.', acceleration='14.9', model='81', origin='US')
# Data(car='Ford Escort 4W', mpg='34.4', cylinders='4', displacement='98.00', horsepower='65.00', weight='2045.', acceleration='16.2', model='81', origin='US')
# Data(car='Ford Escort 2H', mpg='29.9', cylinders='4', displacement='98.00', horsepower='65.00', weight='2380.', acceleration='20.7', model='81', origin='US')
# Data(car='Volkswagen Jetta', mpg='33.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='2190.', acceleration='14.2', model='81', origin='Europe')
# Data(car='Renault 18i', mpg='34.5', cylinders='4', displacement='100.0', horsepower='0', weight='2320.', acceleration='15.8', model='81', origin='Europe')
# Data(car='Honda Prelude', mpg='33.7', cylinders='4', displacement='107.0', horsepower='75.00', weight='2210.', acceleration='14.4', model='81', origin='Japan')
# Data(car='Toyota Corolla', mpg='32.4', cylinders='4', displacement='108.0', horsepower='75.00', weight='2350.', acceleration='16.8', model='81', origin='Japan')
# Data(car='Datsun 200SX', mpg='32.9', cylinders='4', displacement='119.0', horsepower='100.0', weight='2615.', acceleration='14.8', model='81', origin='Japan')
# Data(car='Mazda 626', mpg='31.6', cylinders='4', displacement='120.0', horsepower='74.00', weight='2635.', acceleration='18.3', model='81', origin='Japan')
# Data(car='Peugeot 505s Turbo Diesel', mpg='28.1', cylinders='4', displacement='141.0', horsepower='80.00', weight='3230.', acceleration='20.4', model='81', origin='Europe')
# Data(car='Saab 900s', mpg='0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2800.', acceleration='15.4', model='81', origin='Europe')
# Data(car='Volvo Diesel', mpg='30.7', cylinders='6', displacement='145.0', horsepower='76.00', weight='3160.', acceleration='19.6', model='81', origin='Europe')
# Data(car='Toyota Cressida', mpg='25.4', cylinders='6', displacement='168.0', horsepower='116.0', weight='2900.', acceleration='12.6', model='81', origin='Japan')
# Data(car='Datsun 810 Maxima', mpg='24.2', cylinders='6', displacement='146.0', horsepower='120.0', weight='2930.', acceleration='13.8', model='81', origin='Japan')
# Data(car='Buick Century', mpg='22.4', cylinders='6', displacement='231.0', horsepower='110.0', weight='3415.', acceleration='15.8', model='81', origin='US')
# Data(car='Oldsmobile Cutlass LS', mpg='26.6', cylinders='8', displacement='350.0', horsepower='105.0', weight='3725.', acceleration='19.0', model='81', origin='US')
# Data(car='Ford Grenada gl', mpg='20.2', cylinders='6', displacement='200.0', horsepower='88.00', weight='3060.', acceleration='17.1', model='81', origin='US')
# Data(car='Chrysler Lebaron Salon', mpg='17.6', cylinders='6', displacement='225.0', horsepower='85.00', weight='3465.', acceleration='16.6', model='81', origin='US')
# Data(car='Chevrolet Cavalier', mpg='28.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2605.', acceleration='19.6', model='82', origin='US')
# Data(car='Chevrolet Cavalier Wagon', mpg='27.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2640.', acceleration='18.6', model='82', origin='US')
# Data(car='Chevrolet Cavalier 2-door', mpg='34.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2395.', acceleration='18.0', model='82', origin='US')
# Data(car='Pontiac J2000 SE Hatchback', mpg='31.0', cylinders='4', displacement='112.0', horsepower='85.00', weight='2575.', acceleration='16.2', model='82', origin='US')
# Data(car='Dodge Aries SE', mpg='29.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2525.', acceleration='16.0', model='82', origin='US')
# Data(car='Pontiac Phoenix', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2735.', acceleration='18.0', model='82', origin='US')
# Data(car='Ford Fairmont Futura', mpg='24.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2865.', acceleration='16.4', model='82', origin='US')
# Data(car='AMC Concord DL', mpg='23.0', cylinders='4', displacement='151.0', horsepower='0', weight='3035.', acceleration='20.5', model='82', origin='US')
# Data(car='Volkswagen Rabbit l', mpg='36.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='1980.', acceleration='15.3', model='82', origin='Europe')
# Data(car='Mazda GLC Custom l', mpg='37.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='2025.', acceleration='18.2', model='82', origin='Japan')
# Data(car='Mazda GLC Custom', mpg='31.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='1970.', acceleration='17.6', model='82', origin='Japan')
# Data(car='Plymouth Horizon Miser', mpg='38.0', cylinders='4', displacement='105.0', horsepower='63.00', weight='2125.', acceleration='14.7', model='82', origin='US')
# Data(car='Mercury Lynx l', mpg='36.0', cylinders='4', displacement='98.00', horsepower='70.00', weight='2125.', acceleration='17.3', model='82', origin='US')
# Data(car='Nissan Stanza XE', mpg='36.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2160.', acceleration='14.5', model='82', origin='Japan')
# Data(car='Honda Accord', mpg='36.0', cylinders='4', displacement='107.0', horsepower='75.00', weight='2205.', acceleration='14.5', model='82', origin='Japan')
# Data(car='Toyota Corolla', mpg='34.0', cylinders='4', displacement='108.0', horsepower='70.00', weight='2245', acceleration='16.9', model='82', origin='Japan')
# Data(car='Honda Civic', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.0', model='82', origin='Japan')
# Data(car='Honda Civic (auto)', mpg='32.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.7', model='82', origin='Japan')
# Data(car='Datsun 310 GX', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1995.', acceleration='16.2', model='82', origin='Japan')
# Data(car='Buick Century Limited', mpg='25.0', cylinders='6', displacement='181.0', horsepower='110.0', weight='2945.', acceleration='16.4', model='82', origin='US')
# Data(car='Oldsmobile Cutlass Ciera (diesel)', mpg='38.0', cylinders='6', displacement='262.0', horsepower='85.00', weight='3015.', acceleration='17.0', model='82', origin='US')
# Data(car='Chrysler Lebaron Medallion', mpg='26.0', cylinders='4', displacement='156.0', horsepower='92.00', weight='2585.', acceleration='14.5', model='82', origin='US')
# Data(car='Ford Grenada l', mpg='22.0', cylinders='6', displacement='232.0', horsepower='112.0', weight='2835', acceleration='14.7', model='82', origin='US')
# Data(car='Toyota Celica GT', mpg='32.0', cylinders='4', displacement='144.0', horsepower='96.00', weight='2665.', acceleration='13.9', model='82', origin='Japan')
# Data(car='Dodge Charger 2.2', mpg='36.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2370.', acceleration='13.0', model='82', origin='US')
# Data(car='Chevrolet Camaro', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2950.', acceleration='17.3', model='82', origin='US')
# Data(car='Ford Mustang GL', mpg='27.0', cylinders='4', displacement='140.0', horsepower='86.00', weight='2790.', acceleration='15.6', model='82', origin='US')
# Data(car='Volkswagen Pickup', mpg='44.0', cylinders='4', displacement='97.00', horsepower='52.00', weight='2130.', acceleration='24.6', model='82', origin='Europe')
# Data(car='Dodge Rampage', mpg='32.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2295.', acceleration='11.6', model='82', origin='US')
# Data(car='Ford Ranger', mpg='28.0', cylinders='4', displacement='120.0', horsepower='79.00', weight='2625.', acceleration='18.6', model='82', origin='US')
# Data(car='Chevy S-10', mpg='31.0', cylinders='4', displacement='119.0', horsepower='82.00', weight='2720.', acceleration='19.4', model='82', origin='US')

# %%
with parsed_data('personal_info.csv') as data:
    for row in data:
        print(row)
# Out:
# Data(ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# Data(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# Data(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# Data(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# Data(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# Data(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese')
# Data(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi')
# Data(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian')
# Data(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian')
# Data(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish')
# Data(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin')
# Data(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento')
# Data(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz')
# Data(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch')
# Data(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian')
# Data(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic')
# Data(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari')
# Data(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian')
# Data(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili')
# Data(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew')
# Data(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish')
# Data(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian')
# Data(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian')
# Data(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian')
# Data(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi')
# Data(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh')
# Data(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian')
# Data(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian')
# Data(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik')
# Data(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish')
# Data(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian')
# Data(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole')
# Data(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara')
# Data(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic')
# Data(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao')
# Data(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian')
# Data(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian')
# Data(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish')
# Data(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian')
# Data(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech')
# Data(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha')
# Data(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish')
# Data(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi')
# Data(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino')
# Data(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz')
# Data(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama')
# Data(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish')
# Data(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama')
# Data(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese')
# Data(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian')
# Data(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole')
# Data(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi')
# Data(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian')
# Data(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori')
# Data(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin')
# Data(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana')
# Data(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese')
# Data(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik')
# Data(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek')
# Data(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese')
# Data(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi')
# Data(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian')
# Data(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew')
# Data(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento')
# Data(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati')
# Data(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin')
# Data(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer')
# Data(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento')
# Data(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian')
# Data(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian')
# Data(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha')
# Data(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali')
# Data(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy')
# Data(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho')
# Data(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish')
# Data(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French')
# Data(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi')
# Data(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian')
# Data(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic')
# Data(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish')
# Data(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans')
# Data(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi')
# Data(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish')
# Data(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz')
# Data(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino')
# Data(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian')
# Data(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian')
# Data(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama')
# Data(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese')
# Data(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik')
# Data(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian')
# Data(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara')
# Data(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum')
# Data(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese')
# Data(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao')
# Data(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz')
# Data(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French')
# Data(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian')
# Data(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish')
# Data(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu')
# Data(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz')
# Data(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati')
# Data(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian')
# Data(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai')
# Data(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan')
# Data(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese')
# Data(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan')
# Data(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan')
# Data(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German')
# Data(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili')
# Data(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish')
# Data(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian')
# Data(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin')
# Data(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara')
# Data(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian')
# Data(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati')
# Data(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua')
# Data(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho')
# Data(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi')
# Data(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai')
# Data(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu')
# Data(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin')
# Data(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua')
# Data(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian')
# Data(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili')
# Data(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai')
# Data(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori')
# Data(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew')
# Data(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic')
# Data(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese')
# Data(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya')
# Data(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian')
# Data(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana')
# Data(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali')
# Data(ssn='200-81-7151', first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali')
# Data(ssn='201-53-1249', first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish')
# Data(ssn='202-84-1146', first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans')
# Data(ssn='203-35-7648', first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian')
# Data(ssn='205-69-7375', first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian')
# Data(ssn='205-87-2423', first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu')
# Data(ssn='206-28-6674', first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole')
# Data(ssn='206-83-8848', first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz')
# Data(ssn='208-74-2166', first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian')
# Data(ssn='208-80-5879', first_name='Rockie', last_name='Fryd', gender='Male', language='Korean')
# Data(ssn='209-50-8146', first_name='Kenna', last_name='Meryett', gender='Female', language='Czech')
# Data(ssn='209-58-4708', first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian')
# Data(ssn='210-91-4729', first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek')
# Data(ssn='211-04-1734', first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha')
# Data(ssn='211-13-5247', first_name='Wes', last_name='Weinberg', gender='Male', language='French')
# Data(ssn='211-15-5182', first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish')
# Data(ssn='211-19-6826', first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese')
# Data(ssn='212-40-0215', first_name='Giffie', last_name='Strauss', gender='Male', language='Azeri')
# Data(ssn='212-41-1496', first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil')
# Data(ssn='213-28-1395', first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali')
# Data(ssn='214-29-1189', first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole')
# Data(ssn='214-96-8581', first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian')
# Data(ssn='214-99-7584', first_name='Barny', last_name='Witherden', gender='Male', language='Czech')
# Data(ssn='216-89-3812', first_name='Florian', last_name='Jaze', gender='Male', language='Croatian')
# Data(ssn='216-97-3104', first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama')
# Data(ssn='217-71-3922', first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali')
# Data(ssn='217-81-5416', first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga')
# Data(ssn='218-14-4448', first_name='Keary', last_name='Druhan', gender='Male', language='Dutch')
# Data(ssn='218-25-9873', first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian')
# Data(ssn='218-31-1615', first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari')
# Data(ssn='218-49-7300', first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English')
# Data(ssn='220-16-0476', first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz')
# Data(ssn='220-38-0208', first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz')
# Data(ssn='222-39-8571', first_name='Fidelia', last_name='Domonkos', gender='Female', language='Fijian')
# Data(ssn='223-67-9203', first_name='Markus', last_name='Radband', gender='Male', language='Bosnian')
# Data(ssn='223-98-0846', first_name='Josy', last_name='Hadwick', gender='Female', language='Papiamento')
# Data(ssn='224-12-3436', first_name='Alister', last_name='Eakle', gender='Male', language='Estonian')
# Data(ssn='224-30-9267', first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish')
# Data(ssn='224-54-6919', first_name='Kelly', last_name='Shipman', gender='Male', language='Icelandic')
# Data(ssn='224-84-2271', first_name='Weider', last_name='Carlisle', gender='Male', language='Swedish')
# Data(ssn='224-99-0668', first_name='Brandy', last_name='Steed', gender='Male', language='Croatian')
# Data(ssn='225-08-5789', first_name='Tamra', last_name='Becken', gender='Female', language='Telugu')
# Data(ssn='225-64-2735', first_name='Graig', last_name='Rasher', gender='Male', language='Maltese')
# Data(ssn='226-76-4452', first_name='Van', last_name='Gervaise', gender='Male', language='Greek')
# Data(ssn='227-72-7247', first_name='Mauricio', last_name='Gush', gender='Male', language='Tajik')
# Data(ssn='228-16-7922', first_name='Tabby', last_name='Chitty', gender='Male', language='Spanish')
# Data(ssn='228-55-2042', first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech')
# Data(ssn='228-90-5077', first_name='Jonathon', last_name='Klugel', gender='Male', language='Hindi')
# Data(ssn='229-44-9909', first_name='Barnabas', last_name='Heppenspall', gender='Male', language='Icelandic')
# Data(ssn='230-09-1794', first_name='Xerxes', last_name='Mathivon', gender='Male', language='Danish')
# Data(ssn='230-48-0684', first_name='Clay', last_name='Peaurt', gender='Male', language='Dhivehi')
# Data(ssn='230-99-1485', first_name='Markus', last_name='Revill', gender='Male', language='Moldovan')
# Data(ssn='231-66-9264', first_name='Gisele', last_name='Castelow', gender='Female', language='Hiri Motu')
# Data(ssn='232-18-5397', first_name='Clare', last_name='McGairl', gender='Female', language='Bengali')
# Data(ssn='233-27-2377', first_name='Arlyne', last_name='Stenning', gender='Female', language='Dari')
# Data(ssn='235-10-3518', first_name='Winfield', last_name='Purvis', gender='Male', language='Estonian')
# Data(ssn='236-31-8333', first_name='Wendeline', last_name='Millins', gender='Female', language='Kashmiri')
# Data(ssn='236-37-2567', first_name='Ariel', last_name='Murrigan', gender='Female', language='West Frisian')
# Data(ssn='237-48-6737', first_name='Eal', last_name='Ducastel', gender='Male', language='Indonesian')
# Data(ssn='237-80-7039', first_name='Ardyce', last_name='Hunn', gender='Female', language='Maltese')
# Data(ssn='238-13-8034', first_name='Estrellita', last_name='Heavy', gender='Female', language='Azeri')
# Data(ssn='238-39-9999', first_name='Pauly', last_name='Griffin', gender='Female', language='Georgian')
# Data(ssn='239-09-9133', first_name='Tom', last_name='Roggeman', gender='Male', language='Sotho')
# Data(ssn='239-37-4122', first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana')
# Data(ssn='240-08-8805', first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish')
# Data(ssn='240-32-8915', first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento')
# Data(ssn='240-67-6258', first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi')
# Data(ssn='242-22-9624', first_name='Felice', last_name='Surr', gender='Male', language='Afrikaans')
# Data(ssn='243-37-9496', first_name='Verine', last_name='Etchells', gender='Female', language='Burmese')
# Data(ssn='243-44-4611', first_name='Shani', last_name="O'Tierney", gender='Female', language='Aymara')
# Data(ssn='244-34-2210', first_name='Lek', last_name='Heino', gender='Male', language='New Zealand Sign Language')
# Data(ssn='244-52-7593', first_name='Erda', last_name='Paulusch', gender='Female', language='Gujarati')
# Data(ssn='244-79-3004', first_name='Renault', last_name='Stollard', gender='Male', language='Amharic')
# Data(ssn='244-81-0671', first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan')
# Data(ssn='245-60-5880', first_name='Oby', last_name='Hauxby', gender='Male', language='French')
# Data(ssn='245-77-4110', first_name='Alasdair', last_name='McAndrew', gender='Male', language='Czech')
# Data(ssn='247-08-9326', first_name='Minni', last_name='Scurman', gender='Female', language='Kannada')
# Data(ssn='247-86-5288', first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian')
# Data(ssn='248-07-9757', first_name='Sean', last_name='Ham', gender='Male', language='Luxembourgish')
# Data(ssn='248-23-0150', first_name='Welbie', last_name='Gilley', gender='Male', language='Korean')
# Data(ssn='249-19-5514', first_name='Yehudi', last_name='Pharoah', gender='Male', language='Latvian')
# Data(ssn='253-61-8401', first_name='Genny', last_name='Juara', gender='Female', language='Tswana')
# Data(ssn='254-10-6071', first_name='Dwight', last_name='Eastcourt', gender='Male', language='Oriya')
# Data(ssn='254-92-9669', first_name='Tom', last_name='Larking', gender='Male', language='Icelandic')
# Data(ssn='255-81-0958', first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian')
# Data(ssn='256-54-7507', first_name='Angus', last_name='Cullip', gender='Male', language='Spanish')
# Data(ssn='256-57-0666', first_name='Rip', last_name='Grube', gender='Male', language='Ndebele')
# Data(ssn='257-12-6834', first_name='Derward', last_name='Paladini', gender='Male', language='Thai')
# Data(ssn='257-59-8603', first_name='Cyrillus', last_name='Sanchiz', gender='Male', language='Romanian')
# Data(ssn='257-77-3669', first_name='Ynez', last_name='Hain', gender='Female', language='Kazakh')
# Data(ssn='258-22-6416', first_name='Veriee', last_name='Klein', gender='Female', language='Northern Sotho')
# Data(ssn='259-38-5920', first_name='Jethro', last_name='Rustidge', gender='Male', language='Fijian')
# Data(ssn='261-14-9490', first_name='Lorry', last_name='Boshere', gender='Male', language='Oriya')
# Data(ssn='262-09-2144', first_name='Leigh', last_name='Paxforde', gender='Male', language='Portuguese')
# Data(ssn='262-46-7573', first_name='Lorene', last_name='Vagg', gender='Female', language='Punjabi')
# Data(ssn='262-55-4066', first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian')
# Data(ssn='262-66-7030', first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer')
# Data(ssn='264-39-3910', first_name='Elysia', last_name='Favell', gender='Female', language='Hindi')
# Data(ssn='266-86-9980', first_name='Rita', last_name='Leving', gender='Female', language='Latvian')
# Data(ssn='267-75-6383', first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian')
# Data(ssn='269-01-2640', first_name='Russell', last_name='Dabner', gender='Male', language='Danish')
# Data(ssn='271-04-0134', first_name='Eadith', last_name='Jerg', gender='Female', language='Gagauz')
# Data(ssn='271-81-9938', first_name='James', last_name='Robbins', gender='Male', language='Bengali')
# Data(ssn='271-93-3051', first_name='Augustin', last_name='Agiolfinger', gender='Male', language='Latvian')
# Data(ssn='272-50-7309', first_name='Sig', last_name='Ather', gender='Male', language='Catalan')
# Data(ssn='272-81-7979', first_name='Sherlocke', last_name='Giddings', gender='Male', language='Georgian')
# Data(ssn='273-49-8218', first_name='Haze', last_name='Starkings', gender='Male', language='Portuguese')
# Data(ssn='274-50-3806', first_name='Shurlocke', last_name='Aron', gender='Male', language='Punjabi')
# Data(ssn='274-76-9883', first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali')
# Data(ssn='276-05-2973', first_name='Cly', last_name='Yerlett', gender='Male', language='Kazakh')
# Data(ssn='278-55-5842', first_name='Korie', last_name='Di Pietro', gender='Female', language='German')
# Data(ssn='278-64-4853', first_name='Diane-marie', last_name='Broggini', gender='Female', language='Tsonga')
# Data(ssn='279-12-7167', first_name='Elbertina', last_name='Alders', gender='Female', language='Amharic')
# Data(ssn='279-40-5540', first_name='Montague', last_name='Knowler', gender='Male', language='Chinese')
# Data(ssn='279-49-5682', first_name='Kleon', last_name='Tembridge', gender='Male', language='Gagauz')
# Data(ssn='280-53-7447', first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian')
# Data(ssn='280-98-4410', first_name='Ealasaid', last_name='Devon', gender='Female', language='Tok Pisin')
# Data(ssn='281-23-3458', first_name='Bettina', last_name='Danilov', gender='Female', language='Sotho')
# Data(ssn='282-83-9206', first_name='Jackie', last_name='McPhater', gender='Male', language='Gagauz')
# Data(ssn='283-04-6835', first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha')
# Data(ssn='286-26-4004', first_name='Augustus', last_name='Doodson', gender='Male', language='Romanian')
# Data(ssn='287-57-9688', first_name='Joachim', last_name='Moncreiff', gender='Male', language='Catalan')
# Data(ssn='287-66-2660', first_name='Larissa', last_name='Airy', gender='Female', language='Bislama')
# Data(ssn='288-54-7233', first_name='Hedy', last_name='Eaklee', gender='Female', language='English')
# Data(ssn='288-87-6462', first_name='Stanislaus', last_name='Haylor', gender='Male', language='Kannada')
# Data(ssn='289-03-9882', first_name='Giusto', last_name='Baszniak', gender='Male', language='Yiddish')
# Data(ssn='289-09-8686', first_name='Heath', last_name='Stallan', gender='Male', language='Malayalam')
# Data(ssn='290-25-7300', first_name='Bowie', last_name='Bancroft', gender='Male', language='Thai')
# Data(ssn='290-82-4968', first_name='Ingram', last_name='Kincade', gender='Male', language='Moldovan')
# Data(ssn='293-54-3694', first_name='Theodora', last_name='Geddes', gender='Female', language='Maori')
# Data(ssn='294-27-9936', first_name='Cari', last_name='Bradane', gender='Female', language='Japanese')
# Data(ssn='294-53-1911', first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian')
# Data(ssn='295-63-7693', first_name='Fonzie', last_name='Fattorini', gender='Male', language='Estonian')
# Data(ssn='296-32-7910', first_name='Harlene', last_name='Morrill', gender='Female', language='Swati')
# Data(ssn='296-88-0097', first_name='Herculie', last_name='Branthwaite', gender='Male', language='Hungarian')
# Data(ssn='296-90-4908', first_name='Holt', last_name='Angel', gender='Male', language='Tamil')
# Data(ssn='297-63-1154', first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin')
# Data(ssn='298-06-3497', first_name='Moshe', last_name='Thomassin', gender='Male', language='Polish')
# Data(ssn='298-69-9168', first_name='Shea', last_name='Canon', gender='Male', language='Finnish')
# Data(ssn='298-70-6018', first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans')
# Data(ssn='298-79-7640', first_name='Mycah', last_name='Hillam', gender='Male', language='Swahili')
# Data(ssn='299-03-6911', first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz')
# Data(ssn='299-38-0483', first_name='Robb', last_name='Posner', gender='Male', language='Italian')
# Data(ssn='299-77-1060', first_name='Bellina', last_name='Galbreth', gender='Female', language='Norwegian')
# Data(ssn='300-59-3610', first_name='Tam', last_name='Howles', gender='Male', language='Pashto')
# Data(ssn='300-76-8770', first_name='Danielle', last_name='Rowth', gender='Female', language='Italian')
# Data(ssn='300-80-7209', first_name='Gabbie', last_name='Burney', gender='Female', language='Dutch')
# Data(ssn='301-26-4306', first_name='Emmye', last_name='Whelpdale', gender='Female', language='Tajik')
# Data(ssn='301-51-0522', first_name='Kenneth', last_name='Methley', gender='Male', language='Papiamento')
# Data(ssn='302-64-4858', first_name='Hakeem', last_name='Zelley', gender='Male', language='Afrikaans')
# Data(ssn='304-48-4312', first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin')
# Data(ssn='305-07-1498', first_name='Ruddy', last_name="O'Crotty", gender='Male', language='Spanish')
# Data(ssn='306-23-2423', first_name='Ree', last_name='Meader', gender='Female', language='Polish')
# Data(ssn='306-86-2930', first_name='Kassie', last_name='Neaverson', gender='Female', language='Luxembourgish')
# Data(ssn='308-58-0964', first_name='Talbert', last_name='Osipov', gender='Male', language='Tetum')
# Data(ssn='309-04-0364', first_name='Dov', last_name='Speight', gender='Male', language='Tajik')
# Data(ssn='309-38-8085', first_name='Nell', last_name='Scrigmour', gender='Female', language='Persian')
# Data(ssn='310-60-2027', first_name='Zacherie', last_name='Parken', gender='Male', language='Albanian')
# Data(ssn='311-46-9296', first_name='Alic', last_name='Pabel', gender='Male', language='Fijian')
# Data(ssn='312-38-7084', first_name='Ezri', last_name='Paolicchi', gender='Male', language='Malagasy')
# Data(ssn='312-59-3476', first_name='Sadye', last_name='Beloe', gender='Female', language='Icelandic')
# Data(ssn='312-77-3647', first_name='Hussein', last_name='Blything', gender='Male', language='Hebrew')
# Data(ssn='313-02-7822', first_name='Spence', last_name='Climer', gender='Male', language='Maori')
# Data(ssn='313-52-7312', first_name='Farrand', last_name='MacKenzie', gender='Female', language='French')
# Data(ssn='315-12-5664', first_name='Vere', last_name='Morlon', gender='Female', language='German')
# Data(ssn='315-26-2241', first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian')
# Data(ssn='315-44-9671', first_name='Ximenez', last_name='Maghull', gender='Male', language='Macedonian')
# Data(ssn='315-78-5587', first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin')
# Data(ssn='317-28-1600', first_name='Rodrick', last_name='Abrahams', gender='Male', language='Assamese')
# Data(ssn='317-43-2055', first_name='Jocelyn', last_name='Gildroy', gender='Female', language='Punjabi')
# Data(ssn='318-58-5314', first_name='Stephan', last_name='Peatt', gender='Male', language='New Zealand Sign Language')
# Data(ssn='319-43-0465', first_name='Boothe', last_name='Vanin', gender='Male', language='West Frisian')
# Data(ssn='320-90-1419', first_name='Em', last_name='Darwood', gender='Male', language='Icelandic')
# Data(ssn='320-97-9147', first_name='Roch', last_name='Wahlberg', gender='Female', language='Thai')
# Data(ssn='323-28-6705', first_name='Christiano', last_name='Stoffler', gender='Male', language='Kyrgyz')
# Data(ssn='323-33-8689', first_name='Dulcinea', last_name='Lundberg', gender='Female', language='Dutch')
# Data(ssn='324-39-5230', first_name='Alexandrina', last_name='Dahlbom', gender='Female', language='Moldovan')
# Data(ssn='324-73-8895', first_name='Walliw', last_name='Alstead', gender='Female', language='Guarana')
# Data(ssn='324-75-6098', first_name='Rafael', last_name='Robinett', gender='Male', language='Portuguese')
# Data(ssn='326-64-9957', first_name='Jorgan', last_name='Renowden', gender='Male', language='Swati')
# Data(ssn='327-52-0546', first_name='Carlota', last_name='Hovey', gender='Female', language='English')
# Data(ssn='327-88-7554', first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili')
# Data(ssn='330-99-3055', first_name='Marinna', last_name='Dally', gender='Female', language='Azeri')
# Data(ssn='332-83-6591', first_name='Forrester', last_name='Cullabine', gender='Male', language='Dzongkha')
# Data(ssn='333-52-5097', first_name='Florentia', last_name='Espinazo', gender='Female', language='Tetum')
# Data(ssn='333-95-5025', first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu')
# Data(ssn='335-35-1520', first_name='Ervin', last_name='Hugues', gender='Male', language='Armenian')
# Data(ssn='336-48-2579', first_name='Renee', last_name='Crank', gender='Female', language='Armenian')
# Data(ssn='339-27-8046', first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian')
# Data(ssn='339-71-2687', first_name='Marlie', last_name='Corpe', gender='Female', language='Persian')
# Data(ssn='341-10-6840', first_name='Cyrille', last_name='Critchlow', gender='Male', language='Portuguese')
# Data(ssn='342-05-9057', first_name='Beatrix', last_name='Relton', gender='Female', language='Latvian')
# Data(ssn='342-55-0538', first_name='Hilliary', last_name='Suddards', gender='Female', language='Dzongkha')
# Data(ssn='342-90-9333', first_name='Geri', last_name='Yesinov', gender='Male', language='Norwegian')
# Data(ssn='343-20-8407', first_name='Bradford', last_name='Niemiec', gender='Male', language='Chinese')
# Data(ssn='343-81-3179', first_name='Reinhard', last_name='Bortolutti', gender='Male', language='Kannada')
# Data(ssn='345-74-2160', first_name='Camile', last_name='Pengelly', gender='Female', language='Lao')
# Data(ssn='347-09-3254', first_name='Dulciana', last_name='Hexum', gender='Female', language='Lao')
# Data(ssn='347-64-8652', first_name='Dusty', last_name='Morat', gender='Female', language='Japanese')
# Data(ssn='348-73-4312', first_name='Elberta', last_name='Howden', gender='Female', language='Khmer')
# Data(ssn='348-74-3224', first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian')
# Data(ssn='349-53-8864', first_name='Muffin', last_name='Lord', gender='Female', language='Georgian')
# Data(ssn='349-67-7502', first_name='Ari', last_name='Yitzhakov', gender='Male', language='Zulu')
# Data(ssn='350-20-9593', first_name='Eldridge', last_name='Crispin', gender='Male', language='Dutch')
# Data(ssn='350-80-4646', first_name='Harp', last_name='Du Plantier', gender='Male', language='Dutch')
# Data(ssn='351-73-2802', first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian')
# Data(ssn='355-21-9711', first_name='Daryn', last_name='Battin', gender='Female', language='Georgian')
# Data(ssn='355-52-9767', first_name='Kacy', last_name='Offen', gender='Female', language='Kurdish')
# Data(ssn='355-96-7706', first_name='Lauritz', last_name='Lucock', gender='Male', language='Mongolian')
# Data(ssn='356-39-9199', first_name='Arney', last_name='Polglaze', gender='Male', language='Marathi')
# Data(ssn='357-37-6094', first_name='Chrisse', last_name='Kirton', gender='Male', language='Latvian')
# Data(ssn='358-84-7049', first_name='Emalee', last_name='McCleary', gender='Female', language='Thai')
# Data(ssn='360-69-6230', first_name='Grannie', last_name='Champ', gender='Male', language='Belarusian')
# Data(ssn='361-06-1530', first_name='Luis', last_name='Ashborne', gender='Male', language='Mongolian')
# Data(ssn='361-42-7068', first_name='Ashia', last_name='Ferran', gender='Female', language='West Frisian')
# Data(ssn='361-49-4597', first_name='Adan', last_name='Janssen', gender='Male', language='Swedish')
# Data(ssn='361-83-5004', first_name='Wilona', last_name='Sink', gender='Female', language='Sotho')
# Data(ssn='362-09-8563', first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic')
# Data(ssn='362-12-7902', first_name='Weber', last_name='Legrand', gender='Male', language='Swahili')
# Data(ssn='364-25-0166', first_name='Arnuad', last_name='Planque', gender='Male', language='Hindi')
# Data(ssn='364-65-2174', first_name='Bernarr', last_name='Wollard', gender='Male', language='Irish Gaelic')
# Data(ssn='366-61-0607', first_name='Bethena', last_name='Joicey', gender='Female', language='Haitian Creole')
# Data(ssn='367-22-8998', first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz')
# Data(ssn='367-62-4426', first_name='Sigismondo', last_name='Lerohan', gender='Male', language='Georgian')
# Data(ssn='370-01-6977', first_name='Hugues', last_name='Jeffryes', gender='Male', language='Georgian')
# Data(ssn='370-24-5876', first_name='Sergei', last_name='Risby', gender='Male', language='Bulgarian')
# Data(ssn='370-72-6509', first_name='Wrennie', last_name='McCrorie', gender='Female', language='Papiamento')
# Data(ssn='371-28-5892', first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga')
# Data(ssn='371-44-0582', first_name='Clemmy', last_name='Cogzell', gender='Male', language='Estonian')
# Data(ssn='371-62-3727', first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch')
# Data(ssn='371-88-9249', first_name='Nealon', last_name='Oxtaby', gender='Male', language='German')
# Data(ssn='372-44-7487', first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan')
# Data(ssn='372-62-7057', first_name='Eleanora', last_name='Vazquez', gender='Female', language='Gujarati')
# Data(ssn='373-67-2734', first_name='Ileana', last_name='Luty', gender='Female', language='Italian')
# Data(ssn='374-47-0262', first_name='Bank', last_name='Evitts', gender='Male', language='Aymara')
# Data(ssn='378-08-0805', first_name='Carroll', last_name='Harty', gender='Female', language='Swedish')
# Data(ssn='378-60-2472', first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian')
# Data(ssn='378-66-0449', first_name='Kelby', last_name='Wincer', gender='Male', language='Pashto')
# Data(ssn='378-79-0193', first_name='Kenny', last_name='Josefsen', gender='Male', language='Danish')
# Data(ssn='378-88-6805', first_name='Vittoria', last_name='Oldroyd', gender='Female', language='Moldovan')
# Data(ssn='379-07-8748', first_name='Dyanna', last_name='Noto', gender='Female', language='Polish')
# Data(ssn='380-33-9730', first_name='Katinka', last_name='Piet', gender='Female', language='Malay')
# Data(ssn='380-35-3854', first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama')
# Data(ssn='383-18-4058', first_name='Frederigo', last_name='Cooksey', gender='Male', language='Indonesian')
# Data(ssn='384-30-6793', first_name='Kipp', last_name='Burnyate', gender='Male', language='English')
# Data(ssn='384-94-2772', first_name='Ramsay', last_name='Dolbey', gender='Male', language='Tok Pisin')
# Data(ssn='385-30-1777', first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana')
# Data(ssn='385-34-7828', first_name='Dori', last_name='Quogan', gender='Female', language='Afrikaans')
# Data(ssn='385-98-0431', first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana')
# Data(ssn='386-15-7960', first_name='Steffie', last_name='Tedahl', gender='Female', language='Punjabi')
# Data(ssn='386-34-4088', first_name='Adamo', last_name='Wogden', gender='Male', language='Arabic')
# Data(ssn='386-68-9884', first_name='Francis', last_name='Foch', gender='Male', language='Dzongkha')
# Data(ssn='386-97-3523', first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish')
# Data(ssn='389-31-0910', first_name='Mac', last_name='Westrey', gender='Male', language='Armenian')
# Data(ssn='389-51-1424', first_name='Isadore', last_name='Orbine', gender='Male', language='Pashto')
# Data(ssn='389-84-8254', first_name='Chiquita', last_name='Jolliman', gender='Female', language='Marathi')
# Data(ssn='390-74-3062', first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian')
# Data(ssn='391-14-9280', first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin')
# Data(ssn='391-47-4578', first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese')
# Data(ssn='391-73-2830', first_name='Padget', last_name='Manthorpe', gender='Male', language='Marathi')
# Data(ssn='393-22-6585', first_name='Reinold', last_name='Ellif', gender='Male', language='Nepali')
# Data(ssn='396-51-1559', first_name='Natasha', last_name='Dafter', gender='Female', language='Maori')
# Data(ssn='397-16-5372', first_name='Alonzo', last_name='Mc Mechan', gender='Male', language='Polish')
# Data(ssn='397-29-8349', first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin')
# Data(ssn='397-87-8282', first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian')
# Data(ssn='399-31-2815', first_name='Durward', last_name='Giamitti', gender='Male', language='Tok Pisin')
# Data(ssn='399-63-8810', first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento')
# Data(ssn='399-81-6133', first_name='Viv', last_name='Borsay', gender='Female', language='Chinese')
# Data(ssn='400-21-8654', first_name='Travus', last_name='Miranda', gender='Male', language='Kannada')
# Data(ssn='400-77-6007', first_name='Dannie', last_name='Shurmer', gender='Male', language='Tajik')
# Data(ssn='402-61-3479', first_name='Mariele', last_name='Meyrick', gender='Female', language='Telugu')
# Data(ssn='402-65-2055', first_name='Martie', last_name='Crawshaw', gender='Male', language='Marathi')
# Data(ssn='402-88-5570', first_name='Torry', last_name='Bossons', gender='Male', language='Chinese')
# Data(ssn='403-65-1535', first_name='Cathy', last_name='Gabe', gender='Female', language='Hiri Motu')
# Data(ssn='404-57-4023', first_name='Pattin', last_name='Jarmain', gender='Male', language='Hindi')
# Data(ssn='405-25-1422', first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati')
# Data(ssn='406-15-5123', first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari')
# Data(ssn='406-24-4867', first_name='Renaud', last_name='Fleetwood', gender='Male', language='Papiamento')
# Data(ssn='406-49-0634', first_name='Lolita', last_name='Dailey', gender='Female', language='Czech')
# Data(ssn='407-30-0910', first_name='Gerhard', last_name='Crielly', gender='Male', language='Bislama')
# Data(ssn='407-80-7367', first_name='Sigismundo', last_name='Pothbury', gender='Male', language='Latvian')
# Data(ssn='407-99-6159', first_name='Flynn', last_name='Jirasek', gender='Male', language='Afrikaans')
# Data(ssn='408-83-7943', first_name='Wallie', last_name='Klosterman', gender='Male', language='Hungarian')
# Data(ssn='408-98-3291', first_name='Karia', last_name='Riquet', gender='Female', language='Italian')
# Data(ssn='409-58-2034', first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili')
# Data(ssn='409-90-8946', first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian')
# Data(ssn='410-38-4237', first_name='Gibbie', last_name='Seamer', gender='Male', language='Tok Pisin')
# Data(ssn='410-76-5092', first_name='Spencer', last_name='Dallon', gender='Male', language='Swati')
# Data(ssn='411-21-4276', first_name='Mari', last_name='Livick', gender='Female', language='Pashto')
# Data(ssn='411-43-4217', first_name='Cull', last_name='Noddle', gender='Male', language='Spanish')
# Data(ssn='411-79-4655', first_name='Caterina', last_name='Coey', gender='Female', language='French')
# Data(ssn='412-50-9133', first_name='Dianemarie', last_name='Withey', gender='Female', language='Czech')
# Data(ssn='412-59-0452', first_name='Seamus', last_name='Petrusch', gender='Male', language='Spanish')
# Data(ssn='412-59-8022', first_name='Brenna', last_name='Follin', gender='Female', language='Gagauz')
# Data(ssn='412-79-8951', first_name='Giorgi', last_name='Sisnett', gender='Male', language='Tamil')
# Data(ssn='413-14-3928', first_name='Shaine', last_name='Liebrecht', gender='Male', language='Sotho')
# Data(ssn='413-56-5613', first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali')
# Data(ssn='415-42-0898', first_name='Karlik', last_name='Adlam', gender='Male', language='Mongolian')
# Data(ssn='415-74-2251', first_name='Pattin', last_name='Greson', gender='Male', language='Italian')
# Data(ssn='416-37-7763', first_name='Emelia', last_name='Hancell', gender='Female', language='German')
# Data(ssn='416-38-3607', first_name='Jerry', last_name='Christin', gender='Male', language='Hebrew')
# Data(ssn='416-80-6367', first_name='Myrna', last_name='Christoffe', gender='Female', language='Tok Pisin')
# Data(ssn='416-87-0469', first_name='Dannel', last_name='Whyffen', gender='Male', language='Estonian')
# Data(ssn='418-72-1888', first_name='Roddy', last_name='Worman', gender='Male', language='Bosnian')
# Data(ssn='418-99-6659', first_name='Grenville', last_name='Gulliver', gender='Male', language='Ndebele')
# Data(ssn='420-46-7789', first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language')
# Data(ssn='420-52-3813', first_name='Arnaldo', last_name='Balsdone', gender='Male', language='Zulu')
# Data(ssn='421-01-2511', first_name='Mikaela', last_name='Andrivot', gender='Female', language='English')
# Data(ssn='421-13-9794', first_name='Minne', last_name='Measey', gender='Female', language='Danish')
# Data(ssn='421-20-3448', first_name='Alie', last_name='Gerauld', gender='Female', language='Khmer')
# Data(ssn='421-88-7316', first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch')
# Data(ssn='422-67-4000', first_name='Corby', last_name='Boyington', gender='Male', language='Sotho')
# Data(ssn='423-62-1820', first_name='Ruddy', last_name='Ingerson', gender='Male', language='Maori')
# Data(ssn='423-88-4721', first_name='Trip', last_name='Postlewhite', gender='Male', language='Polish')
# Data(ssn='424-22-9138', first_name='Farand', last_name='Huggon', gender='Female', language='Indonesian')
# Data(ssn='424-91-0692', first_name='Jeanie', last_name='Titchard', gender='Female', language='Swati')
# Data(ssn='424-92-0863', first_name='Halley', last_name='Mendenhall', gender='Female', language='Thai')
# Data(ssn='426-09-8331', first_name='Enrico', last_name='Balentyne', gender='Male', language='Arabic')
# Data(ssn='426-33-4523', first_name='Bibbie', last_name='Lardge', gender='Female', language='Spanish')
# Data(ssn='426-52-3410', first_name='Deeyn', last_name='Feldberg', gender='Female', language='Lithuanian')
# Data(ssn='426-61-5374', first_name='Adolph', last_name='Effemy', gender='Male', language='Norwegian')
# Data(ssn='427-12-4625', first_name='Ethelin', last_name='Huck', gender='Female', language='Bosnian')
# Data(ssn='427-36-0095', first_name='Shandee', last_name='Hawthorne', gender='Female', language='Gujarati')
# Data(ssn='427-96-6355', first_name='Fidel', last_name='Gutierrez', gender='Male', language='Yiddish')
# Data(ssn='428-19-2946', first_name='Dionne', last_name='Bibb', gender='Female', language='Moldovan')
# Data(ssn='428-79-0781', first_name='Mame', last_name='Criag', gender='Female', language='Catalan')
# Data(ssn='429-43-7811', first_name='Felice', last_name='Mound', gender='Male', language='Ndebele')
# Data(ssn='430-27-6236', first_name='Sergent', last_name='Tomich', gender='Male', language='Tajik')
# Data(ssn='430-27-8349', first_name='Boigie', last_name='Balsdon', gender='Male', language='German')
# Data(ssn='432-25-8923', first_name='Violetta', last_name='Remmer', gender='Female', language='Swati')
# Data(ssn='433-08-7855', first_name='Cleo', last_name='Sivior', gender='Female', language='Latvian')
# Data(ssn='434-41-2365', first_name='Obed', last_name='Podmore', gender='Male', language='Georgian')
# Data(ssn='435-34-0115', first_name='Chicky', last_name='Carlos', gender='Male', language='Tamil')
# Data(ssn='438-80-0430', first_name='Gunilla', last_name='Navan', gender='Female', language='Moldovan')
# Data(ssn='438-82-1280', first_name='Salvatore', last_name='Noirel', gender='Male', language='Somali')
# ...
# Data(ssn='770-61-8252', first_name='Elbertina', last_name='Colls', gender='Female', language='Chinese')
# Data(ssn='771-20-6900', first_name='Alejandra', last_name='Tevlin', gender='Female', language='Greek')
# Data(ssn='771-71-0505', first_name='Romona', last_name='Meikle', gender='Female', language='New Zealand Sign Language')
# Data(ssn='773-21-9639', first_name='Brittney', last_name='Byart', gender='Female', language='Tok Pisin')
# Data(ssn='773-53-7438', first_name='Flo', last_name='Sirmond', gender='Female', language='Khmer')
# Data(ssn='773-82-1734', first_name='Maris', last_name='Currin', gender='Female', language='Armenian')
# Data(ssn='774-08-5376', first_name='Pam', last_name='Matterface', gender='Female', language='Swahili')
# Data(ssn='775-09-9949', first_name='Orlando', last_name='Gresley', gender='Male', language='Danish')
# Data(ssn='777-05-1491', first_name='Devora', last_name='Ashbridge', gender='Female', language='Somali')
# Data(ssn='777-68-2978', first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho')
# Data(ssn='777-94-4586', first_name='Siward', last_name='Blues', gender='Male', language='Thai')
# Data(ssn='778-74-8262', first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian')
# Data(ssn='779-59-1449', first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian')
# Data(ssn='780-69-8282', first_name='Sibeal', last_name='Dawney', gender='Female', language='Czech')
# Data(ssn='781-88-2076', first_name='Gelya', last_name='Stell', gender='Female', language='Czech')
# Data(ssn='782-46-9660', first_name='Malina', last_name='Julyan', gender='Female', language='Burmese')
# Data(ssn='782-60-6848', first_name='Jehu', last_name='Scholig', gender='Male', language='Polish')
# Data(ssn='783-22-9258', first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese')
# Data(ssn='784-88-0730', first_name='Baxie', last_name='Judd', gender='Male', language='Maltese')
# Data(ssn='785-14-5978', first_name='Trista', last_name='Watkinson', gender='Female', language='Moldovan')
# Data(ssn='786-56-3561', first_name='Wait', last_name='Boyda', gender='Male', language='Norwegian')
# Data(ssn='786-63-6223', first_name='Adham', last_name='Toope', gender='Male', language='Belarusian')
# Data(ssn='787-05-9008', first_name='Ricki', last_name='Jurges', gender='Female', language='Arabic')
# Data(ssn='787-09-5697', first_name='Chelsea', last_name='Pashby', gender='Female', language='Northern Sotho')
# Data(ssn='787-10-7877', first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu')
# Data(ssn='788-15-2625', first_name='Drusilla', last_name='Bannester', gender='Female', language='Gujarati')
# Data(ssn='789-70-1821', first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri')
# Data(ssn='790-04-1283', first_name='Christyna', last_name='Morrissey', gender='Female', language='Quechua')
# Data(ssn='792-71-8046', first_name='Carly', last_name='Hazley', gender='Female', language='Guarana')
# Data(ssn='794-24-3802', first_name='Esther', last_name='Sayton', gender='Female', language='Somali')
# Data(ssn='795-56-6486', first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz')
# Data(ssn='795-77-5263', first_name='Burty', last_name='Frosdick', gender='Male', language='Marathi')
# Data(ssn='797-05-2289', first_name='Fanchon', last_name='Petrushanko', gender='Female', language='Finnish')
# Data(ssn='797-25-9814', first_name='Aleksandr', last_name='Swalwell', gender='Male', language='Pashto')
# Data(ssn='797-65-2382', first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish')
# Data(ssn='797-87-7992', first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian')
# Data(ssn='798-34-1082', first_name='Henka', last_name='Synder', gender='Female', language='Italian')
# Data(ssn='798-65-5644', first_name='Irita', last_name='Heady', gender='Female', language='Montenegrin')
# Data(ssn='800-06-9721', first_name='Carter', last_name='Waldron', gender='Male', language='Estonian')
# Data(ssn='801-08-8313', first_name='Aida', last_name='Whitemarsh', gender='Female', language='Chinese')
# Data(ssn='801-92-6460', first_name='Levi', last_name='Downgate', gender='Male', language='Belarusian')
# Data(ssn='801-99-2773', first_name='Justinian', last_name='Carlesso', gender='Male', language='Japanese')
# Data(ssn='804-46-0617', first_name='Geneva', last_name='Crinion', gender='Female', language='Hungarian')
# Data(ssn='807-13-5922', first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho')
# Data(ssn='807-24-6202', first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu')
# Data(ssn='807-25-6136', first_name='Sammy', last_name='Linnard', gender='Female', language='Dutch')
# Data(ssn='807-35-8936', first_name='Georgi', last_name='Widd', gender='Male', language='Afrikaans')
# Data(ssn='807-50-8539', first_name='Jaquith', last_name='Erdes', gender='Female', language='Dhivehi')
# Data(ssn='807-60-5615', first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi')
# Data(ssn='808-55-8658', first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese')
# Data(ssn='808-80-2542', first_name='Gustaf', last_name='Hullot', gender='Male', language='Persian')
# Data(ssn='811-65-2750', first_name='Minetta', last_name='Dusting', gender='Female', language='Spanish')
# Data(ssn='812-11-9403', first_name='Carmina', last_name='Turnell', gender='Female', language='West Frisian')
# Data(ssn='813-42-4142', first_name='Killy', last_name='Threadgould', gender='Male', language='Polish')
# Data(ssn='813-47-5215', first_name='Willi', last_name='Collet', gender='Male', language='Gujarati')
# Data(ssn='815-83-0300', first_name='Romeo', last_name='Rayworth', gender='Male', language='Thai')
# Data(ssn='816-31-3858', first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin')
# Data(ssn='816-47-4782', first_name='Wilmer', last_name='Maides', gender='Male', language='Aymara')
# Data(ssn='816-90-2049', first_name='Berry', last_name='Delagnes', gender='Female', language='Bengali')
# Data(ssn='817-04-1950', first_name='Fletcher', last_name='McGrouther', gender='Male', language='Albanian')
# Data(ssn='817-25-7437', first_name='Randall', last_name='Fibbitts', gender='Male', language='Yiddish')
# Data(ssn='817-80-8930', first_name='Lib', last_name='Skein', gender='Female', language='Arabic')
# Data(ssn='818-61-0770', first_name='Stanly', last_name='Casseldine', gender='Male', language='Belarusian')
# Data(ssn='819-52-5886', first_name='Paulette', last_name='McAree', gender='Female', language='Arabic')
# Data(ssn='819-64-1414', first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino')
# Data(ssn='820-96-1105', first_name='Andy', last_name='Sayce', gender='Female', language='Pashto')
# Data(ssn='822-05-9037', first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan')
# Data(ssn='822-30-4861', first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian')
# Data(ssn='823-27-0762', first_name='Marten', last_name='McCord', gender='Male', language='Indonesian')
# Data(ssn='823-75-5753', first_name='Thibaut', last_name='Van Schafflaer', gender='Male', language='Chinese')
# Data(ssn='824-89-4169', first_name='Tamqrah', last_name='Goroni', gender='Female', language='Swedish')
# Data(ssn='826-97-8029', first_name='Llewellyn', last_name='Shimwell', gender='Male', language='Belarusian')
# Data(ssn='827-62-4599', first_name='Phyllys', last_name='Akast', gender='Female', language='Armenian')
# Data(ssn='830-23-1573', first_name='Carine', last_name='Abramin', gender='Female', language='Bislama')
# Data(ssn='831-44-3286', first_name='Leesa', last_name='Finci', gender='Female', language='Nepali')
# Data(ssn='833-01-1428', first_name='Ashlan', last_name='Zannotti', gender='Female', language='Finnish')
# Data(ssn='835-54-3785', first_name='Nathaniel', last_name='Wegman', gender='Male', language='Azeri')
# Data(ssn='836-40-1837', first_name='Brocky', last_name='Kewzick', gender='Male', language='Armenian')
# Data(ssn='836-99-3309', first_name='Cobby', last_name='Mutter', gender='Male', language='Georgian')
# Data(ssn='837-76-5619', first_name='Alleyn', last_name='Parade', gender='Male', language='Croatian')
# Data(ssn='838-69-1351', first_name='Alwin', last_name='Hazzard', gender='Male', language='Kannada')
# Data(ssn='840-41-7929', first_name='Sherlock', last_name='Pinshon', gender='Male', language='Khmer')
# Data(ssn='841-64-8517', first_name='Hugues', last_name='Kenealy', gender='Male', language='Korean')
# Data(ssn='842-90-7557', first_name='Brit', last_name='Weall', gender='Female', language='West Frisian')
# Data(ssn='844-15-4668', first_name='Eleonora', last_name='Delete', gender='Female', language='Hiri Motu')
# Data(ssn='844-50-7305', first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian')
# Data(ssn='846-07-1407', first_name='Tobias', last_name='Blakelock', gender='Male', language='German')
# Data(ssn='846-09-9851', first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language')
# Data(ssn='846-59-9961', first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian')
# Data(ssn='847-34-4817', first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish')
# Data(ssn='847-61-7656', first_name='Brit', last_name='Lodovichi', gender='Male', language='Bislama')
# Data(ssn='848-58-3386', first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese')
# Data(ssn='848-74-2886', first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama')
# Data(ssn='848-76-8808', first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali')
# Data(ssn='849-31-1551', first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German')
# Data(ssn='849-64-6624', first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian')
# Data(ssn='849-98-2973', first_name='Hurley', last_name='Newart', gender='Male', language='Hindi')
# Data(ssn='851-94-2162', first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan')
# Data(ssn='852-15-7707', first_name='Mario', last_name='Lelande', gender='Male', language='Nepali')
# Data(ssn='853-11-8953', first_name='Brice', last_name='Kyd', gender='Male', language='Dari')
# Data(ssn='853-47-3648', first_name='Olag', last_name='Belhome', gender='Male', language='Maltese')
# Data(ssn='854-68-7635', first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan')
# Data(ssn='854-71-2983', first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch')
# Data(ssn='854-79-5334', first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili')
# Data(ssn='856-18-3980', first_name='Neale', last_name='Sesser', gender='Male', language='Maltese')
# Data(ssn='856-27-9112', first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto')
# Data(ssn='856-67-4080', first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi')
# Data(ssn='857-37-5902', first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi')
# Data(ssn='858-03-7735', first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh')
# Data(ssn='858-27-9190', first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian')
# Data(ssn='860-67-0256', first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik')
# Data(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish')
# Data(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian')
# Data(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish')
# Data(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian')
# Data(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama')
# Data(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento')
# Data(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian')
# Data(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam')
# Data(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian')
# Data(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha')
# Data(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian')
# Data(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana')
# Data(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew')
# Data(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic')
# Data(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese')
# Data(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish')
# Data(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan')
# Data(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu')
# Data(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish')
# Data(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi')
# Data(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri')
# Data(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho')
# Data(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga')
# Data(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian')
# Data(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian')
# Data(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian')
# Data(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil')
# Data(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin')
# Data(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha')
# Data(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian')
# Data(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic')
# Data(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua')
# Data(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya')
# Data(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz')
# Data(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana')
# Data(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic')
# Data(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho')
# Data(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali')
# Data(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic')
# Data(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz')
# Data(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino')
# Data(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek')
# Data(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian')
# Data(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum')
